# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14386015672535276605
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3150260322618822378
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 16:54:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    33W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'ResNet50'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 5
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4"
T_all_labels = "T0", "T1", "T2", "T3", "T4"

#base_path = ''
base_path = 'gdrive/My Drive/Research_5_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_ResNet50_None S_ResNet50_imagenet T_ResNet50_None T_ResNet50_imagenet
# ['S_ResNet50_imagenet',
#  'S_ResNet50_None',
#  'T_ResNet50_imagenet',
#  'T_ResNet50_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2034, 128, 128, 3) (2034, 1)
# (678, 128, 128, 3) (678, 1)
# (678, 128, 128, 3) (678, 1)
#
# (2274, 128, 128, 3) (2274, 1)
# (758, 128, 128, 3) (758, 1)
# (758, 128, 128, 3) (758, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2034, 128, 128, 3) (2034, 5)
# (678, 128, 128, 3) (678, 5)
# (678, 128, 128, 3) (678, 5)
#
# (2274, 128, 128, 3) (2274, 5)
# (758, 128, 128, 3) (758, 5)
# (758, 128, 128, 3) (758, 5)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2034
# xTrain_S image Numbers // 10 :  203
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2274
# xTrain_S image Numbers // 10 :  227
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.ResNet50 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.ResNet50 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 20s 195ms/step - loss: 1.4800 - accuracy: 0.4739 - val_loss: 1.6239 - val_accuracy: 0.0619
# Epoch 2/100
# 32/32 [==============================] - 5s 144ms/step - loss: 0.7830 - accuracy: 0.6937 - val_loss: 2.2476 - val_accuracy: 0.1386
# Epoch 3/100
# 32/32 [==============================] - 5s 141ms/step - loss: 0.4861 - accuracy: 0.8230 - val_loss: 3.4211 - val_accuracy: 0.1445
# Epoch 4/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.3905 - accuracy: 0.8520 - val_loss: 3.2255 - val_accuracy: 0.1888
# Epoch 5/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.3365 - accuracy: 0.8751 - val_loss: 4.6661 - val_accuracy: 0.1327
# Epoch 6/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.2433 - accuracy: 0.9036 - val_loss: 4.8252 - val_accuracy: 0.2419
# Epoch 7/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.2332 - accuracy: 0.9120 - val_loss: 3.2753 - val_accuracy: 0.2729
# Epoch 8/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.2694 - accuracy: 0.9100 - val_loss: 6.1680 - val_accuracy: 0.1460
# Epoch 9/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.2218 - accuracy: 0.9267 - val_loss: 5.7000 - val_accuracy: 0.0900
# Epoch 10/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.1859 - accuracy: 0.9312 - val_loss: 7.1214 - val_accuracy: 0.0870
# Epoch 11/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.1756 - accuracy: 0.9390 - val_loss: 6.9039 - val_accuracy: 0.1313
# Epoch 12/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.1150 - accuracy: 0.9582 - val_loss: 5.5269 - val_accuracy: 0.1844
# Epoch 13/100
# 32/32 [==============================] - 4s 141ms/step - loss: 0.1249 - accuracy: 0.9587 - val_loss: 4.3547 - val_accuracy: 0.3009
# Epoch 14/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.1260 - accuracy: 0.9572 - val_loss: 5.1735 - val_accuracy: 0.1740
# Epoch 15/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.1155 - accuracy: 0.9617 - val_loss: 3.4260 - val_accuracy: 0.3274
# Epoch 16/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.1666 - accuracy: 0.9420 - val_loss: 2.6934 - val_accuracy: 0.4690
# Epoch 17/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.1411 - accuracy: 0.9494 - val_loss: 0.6892 - val_accuracy: 0.7950
# Epoch 18/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.1024 - accuracy: 0.9651 - val_loss: 1.4084 - val_accuracy: 0.6357
# Epoch 19/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0914 - accuracy: 0.9676 - val_loss: 3.4186 - val_accuracy: 0.4277
# Epoch 20/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.1085 - accuracy: 0.9720 - val_loss: 1891.6178 - val_accuracy: 0.4558
# Epoch 21/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.3927 - accuracy: 0.9194 - val_loss: 44.4026 - val_accuracy: 0.0782
# Epoch 22/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.2708 - accuracy: 0.9031 - val_loss: 11.3057 - val_accuracy: 0.2537
# Epoch 23/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.1555 - accuracy: 0.9499 - val_loss: 6.5964 - val_accuracy: 0.1180
# Epoch 24/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0945 - accuracy: 0.9666 - val_loss: 3.2596 - val_accuracy: 0.3717
# Epoch 25/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0660 - accuracy: 0.9794 - val_loss: 0.4371 - val_accuracy: 0.8643
# Epoch 26/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.5656 - val_accuracy: 0.8496
# Epoch 27/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0293 - accuracy: 0.9916 - val_loss: 0.7672 - val_accuracy: 0.8186
# Epoch 28/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0467 - accuracy: 0.9857 - val_loss: 0.7009 - val_accuracy: 0.8407
# Epoch 29/100
# 32/32 [==============================] - 4s 141ms/step - loss: 0.0431 - accuracy: 0.9857 - val_loss: 0.4257 - val_accuracy: 0.9041
# Epoch 30/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.1296 - accuracy: 0.9617 - val_loss: 1.9593 - val_accuracy: 0.6534
# Epoch 31/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0984 - accuracy: 0.9646 - val_loss: 1.3163 - val_accuracy: 0.6445
# Epoch 32/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0520 - accuracy: 0.9823 - val_loss: 0.7787 - val_accuracy: 0.8083
# Epoch 33/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0400 - accuracy: 0.9853 - val_loss: 0.5333 - val_accuracy: 0.8348
# Epoch 34/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0349 - accuracy: 0.9872 - val_loss: 0.4009 - val_accuracy: 0.8820
# Epoch 35/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0517 - accuracy: 0.9843 - val_loss: 0.8811 - val_accuracy: 0.8068
# Epoch 36/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0248 - accuracy: 0.9912 - val_loss: 0.7074 - val_accuracy: 0.8201
# Epoch 37/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0354 - accuracy: 0.9867 - val_loss: 0.4174 - val_accuracy: 0.8835
# Epoch 38/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 0.4222 - val_accuracy: 0.8879
# Epoch 39/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 1.1336 - val_accuracy: 0.7611
# Epoch 40/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0320 - accuracy: 0.9887 - val_loss: 2.1214 - val_accuracy: 0.6106
# Epoch 41/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0374 - accuracy: 0.9902 - val_loss: 1.3046 - val_accuracy: 0.7345
# Epoch 42/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.4160 - val_accuracy: 0.8938
# Epoch 43/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.8739 - val_accuracy: 0.8363
# Epoch 44/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.6363 - val_accuracy: 0.8702
# Epoch 45/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.4027 - val_accuracy: 0.9027
# Epoch 46/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.4478 - val_accuracy: 0.9100
# Epoch 47/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0214 - accuracy: 0.9921 - val_loss: 1.1092 - val_accuracy: 0.7611
# Epoch 48/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.5116 - val_accuracy: 0.8702
# Epoch 49/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0527 - accuracy: 0.9843 - val_loss: 1.8238 - val_accuracy: 0.7257
# Epoch 50/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0322 - accuracy: 0.9882 - val_loss: 1.5203 - val_accuracy: 0.7286
# Epoch 51/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0351 - accuracy: 0.9887 - val_loss: 0.6232 - val_accuracy: 0.8805
# Epoch 52/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0337 - accuracy: 0.9897 - val_loss: 0.2772 - val_accuracy: 0.9351
# Epoch 53/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 2.4950 - val_accuracy: 0.5826
# Epoch 54/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0292 - accuracy: 0.9931 - val_loss: 1.7045 - val_accuracy: 0.6844
# Epoch 55/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0331 - accuracy: 0.9897 - val_loss: 0.4231 - val_accuracy: 0.8968
# Epoch 56/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0231 - accuracy: 0.9907 - val_loss: 1.3322 - val_accuracy: 0.7743
# Epoch 57/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.2681 - val_accuracy: 0.9366
# Epoch 58/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0409 - accuracy: 0.9892 - val_loss: 3.8450 - val_accuracy: 0.5693
# Epoch 59/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0468 - accuracy: 0.9872 - val_loss: 0.7046 - val_accuracy: 0.8496
# Epoch 60/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 2.1075 - val_accuracy: 0.6829
# Epoch 61/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.6080 - val_accuracy: 0.8776
# Epoch 62/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.5556 - val_accuracy: 0.8717
# Epoch 63/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.2598 - val_accuracy: 0.9351
# Epoch 64/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9558
# Epoch 65/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.6006 - val_accuracy: 0.8673
# Epoch 66/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.9416 - val_accuracy: 0.7950
# Epoch 67/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0190 - accuracy: 0.9961 - val_loss: 0.2736 - val_accuracy: 0.9263
# Epoch 68/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 1.6236 - val_accuracy: 0.7478
# Epoch 69/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0177 - accuracy: 0.9931 - val_loss: 0.3900 - val_accuracy: 0.9027
# Epoch 70/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0136 - accuracy: 0.9941 - val_loss: 1.3982 - val_accuracy: 0.7139
# Epoch 71/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.9445 - val_accuracy: 0.8245
# Epoch 72/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.3540 - val_accuracy: 0.9115
# Epoch 73/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.9086
# Epoch 74/100
# 32/32 [==============================] - 4s 137ms/step - loss: 8.0774e-04 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9381
# Epoch 75/100
# 32/32 [==============================] - 4s 136ms/step - loss: 4.1155e-04 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9513
# Epoch 76/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.5548 - val_accuracy: 0.8628
# Epoch 77/100
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1952 - val_accuracy: 0.9661
# Epoch 78/100
# 32/32 [==============================] - 4s 137ms/step - loss: 5.8748e-04 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9631
# Epoch 79/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 1.1546 - val_accuracy: 0.8097
# Epoch 80/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 1.2839 - val_accuracy: 0.7345
# Epoch 81/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0671 - accuracy: 0.9803 - val_loss: 0.4975 - val_accuracy: 0.8791
# Epoch 82/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.5712 - val_accuracy: 0.8599
# Epoch 83/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0186 - accuracy: 0.9956 - val_loss: 0.4057 - val_accuracy: 0.8982
# Epoch 84/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0308 - accuracy: 0.9887 - val_loss: 1.3639 - val_accuracy: 0.7625
# Epoch 85/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0744 - accuracy: 0.9813 - val_loss: 1.1179 - val_accuracy: 0.7448
# Epoch 86/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0366 - accuracy: 0.9887 - val_loss: 0.7951 - val_accuracy: 0.8422
# Epoch 87/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0342 - accuracy: 0.9912 - val_loss: 2.0194 - val_accuracy: 0.5678
# Epoch 88/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0418 - accuracy: 0.9862 - val_loss: 0.7430 - val_accuracy: 0.8083
# Epoch 89/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.9800 - val_accuracy: 0.7965
# Epoch 90/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.4058 - val_accuracy: 0.9027
# Epoch 91/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 0.1872 - val_accuracy: 0.9484
# Epoch 92/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.6249 - val_accuracy: 0.8614
# Epoch 93/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 1.0832 - val_accuracy: 0.7773
# Epoch 94/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0122 - accuracy: 0.9951 - val_loss: 0.5828 - val_accuracy: 0.8599
# Epoch 95/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 3.3748 - val_accuracy: 0.4808
# Epoch 96/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0317 - accuracy: 0.9877 - val_loss: 0.9220 - val_accuracy: 0.8304
# Epoch 97/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0494 - accuracy: 0.9838 - val_loss: 1.8613 - val_accuracy: 0.6091
# Epoch 98/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0382 - accuracy: 0.9882 - val_loss: 0.5769 - val_accuracy: 0.8614
# Epoch 99/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.3534 - val_accuracy: 0.9130
# Epoch 100/100
# 32/32 [==============================] - 4s 136ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.4617 - val_accuracy: 0.8938
# Maximal validation accuracy: 96.61%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.479982  0.473943  1.623878      0.061947
# 1   0.783036  0.693707  2.247570      0.138643
# 2   0.486128  0.823009  3.421108      0.144543
# 3   0.390466  0.852016  3.225519      0.188791
# 4   0.336472  0.875123  4.666141      0.132743
# ..       ...       ...       ...           ...
# 95  0.031680  0.987709  0.922001      0.830383
# 96  0.049370  0.983776  1.861267      0.609145
# 97  0.038189  0.988201  0.576897      0.861357
# 98  0.019824  0.993609  0.353402      0.912979
# 99  0.006464  0.998525  0.461704      0.893805
#
# [100 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.18718913197517395
# Maximum validation accuracy: 0.966076672077179

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 31ms/step - loss: 0.4887 - accuracy: 0.8687
# test loss, test acc: [0.48867690563201904, 0.8687315583229065]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 22/22 [==============================] - 1s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 11s 176ms/step - loss: 0.4526 - accuracy: 0.8486 - val_loss: 4342.2852 - val_accuracy: 0.4425
# Epoch 2/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.2708 - accuracy: 0.9120 - val_loss: 7.0718 - val_accuracy: 0.1770
# Epoch 3/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.1772 - accuracy: 0.9282 - val_loss: 1.7085 - val_accuracy: 0.1608
# Epoch 4/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.1425 - accuracy: 0.9503 - val_loss: 6.7755 - val_accuracy: 0.1770
# Epoch 5/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0881 - accuracy: 0.9676 - val_loss: 3.0351 - val_accuracy: 0.1386
# Epoch 6/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0834 - accuracy: 0.9739 - val_loss: 7.5227 - val_accuracy: 0.0649
# Epoch 7/100
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0638 - accuracy: 0.9784 - val_loss: 8.5462 - val_accuracy: 0.0649
# Epoch 8/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0450 - accuracy: 0.9848 - val_loss: 7.1764 - val_accuracy: 0.1770
# Epoch 9/100
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0567 - accuracy: 0.9848 - val_loss: 3.2588 - val_accuracy: 0.0649
# Epoch 10/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0426 - accuracy: 0.9892 - val_loss: 3.1419 - val_accuracy: 0.0649
# Epoch 11/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0338 - accuracy: 0.9921 - val_loss: 3.7324 - val_accuracy: 0.1770
# Epoch 12/100
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 6.5010 - val_accuracy: 0.1770
# Epoch 13/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0402 - accuracy: 0.9872 - val_loss: 5.2891 - val_accuracy: 0.0649
# Epoch 14/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0659 - accuracy: 0.9794 - val_loss: 2.5298 - val_accuracy: 0.0826
# Epoch 15/100
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0403 - accuracy: 0.9877 - val_loss: 5.7816 - val_accuracy: 0.0723
# Epoch 16/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0162 - accuracy: 0.9926 - val_loss: 8.9305 - val_accuracy: 0.0649
# Epoch 17/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0350 - accuracy: 0.9887 - val_loss: 3.2599 - val_accuracy: 0.1504
# Epoch 18/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0542 - accuracy: 0.9848 - val_loss: 6.7652 - val_accuracy: 0.0649
# Epoch 19/100
# 32/32 [==============================] - 4s 138ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 6.7724 - val_accuracy: 0.0664
# Epoch 20/100
# 32/32 [==============================] - 4s 137ms/step - loss: 0.0142 - accuracy: 0.9941 - val_loss: 3.5890 - val_accuracy: 0.1062
# Epoch 21/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9980Restoring model weights from the end of the best epoch: 1.
# 32/32 [==============================] - 4s 140ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 8.9088 - val_accuracy: 0.1873
# Epoch 00021: early stopping
# Maximal validation accuracy: 44.25%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy     val_loss  val_accuracy
# 0   0.452607  0.848574  4342.285156      0.442478
# 1   0.270843  0.911996     7.071841      0.176991
# 2   0.177178  0.928220     1.708506      0.160767
# 3   0.142469  0.950344     6.775542      0.176991
# 4   0.088096  0.967552     3.035070      0.138643
# 5   0.083446  0.973943     7.522728      0.064897
# 6   0.063805  0.978368     8.546235      0.064897
# 7   0.044993  0.984759     7.176381      0.176991
# 8   0.056705  0.984759     3.258780      0.064897
# 9   0.042614  0.989184     3.141906      0.064897
# 10  0.033849  0.992134     3.732431      0.176991
# 11  0.018021  0.995084     6.501048      0.176991
# 12  0.040158  0.987217     5.289052      0.064897
# 13  0.065937  0.979351     2.529755      0.082596
# 14  0.040349  0.987709     5.781558      0.072271
# 15  0.016223  0.992625     8.930491      0.064897
# 16  0.034993  0.988692     3.259866      0.150442
# 17  0.054161  0.984759     6.765165      0.064897
# 18  0.020734  0.994592     6.772437      0.066372
# 19  0.014246  0.994100     3.589005      0.106195
# 20  0.007088  0.998033     8.908834      0.187316

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 1.7085062265396118
# Maximum validation accuracy: 0.44247788190841675

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 27ms/step - loss: 4345.1582 - accuracy: 0.4425
# test loss, test acc: [4345.158203125, 0.44247788190841675]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 22/22 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 12s 184ms/step - loss: 1.3946 - accuracy: 0.4578 - val_loss: 2.8083 - val_accuracy: 0.3958
# Epoch 2/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.9203 - accuracy: 0.6324 - val_loss: 1.9304 - val_accuracy: 0.3958
# Epoch 3/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.8280 - accuracy: 0.6759 - val_loss: 2.6969 - val_accuracy: 0.3971
# Epoch 4/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.6585 - accuracy: 0.7480 - val_loss: 3.6533 - val_accuracy: 0.2111
# Epoch 5/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.5597 - accuracy: 0.7876 - val_loss: 5.5708 - val_accuracy: 0.2111
# Epoch 6/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.5607 - accuracy: 0.7792 - val_loss: 3.6954 - val_accuracy: 0.1609
# Epoch 7/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.4225 - accuracy: 0.8355 - val_loss: 2.8920 - val_accuracy: 0.2243
# Epoch 8/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.4315 - accuracy: 0.8289 - val_loss: 3.0781 - val_accuracy: 0.2876
# Epoch 9/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.3623 - accuracy: 0.8540 - val_loss: 2.4926 - val_accuracy: 0.2401
# Epoch 10/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.2835 - accuracy: 0.8905 - val_loss: 2.6221 - val_accuracy: 0.3351
# Epoch 11/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.3576 - accuracy: 0.8584 - val_loss: 2.4175 - val_accuracy: 0.3430
# Epoch 12/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.2836 - accuracy: 0.8896 - val_loss: 2.2232 - val_accuracy: 0.4446
# Epoch 13/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.2927 - accuracy: 0.8887 - val_loss: 5.0948 - val_accuracy: 0.1715
# Epoch 14/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.2769 - accuracy: 0.8883 - val_loss: 2.0892 - val_accuracy: 0.5831
# Epoch 15/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.2006 - accuracy: 0.9230 - val_loss: 1.3789 - val_accuracy: 0.6398
# Epoch 16/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.2279 - accuracy: 0.9125 - val_loss: 2.0740 - val_accuracy: 0.5224
# Epoch 17/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.2265 - accuracy: 0.9103 - val_loss: 1.0524 - val_accuracy: 0.6926
# Epoch 18/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1648 - accuracy: 0.9376 - val_loss: 1.1530 - val_accuracy: 0.6834
# Epoch 19/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1439 - accuracy: 0.9393 - val_loss: 1.8643 - val_accuracy: 0.6530
# Epoch 20/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1533 - accuracy: 0.9415 - val_loss: 7.2839 - val_accuracy: 0.1979
# Epoch 21/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1555 - accuracy: 0.9468 - val_loss: 3.9907 - val_accuracy: 0.3034
# Epoch 22/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.1189 - accuracy: 0.9573 - val_loss: 3.1405 - val_accuracy: 0.4710
# Epoch 23/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0681 - accuracy: 0.9771 - val_loss: 3.5187 - val_accuracy: 0.4354
# Epoch 24/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.0714 - accuracy: 0.9763 - val_loss: 1.1848 - val_accuracy: 0.7032
# Epoch 25/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1000 - accuracy: 0.9653 - val_loss: 2.4830 - val_accuracy: 0.5343
# Epoch 26/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0937 - accuracy: 0.9683 - val_loss: 22.9430 - val_accuracy: 0.6095
# Epoch 27/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.1080 - accuracy: 0.9609 - val_loss: 1.1163 - val_accuracy: 0.6992
# Epoch 28/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.1008 - accuracy: 0.9688 - val_loss: 2.1055 - val_accuracy: 0.5950
# Epoch 29/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0744 - accuracy: 0.9754 - val_loss: 2.3280 - val_accuracy: 0.5383
# Epoch 30/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0948 - accuracy: 0.9727 - val_loss: 4.4146 - val_accuracy: 0.2810
# Epoch 31/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1083 - accuracy: 0.9626 - val_loss: 2.5121 - val_accuracy: 0.6517
# Epoch 32/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.0476 - accuracy: 0.9828 - val_loss: 0.8806 - val_accuracy: 0.8074
# Epoch 33/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0391 - accuracy: 0.9855 - val_loss: 3.8985 - val_accuracy: 0.7573
# Epoch 34/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0327 - accuracy: 0.9925 - val_loss: 1.1560 - val_accuracy: 0.7361
# Epoch 35/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 1.8551 - val_accuracy: 0.6623
# Epoch 36/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0545 - accuracy: 0.9815 - val_loss: 16.4721 - val_accuracy: 0.6280
# Epoch 37/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 7.6423 - val_accuracy: 0.5290
# Epoch 38/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0757 - accuracy: 0.9749 - val_loss: 2.8951 - val_accuracy: 0.6412
# Epoch 39/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0622 - accuracy: 0.9776 - val_loss: 1.7358 - val_accuracy: 0.6517
# Epoch 40/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.1200 - accuracy: 0.9565 - val_loss: 3.0483 - val_accuracy: 0.6266
# Epoch 41/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0529 - accuracy: 0.9811 - val_loss: 0.9597 - val_accuracy: 0.7863
# Epoch 42/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0551 - accuracy: 0.9815 - val_loss: 3.2466 - val_accuracy: 0.6794
# Epoch 43/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0623 - accuracy: 0.9820 - val_loss: 1.0471 - val_accuracy: 0.7625
# Epoch 44/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 1.3362 - val_accuracy: 0.7335
# Epoch 45/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0283 - accuracy: 0.9899 - val_loss: 2.7909 - val_accuracy: 0.7322
# Epoch 46/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 0.8377 - val_accuracy: 0.8061
# Epoch 47/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0440 - accuracy: 0.9886 - val_loss: 5.2785 - val_accuracy: 0.3219
# Epoch 48/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0233 - accuracy: 0.9934 - val_loss: 2.4473 - val_accuracy: 0.5515
# Epoch 49/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0309 - accuracy: 0.9894 - val_loss: 1.2703 - val_accuracy: 0.7467
# Epoch 50/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0711 - accuracy: 0.9758 - val_loss: 3.9935 - val_accuracy: 0.4697
# Epoch 51/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0531 - accuracy: 0.9802 - val_loss: 1.2077 - val_accuracy: 0.7296
# Epoch 52/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 1.3325 - val_accuracy: 0.7691
# Epoch 53/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 7.4679 - val_accuracy: 0.6623
# Epoch 54/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 3.1288 - val_accuracy: 0.7309
# Epoch 55/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 1.0971 - val_accuracy: 0.7863
# Epoch 56/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0421 - accuracy: 0.9868 - val_loss: 2.8998 - val_accuracy: 0.7032
# Epoch 57/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0616 - accuracy: 0.9798 - val_loss: 1.5698 - val_accuracy: 0.6675
# Epoch 58/100
# 36/36 [==============================] - 5s 140ms/step - loss: 0.0646 - accuracy: 0.9785 - val_loss: 3.5538 - val_accuracy: 0.4485
# Epoch 59/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0193 - accuracy: 0.9956 - val_loss: 1.5837 - val_accuracy: 0.7018
# Epoch 60/100
# 36/36 [==============================] - 5s 137ms/step - loss: 0.0322 - accuracy: 0.9877 - val_loss: 5.6828 - val_accuracy: 0.6016
# Epoch 61/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0618 - accuracy: 0.9758 - val_loss: 1.2148 - val_accuracy: 0.7546
# Epoch 62/100
# 36/36 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9872Restoring model weights from the end of the best epoch: 32.
# 36/36 [==============================] - 5s 140ms/step - loss: 0.0422 - accuracy: 0.9872 - val_loss: 1.7844 - val_accuracy: 0.7058
# Epoch 00062: early stopping
# Maximal validation accuracy: 80.74%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.394614  0.457784  2.808326      0.395778
# 1   0.920302  0.632366  1.930429      0.395778
# 2   0.827993  0.675901  2.696921      0.397098
# 3   0.658460  0.748021  3.653303      0.211082
# 4   0.559651  0.787599  5.570766      0.211082
# ..       ...       ...       ...           ...
# 57  0.064559  0.978452  3.553822      0.448549
# 58  0.019303  0.995602  1.583748      0.701847
# 59  0.032231  0.987687  5.682808      0.601583
# 60  0.061817  0.975814  1.214836      0.754617
# 61  0.042171  0.987247  1.784394      0.705805
#
# [62 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.8376640677452087
# Maximum validation accuracy: 0.8073878884315491

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 24/24 [==============================] - 1s 32ms/step - loss: 1.0372 - accuracy: 0.7968
# test loss, test acc: [1.037183403968811, 0.7968337535858154]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 24/24 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 11s 169ms/step - loss: 0.5781 - accuracy: 0.8012 - val_loss: 61.7346 - val_accuracy: 0.1240
# Epoch 2/100
# 36/36 [==============================] - 5s 138ms/step - loss: 0.3328 - accuracy: 0.8808 - val_loss: 9.3888 - val_accuracy: 0.2111
# Epoch 3/100
# 36/36 [==============================] - 5s 134ms/step - loss: 0.1854 - accuracy: 0.9323 - val_loss: 7.9542 - val_accuracy: 0.2111
# Epoch 4/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.1702 - accuracy: 0.9455 - val_loss: 3.5252 - val_accuracy: 0.2111
# Epoch 5/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.1112 - accuracy: 0.9600 - val_loss: 12.2560 - val_accuracy: 0.2111
# Epoch 6/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0916 - accuracy: 0.9705 - val_loss: 8.3762 - val_accuracy: 0.2111
# Epoch 7/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0829 - accuracy: 0.9732 - val_loss: 10.1756 - val_accuracy: 0.2111
# Epoch 8/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0573 - accuracy: 0.9785 - val_loss: 12.5106 - val_accuracy: 0.2111
# Epoch 9/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0637 - accuracy: 0.9798 - val_loss: 5.1284 - val_accuracy: 0.2111
# Epoch 10/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0971 - accuracy: 0.9701 - val_loss: 4.6791 - val_accuracy: 0.2111
# Epoch 11/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0809 - accuracy: 0.9736 - val_loss: 23.1907 - val_accuracy: 0.2111
# Epoch 12/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0456 - accuracy: 0.9872 - val_loss: 5.6202 - val_accuracy: 0.1240
# Epoch 13/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0369 - accuracy: 0.9894 - val_loss: 2.9637 - val_accuracy: 0.2032
# Epoch 14/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 13.9442 - val_accuracy: 0.2111
# Epoch 15/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0588 - accuracy: 0.9820 - val_loss: 4.6477 - val_accuracy: 0.2111
# Epoch 16/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0511 - accuracy: 0.9846 - val_loss: 6.0818 - val_accuracy: 0.2111
# Epoch 17/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0617 - accuracy: 0.9828 - val_loss: 5.2183 - val_accuracy: 0.1755
# Epoch 18/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0709 - accuracy: 0.9815 - val_loss: 8.5508 - val_accuracy: 0.1240
# Epoch 19/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0894 - accuracy: 0.9723 - val_loss: 10.8221 - val_accuracy: 0.1240
# Epoch 20/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0324 - accuracy: 0.9934 - val_loss: 6.1203 - val_accuracy: 0.1557
# Epoch 21/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 4.7426 - val_accuracy: 0.1847
# Epoch 22/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 2.3585 - val_accuracy: 0.3206
# Epoch 23/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0179 - accuracy: 0.9952 - val_loss: 3.6679 - val_accuracy: 0.3536
# Epoch 24/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0288 - accuracy: 0.9916 - val_loss: 1.6639 - val_accuracy: 0.5303
# Epoch 25/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0193 - accuracy: 0.9934 - val_loss: 2.4406 - val_accuracy: 0.4169
# Epoch 26/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0385 - accuracy: 0.9930 - val_loss: 2.5678 - val_accuracy: 0.6187
# Epoch 27/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 1.1316 - val_accuracy: 0.7032
# Epoch 28/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 1.8854 - val_accuracy: 0.6517
# Epoch 29/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0296 - accuracy: 0.9908 - val_loss: 3.0719 - val_accuracy: 0.5000
# Epoch 30/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0480 - accuracy: 0.9837 - val_loss: 1.0959 - val_accuracy: 0.6398
# Epoch 31/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.5797 - val_accuracy: 0.8364
# Epoch 32/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 1.3774 - val_accuracy: 0.7467
# Epoch 33/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0158 - accuracy: 0.9934 - val_loss: 0.7200 - val_accuracy: 0.8338
# Epoch 34/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0132 - accuracy: 0.9943 - val_loss: 0.9142 - val_accuracy: 0.8206
# Epoch 35/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0621 - accuracy: 0.9820 - val_loss: 1.3828 - val_accuracy: 0.7665
# Epoch 36/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0464 - accuracy: 0.9842 - val_loss: 0.7193 - val_accuracy: 0.8522
# Epoch 37/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 2.4928 - val_accuracy: 0.6451
# Epoch 38/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0160 - accuracy: 0.9965 - val_loss: 0.9315 - val_accuracy: 0.8206
# Epoch 39/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.5172 - val_accuracy: 0.8839
# Epoch 40/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.6966 - val_accuracy: 0.8602
# Epoch 41/100
# 36/36 [==============================] - 5s 139ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 0.7308 - val_accuracy: 0.8892
# Epoch 42/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0353 - accuracy: 0.9890 - val_loss: 3.3380 - val_accuracy: 0.5026
# Epoch 43/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 1.7791 - val_accuracy: 0.7098
# Epoch 44/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.7450 - val_accuracy: 0.8654
# Epoch 45/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.7148 - val_accuracy: 0.8602
# Epoch 46/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0298 - accuracy: 0.9925 - val_loss: 0.9253 - val_accuracy: 0.7982
# Epoch 47/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0163 - accuracy: 0.9956 - val_loss: 1.0229 - val_accuracy: 0.8140
# Epoch 48/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0084 - accuracy: 0.9982 - val_loss: 0.9879 - val_accuracy: 0.8259
# Epoch 49/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 1.1064 - val_accuracy: 0.7955
# Epoch 50/100
# 36/36 [==============================] - 5s 135ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 1.2142 - val_accuracy: 0.8100
# Epoch 51/100
# 36/36 [==============================] - 5s 136ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 1.1015 - val_accuracy: 0.7942
# Epoch 52/100
# 36/36 [==============================] - 5s 139ms/step - loss: 8.0679e-04 - accuracy: 0.9996 - val_loss: 0.6725 - val_accuracy: 0.8945
# Epoch 53/100
# 36/36 [==============================] - 5s 136ms/step - loss: 7.5148e-04 - accuracy: 1.0000 - val_loss: 0.7064 - val_accuracy: 0.8918
# Epoch 54/100
# 36/36 [==============================] - 5s 139ms/step - loss: 6.0837e-04 - accuracy: 1.0000 - val_loss: 0.5929 - val_accuracy: 0.9050
# Epoch 55/100
# 36/36 [==============================] - 5s 139ms/step - loss: 8.3117e-05 - accuracy: 1.0000 - val_loss: 0.5364 - val_accuracy: 0.9156
# Epoch 56/100
# 36/36 [==============================] - 5s 139ms/step - loss: 2.2566e-04 - accuracy: 1.0000 - val_loss: 0.5442 - val_accuracy: 0.9208
# Epoch 57/100
# 36/36 [==============================] - 5s 140ms/step - loss: 1.0146e-04 - accuracy: 1.0000 - val_loss: 0.5278 - val_accuracy: 0.9248
# Epoch 58/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.0658e-04 - accuracy: 1.0000 - val_loss: 0.5087 - val_accuracy: 0.9208
# Epoch 59/100
# 36/36 [==============================] - 5s 135ms/step - loss: 8.0598e-05 - accuracy: 1.0000 - val_loss: 0.5105 - val_accuracy: 0.9195
# Epoch 60/100
# 36/36 [==============================] - 5s 136ms/step - loss: 4.9718e-05 - accuracy: 1.0000 - val_loss: 0.5211 - val_accuracy: 0.9222
# Epoch 61/100
# 36/36 [==============================] - 5s 136ms/step - loss: 3.6382e-05 - accuracy: 1.0000 - val_loss: 0.5256 - val_accuracy: 0.9235
# Epoch 62/100
# 36/36 [==============================] - 5s 136ms/step - loss: 3.6436e-05 - accuracy: 1.0000 - val_loss: 0.5258 - val_accuracy: 0.9235
# Epoch 63/100
# 36/36 [==============================] - 5s 136ms/step - loss: 4.0989e-05 - accuracy: 1.0000 - val_loss: 0.5282 - val_accuracy: 0.9235
# Epoch 64/100
# 36/36 [==============================] - 5s 135ms/step - loss: 2.8451e-05 - accuracy: 1.0000 - val_loss: 0.5288 - val_accuracy: 0.9222
# Epoch 65/100
# 36/36 [==============================] - 5s 135ms/step - loss: 1.8862e-05 - accuracy: 1.0000 - val_loss: 0.5301 - val_accuracy: 0.9222
# Epoch 66/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.2073e-04 - accuracy: 1.0000 - val_loss: 0.5351 - val_accuracy: 0.9235
# Epoch 67/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.7866e-05 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.9235
# Epoch 68/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.4141e-05 - accuracy: 1.0000 - val_loss: 0.5386 - val_accuracy: 0.9222
# Epoch 69/100
# 36/36 [==============================] - 5s 136ms/step - loss: 2.2583e-05 - accuracy: 1.0000 - val_loss: 0.5402 - val_accuracy: 0.9235
# Epoch 70/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.8113e-05 - accuracy: 1.0000 - val_loss: 0.5398 - val_accuracy: 0.9248
# Epoch 71/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.5331e-05 - accuracy: 1.0000 - val_loss: 0.5409 - val_accuracy: 0.9222
# Epoch 72/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.7825e-05 - accuracy: 1.0000 - val_loss: 0.5436 - val_accuracy: 0.9222
# Epoch 73/100
# 36/36 [==============================] - 5s 136ms/step - loss: 2.5954e-05 - accuracy: 1.0000 - val_loss: 0.5443 - val_accuracy: 0.9222
# Epoch 74/100
# 36/36 [==============================] - 5s 136ms/step - loss: 1.1637e-05 - accuracy: 1.0000 - val_loss: 0.5430 - val_accuracy: 0.9222
# Epoch 75/100
# 36/36 [==============================] - 5s 136ms/step - loss: 3.0028e-05 - accuracy: 1.0000 - val_loss: 0.5473 - val_accuracy: 0.9208
# Epoch 76/100
# 36/36 [==============================] - 5s 136ms/step - loss: 3.5710e-05 - accuracy: 1.0000 - val_loss: 0.5559 - val_accuracy: 0.9235
# Epoch 77/100
# 36/36 [==============================] - ETA: 0s - loss: 1.0438e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 57.
# 36/36 [==============================] - 5s 139ms/step - loss: 1.0438e-05 - accuracy: 1.0000 - val_loss: 0.5557 - val_accuracy: 0.9235
# Epoch 00077: early stopping
# Maximal validation accuracy: 92.48%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.578132  0.801231  61.734562      0.124011
# 1   0.332825  0.880827   9.388794      0.211082
# 2   0.185376  0.932278   7.954237      0.211082
# 3   0.170243  0.945471   3.525187      0.211082
# 4   0.111212  0.959982  12.256014      0.211082
# ..       ...       ...        ...           ...
# 72  0.000026  1.000000   0.544342      0.922164
# 73  0.000012  1.000000   0.543010      0.922164
# 74  0.000030  1.000000   0.547262      0.920844
# 75  0.000036  1.000000   0.555926      0.923483
# 76  0.000010  1.000000   0.555701      0.923483
#
# [77 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.5087470412254333
# Maximum validation accuracy: 0.9248021245002747

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 24/24 [==============================] - 1s 27ms/step - loss: 0.4890 - accuracy: 0.9182
# test loss, test acc: [0.4889509975910187, 0.9182057976722717]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 24/24 [==============================] - 1s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_ResNet50_None
# test loss, test acc: [0.48867690563201904, 0.8687315583229065]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_ResNet50_imagenet
# test loss, test acc: [4345.158203125, 0.44247788190841675]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_ResNet50_None
# test loss, test acc: [1.037183403968811, 0.7968337535858154]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_ResNet50_imagenet
# test loss, test acc: [0.4889509975910187, 0.9182057976722717]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_ResNet50_None →→→ Target Test
# 24/24 [==============================] - 1s 27ms/step - loss: 6.1358 - accuracy: 0.1675
# test loss, test acc: [6.13580322265625, 0.16754616796970367]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_ResNet50_imagenet →→→ Target Test
# 24/24 [==============================] - 1s 27ms/step - loss: 4649.8491 - accuracy: 0.3958
# test loss, test acc: [4649.84912109375, 0.3957783579826355]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_ResNet50_None →→→ Source Test
# 22/22 [==============================] - 1s 27ms/step - loss: 6.3176 - accuracy: 0.3038
# test loss, test acc: [6.3176069259643555, 0.30383479595184326]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_ResNet50_imagenet →→→ Source Test
# 22/22 [==============================] - 1s 27ms/step - loss: 6.6665 - accuracy: 0.3053
# test loss, test acc: [6.666532039642334, 0.3053097426891327]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
