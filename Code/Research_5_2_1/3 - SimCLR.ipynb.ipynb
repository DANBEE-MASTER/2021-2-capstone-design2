# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import pandas as pd
import os

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4223579647113074298
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1438593531296811125
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Tue Dec 14 01:52:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. Hyperparameter setup

# %%
# Dataset hyperparameters
image_size = 128
image_channels = 3

# Algorithm hyperparameters
num_epochs = 100
patience_num = 10
class_num = 5
batch_size = 64  
width = 128
temperature = 0.1

# Stronger augmentations for contrastive, weaker ones for supervised training
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2}
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

#base_path = ''
base_path = 'gdrive/My Drive/Research_5_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/3 - SimCLR_result/'

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
# Out:
# (2034, 128, 128, 3) (2034, 1)
# (678, 128, 128, 3) (678, 1)
# (678, 128, 128, 3) (678, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

# %% [markdown]
# ## 2-2. Dataset

# %%
labeled_train_data = tf.data.Dataset.from_tensor_slices((xTrain_S, yTrain_S))
unlabeled_train_data = tf.data.Dataset.from_tensor_slices((xValid_S, yValid_S))
test_data = tf.data.Dataset.from_tensor_slices((xTest_S, yTest_S))

# %%
labeled_train_dataset = labeled_train_data.batch(batch_size)
unlabeled_train_dataset = unlabeled_train_data.batch(batch_size)
test_dataset = test_data.batch(batch_size)

# %%
train_dataset = tf.data.Dataset.zip(
        (unlabeled_train_dataset, labeled_train_dataset)
    ).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
print ('labeled_train_dataset : ' , labeled_train_dataset)
print ('labeled_train_dataset 총 batch_size 세트 : ' , len(labeled_train_dataset))
print ('unlabeled_train_dataset : ' , unlabeled_train_dataset)
print ('unlabeled_train_dataset 총 batch_size 세트 : ' , len(unlabeled_train_dataset))
print ('test_dataset : ' , test_dataset)
print ('test_dataset 총 batch_size 세트 : ' , len(test_dataset)) 
print ('train_dataset : ' , train_dataset)
print ('train_dataset 총 batch_size 세트 : ' , len(train_dataset))
# Out:
# labeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# labeled_train_dataset 총 batch_size 세트 :  32
# unlabeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# unlabeled_train_dataset 총 batch_size 세트 :  11
# test_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# test_dataset 총 batch_size 세트 :  11
# train_dataset :  <PrefetchDataset shapes: (((None, 128, 128, 3), (None, 1)), ((None, 128, 128, 3), (None, 1))), types: ((tf.float32, tf.int32), (tf.float32, tf.int32))>
# train_dataset 총 batch_size 세트 :  11

# %% [markdown]
# ## 2-3. Image augmentations and visualize_augmentations

# %%
from tensorflow.keras.layers.experimental import preprocessing

# %%
# Distorts the color distibutions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def call(self, images, training=True):
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images


# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    zoom_factor = 1.0 - tf.sqrt(min_area)
    return tf.keras.Sequential(
        [
            tf.keras.Input(shape=(image_size, image_size, image_channels)),
            #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255),
            tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
            tf.keras.layers.experimental.preprocessing.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
            tf.keras.layers.experimental.preprocessing.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
            RandomColorAffine(brightness, jitter),
        ]
    )


def visualize_augmentations(num_images):
    # Sample a batch from a dataset
    images = next(iter(train_dataset))[0][0][:num_images]
    # Apply augmentations
    augmented_images = zip(
        (images),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255)(images),
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Weakly augmented:",
        "Strongly augmented:",
        "Strongly augmented:",
    ]
    plt.figure(figsize=(num_images * 2.2, 4 * 2.2), dpi=100)
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc="left")
            plt.axis("off")
    plt.tight_layout()

# %%
visualize_augmentations(num_images=8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 3. Network

# %% [markdown]
# ## 3-1. Encoder architecture

# %%
def get_encoder():
    base_model = tf.keras.applications.Xception(
    weights='imagenet',
    include_top=False,
    pooling='avg')
    
    model = keras.Sequential([
    base_model,
    layers.Dense(width, activation="relu"),
    ])
    
    return model

# %% [markdown]
# ## 3-2. Supervised baseline model - original image

# %%
# Baseline supervised training with random initialization
baseline_model_original_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        #get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_original_image",
)

baseline_model_original_image.summary()

baseline_model_original_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step
# Model: "baseline_model_original_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 128)               21123752
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 21,148,845
# Trainable params: 21,094,317
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_original_image_history = baseline_model_original_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_original_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 32/32 [==============================] - 21s 308ms/step - loss: 0.5257 - acc: 0.8343 - val_loss: 1.1162 - val_acc: 0.8407
# Epoch 2/100
# 32/32 [==============================] - 8s 259ms/step - loss: 0.1456 - acc: 0.9484 - val_loss: 2.4812 - val_acc: 0.8732
# Epoch 3/100
# 32/32 [==============================] - 8s 254ms/step - loss: 0.1025 - acc: 0.9631 - val_loss: 1.5525 - val_acc: 0.8260
# Epoch 4/100
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0683 - acc: 0.9794 - val_loss: 0.4083 - val_acc: 0.9056
# Epoch 5/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.1066 - acc: 0.9710 - val_loss: 0.4961 - val_acc: 0.9012
# Epoch 6/100
# 32/32 [==============================] - 8s 256ms/step - loss: 0.0813 - acc: 0.9798 - val_loss: 0.7319 - val_acc: 0.8392
# Epoch 7/100
# 32/32 [==============================] - 8s 258ms/step - loss: 0.0480 - acc: 0.9887 - val_loss: 0.4707 - val_acc: 0.9218
# Epoch 8/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0460 - acc: 0.9828 - val_loss: 0.7822 - val_acc: 0.9115
# Epoch 9/100
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0640 - acc: 0.9828 - val_loss: 0.2752 - val_acc: 0.9602
# Epoch 10/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0147 - acc: 0.9966 - val_loss: 0.4298 - val_acc: 0.9351
# Epoch 11/100
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0073 - acc: 0.9990 - val_loss: 0.2154 - val_acc: 0.9661
# Epoch 12/100
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0020 - acc: 0.9995 - val_loss: 0.1500 - val_acc: 0.9720
# Epoch 13/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0026 - acc: 0.9990 - val_loss: 0.1911 - val_acc: 0.9676
# Epoch 14/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0493 - acc: 0.9867 - val_loss: 0.4610 - val_acc: 0.9204
# Epoch 15/100
# 32/32 [==============================] - 8s 254ms/step - loss: 0.0106 - acc: 0.9961 - val_loss: 0.2037 - val_acc: 0.9676
# Epoch 16/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0272 - acc: 0.9907 - val_loss: 0.1652 - val_acc: 0.9676
# Epoch 17/100
# 32/32 [==============================] - 8s 259ms/step - loss: 0.0321 - acc: 0.9941 - val_loss: 0.1488 - val_acc: 0.9749
# Epoch 18/100
# 32/32 [==============================] - 8s 256ms/step - loss: 0.0242 - acc: 0.9951 - val_loss: 0.1822 - val_acc: 0.9558
# Epoch 19/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0063 - acc: 0.9990 - val_loss: 0.2925 - val_acc: 0.9440
# Epoch 20/100
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0066 - acc: 0.9985 - val_loss: 0.1979 - val_acc: 0.9558
# Epoch 21/100
# 32/32 [==============================] - 8s 255ms/step - loss: 5.9210e-04 - acc: 1.0000 - val_loss: 0.1192 - val_acc: 0.9705
# Epoch 22/100
# 32/32 [==============================] - 8s 256ms/step - loss: 1.6004e-04 - acc: 1.0000 - val_loss: 0.0857 - val_acc: 0.9749
# Epoch 23/100
# 32/32 [==============================] - 8s 260ms/step - loss: 1.0082e-04 - acc: 1.0000 - val_loss: 0.0708 - val_acc: 0.9794
# Epoch 24/100
# 32/32 [==============================] - 8s 256ms/step - loss: 7.4804e-05 - acc: 1.0000 - val_loss: 0.0654 - val_acc: 0.9794
# Epoch 25/100
# 32/32 [==============================] - 8s 260ms/step - loss: 5.9184e-05 - acc: 1.0000 - val_loss: 0.0620 - val_acc: 0.9823
# Epoch 26/100
# 32/32 [==============================] - 8s 256ms/step - loss: 4.8642e-05 - acc: 1.0000 - val_loss: 0.0599 - val_acc: 0.9823
# Epoch 27/100
# 32/32 [==============================] - 8s 259ms/step - loss: 4.1037e-05 - acc: 1.0000 - val_loss: 0.0586 - val_acc: 0.9838
# Epoch 28/100
# 32/32 [==============================] - 8s 256ms/step - loss: 3.5294e-05 - acc: 1.0000 - val_loss: 0.0579 - val_acc: 0.9838
# Epoch 29/100
# 32/32 [==============================] - 8s 256ms/step - loss: 3.0806e-05 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 0.9838
# Epoch 30/100
# 32/32 [==============================] - 8s 256ms/step - loss: 2.7206e-05 - acc: 1.0000 - val_loss: 0.0575 - val_acc: 0.9838
# Epoch 31/100
# 32/32 [==============================] - 8s 256ms/step - loss: 2.4263e-05 - acc: 1.0000 - val_loss: 0.0576 - val_acc: 0.9838
# Epoch 32/100
# 32/32 [==============================] - 8s 256ms/step - loss: 2.1819e-05 - acc: 1.0000 - val_loss: 0.0578 - val_acc: 0.9838
# Epoch 33/100
# 32/32 [==============================] - 8s 256ms/step - loss: 1.9757e-05 - acc: 1.0000 - val_loss: 0.0580 - val_acc: 0.9838
# Epoch 34/100
# 32/32 [==============================] - 8s 255ms/step - loss: 1.7997e-05 - acc: 1.0000 - val_loss: 0.0583 - val_acc: 0.9838
# Epoch 35/100
# 32/32 [==============================] - 8s 256ms/step - loss: 1.6479e-05 - acc: 1.0000 - val_loss: 0.0587 - val_acc: 0.9838
# Epoch 36/100
# 32/32 [==============================] - 8s 256ms/step - loss: 1.5154e-05 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 0.9838
# Epoch 37/100
# 32/32 [==============================] - ETA: 0s - loss: 1.3990e-05 - acc: 1.0000Restoring model weights from the end of the best epoch: 27.
# 32/32 [==============================] - 8s 259ms/step - loss: 1.3990e-05 - acc: 1.0000 - val_loss: 0.0593 - val_acc: 0.9838
# Epoch 00037: early stopping
# Maximal validation accuracy: 98.38%

# %%
baseline_model_original_image_df = pd.DataFrame(baseline_model_original_image_history.history)
baseline_model_original_image_df.to_csv( path_model_result + 'baseline_model_original_image_df.csv' )
baseline_model_original_image_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.525664  0.834317  1.116245  0.840708
# 1   0.145649  0.948378  2.481155  0.873156
# 2   0.102476  0.963127  1.552456  0.825959
# 3   0.068252  0.979351  0.408259  0.905605
# 4   0.106633  0.970993  0.496054  0.901180
# 5   0.081287  0.979843  0.731911  0.839233
# 6   0.048000  0.988692  0.470650  0.921829
# 7   0.046011  0.982793  0.782196  0.911504
# 8   0.064002  0.982793  0.275212  0.960177
# 9   0.014683  0.996558  0.429831  0.935103
# 10  0.007333  0.999017  0.215408  0.966077
# 11  0.001990  0.999508  0.149974  0.971976
# 12  0.002571  0.999017  0.191111  0.967552
# 13  0.049259  0.986726  0.460975  0.920354
# 14  0.010624  0.996067  0.203689  0.967552
# 15  0.027229  0.990659  0.165151  0.967552
# 16  0.032061  0.994100  0.148828  0.974926
# 17  0.024221  0.995084  0.182233  0.955752
# 18  0.006251  0.999017  0.292531  0.943953
# 19  0.006574  0.998525  0.197910  0.955752
# 20  0.000592  1.000000  0.119190  0.970501
# 21  0.000160  1.000000  0.085671  0.974926
# 22  0.000101  1.000000  0.070813  0.979351
# 23  0.000075  1.000000  0.065399  0.979351
# 24  0.000059  1.000000  0.062020  0.982301
# 25  0.000049  1.000000  0.059851  0.982301
# 26  0.000041  1.000000  0.058565  0.983776
# 27  0.000035  1.000000  0.057891  0.983776
# 28  0.000031  1.000000  0.057572  0.983776
# 29  0.000027  1.000000  0.057520  0.983776
# 30  0.000024  1.000000  0.057609  0.983776
# 31  0.000022  1.000000  0.057795  0.983776
# 32  0.000020  1.000000  0.058045  0.983776
# 33  0.000018  1.000000  0.058337  0.983776
# 34  0.000016  1.000000  0.058654  0.983776
# 35  0.000015  1.000000  0.058982  0.983776
# 36  0.000014  1.000000  0.059313  0.983776

# %% [markdown]
# ## 3-3. Supervised baseline model - augmenter image

# %%
# Baseline supervised training with random initialization
baseline_model_augmenter_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_augmenter_image",
)

baseline_model_augmenter_image.summary()

baseline_model_augmenter_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Model: "baseline_model_augmenter_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 128, 128, 3)       0
#
#  sequential_5 (Sequential)   (None, 128)               21123752
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 21,148,845
# Trainable params: 21,094,317
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_augmenter_image_history = baseline_model_augmenter_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_augmenter_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 32/32 [==============================] - 14s 289ms/step - loss: 0.5629 - acc: 0.8083 - val_loss: 3.0462 - val_acc: 0.8156
# Epoch 2/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.2306 - acc: 0.9169 - val_loss: 1.6004 - val_acc: 0.8437
# Epoch 3/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.2124 - acc: 0.9263 - val_loss: 2.4785 - val_acc: 0.8732
# Epoch 4/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.1432 - acc: 0.9528 - val_loss: 3.7245 - val_acc: 0.8481
# Epoch 5/100
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0986 - acc: 0.9715 - val_loss: 0.8084 - val_acc: 0.8835
# Epoch 6/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0805 - acc: 0.9720 - val_loss: 0.9698 - val_acc: 0.8245
# Epoch 7/100
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0665 - acc: 0.9813 - val_loss: 0.3211 - val_acc: 0.9130
# Epoch 8/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0786 - acc: 0.9779 - val_loss: 1.5977 - val_acc: 0.7802
# Epoch 9/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0539 - acc: 0.9867 - val_loss: 6.9978 - val_acc: 0.6888
# Epoch 10/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0612 - acc: 0.9813 - val_loss: 0.2760 - val_acc: 0.9322
# Epoch 11/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0439 - acc: 0.9872 - val_loss: 0.4709 - val_acc: 0.9336
# Epoch 12/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0461 - acc: 0.9872 - val_loss: 0.3336 - val_acc: 0.9189
# Epoch 13/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0772 - acc: 0.9789 - val_loss: 0.6720 - val_acc: 0.8909
# Epoch 14/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0843 - acc: 0.9744 - val_loss: 1.0934 - val_acc: 0.8245
# Epoch 15/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0479 - acc: 0.9857 - val_loss: 0.4919 - val_acc: 0.8982
# Epoch 16/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0325 - acc: 0.9912 - val_loss: 0.4802 - val_acc: 0.9174
# Epoch 17/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0372 - acc: 0.9916 - val_loss: 0.2686 - val_acc: 0.9484
# Epoch 18/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0408 - acc: 0.9882 - val_loss: 0.2175 - val_acc: 0.9528
# Epoch 19/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0162 - acc: 0.9956 - val_loss: 0.4439 - val_acc: 0.9233
# Epoch 20/100
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0317 - acc: 0.9897 - val_loss: 0.1684 - val_acc: 0.9528
# Epoch 21/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0286 - acc: 0.9931 - val_loss: 0.2038 - val_acc: 0.9469
# Epoch 22/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0131 - acc: 0.9971 - val_loss: 0.2033 - val_acc: 0.9558
# Epoch 23/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0184 - acc: 0.9946 - val_loss: 0.3981 - val_acc: 0.9145
# Epoch 24/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0339 - acc: 0.9902 - val_loss: 0.1600 - val_acc: 0.9528
# Epoch 25/100
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0172 - acc: 0.9941 - val_loss: 0.1606 - val_acc: 0.9617
# Epoch 26/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0184 - acc: 0.9946 - val_loss: 0.1536 - val_acc: 0.9558
# Epoch 27/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0319 - acc: 0.9912 - val_loss: 0.9779 - val_acc: 0.8142
# Epoch 28/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0337 - acc: 0.9892 - val_loss: 0.3349 - val_acc: 0.8953
# Epoch 29/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0274 - acc: 0.9907 - val_loss: 0.1721 - val_acc: 0.9543
# Epoch 30/100
# 32/32 [==============================] - 8s 260ms/step - loss: 0.0319 - acc: 0.9926 - val_loss: 0.3191 - val_acc: 0.8968
# Epoch 31/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0325 - acc: 0.9921 - val_loss: 0.3109 - val_acc: 0.9189
# Epoch 32/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0266 - acc: 0.9931 - val_loss: 0.2454 - val_acc: 0.9572
# Epoch 33/100
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0180 - acc: 0.9956 - val_loss: 0.0845 - val_acc: 0.9808
# Epoch 34/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0212 - acc: 0.9956 - val_loss: 0.1015 - val_acc: 0.9705
# Epoch 35/100
# 32/32 [==============================] - 8s 265ms/step - loss: 0.0057 - acc: 0.9985 - val_loss: 0.0556 - val_acc: 0.9823
# Epoch 36/100
# 32/32 [==============================] - 8s 261ms/step - loss: 6.6200e-04 - acc: 1.0000 - val_loss: 0.0572 - val_acc: 0.9808
# Epoch 37/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0194 - acc: 0.9951 - val_loss: 0.0892 - val_acc: 0.9749
# Epoch 38/100
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0315 - acc: 0.9921 - val_loss: 0.1132 - val_acc: 0.9631
# Epoch 39/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0185 - acc: 0.9951 - val_loss: 0.2705 - val_acc: 0.9587
# Epoch 40/100
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0176 - acc: 0.9946 - val_loss: 0.0638 - val_acc: 0.9838
# Epoch 41/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0233 - acc: 0.9946 - val_loss: 0.1111 - val_acc: 0.9705
# Epoch 42/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0106 - acc: 0.9975 - val_loss: 0.1108 - val_acc: 0.9720
# Epoch 43/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0044 - acc: 0.9975 - val_loss: 0.0846 - val_acc: 0.9764
# Epoch 44/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0195 - acc: 0.9961 - val_loss: 0.1113 - val_acc: 0.9646
# Epoch 45/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0027 - acc: 0.9990 - val_loss: 0.0968 - val_acc: 0.9749
# Epoch 46/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0060 - acc: 0.9990 - val_loss: 0.0629 - val_acc: 0.9823
# Epoch 47/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0027 - acc: 0.9990 - val_loss: 0.0770 - val_acc: 0.9749
# Epoch 48/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0057 - acc: 0.9980 - val_loss: 0.1263 - val_acc: 0.9735
# Epoch 49/100
# 32/32 [==============================] - 8s 261ms/step - loss: 0.0148 - acc: 0.9951 - val_loss: 0.2714 - val_acc: 0.9543
# Epoch 50/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0469 - acc: 0.9902Restoring model weights from the end of the best epoch: 40.
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0469 - acc: 0.9902 - val_loss: 1.8382 - val_acc: 0.8215
# Epoch 00050: early stopping
# Maximal validation accuracy: 98.38%

# %%
baseline_model_augmenter_image_df = pd.DataFrame(baseline_model_augmenter_image_history.history)
baseline_model_augmenter_image_df.to_csv( path_model_result + 'baseline_model_augmenter_image_df.csv' )
baseline_model_augmenter_image_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.562857  0.808260  3.046184  0.815634
# 1   0.230623  0.916912  1.600422  0.843658
# 2   0.212414  0.926254  2.478455  0.873156
# 3   0.143173  0.952802  3.724475  0.848083
# 4   0.098592  0.971485  0.808408  0.883481
# 5   0.080464  0.971976  0.969836  0.824484
# 6   0.066491  0.981318  0.321107  0.912979
# 7   0.078564  0.977876  1.597719  0.780236
# 8   0.053939  0.986726  6.997818  0.688791
# 9   0.061248  0.981318  0.275963  0.932153
# 10  0.043911  0.987217  0.470875  0.933628
# 11  0.046081  0.987217  0.333619  0.918879
# 12  0.077173  0.978859  0.672006  0.890855
# 13  0.084315  0.974435  1.093385  0.824484
# 14  0.047945  0.985742  0.491867  0.898230
# 15  0.032452  0.991150  0.480237  0.917404
# 16  0.037246  0.991642  0.268612  0.948378
# 17  0.040779  0.988201  0.217477  0.952802
# 18  0.016161  0.995575  0.443898  0.923304
# 19  0.031656  0.989676  0.168391  0.952802
# 20  0.028634  0.993117  0.203841  0.946903
# 21  0.013057  0.997050  0.203304  0.955752
# 22  0.018450  0.994592  0.398114  0.914454
# 23  0.033919  0.990167  0.160013  0.952802
# 24  0.017205  0.994100  0.160571  0.961652
# 25  0.018423  0.994592  0.153605  0.955752
# 26  0.031877  0.991150  0.977891  0.814159
# 27  0.033664  0.989184  0.334871  0.895280
# 28  0.027374  0.990659  0.172117  0.954277
# 29  0.031884  0.992625  0.319076  0.896755
# 30  0.032498  0.992134  0.310948  0.918879
# 31  0.026595  0.993117  0.245366  0.957227
# 32  0.017998  0.995575  0.084471  0.980826
# 33  0.021224  0.995575  0.101527  0.970501
# 34  0.005685  0.998525  0.055594  0.982301
# 35  0.000662  1.000000  0.057154  0.980826
# 36  0.019437  0.995084  0.089159  0.974926
# 37  0.031531  0.992134  0.113189  0.963127
# 38  0.018478  0.995084  0.270513  0.958702
# 39  0.017649  0.994592  0.063837  0.983776
# 40  0.023315  0.994592  0.111136  0.970501
# 41  0.010645  0.997542  0.110813  0.971976
# 42  0.004373  0.997542  0.084609  0.976401
# 43  0.019537  0.996067  0.111277  0.964602
# 44  0.002716  0.999017  0.096805  0.974926
# 45  0.005971  0.999017  0.062864  0.982301
# 46  0.002717  0.999017  0.077043  0.974926
# 47  0.005714  0.998033  0.126270  0.973451
# 48  0.014816  0.995084  0.271374  0.954277
# 49  0.046858  0.990167  1.838214  0.821534

# %% [markdown]
# ## 3-4. ContrastiveModel - augmenter image

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder = get_encoder()
        # Non-linear MLP as projection head
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(class_num)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(
            name="c_acc"
        )
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        (unlabeled_images, _), (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

# Contrastive pretraining
pretraining_model = ContrastiveModel()
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)

pretraining_history = pretraining_model.fit(
    train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense_8 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 645
# Trainable params: 645
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 11/11 [==============================] - 23s 1s/step - c_loss: 3.3748 - c_acc: 0.2001 - p_loss: 1.5795 - p_acc: 0.2784 - val_p_loss: 1.6372 - val_p_acc: 0.2891
# Epoch 2/100
# 11/11 [==============================] - 11s 999ms/step - c_loss: 2.1930 - c_acc: 0.3813 - p_loss: 1.5890 - p_acc: 0.3551 - val_p_loss: 1.6869 - val_p_acc: 0.3673
# Epoch 3/100
# 11/11 [==============================] - 11s 1s/step - c_loss: 1.6411 - c_acc: 0.5062 - p_loss: 1.4543 - p_acc: 0.4247 - val_p_loss: 1.3131 - val_p_acc: 0.5501
# Epoch 4/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 1.3226 - c_acc: 0.6027 - p_loss: 1.3123 - p_acc: 0.5156 - val_p_loss: 1.2978 - val_p_acc: 0.5280
# Epoch 5/100
# 11/11 [==============================] - 11s 995ms/step - c_loss: 1.0668 - c_acc: 0.6787 - p_loss: 1.3111 - p_acc: 0.5199 - val_p_loss: 1.1804 - val_p_acc: 0.6475
# Epoch 6/100
# 11/11 [==============================] - 11s 985ms/step - c_loss: 0.9844 - c_acc: 0.7214 - p_loss: 1.0917 - p_acc: 0.6406 - val_p_loss: 1.0900 - val_p_acc: 0.6268
# Epoch 7/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.7919 - c_acc: 0.7804 - p_loss: 1.1006 - p_acc: 0.5625 - val_p_loss: 1.1051 - val_p_acc: 0.5664
# Epoch 8/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.7296 - c_acc: 0.8057 - p_loss: 0.9705 - p_acc: 0.6463 - val_p_loss: 0.8218 - val_p_acc: 0.7581
# Epoch 9/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.5998 - c_acc: 0.8444 - p_loss: 0.8119 - p_acc: 0.7315 - val_p_loss: 0.7695 - val_p_acc: 0.7375
# Epoch 10/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.5426 - c_acc: 0.8600 - p_loss: 0.7346 - p_acc: 0.7628 - val_p_loss: 0.7037 - val_p_acc: 0.7714
# Epoch 11/100
# 11/11 [==============================] - 11s 996ms/step - c_loss: 0.5026 - c_acc: 0.8792 - p_loss: 0.7159 - p_acc: 0.7514 - val_p_loss: 0.6548 - val_p_acc: 0.7729
# Epoch 12/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.4450 - c_acc: 0.9005 - p_loss: 0.6470 - p_acc: 0.7898 - val_p_loss: 0.6125 - val_p_acc: 0.8127
# Epoch 13/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.3926 - c_acc: 0.9117 - p_loss: 0.6472 - p_acc: 0.7898 - val_p_loss: 0.5887 - val_p_acc: 0.8097
# Epoch 14/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.3484 - c_acc: 0.9284 - p_loss: 0.5989 - p_acc: 0.8054 - val_p_loss: 0.5526 - val_p_acc: 0.8304
# Epoch 15/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.3221 - c_acc: 0.9407 - p_loss: 0.5571 - p_acc: 0.8153 - val_p_loss: 0.5542 - val_p_acc: 0.8348
# Epoch 16/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.2990 - c_acc: 0.9374 - p_loss: 0.5377 - p_acc: 0.8210 - val_p_loss: 0.5172 - val_p_acc: 0.8407
# Epoch 17/100
# 11/11 [==============================] - 11s 999ms/step - c_loss: 0.2788 - c_acc: 0.9436 - p_loss: 0.4920 - p_acc: 0.8352 - val_p_loss: 0.4976 - val_p_acc: 0.8437
# Epoch 18/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.2580 - c_acc: 0.9544 - p_loss: 0.4721 - p_acc: 0.8438 - val_p_loss: 0.4866 - val_p_acc: 0.8510
# Epoch 19/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.2378 - c_acc: 0.9598 - p_loss: 0.4721 - p_acc: 0.8494 - val_p_loss: 0.4205 - val_p_acc: 0.8658
# Epoch 20/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.2174 - c_acc: 0.9609 - p_loss: 0.4284 - p_acc: 0.8594 - val_p_loss: 0.3996 - val_p_acc: 0.8687
# Epoch 21/100
# 11/11 [==============================] - 11s 985ms/step - c_loss: 0.1974 - c_acc: 0.9736 - p_loss: 0.4417 - p_acc: 0.8438 - val_p_loss: 0.4159 - val_p_acc: 0.8643
# Epoch 22/100
# 11/11 [==============================] - 11s 996ms/step - c_loss: 0.1806 - c_acc: 0.9689 - p_loss: 0.4419 - p_acc: 0.8494 - val_p_loss: 0.3898 - val_p_acc: 0.8761
# Epoch 23/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.1617 - c_acc: 0.9783 - p_loss: 0.4245 - p_acc: 0.8537 - val_p_loss: 0.3696 - val_p_acc: 0.8850
# Epoch 24/100
# 11/11 [==============================] - 11s 989ms/step - c_loss: 0.1857 - c_acc: 0.9743 - p_loss: 0.3963 - p_acc: 0.8707 - val_p_loss: 0.3627 - val_p_acc: 0.8850
# Epoch 25/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.1916 - c_acc: 0.9678 - p_loss: 0.3734 - p_acc: 0.8707 - val_p_loss: 0.3393 - val_p_acc: 0.8820
# Epoch 26/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.1783 - c_acc: 0.9758 - p_loss: 0.3666 - p_acc: 0.8778 - val_p_loss: 0.3389 - val_p_acc: 0.8850
# Epoch 27/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.1555 - c_acc: 0.9772 - p_loss: 0.3614 - p_acc: 0.8778 - val_p_loss: 0.3162 - val_p_acc: 0.8894
# Epoch 28/100
# 11/11 [==============================] - 11s 995ms/step - c_loss: 0.1531 - c_acc: 0.9776 - p_loss: 0.4018 - p_acc: 0.8537 - val_p_loss: 0.3340 - val_p_acc: 0.8938
# Epoch 29/100
# 11/11 [==============================] - 11s 996ms/step - c_loss: 0.1237 - c_acc: 0.9859 - p_loss: 0.3787 - p_acc: 0.8707 - val_p_loss: 0.3082 - val_p_acc: 0.8982
# Epoch 30/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.1216 - c_acc: 0.9859 - p_loss: 0.3418 - p_acc: 0.8736 - val_p_loss: 0.2868 - val_p_acc: 0.8997
# Epoch 31/100
# 11/11 [==============================] - 11s 1000ms/step - c_loss: 0.1077 - c_acc: 0.9891 - p_loss: 0.3360 - p_acc: 0.8835 - val_p_loss: 0.2829 - val_p_acc: 0.9027
# Epoch 32/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.1106 - c_acc: 0.9859 - p_loss: 0.3397 - p_acc: 0.8807 - val_p_loss: 0.2831 - val_p_acc: 0.9041
# Epoch 33/100
# 11/11 [==============================] - 11s 995ms/step - c_loss: 0.1115 - c_acc: 0.9873 - p_loss: 0.3263 - p_acc: 0.8920 - val_p_loss: 0.2911 - val_p_acc: 0.9071
# Epoch 34/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.1171 - c_acc: 0.9848 - p_loss: 0.3158 - p_acc: 0.8935 - val_p_loss: 0.2891 - val_p_acc: 0.9056
# Epoch 35/100
# 11/11 [==============================] - 11s 999ms/step - c_loss: 0.1120 - c_acc: 0.9852 - p_loss: 0.3205 - p_acc: 0.8991 - val_p_loss: 0.2932 - val_p_acc: 0.9100
# Epoch 36/100
# 11/11 [==============================] - 11s 997ms/step - c_loss: 0.1094 - c_acc: 0.9877 - p_loss: 0.3377 - p_acc: 0.9006 - val_p_loss: 0.2904 - val_p_acc: 0.9130
# Epoch 37/100
# 11/11 [==============================] - 11s 995ms/step - c_loss: 0.0930 - c_acc: 0.9917 - p_loss: 0.3148 - p_acc: 0.8977 - val_p_loss: 0.2687 - val_p_acc: 0.9145
# Epoch 38/100
# 11/11 [==============================] - 11s 996ms/step - c_loss: 0.0930 - c_acc: 0.9895 - p_loss: 0.2966 - p_acc: 0.8977 - val_p_loss: 0.2725 - val_p_acc: 0.9159
# Epoch 39/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.0871 - c_acc: 0.9928 - p_loss: 0.2947 - p_acc: 0.9034 - val_p_loss: 0.2745 - val_p_acc: 0.9218
# Epoch 40/100
# 11/11 [==============================] - 11s 998ms/step - c_loss: 0.0995 - c_acc: 0.9884 - p_loss: 0.2919 - p_acc: 0.9148 - val_p_loss: 0.2643 - val_p_acc: 0.9263
# Epoch 41/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0782 - c_acc: 0.9942 - p_loss: 0.2887 - p_acc: 0.9062 - val_p_loss: 0.2725 - val_p_acc: 0.9115
# Epoch 42/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.0765 - c_acc: 0.9935 - p_loss: 0.2928 - p_acc: 0.8963 - val_p_loss: 0.2685 - val_p_acc: 0.9130
# Epoch 43/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.0717 - c_acc: 0.9931 - p_loss: 0.2893 - p_acc: 0.9077 - val_p_loss: 0.2645 - val_p_acc: 0.9174
# Epoch 44/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0687 - c_acc: 0.9949 - p_loss: 0.2892 - p_acc: 0.8920 - val_p_loss: 0.2600 - val_p_acc: 0.9189
# Epoch 45/100
# 11/11 [==============================] - 11s 996ms/step - c_loss: 0.0667 - c_acc: 0.9920 - p_loss: 0.2837 - p_acc: 0.8977 - val_p_loss: 0.2481 - val_p_acc: 0.9292
# Epoch 46/100
# 11/11 [==============================] - 11s 985ms/step - c_loss: 0.0719 - c_acc: 0.9928 - p_loss: 0.2780 - p_acc: 0.9091 - val_p_loss: 0.2498 - val_p_acc: 0.9248
# Epoch 47/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0900 - c_acc: 0.9906 - p_loss: 0.2642 - p_acc: 0.9148 - val_p_loss: 0.2508 - val_p_acc: 0.9218
# Epoch 48/100
# 11/11 [==============================] - 11s 985ms/step - c_loss: 0.0729 - c_acc: 0.9931 - p_loss: 0.2737 - p_acc: 0.9034 - val_p_loss: 0.2286 - val_p_acc: 0.9277
# Epoch 49/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.0734 - c_acc: 0.9953 - p_loss: 0.2537 - p_acc: 0.9119 - val_p_loss: 0.2305 - val_p_acc: 0.9277
# Epoch 50/100
# 11/11 [==============================] - 11s 1000ms/step - c_loss: 0.0739 - c_acc: 0.9902 - p_loss: 0.2582 - p_acc: 0.9190 - val_p_loss: 0.2267 - val_p_acc: 0.9307
# Epoch 51/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.0755 - c_acc: 0.9931 - p_loss: 0.2609 - p_acc: 0.9148 - val_p_loss: 0.2230 - val_p_acc: 0.9307
# Epoch 52/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0732 - c_acc: 0.9949 - p_loss: 0.2537 - p_acc: 0.9190 - val_p_loss: 0.2371 - val_p_acc: 0.9174
# Epoch 53/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0777 - c_acc: 0.9924 - p_loss: 0.2470 - p_acc: 0.9134 - val_p_loss: 0.2268 - val_p_acc: 0.9307
# Epoch 54/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.0741 - c_acc: 0.9931 - p_loss: 0.2597 - p_acc: 0.9119 - val_p_loss: 0.2250 - val_p_acc: 0.9248
# Epoch 55/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.0804 - c_acc: 0.9891 - p_loss: 0.2464 - p_acc: 0.9134 - val_p_loss: 0.2143 - val_p_acc: 0.9218
# Epoch 56/100
# 11/11 [==============================] - 11s 986ms/step - c_loss: 0.0777 - c_acc: 0.9924 - p_loss: 0.2202 - p_acc: 0.9176 - val_p_loss: 0.2181 - val_p_acc: 0.9248
# Epoch 57/100
# 11/11 [==============================] - 11s 985ms/step - c_loss: 0.0724 - c_acc: 0.9938 - p_loss: 0.2178 - p_acc: 0.9219 - val_p_loss: 0.2208 - val_p_acc: 0.9218
# Epoch 58/100
# 11/11 [==============================] - 11s 988ms/step - c_loss: 0.0639 - c_acc: 0.9946 - p_loss: 0.2508 - p_acc: 0.9134 - val_p_loss: 0.2466 - val_p_acc: 0.9292
# Epoch 59/100
# 11/11 [==============================] - 11s 987ms/step - c_loss: 0.0686 - c_acc: 0.9931 - p_loss: 0.2562 - p_acc: 0.9205 - val_p_loss: 0.2632 - val_p_acc: 0.9218
# Epoch 60/100
# 11/11 [==============================] - ETA: 0s - c_loss: 0.0877 - c_acc: 0.9873 - p_loss: 0.2594 - p_acc: 0.9148Restoring model weights from the end of the best epoch: 50.
# 11/11 [==============================] - 11s 994ms/step - c_loss: 0.0877 - c_acc: 0.9873 - p_loss: 0.2594 - p_acc: 0.9148 - val_p_loss: 0.2442 - val_p_acc: 0.9204
# Epoch 00060: early stopping
# Maximal validation accuracy: 93.07%

# %%
pretraining_model_df = pd.DataFrame(pretraining_history.history)
pretraining_model_df.to_csv( path_model_result + 'pretraining_model_df.csv' )
pretraining_model_df
# Out:
#       c_loss     c_acc    p_loss     p_acc  val_p_loss  val_p_acc
# 0   3.374825  0.200072  1.579532  0.278409    1.637241   0.289086
# 1   2.193048  0.381331  1.588976  0.355114    1.686883   0.367257
# 2   1.641075  0.506150  1.454251  0.424716    1.313137   0.550147
# 3   1.322584  0.602750  1.312298  0.515625    1.297770   0.528024
# 4   1.066760  0.678726  1.311123  0.519886    1.180363   0.647493
# 5   0.984432  0.721418  1.091689  0.640625    1.089988   0.626844
# 6   0.791873  0.780391  1.100602  0.562500    1.105130   0.566372
# 7   0.729613  0.805716  0.970460  0.646307    0.821830   0.758112
# 8   0.599803  0.844428  0.811943  0.731534    0.769535   0.737463
# 9   0.542554  0.859986  0.734614  0.762784    0.703731   0.771386
# 10  0.502552  0.879161  0.715887  0.751420    0.654775   0.772861
# 11  0.445006  0.900506  0.646952  0.789773    0.612536   0.812684
# 12  0.392574  0.911722  0.647248  0.789773    0.588670   0.809735
# 13  0.348370  0.928365  0.598867  0.805398    0.552594   0.830383
# 14  0.322113  0.940666  0.557089  0.815341    0.554166   0.834808
# 15  0.298983  0.937410  0.537711  0.821023    0.517242   0.840708
# 16  0.278766  0.943560  0.492009  0.835227    0.497639   0.843658
# 17  0.258026  0.954414  0.472079  0.843750    0.486641   0.851032
# 18  0.237786  0.959841  0.472069  0.849432    0.420526   0.865782
# 19  0.217422  0.960926  0.428379  0.859375    0.399580   0.868732
# 20  0.197358  0.973589  0.441747  0.843750    0.415896   0.864307
# 21  0.180574  0.968886  0.441936  0.849432    0.389832   0.876106
# 22  0.161663  0.978292  0.424525  0.853693    0.369630   0.884956
# 23  0.185688  0.974313  0.396314  0.870739    0.362699   0.884956
# 24  0.191589  0.967800  0.373363  0.870739    0.339304   0.882006
# 25  0.178307  0.975760  0.366606  0.877841    0.338889   0.884956
# 26  0.155504  0.977207  0.361424  0.877841    0.316188   0.889381
# 27  0.153058  0.977569  0.401786  0.853693    0.333961   0.893805
# 28  0.123708  0.985890  0.378710  0.870739    0.308199   0.898230
# 29  0.121582  0.985890  0.341834  0.873580    0.286805   0.899705
# 30  0.107674  0.989146  0.335972  0.883523    0.282936   0.902655
# 31  0.110568  0.985890  0.339670  0.880682    0.283053   0.904130
# 32  0.111537  0.987337  0.326320  0.892045    0.291072   0.907080
# 33  0.117080  0.984805  0.315847  0.893466    0.289114   0.905605
# 34  0.111960  0.985166  0.320469  0.899148    0.293220   0.910029
# 35  0.109379  0.987699  0.337669  0.900568    0.290351   0.912979
# 36  0.093022  0.991679  0.314832  0.897727    0.268725   0.914454
# 37  0.093030  0.989508  0.296578  0.897727    0.272481   0.915929
# 38  0.087102  0.992764  0.294673  0.903409    0.274541   0.921829
# 39  0.099467  0.988423  0.291897  0.914773    0.264291   0.926254
# 40  0.078232  0.994211  0.288733  0.906250    0.272457   0.911504
# 41  0.076514  0.993488  0.292750  0.896307    0.268474   0.912979
# 42  0.071651  0.993126  0.289348  0.907670    0.264530   0.917404
# 43  0.068650  0.994935  0.289186  0.892045    0.259950   0.918879
# 44  0.066667  0.992041  0.283679  0.897727    0.248139   0.929204
# 45  0.071872  0.992764  0.278003  0.909091    0.249833   0.924779
# 46  0.089982  0.990593  0.264154  0.914773    0.250789   0.921829
# 47  0.072851  0.993126  0.273658  0.903409    0.228572   0.927729
# 48  0.073438  0.995297  0.253709  0.911932    0.230508   0.927729
# 49  0.073935  0.990232  0.258228  0.919034    0.226708   0.930678
# 50  0.075509  0.993126  0.260890  0.914773    0.222987   0.930678
# 51  0.073170  0.994935  0.253735  0.919034    0.237123   0.917404
# 52  0.077684  0.992402  0.247038  0.913352    0.226833   0.930678
# 53  0.074138  0.993126  0.259742  0.911932    0.224974   0.924779
# 54  0.080384  0.989146  0.246420  0.913352    0.214295   0.921829
# 55  0.077740  0.992402  0.220157  0.917614    0.218083   0.924779
# 56  0.072365  0.993850  0.217810  0.921875    0.220760   0.921829
# 57  0.063883  0.994573  0.250787  0.913352    0.246625   0.929204
# 58  0.068553  0.993126  0.256246  0.920455    0.263182   0.921829
# 59  0.087662  0.987337  0.259351  0.914773    0.244154   0.920354

# %% [markdown]
# ## 3-5. Finetuning_model - augmenter image

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(class_num),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# 32/32 [==============================] - ETA: 0s - loss: 0.3877 - acc: 0.8707WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 14s 286ms/step - loss: 0.3877 - acc: 0.8707 - val_loss: 0.6347 - val_acc: 0.8820
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 0.1583 - acc: 0.9444WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 265ms/step - loss: 0.1583 - acc: 0.9444 - val_loss: 4.2311 - val_acc: 0.6372
# Epoch 3/100
# 32/32 [==============================] - ETA: 0s - loss: 0.1283 - acc: 0.9543WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.1283 - acc: 0.9543 - val_loss: 1.2708 - val_acc: 0.8540
# Epoch 4/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0968 - acc: 0.9661WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0968 - acc: 0.9661 - val_loss: 1.1998 - val_acc: 0.8156
# Epoch 5/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0932 - acc: 0.9666WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0932 - acc: 0.9666 - val_loss: 1.5124 - val_acc: 0.8171
# Epoch 6/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0709 - acc: 0.9798WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0709 - acc: 0.9798 - val_loss: 1.4049 - val_acc: 0.7994
# Epoch 7/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0601 - acc: 0.9774WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0601 - acc: 0.9774 - val_loss: 0.3927 - val_acc: 0.9233
# Epoch 8/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0367 - acc: 0.9862WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0367 - acc: 0.9862 - val_loss: 0.2094 - val_acc: 0.9322
# Epoch 9/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0453 - acc: 0.9867WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0453 - acc: 0.9867 - val_loss: 0.0854 - val_acc: 0.9764
# Epoch 10/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0489 - acc: 0.9857WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0489 - acc: 0.9857 - val_loss: 0.2884 - val_acc: 0.9292
# Epoch 11/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0411 - acc: 0.9867WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0411 - acc: 0.9867 - val_loss: 0.1205 - val_acc: 0.9602
# Epoch 12/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0247 - acc: 0.9921WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0247 - acc: 0.9921 - val_loss: 0.1020 - val_acc: 0.9735
# Epoch 13/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0351 - acc: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0351 - acc: 0.9892 - val_loss: 0.4752 - val_acc: 0.9233
# Epoch 14/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0585 - acc: 0.9828WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0585 - acc: 0.9828 - val_loss: 1.1724 - val_acc: 0.8614
# Epoch 15/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0300 - acc: 0.9912WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0300 - acc: 0.9912 - val_loss: 0.2224 - val_acc: 0.9484
# Epoch 16/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0350 - acc: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0350 - acc: 0.9882 - val_loss: 0.2442 - val_acc: 0.9558
# Epoch 17/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0366 - acc: 0.9897WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0366 - acc: 0.9897 - val_loss: 0.2386 - val_acc: 0.9572
# Epoch 18/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0459 - acc: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0459 - acc: 0.9892 - val_loss: 0.5663 - val_acc: 0.9056
# Epoch 19/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0269 - acc: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0269 - acc: 0.9907 - val_loss: 1.3417 - val_acc: 0.8658
# Epoch 20/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0296 - acc: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0296 - acc: 0.9907 - val_loss: 0.1940 - val_acc: 0.9499
# Epoch 21/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0271 - acc: 0.9931WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0271 - acc: 0.9931 - val_loss: 0.1429 - val_acc: 0.9558
# Epoch 22/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0186 - acc: 0.9936WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0186 - acc: 0.9936 - val_loss: 0.1149 - val_acc: 0.9720
# Epoch 23/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0099 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0099 - acc: 0.9975 - val_loss: 0.2010 - val_acc: 0.9558
# Epoch 24/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0099 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0099 - acc: 0.9966 - val_loss: 0.1027 - val_acc: 0.9735
# Epoch 25/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0380 - acc: 0.9921WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0380 - acc: 0.9921 - val_loss: 0.1453 - val_acc: 0.9676
# Epoch 26/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0273 - acc: 0.9926WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0273 - acc: 0.9926 - val_loss: 0.1330 - val_acc: 0.9749
# Epoch 27/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0190 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0190 - acc: 0.9946 - val_loss: 1.4652 - val_acc: 0.8923
# Epoch 28/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0228 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0228 - acc: 0.9966 - val_loss: 0.1539 - val_acc: 0.9661
# Epoch 29/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0203 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0203 - acc: 0.9951 - val_loss: 0.3188 - val_acc: 0.9646
# Epoch 30/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0295 - acc: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0295 - acc: 0.9907 - val_loss: 0.1564 - val_acc: 0.9735
# Epoch 31/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0070 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0070 - acc: 0.9980 - val_loss: 0.1359 - val_acc: 0.9720
# Epoch 32/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0323 - acc: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0323 - acc: 0.9907 - val_loss: 0.1232 - val_acc: 0.9749
# Epoch 33/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0191 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0191 - acc: 0.9946 - val_loss: 0.1788 - val_acc: 0.9499
# Epoch 34/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0119 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0119 - acc: 0.9975 - val_loss: 0.1920 - val_acc: 0.9410
# Epoch 35/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0494 - acc: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0494 - acc: 0.9882 - val_loss: 1.1681 - val_acc: 0.8378
# Epoch 36/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0785 - acc: 0.9794WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0785 - acc: 0.9794 - val_loss: 0.7578 - val_acc: 0.8230
# Epoch 37/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0470 - acc: 0.9857WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0470 - acc: 0.9857 - val_loss: 1.7533 - val_acc: 0.8245
# Epoch 38/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0299 - acc: 0.9897WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0299 - acc: 0.9897 - val_loss: 1.6250 - val_acc: 0.8142
# Epoch 39/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0400 - acc: 0.9862WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0400 - acc: 0.9862 - val_loss: 1.9208 - val_acc: 0.7935
# Epoch 40/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0413 - acc: 0.9887WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0413 - acc: 0.9887 - val_loss: 0.3683 - val_acc: 0.9351
# Epoch 41/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0182 - acc: 0.9956WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0182 - acc: 0.9956 - val_loss: 0.2678 - val_acc: 0.9543
# Epoch 42/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0051 - acc: 0.9980 - val_loss: 0.1298 - val_acc: 0.9735
# Epoch 43/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0056 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0056 - acc: 0.9980 - val_loss: 0.1289 - val_acc: 0.9735
# Epoch 44/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0022 - acc: 0.9990 - val_loss: 0.1339 - val_acc: 0.9764
# Epoch 45/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0170 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0170 - acc: 0.9966 - val_loss: 0.1069 - val_acc: 0.9794
# Epoch 46/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0126 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0126 - acc: 0.9966 - val_loss: 2.1460 - val_acc: 0.8422
# Epoch 47/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0250 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0250 - acc: 0.9941 - val_loss: 0.1224 - val_acc: 0.9779
# Epoch 48/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0166 - acc: 0.9961WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0166 - acc: 0.9961 - val_loss: 0.1717 - val_acc: 0.9661
# Epoch 49/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0054 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0054 - acc: 0.9990 - val_loss: 0.0640 - val_acc: 0.9853
# Epoch 50/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0655 - val_acc: 0.9882
# Epoch 51/100
# 32/32 [==============================] - ETA: 0s - loss: 7.3631e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 7.3631e-04 - acc: 1.0000 - val_loss: 0.0817 - val_acc: 0.9838
# Epoch 52/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0886 - val_acc: 0.9838
# Epoch 53/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0012 - acc: 0.9995    WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0012 - acc: 0.9995 - val_loss: 0.1094 - val_acc: 0.9808
# Epoch 54/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0016 - acc: 0.9995 - val_loss: 0.1927 - val_acc: 0.9720
# Epoch 55/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0116 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0116 - acc: 0.9966 - val_loss: 0.1037 - val_acc: 0.9794
# Epoch 56/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0078 - acc: 0.9971WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0078 - acc: 0.9971 - val_loss: 0.2540 - val_acc: 0.9558
# Epoch 57/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0150 - acc: 0.9971WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0150 - acc: 0.9971 - val_loss: 0.1128 - val_acc: 0.9720
# Epoch 58/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0049 - acc: 0.9990 - val_loss: 0.0881 - val_acc: 0.9794
# Epoch 59/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0045 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0045 - acc: 0.9985 - val_loss: 0.0828 - val_acc: 0.9764
# Epoch 60/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0061 - acc: 0.9980 - val_loss: 0.0986 - val_acc: 0.9735
# Epoch 61/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0060 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0060 - acc: 0.9985 - val_loss: 0.0502 - val_acc: 0.9882
# Epoch 62/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0046 - acc: 0.9980 - val_loss: 0.0504 - val_acc: 0.9867
# Epoch 63/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0106 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0106 - acc: 0.9985 - val_loss: 0.0692 - val_acc: 0.9838
# Epoch 64/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0103 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0103 - acc: 0.9975 - val_loss: 0.1563 - val_acc: 0.9749
# Epoch 65/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0068 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0068 - acc: 0.9975 - val_loss: 0.0583 - val_acc: 0.9853
# Epoch 66/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0209 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0209 - acc: 0.9941 - val_loss: 0.8070 - val_acc: 0.9322
# Epoch 67/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0107 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0107 - acc: 0.9966 - val_loss: 2.3734 - val_acc: 0.8864
# Epoch 68/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0167 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0167 - acc: 0.9941 - val_loss: 0.5888 - val_acc: 0.9204
# Epoch 69/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0026 - acc: 0.9995 - val_loss: 0.1587 - val_acc: 0.9705
# Epoch 70/100
# 32/32 [==============================] - ETA: 0s - loss: 3.9050e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 3.9050e-04 - acc: 1.0000 - val_loss: 0.1002 - val_acc: 0.9794
# Epoch 71/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0034 - acc: 0.9990 - val_loss: 0.2770 - val_acc: 0.9602
# Epoch 72/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0151 - acc: 0.9961WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0151 - acc: 0.9961 - val_loss: 0.2463 - val_acc: 0.9617
# Epoch 73/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0192 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0192 - acc: 0.9951 - val_loss: 0.1582 - val_acc: 0.9661
# Epoch 74/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0315 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0315 - acc: 0.9951 - val_loss: 0.1359 - val_acc: 0.9779
# Epoch 75/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0153 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0153 - acc: 0.9946 - val_loss: 0.6359 - val_acc: 0.9189
# Epoch 76/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0220 - acc: 0.9916WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0220 - acc: 0.9916 - val_loss: 0.1012 - val_acc: 0.9705
# Epoch 77/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0433 - acc: 0.9897WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0433 - acc: 0.9897 - val_loss: 0.2928 - val_acc: 0.9572
# Epoch 78/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0331 - acc: 0.9897WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0331 - acc: 0.9897 - val_loss: 0.7295 - val_acc: 0.8953
# Epoch 79/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0314 - acc: 0.9931WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0314 - acc: 0.9931 - val_loss: 0.3961 - val_acc: 0.9440
# Epoch 80/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0073 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0073 - acc: 0.9985 - val_loss: 0.1678 - val_acc: 0.9705
# Epoch 81/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0089 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0089 - acc: 0.9975 - val_loss: 0.1531 - val_acc: 0.9690
# Epoch 82/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0109 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0109 - acc: 0.9966 - val_loss: 0.0879 - val_acc: 0.9794
# Epoch 83/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0133 - acc: 0.9956WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0133 - acc: 0.9956 - val_loss: 0.1044 - val_acc: 0.9764
# Epoch 84/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0177 - acc: 0.9926WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0177 - acc: 0.9926 - val_loss: 0.1383 - val_acc: 0.9646
# Epoch 85/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0110 - acc: 0.9956WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0110 - acc: 0.9956 - val_loss: 0.0933 - val_acc: 0.9661
# Epoch 86/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0028 - acc: 0.9985 - val_loss: 0.1313 - val_acc: 0.9676
# Epoch 87/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0076 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0076 - acc: 0.9990 - val_loss: 0.0540 - val_acc: 0.9897
# Epoch 88/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0206 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0206 - acc: 0.9946 - val_loss: 1.6624 - val_acc: 0.8702
# Epoch 89/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0283 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0283 - acc: 0.9946 - val_loss: 0.1683 - val_acc: 0.9720
# Epoch 90/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0202 - acc: 0.9946WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0202 - acc: 0.9946 - val_loss: 0.2876 - val_acc: 0.9454
# Epoch 91/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0178 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 262ms/step - loss: 0.0178 - acc: 0.9941 - val_loss: 0.5758 - val_acc: 0.9189
# Epoch 92/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0276 - acc: 0.9907WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0276 - acc: 0.9907 - val_loss: 0.1466 - val_acc: 0.9602
# Epoch 93/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0053 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0053 - acc: 0.9985 - val_loss: 0.1457 - val_acc: 0.9690
# Epoch 94/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9985WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0025 - acc: 0.9985 - val_loss: 0.0972 - val_acc: 0.9794
# Epoch 95/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0027 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0027 - acc: 0.9990 - val_loss: 0.0682 - val_acc: 0.9853
# Epoch 96/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0133 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0133 - acc: 0.9980 - val_loss: 0.1388 - val_acc: 0.9735
# Epoch 97/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0060 - acc: 0.9980WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0060 - acc: 0.9980 - val_loss: 0.1105 - val_acc: 0.9705
# Epoch 98/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0011 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.1115 - val_acc: 0.9735
# Epoch 99/100
# 32/32 [==============================] - ETA: 0s - loss: 3.4924e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 3.4924e-04 - acc: 1.0000 - val_loss: 0.1089 - val_acc: 0.9764
# Epoch 100/100
# 32/32 [==============================] - ETA: 0s - loss: 1.4946e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 32/32 [==============================] - 8s 263ms/step - loss: 1.4946e-04 - acc: 1.0000 - val_loss: 0.0965 - val_acc: 0.9749
# Maximal validation accuracy: 98.97%

# %%
finetuning_model_df = pd.DataFrame(finetuning_history.history)
finetuning_model_df.to_csv( path_model_result + 'finetuning_model_df.csv' )
finetuning_model_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.387682  0.870698  0.634669  0.882006
# 1   0.158279  0.944444  4.231102  0.637168
# 2   0.128293  0.954277  1.270784  0.853982
# 3   0.096846  0.966077  1.199804  0.815634
# 4   0.093208  0.966568  1.512386  0.817109
# ..       ...       ...       ...       ...
# 95  0.013263  0.998033  0.138829  0.973451
# 96  0.006035  0.998033  0.110459  0.970501
# 97  0.001121  1.000000  0.111484  0.973451
# 98  0.000349  1.000000  0.108925  0.976401
# 99  0.000149  1.000000  0.096517  0.974926
#
# [100 rows x 4 columns]

# %% [markdown]
# ## 4. Result Report

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history):
    for metric_key, metric_name in zip(["acc", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_model_original_image_history.history[f"val_{metric_key}"], label="original_image baseline"
        )
        plt.plot(
            baseline_model_augmenter_image_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")

plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history)

# %%
print (max(baseline_model_original_image_history.history["val_acc"]) * 100)
print (max(baseline_model_augmenter_image_history.history["val_acc"]) * 100)
print (max(pretraining_history.history["val_p_acc"]) * 100)
print (max(finetuning_history.history["val_acc"]) * 100)
# Out:
# 98.3775794506073
# 98.3775794506073
# 93.06784868240356
# 98.9675521850586

# %% [markdown]
# ## 5. Model Save

# %%
save_model = keras.Sequential(
    [
        pretraining_model.encoder,
    ],
    name="pretraining_model",
)

save_model.summary()
# Out:
# Model: "pretraining_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 128)               21123752
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.ckpt' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: gdrive/My Drive/Research_3_1_2/model_result/3 - SimCLR_model_result - 1/pretraining_model_encoder.ckpt/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
