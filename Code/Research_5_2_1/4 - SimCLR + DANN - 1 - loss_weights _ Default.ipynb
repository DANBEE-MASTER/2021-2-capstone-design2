# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
from keras.utils import np_utils
import tensorflow as tf
import pandas as pd
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
import tqdm

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3515258913891993261
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 6375921636287246543
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Tue Dec 14 02:35:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 5
imagenet_patience_num = 30

#base_path = ''
base_path = 'gdrive/My Drive/Research_5_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/4 - SimCLR + DANN_result - 1/'
model_path = path_model_result + 'model_'

basemodel_load = tf.keras.models.load_model( 'gdrive/My Drive/Research_5_2_1/model_result/3 - SimCLR_result/pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Data Setting

# %% [markdown]
# ## 2-1. Data Load

# %%
combined_train_imgs = np.load(path_data + 'combined_train_imgs.npy')
combined_train_labels = np.load(path_data + 'combined_train_labels.npy')
combined_train_domain = np.load(path_data + 'combined_train_domain.npy')

combined_Valid_imgs = np.load(path_data + 'combined_Valid_imgs.npy')
combined_Valid_labels = np.load(path_data + 'combined_Valid_labels.npy')
combined_Valid_domain = np.load(path_data + 'combined_Valid_domain.npy')

combined_test_imgs = np.load(path_data + 'combined_test_imgs.npy')
combined_test_labels = np.load(path_data + 'combined_test_labels.npy')
combined_test_domain = np.load(path_data + 'combined_test_domain.npy')

# %%
sample_weights_class_label = np.load(path_data + 'sample_weights_class_label.npy')
sample_weights_domain_label = np.load(path_data + 'sample_weights_domain_label.npy')

# %%
print(combined_train_imgs.shape)
print(combined_train_labels.shape)
print(combined_train_domain.shape)
print()
print(combined_Valid_imgs.shape)
print(combined_Valid_labels.shape)
print(combined_Valid_domain.shape)
print()
print(sample_weights_class_label.shape)
print(sample_weights_domain_label.shape)
# Out:
# (4308, 128, 128, 3)
# (4308, 5)
# (4308, 2)
#
# (1436, 128, 128, 3)
# (1436, 5)
# (1436, 2)
#
# (4308,)
# (4308,)

# %%
xValid_S = np.load(path_data + 'xValid_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')

xValid_T = np.load(path_data + 'xValid_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')

Valid_S_domain = np.load(path_data + 'Valid_S_domain.npy')
Valid_T_domain = np.load(path_data + 'Valid_T_domain.npy')

xValid_S = xValid_S.astype('float32')/255
yValid_S = np_utils.to_categorical(yValid_S, class_num)

xValid_T = xValid_T.astype('float32')/255
yValid_T = np_utils.to_categorical(yValid_T, class_num)

# %%
print(xValid_S.shape, yValid_S.shape)
print(xValid_T.shape, yValid_T.shape)
print()
print(Valid_S_domain.shape)
print(Valid_T_domain.shape)
# Out:
# (678, 128, 128, 3) (678, 5)
# (758, 128, 128, 3) (758, 5)
#
# (678, 2)
# (758, 2)

# %%
xTest_S = np.load(path_data + 'xTest_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTest_T = np.load(path_data + 'xTest_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

test_S_domain = np.load(path_data + 'test_S_domain.npy')
test_T_domain = np.load(path_data + 'test_T_domain.npy')

xTest_S = xTest_S.astype('float32')/255
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTest_T = xTest_T.astype('float32')/255
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTest_S.shape, yTest_S.shape)
print(xTest_T.shape, yTest_T.shape)
print()
print(test_S_domain.shape)
print(test_T_domain.shape)
# Out:
# (678, 128, 128, 3) (678, 5)
# (758, 128, 128, 3) (758, 5)
#
# (678, 2)
# (758, 2)

# %% [markdown]
# # 3. DANN Network

# %% [markdown]
# ## 3-1. DANN Setting

# %%
@tf.custom_gradient
def GradientReversalOperator(x):
    def grad(dy):
        return -1 * dy
    return x, grad

class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()
    def call(self, inputs):
        return GradientReversalOperator(inputs)

def classifier(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(64, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out) 
    return classifier_output

def discriminator(inp):
    out = Dense(32, activation="relu")(inp)
    discriminator_output = Dense(2, activation="softmax", name="discriminator_output")(out)
    return discriminator_output

def dann():    
    inp = Input(shape=(image_size, image_size, image_channels))
    feature_output = basemodel_load(inp)
    classifier_output = classifier(feature_output)
    grl_layer = GradientReversalLayer()(feature_output)
    discriminator_output = discriminator(grl_layer)
    model = tf.keras.models.Model(inputs=inp, outputs=[discriminator_output,classifier_output])
    return model

# %% [markdown]
# ## 3-2. Model Training

# %%
model = dann()
#print(S_dann_model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
model.compile(optimizer='adam', 
              loss={'discriminator_output': 'binary_crossentropy',
                    'classifier_output': 'categorical_crossentropy'},
              metrics = ['accuracy'])


ES = EarlyStopping(monitor='val_classifier_output_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)
MC = ModelCheckpoint( path_model_result + 'model_{epoch}.h5', monitor='val_classifier_output_accuracy', mode='max', verbose=1, save_best_only=False, save_freq='epoch')


dann_model = model.fit(combined_train_imgs,[combined_train_domain,combined_train_labels], 
                        sample_weight=[sample_weights_domain_label, sample_weights_class_label],
                        epochs=num_epochs, batch_size=batch_size, validation_data=(combined_Valid_imgs,[combined_Valid_domain,combined_Valid_labels]), callbacks=[ES, MC])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(dann_model.history["val_classifier_output_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 68/68 [==============================] - ETA: 0s - loss: 1.2709 - discriminator_output_loss: 0.9971 - classifier_output_loss: 0.2738 - discriminator_output_accuracy: 0.4225 - classifier_output_accuracy: 0.5754
# Epoch 00001: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 68/68 [==============================] - 33s 294ms/step - loss: 1.2709 - discriminator_output_loss: 0.9971 - classifier_output_loss: 0.2738 - discriminator_output_accuracy: 0.4225 - classifier_output_accuracy: 0.5754 - val_loss: 19.8409 - val_discriminator_output_loss: 2.5649 - val_classifier_output_loss: 17.2760 - val_discriminator_output_accuracy: 0.6825 - val_classifier_output_accuracy: 0.5794
# Epoch 2/100
# 68/68 [==============================] - ETA: 0s - loss: 0.8843 - discriminator_output_loss: 0.7620 - classifier_output_loss: 0.1222 - discriminator_output_accuracy: 0.5246 - classifier_output_accuracy: 0.6026
# Epoch 00002: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# 68/68 [==============================] - 18s 268ms/step - loss: 0.8843 - discriminator_output_loss: 0.7620 - classifier_output_loss: 0.1222 - discriminator_output_accuracy: 0.5246 - classifier_output_accuracy: 0.6026 - val_loss: 19.7425 - val_discriminator_output_loss: 6.0594 - val_classifier_output_loss: 13.6831 - val_discriminator_output_accuracy: 0.4596 - val_classifier_output_accuracy: 0.4937
# Epoch 3/100
# 68/68 [==============================] - ETA: 0s - loss: 0.8165 - discriminator_output_loss: 0.7045 - classifier_output_loss: 0.1120 - discriminator_output_accuracy: 0.5364 - classifier_output_accuracy: 0.6005
# Epoch 00003: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
h5
# 68/68 [==============================] - 18s 269ms/step - loss: 0.6940 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0024 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6200 - val_loss: 3.1888 - val_discriminator_output_loss: 0.6919 - val_classifier_output_loss: 2.4969 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.6052
# Epoch 39/100
# 68/68 [==============================] - ETA: 0s - loss: 0.6948 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0032 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6247
# Epoch 00039: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_39.h5
# 68/68 [==============================] - 18s 269ms/step - loss: 0.6948 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0032 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6247 - val_loss: 2.9314 - val_discriminator_output_loss: 0.6909 - val_classifier_output_loss: 2.2404 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.6163
# Epoch 40/100
# 68/68 [==============================] - ETA: 0s - loss: 0.6996 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0080 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6230
# Epoch 00040: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_40.h5
# 68/68 [==============================] - 18s 269ms/step - loss: 0.6996 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0080 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6230 - val_loss: 3.1176 - val_discriminator_output_loss: 0.6918 - val_classifier_output_loss: 2.4258 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.5857
# Epoch 41/100
# 68/68 [==============================] - ETA: 0s - loss: 0.6988 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0072 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6263
# Epoch 00041: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_41.h5
# 68/68 [==============================] - 18s 268ms/step - loss: 0.6988 - discriminator_output_loss: 0.6916 - classifier_output_loss: 0.0072 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6263 - val_loss: 2.9709 - val_discriminator_output_loss: 0.6910 - val_classifier_output_loss: 2.2798 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.6003
# Epoch 42/100
# 68/68 [==============================] - ETA: 0s - loss: 0.6973 - discriminator_output_loss: 0.6923 - classifier_output_loss: 0.0049 - discriminator_output_accuracy: 0.5162 - classifier_output_accuracy: 0.6161
# Epoch 00042: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_42.h5
# 68/68 [==============================] - 18s 268ms/step - loss: 0.6973 - discriminator_output_loss: 0.6923 - classifier_output_loss: 0.0049 - discriminator_output_accuracy: 0.5162 - classifier_output_accuracy: 0.6161 - val_loss: 3.0773 - val_discriminator_output_loss: 0.6917 - val_classifier_output_loss: 2.3856 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.6497
# Epoch 43/100
# 68/68 [==============================] - ETA: 0s - loss: 0.6996 - discriminator_output_loss: 0.6915 - classifier_output_loss: 0.0081 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6237Restoring model weights from the end of the best epoch: 13.
#
# Epoch 00043: saving model to gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_43.h5
# 68/68 [==============================] - 18s 270ms/step - loss: 0.6996 - discriminator_output_loss: 0.6915 - classifier_output_loss: 0.0081 - discriminator_output_accuracy: 0.5279 - classifier_output_accuracy: 0.6237 - val_loss: 2.7285 - val_discriminator_output_loss: 0.6855 - val_classifier_output_loss: 2.0429 - val_discriminator_output_accuracy: 0.5279 - val_classifier_output_accuracy: 0.6226
# Epoch 00043: early stopping
# Maximal validation accuracy: 65.95%

# %%
dann_model_df = pd.DataFrame(dann_model.history)
dann_model_df.to_csv( path_model_result + 'history_df.csv' )
dann_model_df
# Out:
#         loss  ...  val_classifier_output_accuracy
# 0   1.270881  ...                        0.579387
# 1   0.884252  ...                        0.493733
# 2   0.816514  ...                        0.332869
# 3   0.768335  ...                        0.550139
# 4   0.791259  ...                        0.571031
# 5   0.733439  ...                        0.625348
# 6   0.732802  ...                        0.587047
# 7   0.788845  ...                        0.260446
# 8   0.792323  ...                        0.565460
# 9   0.732630  ...                        0.616992
# 10  0.716639  ...                        0.618384
# 11  0.712323  ...                        0.596797
# 12  0.726667  ...                        0.659471
# 13  0.699931  ...                        0.582869
# 14  0.745590  ...                        0.468663
# 15  0.738946  ...                        0.594011
# 16  0.703504  ...                        0.561281
# 17  0.702530  ...                        0.536908
# 18  0.699563  ...                        0.611421
# 19  0.699075  ...                        0.573120
# 20  0.704537  ...                        0.568245
# 21  0.692465  ...                        0.578691
# 22  0.688309  ...                        0.616295
# 23  0.726407  ...                        0.555710
# 24  0.727612  ...                        0.622563
# 25  0.704699  ...                        0.628830
# 26  0.705069  ...                        0.624652
# 27  0.707525  ...                        0.599582
# 28  0.734025  ...                        0.517409
# 29  0.707140  ...                        0.633008
# 30  0.750420  ...                        0.636490
# 31  0.757365  ...                        0.494429
# 32  0.736315  ...                        0.366992
# 33  0.699801  ...                        0.644847
# 34  0.694481  ...                        0.628134
# 35  0.701764  ...                        0.603760
# 36  0.700683  ...                        0.592618
# 37  0.694000  ...                        0.605153
# 38  0.694793  ...                        0.616295
# 39  0.699635  ...                        0.585655
# 40  0.698827  ...                        0.600279
# 41  0.697273  ...                        0.649721
# 42  0.699635  ...                        0.622563
#
# [43 rows x 10 columns]

# %%
dann_model_df.loc[:, ['loss', 'discriminator_output_loss', 'classifier_output_loss', 'val_loss']].plot();
plt.savefig(path_model_result + 'loss,val_loss.png')
dann_model_df.loc[:, ['discriminator_output_accuracy', 'classifier_output_accuracy', 'val_discriminator_output_accuracy', 'val_classifier_output_accuracy']].plot();
plt.savefig(path_model_result + 'accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(dann_model_df['val_loss'].min()))
print("Maximum val_classifier_output_accuracy: {}".format(dann_model_df['val_classifier_output_accuracy'].max()))
# Out:
# Minimum validation loss: 2.6033108234405518
# Maximum val_classifier_output_accuracy: 0.6594707369804382

# %%
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 50ms/step - loss: 1.4834 - discriminator_output_loss: 1.3191 - classifier_output_loss: 0.1644 - discriminator_output_accuracy: 0.1858 - classifier_output_accuracy: 0.9705
# dann_source_acc : 97.05015 %

# %%
print("Evaluate on test data")
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 24/24 [==============================] - 1s 36ms/step - loss: 6.7082 - discriminator_output_loss: 0.6597 - classifier_output_loss: 6.0485 - discriminator_output_accuracy: 0.8034 - classifier_output_accuracy: 0.3430
# dann_target_acc : 34.30079 %

# %% [markdown]
# ## 3-3. Load_weights and epoch_train,epoch_evaluate

# %%
def epoch_train():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xValid_S,[Valid_S_domain, yValid_S] )
        target_acc = model.evaluate( xValid_T,[Valid_T_domain, yValid_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_train_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_train_df.to_csv( path_model_result + 'epoch_train_df_df.csv' )
    epoch_train_df

    return ()

# %%
epoch_train()
# Out:
# 43
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.8921 - discriminator_output_loss: 0.2943 - classifier_output_loss: 1.5978 - discriminator_output_accuracy: 0.9985 - classifier_output_accuracy: 0.8245
# 24/24 [==============================] - 1s 30ms/step - loss: 35.8954 - discriminator_output_loss: 4.5959 - classifier_output_loss: 31.2994 - discriminator_output_accuracy: 0.3997 - classifier_output_accuracy: 0.3602
# dann_source_acc : 82.44838 %
# dann_target_acc : 36.01583 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 27.7705 - discriminator_output_loss: 12.0321 - classifier_output_loss: 15.7384 - discriminator_output_accuracy: 0.1563 - classifier_output_accuracy: 0.7198
# 24/24 [==============================] - 1s 30ms/step - loss: 12.5619 - discriminator_output_loss: 0.7171 - classifier_output_loss: 11.8448 - discriminator_output_accuracy: 0.7309 - classifier_output_accuracy: 0.2916
# dann_source_acc : 71.9764 %
# dann_target_acc : 29.15567 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# 22/22 [==============================] - 1s 30ms/step - loss:
%
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8083 - discriminator_output_loss: 0.7689 - classifier_output_loss: 0.0394 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9897
# 24/24 [==============================] - 1s 30ms/step - loss: 4.8519 - discriminator_output_loss: 0.6180 - classifier_output_loss: 4.2340 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2731
# dann_source_acc : 98.96755 %
# dann_target_acc : 27.30871 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.9976 - discriminator_output_loss: 0.7616 - classifier_output_loss: 0.2360 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9617
# 24/24 [==============================] - 1s 30ms/step - loss: 6.1785 - discriminator_output_loss: 0.6306 - classifier_output_loss: 5.5478 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2256
# dann_source_acc : 96.16519 %
# dann_target_acc : 22.55937 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8200 - discriminator_output_loss: 0.7592 - classifier_output_loss: 0.0609 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9882
# 24/24 [==============================] - 1s 30ms/step - loss: 5.6189 - discriminator_output_loss: 0.6351 - classifier_output_loss: 4.9838 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1926
# dann_source_acc : 98.82006 %
# dann_target_acc : 19.26121 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.7977 - discriminator_output_loss: 0.7456 - classifier_output_loss: 0.0521 - discriminator_output_accuracy: 0.0516 - classifier_output_accuracy: 0.9926
# 24/24 [==============================] - 1s 30ms/step - loss: 5.7270 - discriminator_output_loss: 0.6366 - classifier_output_loss: 5.0904 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2084
# dann_source_acc : 99.26254 %
# dann_target_acc : 20.84433 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.7681 - discriminator_output_loss: 0.7151 - classifier_output_loss: 0.0530 - discriminator_output_accuracy: 0.2153 - classifier_output_accuracy: 0.9912
# 24/24 [==============================] - 1s 30ms/step - loss: 5.1180 - discriminator_output_loss: 0.6472 - classifier_output_loss: 4.4708 - discriminator_output_accuracy: 0.9406 - classifier_output_accuracy: 0.2810
# dann_source_acc : 99.11504 %
# dann_target_acc : 28.10026 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.0080 - discriminator_output_loss: 0.7697 - classifier_output_loss: 0.2382 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9086
# 24/24 [==============================] - 1s 30ms/step - loss: 4.7640 - discriminator_output_loss: 0.6294 - classifier_output_loss: 4.1346 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2401
# dann_source_acc : 90.85546 %
# dann_target_acc : 24.01055 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# 22/22 [==============================] - 1s 29ms/step - loss: 0.9407 - discriminator_output_loss: 0.7585 - classifier_output_loss: 0.1822 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9587
# 24/24 [==============================] - 1s 30ms/step - loss: 6.7457 - discriminator_output_loss: 0.6302 - classifier_output_loss: 6.1155 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3219
# dann_source_acc : 95.87021 %
# dann_target_acc : 32.18997 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.9218 - discriminator_output_loss: 0.7536 - classifier_output_loss: 0.1682 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9558
# 24/24 [==============================] - 1s 30ms/step - loss: 6.6123 - discriminator_output_loss: 0.6355 - classifier_output_loss: 5.9768 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3364
# dann_source_acc : 95.57522 %
# dann_target_acc : 33.64116 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# 22/22 [==============================] - 1s 29ms/step - loss: 0.8232 - discriminator_output_loss: 0.7548 - classifier_output_loss: 0.0684 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9779
# 24/24 [==============================] - 1s 30ms/step - loss: 5.7097 - discriminator_output_loss: 0.6334 - classifier_output_loss: 5.0763 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3087
# dann_source_acc : 97.78761 %
# dann_target_acc : 30.87071 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8035 - discriminator_output_loss: 0.7490 - classifier_output_loss: 0.0544 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9749
# 24/24 [==============================] - 1s 31ms/step - loss: 5.2862 - discriminator_output_loss: 0.6388 - classifier_output_loss: 4.6474 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2639
# dann_source_acc : 97.49262 %
# dann_target_acc : 26.38522 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.7848 - discriminator_output_loss: 0.7470 - classifier_output_loss: 1.0378 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7684
# 24/24 [==============================] - 1s 31ms/step - loss: 6.0190 - discriminator_output_loss: 0.6475 - classifier_output_loss: 5.3715 - discriminator_output_accuracy: 0.9657 - classifier_output_accuracy: 0.2929
# dann_source_acc : 76.84366 %
# dann_target_acc : 29.2876 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.3679 - discriminator_output_loss: 0.7547 - classifier_output_loss: 0.6132 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9218
# 24/24 [==============================] - 1s 31ms/step - loss: 6.0010 - discriminator_output_loss: 0.6348 - classifier_output_loss: 5.3662 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3747
# dann_source_acc : 92.18289 %
# dann_target_acc : 37.46702 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.1168 - discriminator_output_loss: 0.7344 - classifier_output_loss: 0.3824 - discriminator_output_accuracy: 0.1445 - classifier_output_accuracy: 0.9454
# 24/24 [==============================] - 1s 30ms/step - loss: 6.3888 - discriminator_output_loss: 0.6496 - classifier_output_loss: 5.7392 - discriminator_output_accuracy: 0.8826 - classifier_output_accuracy: 0.3602
# dann_source_acc : 94.54277 %
# dann_target_acc : 36.01583 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 12.0224 - discriminator_output_loss: 0.7588 - classifier_output_loss: 11.2636 - discriminator_output_accuracy: 0.0472 - classifier_output_accuracy: 0.6106
# 24/24 [==============================] - 1s 30ms/step - loss: 25.1900 - discriminator_output_loss: 0.6593 - classifier_output_loss: 24.5307 - discriminator_output_accuracy: 0.8536 - classifier_output_accuracy: 0.3905
# dann_source_acc : 61.06195 %
# dann_target_acc : 39.05013 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 2.8104 - discriminator_output_loss: 0.7601 - classifier_output_loss: 2.0504 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7065
# 24/24 [==============================] - 1s 30ms/step - loss: 18.1115 - discriminator_output_loss: 0.6307 - classifier_output_loss: 17.4808 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.0633
# dann_source_acc : 70.64897 %
# dann_target_acc : 6.33245 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_34.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_34.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8641 - discriminator_output_loss: 0.7761 - classifier_output_loss: 0.0880 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9764
# 24/24 [==============================] - 1s 30ms/step - loss: 4.5723 - discriminator_output_loss: 0.5911 - classifier_output_loss: 3.9812 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3483
# dann_source_acc : 97.64012 %
# dann_target_acc : 34.8285 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_35.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_35.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8279 - discriminator_output_loss: 0.7579 - classifier_output_loss: 0.0700 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9853
# 24/24 [==============================] - 1s 30ms/step - loss: 4.9141 - discriminator_output_loss: 0.6326 - classifier_output_loss: 4.2815 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3087
# dann_source_acc : 98.52507 %
# dann_target_acc : 30.87071 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_36.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_36.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8176 - discriminator_output_loss: 0.7549 - classifier_output_loss: 0.0626 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9808
# 24/24 [==============================] - 1s 30ms/step - loss: 4.9908 - discriminator_output_loss: 0.6363 - classifier_output_loss: 4.3545 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2665
# dann_source_acc : 98.0826 %
# dann_target_acc : 26.64908 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_37.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_37.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8095 - discriminator_output_loss: 0.7513 - classifier_output_loss: 0.0582 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9882
# 24/24 [==============================] - 1s 30ms/step - loss: 6.3546 - discriminator_output_loss: 0.6376 - classifier_output_loss: 5.7170 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2388
# dann_source_acc : 98.82006 %
# dann_target_acc : 23.87863 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_38.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_38.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8030 - discriminator_output_loss: 0.7534 - classifier_output_loss: 0.0496 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9897
# 24/24 [==============================] - 1s 30ms/step - loss: 5.3228 - discriminator_output_loss: 0.6369 - classifier_output_loss: 4.6859 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2612
# dann_source_acc : 98.96755 %
# dann_target_acc : 26.12137 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_39.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_39.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8132 - discriminator_output_loss: 0.7526 - classifier_output_loss: 0.0606 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9882
# 24/24 [==============================] - 1s 31ms/step - loss: 4.8260 - discriminator_output_loss: 0.6357 - classifier_output_loss: 4.1902 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2836
# dann_source_acc : 98.82006 %
# dann_target_acc : 28.36412 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_40.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_40.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8447 - discriminator_output_loss: 0.7515 - classifier_output_loss: 0.0932 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9720
# 24/24 [==============================] - 1s 31ms/step - loss: 5.1506 - discriminator_output_loss: 0.6384 - classifier_output_loss: 4.5121 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2401
# dann_source_acc : 97.19764 %
# dann_target_acc : 24.01055 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_41.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_41.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8061 - discriminator_output_loss: 0.7491 - classifier_output_loss: 0.0570 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9853
# 24/24 [==============================] - 1s 30ms/step - loss: 4.9071 - discriminator_output_loss: 0.6391 - classifier_output_loss: 4.2681 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2559
# dann_source_acc : 98.52507 %
# dann_target_acc : 25.59367 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_42.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_42.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.9309 - discriminator_output_loss: 0.7504 - classifier_output_loss: 0.1804 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9690
# 24/24 [==============================] - 1s 30ms/step - loss: 4.9972 - discriminator_output_loss: 0.6392 - classifier_output_loss: 4.3580 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3641
# dann_source_acc : 96.90266 %
# dann_target_acc : 36.41161 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_43.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_43.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.4306 - discriminator_output_loss: 1.3255 - classifier_output_loss: 0.1051 - discriminator_output_accuracy: 0.1829 - classifier_output_accuracy: 0.9838
# 24/24 [==============================] - 1s 30ms/step - loss: 6.1217 - discriminator_output_loss: 0.6591 - classifier_output_loss: 5.4626 - discriminator_output_accuracy: 0.8074 - classifier_output_accuracy: 0.3694
# dann_source_acc : 98.37758 %
# dann_target_acc : 36.93931 %
# ()

# %%
def epoch_evaluate():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
        target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_evaluate_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_evaluate_df.to_csv( path_model_result + 'epoch_evaluate_df.csv' )
    epoch_evaluate_df

    return ()

# %%
epoch_evaluate()
# Out:
# 43
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model
h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_14.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.9772 - discriminator_output_loss: 0.6769 - classifier_output_loss: 0.3003 - discriminator_output_accuracy: 0.4086 - classifier_output_accuracy: 0.9263
# 24/24 [==============================] - 1s 30ms/step - loss: 9.2776 - discriminator_output_loss: 0.6464 - classifier_output_loss: 8.6312 - discriminator_output_accuracy: 0.9565 - classifier_output_accuracy: 0.2309
# dann_source_acc : 92.62537 %
# dann_target_acc : 23.08707 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_15.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_15.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.6694 - discriminator_output_loss: 0.7894 - classifier_output_loss: 0.8800 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7286
# 24/24 [==============================] - 1s 30ms/step - loss: 5.0126 - discriminator_output_loss: 0.6214 - classifier_output_loss: 4.3911 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1900
# dann_source_acc : 72.86136 %
# dann_target_acc : 18.99736 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_16.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_16.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.0701 - discriminator_output_loss: 0.7564 - classifier_output_loss: 0.3138 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9572
# 24/24 [==============================] - 1s 30ms/step - loss: 7.7656 - discriminator_output_loss: 0.6335 - classifier_output_loss: 7.1321 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2401
# dann_source_acc : 95.72271 %
# dann_target_acc : 24.01055 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_17.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_17.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.9052 - discriminator_output_loss: 0.7455 - classifier_output_loss: 0.1596 - discriminator_output_accuracy: 0.0369 - classifier_output_accuracy: 0.9572
# 24/24 [==============================] - 1s 30ms/step - loss: 6.2858 - discriminator_output_loss: 0.6355 - classifier_output_loss: 5.6502 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1821
# dann_source_acc : 95.72271 %
# dann_target_acc : 18.20581 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# 22/22 [==============================] - 1s 29ms/step - loss: 0.9558 - discriminator_output_loss: 0.7442 - classifier_output_loss: 0.2116 - discriminator_output_accuracy: 0.0546 - classifier_output_accuracy: 0.9440
# 24/24 [==============================] - 1s 31ms/step - loss: 5.9231 - discriminator_output_loss: 0.6450 - classifier_output_loss: 5.2781 - discriminator_output_accuracy: 0.9697 - classifier_output_accuracy: 0.1398
# dann_source_acc : 94.39528 %
# dann_target_acc : 13.98417 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8148 - discriminator_output_loss: 0.7691 - classifier_output_loss: 0.0457 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9853
# 24/24 [==============================] - 1s 31ms/step - loss: 4.8326 - discriminator_output_loss: 0.6188 - classifier_output_loss: 4.2138 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2454
# dann_source_acc : 98.52507 %
# dann_target_acc : 24.53826 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.0009 - discriminator_output_loss: 0.7614 - classifier_output_loss: 0.2395 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9484
# 24/24 [==============================] - 1s 31ms/step - loss: 6.3412 - discriminator_output_loss: 0.6308 - classifier_output_loss: 5.7104 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1992
# dann_source_acc : 94.83776 %
# dann_target_acc : 19.92084 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8726 - discriminator_output_loss: 0.7587 - classifier_output_loss: 0.1139 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9764
# 24/24 [==============================] - 1s 31ms/step - loss: 5.6791 - discriminator_output_loss: 0.6351 - classifier_output_loss: 5.0440 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1662
# dann_source_acc : 97.64012 %
# dann_target_acc : 16.62269 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8309 - discriminator_output_loss: 0.7462 - classifier_output_loss: 0.0847 - discriminator_output_accuracy: 0.0339 - classifier_output_accuracy: 0.9838
# 24/24 [==============================] - 1s 31ms/step - loss: 5.8015 - discriminator_output_loss: 0.6365 - classifier_output_loss: 5.1649 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.1847
# dann_source_acc : 98.37758 %
# dann_target_acc : 18.46966 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8007 - discriminator_output_loss: 0.7179 - classifier_output_loss: 0.0828 - discriminator_output_accuracy: 0.2021 - classifier_output_accuracy: 0.9823
# 24/24 [==============================] - 1s 31ms/step - loss: 5.1674 - discriminator_output_loss: 0.6471 - classifier_output_loss: 4.5203 - discriminator_output_accuracy: 0.9406 - classifier_output_accuracy: 0.2757
# dann_source_acc : 98.23009 %
# dann_target_acc : 27.57256 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 1.0972 - discriminator_output_loss: 0.7676 - classifier_output_loss: 0.3296 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9086
# 24/24 [==============================] - 1s 31ms/step - loss: 4.8734 - discriminator_output_loss: 0.6289 - classifier_output_loss: 4.2445 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2282
# dann_source_acc : 90.85546 %
# dann_target_acc : 22.82322 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.9647 - discriminator_output_loss: 0.7584 - classifier_output_loss: 0.2063 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9440
# 24/24 [==============================] - 1s 31ms/step - loss: 5.6495 - discriminator_output_loss: 0.6305 - classifier_output_loss: 5.0190 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3311
# dann_source_acc : 94.39528 %
# dann_target_acc : 33.11346 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.0287 - discriminator_output_loss: 0.7537 - classifier_output_loss: 0.2749 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9558
# 24/24 [==============================] - 1s 31ms/step - loss: 5.9063 - discriminator_output_loss: 0.6354 - classifier_output_loss: 5.2710 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3219
# dann_source_acc : 95.57522 %
# dann_target_acc : 32.18997 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8639 - discriminator_output_loss: 0.7550 - classifier_output_loss: 0.1089 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9720
# 24/24 [==============================] - 1s 31ms/step - loss: 5.4579 - discriminator_output_loss: 0.6333 - classifier_output_loss: 4.8245 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3008
# dann_source_acc : 97.19764 %
# dann_target_acc : 30.07916 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8404 - discriminator_output_loss: 0.7492 - classifier_output_loss: 0.0913 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9720
# 24/24 [==============================] - 1s 31ms/step - loss: 5.0456 - discriminator_output_loss: 0.6388 - classifier_output_loss: 4.4068 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2718
# dann_source_acc : 97.19764 %
# dann_target_acc : 27.17678 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 1.8392 - discriminator_output_loss: 0.7470 - classifier_output_loss: 1.0922 - discriminator_output_accuracy: 0.0015 - classifier_output_accuracy: 0.7699
# 24/24 [==============================] - 1s 31ms/step - loss: 6.4426 - discriminator_output_loss: 0.6468 - classifier_output_loss: 5.7957 - discriminator_output_accuracy: 0.9776 - classifier_output_accuracy: 0.2810
# dann_source_acc : 76.99115 %
# dann_target_acc : 28.10026 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.3802 - discriminator_output_loss: 0.7547 - classifier_output_loss: 0.6254 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9218
# 24/24 [==============================] - 1s 31ms/step - loss: 6.0365 - discriminator_output_loss: 0.6347 - classifier_output_loss: 5.4018 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3839
# dann_source_acc : 92.18289 %
# dann_target_acc : 38.3905 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 1.3033 - discriminator_output_loss: 0.7340 - classifier_output_loss: 0.5693 - discriminator_output_accuracy: 0.1416 - classifier_output_accuracy: 0.9336
# 24/24 [==============================] - 1s 31ms/step - loss: 6.3155 - discriminator_output_loss: 0.6489 - classifier_output_loss: 5.6666 - discriminator_output_accuracy: 0.8997 - classifier_output_accuracy: 0.3549
# dann_source_acc : 93.36283 %
# dann_target_acc : 35.48813 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 11.7099 - discriminator_output_loss: 0.7607 - classifier_output_loss: 10.9493 - discriminator_output_accuracy: 0.0442 - classifier_output_accuracy: 0.6268
# 24/24 [==============================] - 1s 31ms/step - loss: 23.9913 - discriminator_output_loss: 0.6612 - classifier_output_loss: 23.3301 - discriminator_output_accuracy: 0.8522 - classifier_output_accuracy: 0.3865
# dann_source_acc : 62.68436 %
# dann_target_acc : 38.65435 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 3.0584 - discriminator_output_loss: 0.7601 - classifier_output_loss: 2.2983 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7139
# 24/24 [==============================] - 1s 31ms/step - loss: 16.7774 - discriminator_output_loss: 0.6307 - classifier_output_loss: 16.1467 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.0633
# dann_source_acc : 71.38643 %
# dann_target_acc : 6.33245 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_34.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_34.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8850 - discriminator_output_loss: 0.7768 - classifier_output_loss: 0.1082 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9779
# 24/24 [==============================] - 1s 31ms/step - loss: 4.4679 - discriminator_output_loss: 0.5879 - classifier_output_loss: 3.8799 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3483
# dann_source_acc : 97.78761 %
# dann_target_acc : 34.8285 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_35.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_35.h5
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8380 - discriminator_output_loss: 0.7575 - classifier_output_loss: 0.0804 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9838
# 24/24 [==============================] - 1s 31ms/step - loss: 4.9772 - discriminator_output_loss: 0.6322 - classifier_output_loss: 4.3450 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2902
# dann_source_acc : 98.37758 %
# dann_target_acc : 29.02375 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_36.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_36.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8449 - discriminator_output_loss: 0.7550 - classifier_output_loss: 0.0900 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9749
# 24/24 [==============================] - 1s 31ms/step - loss: 5.2878 - discriminator_output_loss: 0.6365 - classifier_output_loss: 4.6513 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2361
# dann_source_acc : 97.49262 %
# dann_target_acc : 23.61478 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_37.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_37.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8132 - discriminator_output_loss: 0.7513 - classifier_output_loss: 0.0619 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9808
# 24/24 [==============================] - 1s 31ms/step - loss: 6.5684 - discriminator_output_loss: 0.6375 - classifier_output_loss: 5.9309 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2256
# dann_source_acc : 98.0826 %
# dann_target_acc : 22.55937 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_38.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_38.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8033 - discriminator_output_loss: 0.7529 - classifier_output_loss: 0.0505 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9882
# 24/24 [==============================] - 1s 31ms/step - loss: 5.6306 - discriminator_output_loss: 0.6371 - classifier_output_loss: 4.9935 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2441
# dann_source_acc : 98.82006 %
# dann_target_acc : 24.40633 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_39.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_39.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8331 - discriminator_output_loss: 0.7534 - classifier_output_loss: 0.0798 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9838
# 24/24 [==============================] - 1s 31ms/step - loss: 5.0351 - discriminator_output_loss: 0.6358 - classifier_output_loss: 4.3993 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2731
# dann_source_acc : 98.37758 %
# dann_target_acc : 27.30871 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_40.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_40.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8824 - discriminator_output_loss: 0.7514 - classifier_output_loss: 0.1310 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9587
# 24/24 [==============================] - 1s 31ms/step - loss: 5.2759 - discriminator_output_loss: 0.6384 - classifier_output_loss: 4.6375 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2243
# dann_source_acc : 95.87021 %
# dann_target_acc : 22.42744 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_41.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_41.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8236 - discriminator_output_loss: 0.7492 - classifier_output_loss: 0.0744 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9838
# 24/24 [==============================] - 1s 31ms/step - loss: 5.0883 - discriminator_output_loss: 0.6392 - classifier_output_loss: 4.4492 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.2520
# dann_source_acc : 98.37758 %
# dann_target_acc : 25.19789 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_42.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_42.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 0.9925 - discriminator_output_loss: 0.7504 - classifier_output_loss: 0.2421 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9631
# 24/24 [==============================] - 1s 31ms/step - loss: 5.1825 - discriminator_output_loss: 0.6392 - classifier_output_loss: 4.5433 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3140
# dann_source_acc : 96.31268 %
# dann_target_acc : 31.39842 %
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_43.h5
# gdrive/My Drive/Research_3_1_2/model_result/4 - SimCLR + DANN_model_result - 1/model_43.h5
# 22/22 [==============================] - 1s 30ms/step - loss: 1.4834 - discriminator_output_loss: 1.3191 - classifier_output_loss: 0.1644 - discriminator_output_accuracy: 0.1858 - classifier_output_accuracy: 0.9705
# 24/24 [==============================] - 1s 31ms/step - loss: 6.7082 - discriminator_output_loss: 0.6597 - classifier_output_loss: 6.0485 - discriminator_output_accuracy: 0.8034 - classifier_output_accuracy: 0.3430
# dann_source_acc : 97.05015 %
# dann_target_acc : 34.30079 %
# ()

# %%
model.load_weights('gdrive/My Drive/Research_5_2_1/model_result/4 - SimCLR + DANN_result - 1/model_30.h5')
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_target_acc :',round(source_acc [-1]*100,5),'%')
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 30ms/step - loss: 1.3802 - discriminator_output_loss: 0.7547 - classifier_output_loss: 0.6254 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9218
# dann_target_acc : 92.18289 %
# 24/24 [==============================] - 1s 31ms/step - loss: 6.0365 - discriminator_output_loss: 0.6347 - classifier_output_loss: 5.4018 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.3839
# dann_target_acc : 38.3905 %

# %% [markdown]
# # 4. Result Report

# %%
print( 'dann_model' + " →→→ Target Test")
print('target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# dann_model →→→ Target Test
# target_acc : 38.3905 %

# %% [markdown]
# # 5. Model Save

# %%
model.save( path_model_result + 'dann_model_last.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %% [markdown]
# ## 기타 - TSNE 확인

# %%
def plot_embedding1(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def plot_embedding2(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(30,30))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
TSNE_model_none = dann()

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 4478.94it/s]

# %%
feature_model = Model(model.input, model.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 2282.36it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 2739.60it/s]

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 4968.00it/s]

# %%
feature_model = Model(model.input, model.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 2453.95it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1436/1436 [00:00<00:00, 2648.17it/s]
