# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6122205365439735429
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13027059813645538339
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 15:25:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    32W / 250W |    375MiB / 16280MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'DenseNet121'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 5
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4"
T_all_labels = "T0", "T1", "T2", "T3", "T4"

#base_path = ''
base_path = 'gdrive/My Drive/Research_5_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_DenseNet121_None S_DenseNet121_imagenet T_DenseNet121_None T_DenseNet121_imagenet
# ['S_DenseNet121_imagenet',
#  'S_DenseNet121_None',
#  'T_DenseNet121_imagenet',
#  'T_DenseNet121_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2034, 128, 128, 3) (2034, 1)
# (678, 128, 128, 3) (678, 1)
# (678, 128, 128, 3) (678, 1)
#
# (2274, 128, 128, 3) (2274, 1)
# (758, 128, 128, 3) (758, 1)
# (758, 128, 128, 3) (758, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2034, 128, 128, 3) (2034, 5)
# (678, 128, 128, 3) (678, 5)
# (678, 128, 128, 3) (678, 5)
#
# (2274, 128, 128, 3) (2274, 5)
# (758, 128, 128, 3) (758, 5)
# (758, 128, 128, 3) (758, 5)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2034
# xTrain_S image Numbers // 10 :  203
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2274
# xTrain_S image Numbers // 10 :  227
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 27s 248ms/step - loss: 0.7026 - accuracy: 0.7424 - val_loss: 1.9261 - val_accuracy: 0.0619
# Epoch 2/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.4117 - accuracy: 0.8486 - val_loss: 4.5463 - val_accuracy: 0.1386
# Epoch 3/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.3076 - accuracy: 0.8864 - val_loss: 3.6683 - val_accuracy: 0.0929
# Epoch 4/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.2763 - accuracy: 0.8968 - val_loss: 5.5491 - val_accuracy: 0.1401
# Epoch 5/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.3404 - accuracy: 0.8648 - val_loss: 5.1128 - val_accuracy: 0.1696
# Epoch 6/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.2294 - accuracy: 0.9061 - val_loss: 4.9699 - val_accuracy: 0.1534
# Epoch 7/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.1821 - accuracy: 0.9248 - val_loss: 7.2595 - val_accuracy: 0.1785
# Epoch 8/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.2174 - accuracy: 0.9120 - val_loss: 4.3898 - val_accuracy: 0.1091
# Epoch 9/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.2095 - accuracy: 0.9164 - val_loss: 3.5315 - val_accuracy: 0.1991
# Epoch 10/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.1816 - accuracy: 0.9243 - val_loss: 4.9552 - val_accuracy: 0.1460
# Epoch 11/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.1782 - accuracy: 0.9282 - val_loss: 1.6751 - val_accuracy: 0.5723
# Epoch 12/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.1607 - accuracy: 0.9341 - val_loss: 6.3626 - val_accuracy: 0.1150
# Epoch 13/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.1188 - accuracy: 0.9548 - val_loss: 0.6816 - val_accuracy: 0.7596
# Epoch 14/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.1208 - accuracy: 0.9523 - val_loss: 2.5777 - val_accuracy: 0.4381
# Epoch 15/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.1031 - accuracy: 0.9651 - val_loss: 0.7243 - val_accuracy: 0.7596
# Epoch 16/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.1009 - accuracy: 0.9646 - val_loss: 3.6201 - val_accuracy: 0.4410
# Epoch 17/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.1390 - accuracy: 0.9489 - val_loss: 1.7012 - val_accuracy: 0.5723
# Epoch 18/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.1391 - accuracy: 0.9489 - val_loss: 1.9577 - val_accuracy: 0.6445
# Epoch 19/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0797 - accuracy: 0.9735 - val_loss: 0.4736 - val_accuracy: 0.8687
# Epoch 20/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0979 - accuracy: 0.9636 - val_loss: 1.5861 - val_accuracy: 0.7404
# Epoch 21/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0932 - accuracy: 0.9676 - val_loss: 1.2608 - val_accuracy: 0.7596
# Epoch 22/100
# 32/32 [==============================] - 5s 152ms/step - loss: 0.0673 - accuracy: 0.9739 - val_loss: 0.3452 - val_accuracy: 0.8953
# Epoch 23/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0822 - accuracy: 0.9680 - val_loss: 0.3552 - val_accuracy: 0.8864
# Epoch 24/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0875 - accuracy: 0.9725 - val_loss: 2.7631 - val_accuracy: 0.5885
# Epoch 25/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0675 - accuracy: 0.9774 - val_loss: 1.4671 - val_accuracy: 0.7198
# Epoch 26/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.0381 - accuracy: 0.9872 - val_loss: 0.2530 - val_accuracy: 0.9248
# Epoch 27/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0653 - accuracy: 0.9774 - val_loss: 1.7398 - val_accuracy: 0.6696
# Epoch 28/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0982 - accuracy: 0.9676 - val_loss: 2.3813 - val_accuracy: 0.6667
# Epoch 29/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0472 - accuracy: 0.9843 - val_loss: 1.3572 - val_accuracy: 0.7552
# Epoch 30/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0404 - accuracy: 0.9838 - val_loss: 0.3217 - val_accuracy: 0.8997
# Epoch 31/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0415 - accuracy: 0.9872 - val_loss: 0.6949 - val_accuracy: 0.8260
# Epoch 32/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0225 - accuracy: 0.9941 - val_loss: 0.3707 - val_accuracy: 0.9204
# Epoch 33/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0216 - accuracy: 0.9946 - val_loss: 0.3402 - val_accuracy: 0.9130
# Epoch 34/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0477 - accuracy: 0.9857 - val_loss: 0.4638 - val_accuracy: 0.8820
# Epoch 35/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.1001 - accuracy: 0.9680 - val_loss: 3.8450 - val_accuracy: 0.4661
# Epoch 36/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0594 - accuracy: 0.9823 - val_loss: 1.5754 - val_accuracy: 0.7301
# Epoch 37/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0484 - accuracy: 0.9857 - val_loss: 1.5244 - val_accuracy: 0.7596
# Epoch 38/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0349 - accuracy: 0.9902 - val_loss: 0.5683 - val_accuracy: 0.8820
# Epoch 39/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.5939 - val_accuracy: 0.8702
# Epoch 40/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.3139 - val_accuracy: 0.9233
# Epoch 41/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.4474 - val_accuracy: 0.8864
# Epoch 42/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.8663 - val_accuracy: 0.8215
# Epoch 43/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.8833 - val_accuracy: 0.8304
# Epoch 44/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0283 - accuracy: 0.9897 - val_loss: 0.4030 - val_accuracy: 0.9056
# Epoch 45/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0313 - accuracy: 0.9902 - val_loss: 3.5193 - val_accuracy: 0.5487
# Epoch 46/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.3809 - val_accuracy: 0.9115
# Epoch 47/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.6493 - val_accuracy: 0.8732
# Epoch 48/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 2.0266 - val_accuracy: 0.6844
# Epoch 49/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0508 - accuracy: 0.9813 - val_loss: 2.3091 - val_accuracy: 0.7448
# Epoch 50/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0348 - accuracy: 0.9897 - val_loss: 0.5042 - val_accuracy: 0.8805
# Epoch 51/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0389 - accuracy: 0.9882 - val_loss: 1.2382 - val_accuracy: 0.7375
# Epoch 52/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 1.8052 - val_accuracy: 0.7080
# Epoch 53/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.9701 - val_accuracy: 0.8024
# Epoch 54/100
# 32/32 [==============================] - 5s 156ms/step - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.5923 - val_accuracy: 0.8746
# Epoch 55/100
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9661
# Epoch 56/100
# 32/32 [==============================] - 5s 155ms/step - loss: 7.0696e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9705
# Epoch 57/100
# 32/32 [==============================] - 5s 154ms/step - loss: 6.0925e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9720
# Epoch 58/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0026 - accuracy: 0.9980 - val_loss: 0.1772 - val_accuracy: 0.9646
# Epoch 59/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0542 - accuracy: 0.9857 - val_loss: 3.0376 - val_accuracy: 0.6047
# Epoch 60/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.1073 - accuracy: 0.9690 - val_loss: 2.6871 - val_accuracy: 0.6431
# Epoch 61/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0597 - accuracy: 0.9798 - val_loss: 1.9975 - val_accuracy: 0.6799
# Epoch 62/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0376 - accuracy: 0.9877 - val_loss: 2.0541 - val_accuracy: 0.7124
# Epoch 63/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.4141 - val_accuracy: 0.9071
# Epoch 64/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.1965 - val_accuracy: 0.9587
# Epoch 65/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.6827 - val_accuracy: 0.8673
# Epoch 66/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.4379 - val_accuracy: 0.9012
# Epoch 67/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.5162 - val_accuracy: 0.8820
# Epoch 68/100
# 32/32 [==============================] - 5s 148ms/step - loss: 9.8795e-04 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9690
# Epoch 69/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0291 - accuracy: 0.9936 - val_loss: 3.1810 - val_accuracy: 0.5811
# Epoch 70/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0544 - accuracy: 0.9774 - val_loss: 2.7720 - val_accuracy: 0.7080
# Epoch 71/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0770 - accuracy: 0.9784 - val_loss: 4.1265 - val_accuracy: 0.5088
# Epoch 72/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0312 - accuracy: 0.9872 - val_loss: 2.2122 - val_accuracy: 0.6032
# Epoch 73/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.3098 - val_accuracy: 0.9174
# Epoch 74/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.5160 - val_accuracy: 0.8776
# Epoch 75/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.2279 - val_accuracy: 0.9499
# Epoch 76/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.6783 - val_accuracy: 0.8717
# Epoch 77/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 3.1934 - val_accuracy: 0.6740
# Epoch 78/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 1.8159 - val_accuracy: 0.7271
# Epoch 79/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.7164 - val_accuracy: 0.8422
# Epoch 80/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0252 - accuracy: 0.9921 - val_loss: 1.5959 - val_accuracy: 0.7316
# Epoch 81/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0617 - accuracy: 0.9823 - val_loss: 2.5885 - val_accuracy: 0.7021
# Epoch 82/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.1079 - accuracy: 0.9676 - val_loss: 3.0094 - val_accuracy: 0.6254
# Epoch 83/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0346 - accuracy: 0.9907 - val_loss: 2.6300 - val_accuracy: 0.6962
# Epoch 84/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.8068 - val_accuracy: 0.8584
# Epoch 85/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0278 - accuracy: 0.9902 - val_loss: 0.9605 - val_accuracy: 0.8274
# Epoch 86/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.1884 - val_accuracy: 0.9454
# Epoch 87/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9995Restoring model weights from the end of the best epoch: 57.
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.3007 - val_accuracy: 0.9115
# Epoch 00087: early stopping
# Maximal validation accuracy: 97.20%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.702650  0.742380  1.926140      0.061947
# 1   0.411727  0.848574  4.546323      0.138643
# 2   0.307593  0.886431  3.668303      0.092920
# 3   0.276343  0.896755  5.549130      0.140118
# 4   0.340427  0.864798  5.112846      0.169617
# ..       ...       ...       ...           ...
# 82  0.034648  0.990659  2.630008      0.696165
# 83  0.012188  0.996558  0.806818      0.858407
# 84  0.027832  0.990167  0.960545      0.827434
# 85  0.012801  0.995575  0.188430      0.945428
# 86  0.003452  0.999508  0.300691      0.911504
#
# [87 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.13484235107898712
# Maximum validation accuracy: 0.9719763994216919

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0921 - accuracy: 0.9720
# test loss, test acc: [0.092092365026474, 0.9719763994216919]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 22/22 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 16s 211ms/step - loss: 0.3614 - accuracy: 0.8663 - val_loss: 7.2272 - val_accuracy: 0.4705
# Epoch 2/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.1532 - accuracy: 0.9415 - val_loss: 4.8075 - val_accuracy: 0.5442
# Epoch 3/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.1019 - accuracy: 0.9646 - val_loss: 0.6482 - val_accuracy: 0.8687
# Epoch 4/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0852 - accuracy: 0.9720 - val_loss: 1.4475 - val_accuracy: 0.7773
# Epoch 5/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0401 - accuracy: 0.9857 - val_loss: 1.4407 - val_accuracy: 0.7655
# Epoch 6/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0613 - accuracy: 0.9794 - val_loss: 1.7921 - val_accuracy: 0.7832
# Epoch 7/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0421 - accuracy: 0.9867 - val_loss: 1.3039 - val_accuracy: 0.7906
# Epoch 8/100
# 32/32 [==============================] - 5s 154ms/step - loss: 0.0439 - accuracy: 0.9867 - val_loss: 0.5379 - val_accuracy: 0.8761
# Epoch 9/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0569 - accuracy: 0.9848 - val_loss: 0.4677 - val_accuracy: 0.9027
# Epoch 10/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 1.2386 - val_accuracy: 0.7920
# Epoch 11/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0475 - accuracy: 0.9848 - val_loss: 0.6082 - val_accuracy: 0.8599
# Epoch 12/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0329 - accuracy: 0.9916 - val_loss: 0.1785 - val_accuracy: 0.9558
# Epoch 13/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0149 - accuracy: 0.9961 - val_loss: 0.4141 - val_accuracy: 0.8997
# Epoch 14/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0202 - accuracy: 0.9951 - val_loss: 0.2167 - val_accuracy: 0.9322
# Epoch 15/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0264 - accuracy: 0.9921 - val_loss: 0.3936 - val_accuracy: 0.9041
# Epoch 16/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0216 - accuracy: 0.9916 - val_loss: 0.3173 - val_accuracy: 0.9263
# Epoch 17/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.5803 - val_accuracy: 0.8953
# Epoch 18/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0712 - accuracy: 0.9813 - val_loss: 1.0618 - val_accuracy: 0.8156
# Epoch 19/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.5410 - val_accuracy: 0.9027
# Epoch 20/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0232 - accuracy: 0.9916 - val_loss: 0.1413 - val_accuracy: 0.9705
# Epoch 21/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0173 - accuracy: 0.9936 - val_loss: 0.1633 - val_accuracy: 0.9587
# Epoch 22/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0139 - accuracy: 0.9966 - val_loss: 0.2391 - val_accuracy: 0.9484
# Epoch 23/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0609 - accuracy: 0.9813 - val_loss: 3.9339 - val_accuracy: 0.6593
# Epoch 24/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0260 - accuracy: 0.9936 - val_loss: 0.3060 - val_accuracy: 0.9174
# Epoch 25/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.1728 - val_accuracy: 0.9690
# Epoch 26/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0188 - accuracy: 0.9961 - val_loss: 0.0906 - val_accuracy: 0.9749
# Epoch 27/100
# 32/32 [==============================] - 5s 153ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0427 - val_accuracy: 0.9882
# Epoch 28/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0218 - accuracy: 0.9961 - val_loss: 0.4350 - val_accuracy: 0.8997
# Epoch 29/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0277 - accuracy: 0.9921 - val_loss: 0.4829 - val_accuracy: 0.9174
# Epoch 30/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0358 - accuracy: 0.9882 - val_loss: 0.5295 - val_accuracy: 0.8776
# Epoch 31/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0244 - accuracy: 0.9916 - val_loss: 0.2255 - val_accuracy: 0.9440
# Epoch 32/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0229 - accuracy: 0.9941 - val_loss: 0.2695 - val_accuracy: 0.9587
# Epoch 33/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.3536 - val_accuracy: 0.9248
# Epoch 34/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.0725 - val_accuracy: 0.9823
# Epoch 35/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0135 - accuracy: 0.9975 - val_loss: 0.1038 - val_accuracy: 0.9808
# Epoch 36/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.9269 - val_accuracy: 0.8407
# Epoch 37/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0275 - accuracy: 0.9897 - val_loss: 4.2879 - val_accuracy: 0.6357
# Epoch 38/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 0.2556 - val_accuracy: 0.9263
# Epoch 39/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0194 - accuracy: 0.9956 - val_loss: 0.1203 - val_accuracy: 0.9720
# Epoch 40/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0107 - accuracy: 0.9980 - val_loss: 0.2556 - val_accuracy: 0.9528
# Epoch 41/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.2032 - val_accuracy: 0.9366
# Epoch 42/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0901 - val_accuracy: 0.9661
# Epoch 43/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0443 - val_accuracy: 0.9853
# Epoch 44/100
# 32/32 [==============================] - 5s 153ms/step - loss: 4.7086e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9926
# Epoch 45/100
# 32/32 [==============================] - 5s 149ms/step - loss: 3.6735e-04 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9926
# Epoch 46/100
# 32/32 [==============================] - 5s 149ms/step - loss: 1.5674e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9926
# Epoch 47/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0444 - val_accuracy: 0.9853
# Epoch 48/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0134 - accuracy: 0.9971 - val_loss: 0.0955 - val_accuracy: 0.9808
# Epoch 49/100
# 32/32 [==============================] - 5s 149ms/step - loss: 9.8028e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9764
# Epoch 50/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0248 - accuracy: 0.9951 - val_loss: 0.1049 - val_accuracy: 0.9749
# Epoch 51/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.2407 - val_accuracy: 0.9425
# Epoch 52/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.1681 - val_accuracy: 0.9558
# Epoch 53/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.4036 - val_accuracy: 0.9145
# Epoch 54/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0486 - accuracy: 0.9867 - val_loss: 1.8733 - val_accuracy: 0.7360
# Epoch 55/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.4613 - val_accuracy: 0.9159
# Epoch 56/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.4330 - val_accuracy: 0.9100
# Epoch 57/100
# 32/32 [==============================] - 5s 151ms/step - loss: 0.0319 - accuracy: 0.9931 - val_loss: 0.5270 - val_accuracy: 0.8791
# Epoch 58/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0184 - accuracy: 0.9931 - val_loss: 0.1434 - val_accuracy: 0.9602
# Epoch 59/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0284 - accuracy: 0.9916 - val_loss: 0.6066 - val_accuracy: 0.8540
# Epoch 60/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.5874 - val_accuracy: 0.8894
# Epoch 61/100
# 32/32 [==============================] - 5s 150ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.3719 - val_accuracy: 0.9174
# Epoch 62/100
# 32/32 [==============================] - 5s 148ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 0.1258 - val_accuracy: 0.9705
# Epoch 63/100
# 32/32 [==============================] - 5s 149ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.0915 - val_accuracy: 0.9808
# Epoch 64/100
# 32/32 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 44.
# 32/32 [==============================] - 5s 155ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9794
# Epoch 00064: early stopping
# Maximal validation accuracy: 99.26%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.361365  0.866273  7.227202      0.470501
# 1   0.153239  0.941495  4.807464      0.544248
# 2   0.101924  0.964602  0.648233      0.868732
# 3   0.085182  0.971976  1.447532      0.777286
# 4   0.040148  0.985742  1.440661      0.765487
# ..       ...       ...       ...           ...
# 59  0.017984  0.994100  0.587383      0.889381
# 60  0.033703  0.988692  0.371855      0.917404
# 61  0.024610  0.992625  0.125767      0.970501
# 62  0.012950  0.995084  0.091507      0.980826
# 63  0.002150  1.000000  0.089618      0.979351
#
# [64 rows x 4 columns]

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.027831347659230232
# Maximum validation accuracy: 0.99262535572052

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0558 - accuracy: 0.9808
# test loss, test acc: [0.05582685023546219, 0.9808259606361389]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 22/22 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 18s 235ms/step - loss: 0.9363 - accuracy: 0.6306 - val_loss: 1.4774 - val_accuracy: 0.2507
# Epoch 2/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.6395 - accuracy: 0.7480 - val_loss: 1.8501 - val_accuracy: 0.1596
# Epoch 3/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.4771 - accuracy: 0.8118 - val_loss: 1.8802 - val_accuracy: 0.1438
# Epoch 4/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.4131 - accuracy: 0.8426 - val_loss: 3.8116 - val_accuracy: 0.1108
# Epoch 5/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.4540 - accuracy: 0.8294 - val_loss: 4.4861 - val_accuracy: 0.1240
# Epoch 6/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.3596 - accuracy: 0.8558 - val_loss: 6.8468 - val_accuracy: 0.1214
# Epoch 7/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.3408 - accuracy: 0.8694 - val_loss: 4.1963 - val_accuracy: 0.1306
# Epoch 8/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.3264 - accuracy: 0.8808 - val_loss: 4.1184 - val_accuracy: 0.1438
# Epoch 9/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.2726 - accuracy: 0.8958 - val_loss: 4.4400 - val_accuracy: 0.1781
# Epoch 10/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.2741 - accuracy: 0.8958 - val_loss: 2.9503 - val_accuracy: 0.2084
# Epoch 11/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.3041 - accuracy: 0.8769 - val_loss: 1.6907 - val_accuracy: 0.5224
# Epoch 12/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.2306 - accuracy: 0.9077 - val_loss: 2.6087 - val_accuracy: 0.4288
# Epoch 13/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.2282 - accuracy: 0.9081 - val_loss: 0.8637 - val_accuracy: 0.7493
# Epoch 14/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.1837 - accuracy: 0.9261 - val_loss: 3.8319 - val_accuracy: 0.2269
# Epoch 15/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1756 - accuracy: 0.9318 - val_loss: 1.8680 - val_accuracy: 0.5053
# Epoch 16/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.2187 - accuracy: 0.9213 - val_loss: 1.8076 - val_accuracy: 0.6319
# Epoch 17/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1660 - accuracy: 0.9358 - val_loss: 2.5661 - val_accuracy: 0.4749
# Epoch 18/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1590 - accuracy: 0.9340 - val_loss: 3.1506 - val_accuracy: 0.4129
# Epoch 19/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1508 - accuracy: 0.9393 - val_loss: 2.5516 - val_accuracy: 0.6293
# Epoch 20/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.1529 - accuracy: 0.9367 - val_loss: 1.0364 - val_accuracy: 0.7507
# Epoch 21/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.1303 - accuracy: 0.9521 - val_loss: 9.5722 - val_accuracy: 0.2863
# Epoch 22/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1470 - accuracy: 0.9358 - val_loss: 2.1335 - val_accuracy: 0.4749
# Epoch 23/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1224 - accuracy: 0.9551 - val_loss: 2.4167 - val_accuracy: 0.5264
# Epoch 24/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0949 - accuracy: 0.9661 - val_loss: 1.6091 - val_accuracy: 0.6926
# Epoch 25/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0886 - accuracy: 0.9679 - val_loss: 3.9704 - val_accuracy: 0.5251
# Epoch 26/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0871 - accuracy: 0.9653 - val_loss: 2.8197 - val_accuracy: 0.5818
# Epoch 27/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1090 - accuracy: 0.9626 - val_loss: 2.2585 - val_accuracy: 0.5818
# Epoch 28/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1236 - accuracy: 0.9499 - val_loss: 9.5435 - val_accuracy: 0.2296
# Epoch 29/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0998 - accuracy: 0.9657 - val_loss: 1.2117 - val_accuracy: 0.7164
# Epoch 30/100
# 36/36 [==============================] - 6s 155ms/step - loss: 0.0609 - accuracy: 0.9780 - val_loss: 0.7975 - val_accuracy: 0.8325
# Epoch 31/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0821 - accuracy: 0.9679 - val_loss: 3.4576 - val_accuracy: 0.4908
# Epoch 32/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1106 - accuracy: 0.9644 - val_loss: 9.0317 - val_accuracy: 0.2427
# Epoch 33/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.1457 - accuracy: 0.9446 - val_loss: 6.7347 - val_accuracy: 0.1755
# Epoch 34/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0781 - accuracy: 0.9714 - val_loss: 3.3188 - val_accuracy: 0.5079
# Epoch 35/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0683 - accuracy: 0.9745 - val_loss: 2.1529 - val_accuracy: 0.7058
# Epoch 36/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0564 - accuracy: 0.9837 - val_loss: 1.1234 - val_accuracy: 0.7124
# Epoch 37/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0679 - accuracy: 0.9754 - val_loss: 1.8559 - val_accuracy: 0.6873
# Epoch 38/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0427 - accuracy: 0.9864 - val_loss: 0.8100 - val_accuracy: 0.7995
# Epoch 39/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1182 - accuracy: 0.9560 - val_loss: 0.9383 - val_accuracy: 0.7797
# Epoch 40/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0525 - accuracy: 0.9828 - val_loss: 1.0038 - val_accuracy: 0.7256
# Epoch 41/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0513 - accuracy: 0.9833 - val_loss: 6.6234 - val_accuracy: 0.3113
# Epoch 42/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0414 - accuracy: 0.9868 - val_loss: 1.6710 - val_accuracy: 0.6807
# Epoch 43/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0453 - accuracy: 0.9859 - val_loss: 3.2030 - val_accuracy: 0.4538
# Epoch 44/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0387 - accuracy: 0.9881 - val_loss: 2.0051 - val_accuracy: 0.6438
# Epoch 45/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0265 - accuracy: 0.9903 - val_loss: 7.2907 - val_accuracy: 0.3496
# Epoch 46/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 2.7477 - val_accuracy: 0.5989
# Epoch 47/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0522 - accuracy: 0.9815 - val_loss: 6.1734 - val_accuracy: 0.3931
# Epoch 48/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0822 - accuracy: 0.9705 - val_loss: 4.5049 - val_accuracy: 0.3852
# Epoch 49/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0662 - accuracy: 0.9763 - val_loss: 7.2218 - val_accuracy: 0.2929
# Epoch 50/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0186 - accuracy: 0.9952 - val_loss: 1.7318 - val_accuracy: 0.6372
# Epoch 51/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0141 - accuracy: 0.9969 - val_loss: 0.8842 - val_accuracy: 0.8272
# Epoch 52/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0332 - accuracy: 0.9908 - val_loss: 5.8019 - val_accuracy: 0.5739
# Epoch 53/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 2.6278 - val_accuracy: 0.5950
# Epoch 54/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0301 - accuracy: 0.9894 - val_loss: 2.5922 - val_accuracy: 0.6082
# Epoch 55/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0213 - accuracy: 0.9952 - val_loss: 1.1913 - val_accuracy: 0.7823
# Epoch 56/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 1.1275 - val_accuracy: 0.7388
# Epoch 57/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0246 - accuracy: 0.9899 - val_loss: 0.9643 - val_accuracy: 0.8338
# Epoch 58/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0386 - accuracy: 0.9828 - val_loss: 1.5941 - val_accuracy: 0.7388
# Epoch 59/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0628 - accuracy: 0.9802 - val_loss: 9.1877 - val_accuracy: 0.4578
# Epoch 60/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0440 - accuracy: 0.9846 - val_loss: 3.6715 - val_accuracy: 0.5580
# Epoch 61/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0321 - accuracy: 0.9886 - val_loss: 1.1629 - val_accuracy: 0.7850
# Epoch 62/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0353 - accuracy: 0.9881 - val_loss: 0.8998 - val_accuracy: 0.8127
# Epoch 63/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.8493 - val_accuracy: 0.7916
# Epoch 64/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 2.2106 - val_accuracy: 0.6161
# Epoch 65/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0106 - accuracy: 0.9960 - val_loss: 0.6211 - val_accuracy: 0.8681
# Epoch 66/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0305 - accuracy: 0.9894 - val_loss: 1.3059 - val_accuracy: 0.7704
# Epoch 67/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0331 - accuracy: 0.9864 - val_loss: 16.3874 - val_accuracy: 0.2559
# Epoch 68/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0653 - accuracy: 0.9780 - val_loss: 3.5844 - val_accuracy: 0.6913
# Epoch 69/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0257 - accuracy: 0.9934 - val_loss: 1.4089 - val_accuracy: 0.7216
# Epoch 70/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0278 - accuracy: 0.9912 - val_loss: 1.1679 - val_accuracy: 0.8206
# Epoch 71/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 1.6628 - val_accuracy: 0.6623
# Epoch 72/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.5817 - val_accuracy: 0.8575
# Epoch 73/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.9092 - val_accuracy: 0.8127
# Epoch 74/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 1.2658 - val_accuracy: 0.7968
# Epoch 75/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0133 - accuracy: 0.9947 - val_loss: 0.9341 - val_accuracy: 0.7929
# Epoch 76/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9140 - val_accuracy: 0.8127
# Epoch 77/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.6382 - val_accuracy: 0.8826
# Epoch 78/100
# 36/36 [==============================] - 5s 149ms/step - loss: 5.8662e-04 - accuracy: 1.0000 - val_loss: 0.5877 - val_accuracy: 0.8813
# Epoch 79/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.4999 - val_accuracy: 0.8997
# Epoch 80/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 2.3155 - val_accuracy: 0.6293
# Epoch 81/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 2.3813 - val_accuracy: 0.5923
# Epoch 82/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0597 - accuracy: 0.9798 - val_loss: 5.1342 - val_accuracy: 0.4921
# Epoch 83/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0495 - accuracy: 0.9807 - val_loss: 2.2738 - val_accuracy: 0.6293
# Epoch 84/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0345 - accuracy: 0.9855 - val_loss: 5.2918 - val_accuracy: 0.4485
# Epoch 85/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 8.3543 - val_accuracy: 0.3140
# Epoch 86/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0366 - accuracy: 0.9881 - val_loss: 2.6158 - val_accuracy: 0.5343
# Epoch 87/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 1.0441 - val_accuracy: 0.7929
# Epoch 88/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0294 - accuracy: 0.9934 - val_loss: 5.7391 - val_accuracy: 0.3997
# Epoch 89/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0463 - accuracy: 0.9828 - val_loss: 4.8772 - val_accuracy: 0.6108
# Epoch 90/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0187 - accuracy: 0.9934 - val_loss: 3.0635 - val_accuracy: 0.6016
# Epoch 91/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 1.7209 - val_accuracy: 0.7322
# Epoch 92/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.6337 - val_accuracy: 0.8615
# Epoch 93/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.9024 - val_accuracy: 0.7876
# Epoch 94/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 1.0424 - val_accuracy: 0.8298
# Epoch 95/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0173 - accuracy: 0.9938 - val_loss: 1.5946 - val_accuracy: 0.7770
# Epoch 96/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0130 - accuracy: 0.9952 - val_loss: 2.0100 - val_accuracy: 0.7348
# Epoch 97/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0291 - accuracy: 0.9872 - val_loss: 2.0090 - val_accuracy: 0.6834
# Epoch 98/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0455 - accuracy: 0.9868 - val_loss: 4.0913 - val_accuracy: 0.4591
# Epoch 99/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0553 - accuracy: 0.9802 - val_loss: 2.0045 - val_accuracy: 0.6755
# Epoch 100/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0325 - accuracy: 0.9881 - val_loss: 3.9530 - val_accuracy: 0.3391
# Maximal validation accuracy: 89.97%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.936333  0.630607  1.477429      0.250660
# 1   0.639473  0.748021  1.850068      0.159631
# 2   0.477080  0.811785  1.880238      0.143799
# 3   0.413077  0.842568  3.811615      0.110818
# 4   0.453958  0.829376  4.486063      0.124011
# ..       ...       ...       ...           ...
# 95  0.012975  0.995163  2.010043      0.734828
# 96  0.029099  0.987247  2.009035      0.683377
# 97  0.045469  0.986807  4.091299      0.459103
# 98  0.055256  0.980211  2.004477      0.675462
# 99  0.032465  0.988127  3.952972      0.339050
#
# [100 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.4998959004878998
# Maximum validation accuracy: 0.8997361660003662

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 24/24 [==============================] - 1s 39ms/step - loss: 4.2729 - accuracy: 0.3509
# test loss, test acc: [4.272927761077881, 0.35092347860336304]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 24/24 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 17s 204ms/step - loss: 0.4978 - accuracy: 0.8179 - val_loss: 4.4955 - val_accuracy: 0.1913
# Epoch 2/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.2241 - accuracy: 0.9160 - val_loss: 1.1933 - val_accuracy: 0.6662
# Epoch 3/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.1191 - accuracy: 0.9538 - val_loss: 3.3761 - val_accuracy: 0.5976
# Epoch 4/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1221 - accuracy: 0.9551 - val_loss: 1.6756 - val_accuracy: 0.6042
# Epoch 5/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0975 - accuracy: 0.9639 - val_loss: 0.8092 - val_accuracy: 0.7784
# Epoch 6/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1182 - accuracy: 0.9556 - val_loss: 6.9315 - val_accuracy: 0.5066
# Epoch 7/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.1293 - accuracy: 0.9538 - val_loss: 0.4087 - val_accuracy: 0.8865
# Epoch 8/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.1289 - accuracy: 0.9569 - val_loss: 0.8838 - val_accuracy: 0.8061
# Epoch 9/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0633 - accuracy: 0.9771 - val_loss: 1.0615 - val_accuracy: 0.7639
# Epoch 10/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0517 - accuracy: 0.9824 - val_loss: 0.3867 - val_accuracy: 0.8918
# Epoch 11/100
# 36/36 [==============================] - 6s 154ms/step - loss: 0.0398 - accuracy: 0.9886 - val_loss: 0.4593 - val_accuracy: 0.8945
# Epoch 12/100
# 36/36 [==============================] - 6s 154ms/step - loss: 0.0211 - accuracy: 0.9943 - val_loss: 0.3711 - val_accuracy: 0.9103
# Epoch 13/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.6172 - val_accuracy: 0.8773
# Epoch 14/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0731 - accuracy: 0.9758 - val_loss: 5.3529 - val_accuracy: 0.5989
# Epoch 15/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.1051 - accuracy: 0.9648 - val_loss: 1.4274 - val_accuracy: 0.7005
# Epoch 16/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0515 - accuracy: 0.9828 - val_loss: 1.0477 - val_accuracy: 0.7718
# Epoch 17/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0235 - accuracy: 0.9903 - val_loss: 0.3824 - val_accuracy: 0.8945
# Epoch 18/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0296 - accuracy: 0.9908 - val_loss: 1.9655 - val_accuracy: 0.6913
# Epoch 19/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0395 - accuracy: 0.9886 - val_loss: 0.6811 - val_accuracy: 0.8298
# Epoch 20/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0600 - accuracy: 0.9776 - val_loss: 0.8106 - val_accuracy: 0.8021
# Epoch 21/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0368 - accuracy: 0.9868 - val_loss: 3.0568 - val_accuracy: 0.5251
# Epoch 22/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0324 - accuracy: 0.9886 - val_loss: 0.3257 - val_accuracy: 0.9169
# Epoch 23/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0236 - accuracy: 0.9916 - val_loss: 3.1257 - val_accuracy: 0.5792
# Epoch 24/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0407 - accuracy: 0.9868 - val_loss: 0.9945 - val_accuracy: 0.8074
# Epoch 25/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.5167 - val_accuracy: 0.9011
# Epoch 26/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0209 - accuracy: 0.9938 - val_loss: 0.6114 - val_accuracy: 0.8325
# Epoch 27/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.4221 - val_accuracy: 0.9208
# Epoch 28/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.3752 - val_accuracy: 0.8997
# Epoch 29/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.3615 - val_accuracy: 0.9037
# Epoch 30/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.5902 - val_accuracy: 0.8654
# Epoch 31/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0399 - accuracy: 0.9872 - val_loss: 0.6300 - val_accuracy: 0.8641
# Epoch 32/100
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0181 - accuracy: 0.9930 - val_loss: 0.2466 - val_accuracy: 0.9393
# Epoch 33/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0251 - accuracy: 0.9925 - val_loss: 0.6281 - val_accuracy: 0.8760
# Epoch 34/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0730 - accuracy: 0.9749 - val_loss: 1.6396 - val_accuracy: 0.6623
# Epoch 35/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0495 - accuracy: 0.9850 - val_loss: 0.4867 - val_accuracy: 0.8799
# Epoch 36/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.6103 - val_accuracy: 0.8681
# Epoch 37/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0206 - accuracy: 0.9921 - val_loss: 1.4474 - val_accuracy: 0.7573
# Epoch 38/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.6661 - val_accuracy: 0.8311
# Epoch 39/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 0.5582 - val_accuracy: 0.8747
# Epoch 40/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.7563 - val_accuracy: 0.8311
# Epoch 41/100
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.5051 - val_accuracy: 0.8694
# Epoch 42/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.3915 - val_accuracy: 0.8984
# Epoch 43/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.3630 - val_accuracy: 0.9406
# Epoch 44/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 1.7415 - val_accuracy: 0.7230
# Epoch 45/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0437 - accuracy: 0.9837 - val_loss: 10.6982 - val_accuracy: 0.5923
# Epoch 46/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0450 - accuracy: 0.9837 - val_loss: 0.8226 - val_accuracy: 0.8364
# Epoch 47/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0303 - accuracy: 0.9881 - val_loss: 0.9723 - val_accuracy: 0.8430
# Epoch 48/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 1.0377 - val_accuracy: 0.8100
# Epoch 49/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0385 - accuracy: 0.9881 - val_loss: 2.5475 - val_accuracy: 0.6807
# Epoch 50/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0329 - accuracy: 0.9903 - val_loss: 0.9276 - val_accuracy: 0.8074
# Epoch 51/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.4554 - val_accuracy: 0.8984
# Epoch 52/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.6687 - val_accuracy: 0.8496
# Epoch 53/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.3833 - val_accuracy: 0.9116
# Epoch 54/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.2749 - val_accuracy: 0.9288
# Epoch 55/100
# 36/36 [==============================] - 5s 153ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.2420 - val_accuracy: 0.9499
# Epoch 56/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.3881 - val_accuracy: 0.9169
# Epoch 57/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.3835 - val_accuracy: 0.9261
# Epoch 58/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0101 - accuracy: 0.9947 - val_loss: 0.3268 - val_accuracy: 0.9169
# Epoch 59/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.4549 - val_accuracy: 0.8852
# Epoch 60/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.3972 - val_accuracy: 0.9182
# Epoch 61/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.3408 - val_accuracy: 0.9222
# Epoch 62/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 0.4676 - val_accuracy: 0.8958
# Epoch 63/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.9559 - val_accuracy: 0.8206
# Epoch 64/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0868 - accuracy: 0.9754 - val_loss: 3.2610 - val_accuracy: 0.5712
# Epoch 65/100
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0382 - accuracy: 0.9886 - val_loss: 1.0019 - val_accuracy: 0.7916
# Epoch 66/100
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0502 - accuracy: 0.9859 - val_loss: 1.6786 - val_accuracy: 0.7902
# Epoch 67/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.4513 - val_accuracy: 0.9011
# Epoch 68/100
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0119 - accuracy: 0.9952 - val_loss: 1.0789 - val_accuracy: 0.8562
# Epoch 69/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.4089 - val_accuracy: 0.9222
# Epoch 70/100
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.4379 - val_accuracy: 0.9195
# Epoch 71/100
# 36/36 [==============================] - 5s 148ms/step - loss: 4.8755e-04 - accuracy: 1.0000 - val_loss: 0.3105 - val_accuracy: 0.9340
# Epoch 72/100
# 36/36 [==============================] - 5s 148ms/step - loss: 2.4660e-04 - accuracy: 1.0000 - val_loss: 0.2776 - val_accuracy: 0.9420
# Epoch 73/100
# 36/36 [==============================] - 5s 152ms/step - loss: 3.1343e-04 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9472
# Epoch 74/100
# 36/36 [==============================] - 5s 149ms/step - loss: 1.8818e-04 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9499
# Epoch 75/100
# 36/36 [==============================] - ETA: 0s - loss: 7.4290e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 55.
# 36/36 [==============================] - 6s 154ms/step - loss: 7.4290e-05 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9499
# Epoch 00075: early stopping
# Maximal validation accuracy: 94.99%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.497771  0.817942  4.495474      0.191293
# 1   0.224123  0.916007  1.193342      0.666227
# 2   0.119122  0.953826  3.376125      0.597625
# 3   0.122116  0.955145  1.675595      0.604222
# 4   0.097475  0.963940  0.809224      0.778364
# ..       ...       ...       ...           ...
# 70  0.000488  1.000000  0.310465      0.934037
# 71  0.000247  1.000000  0.277552      0.941953
# 72  0.000313  1.000000  0.267099      0.947230
# 73  0.000188  1.000000  0.258065      0.949868
# 74  0.000074  1.000000  0.258893      0.949868
#
# [75 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.24204181134700775
# Maximum validation accuracy: 0.9498680830001831

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2632 - accuracy: 0.9472
# test loss, test acc: [0.263239324092865, 0.9472295641899109]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 24/24 [==============================] - 2s 25ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_DenseNet121_None
# test loss, test acc: [0.092092365026474, 0.9719763994216919]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_DenseNet121_imagenet
# test loss, test acc: [0.05582685023546219, 0.9808259606361389]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_DenseNet121_None
# test loss, test acc: [4.272927761077881, 0.35092347860336304]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_DenseNet121_imagenet
# test loss, test acc: [0.263239324092865, 0.9472295641899109]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_DenseNet121_None →→→ Target Test
# 24/24 [==============================] - 1s 28ms/step - loss: 5.8824 - accuracy: 0.2322
# test loss, test acc: [5.882412433624268, 0.23218996822834015]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_DenseNet121_imagenet →→→ Target Test
# 24/24 [==============================] - 1s 28ms/step - loss: 3.8717 - accuracy: 0.3008
# test loss, test acc: [3.8716766834259033, 0.30079156160354614]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_DenseNet121_None →→→ Source Test
# 22/22 [==============================] - 1s 28ms/step - loss: 6.2117 - accuracy: 0.2596
# test loss, test acc: [6.211740016937256, 0.25958701968193054]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_DenseNet121_imagenet →→→ Source Test
# 22/22 [==============================] - 1s 28ms/step - loss: 5.3117 - accuracy: 0.2316
# test loss, test acc: [5.311720371246338, 0.23156341910362244]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
