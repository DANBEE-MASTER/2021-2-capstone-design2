# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import pandas as pd
import os

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7701298808222649505
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12851507493724168627
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 19:54:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    33W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. Hyperparameter setup

# %%
# Dataset hyperparameters
image_size = 128
image_channels = 3

# Algorithm hyperparameters
num_epochs = 100
patience_num = 10
class_num = 3
batch_size = 64  
width = 128
temperature = 0.1

# Stronger augmentations for contrastive, weaker ones for supervised training
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2}
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

#base_path = ''
base_path = 'gdrive/My Drive/Research_3_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/3 - SimCLR_result/'

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
# Out:
# (1440, 128, 128, 3) (1440, 1)
# (480, 128, 128, 3) (480, 1)
# (480, 128, 128, 3) (480, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

# %% [markdown]
# ## 2-2. Dataset

# %%
labeled_train_data = tf.data.Dataset.from_tensor_slices((xTrain_S, yTrain_S))
unlabeled_train_data = tf.data.Dataset.from_tensor_slices((xValid_S, yValid_S))
test_data = tf.data.Dataset.from_tensor_slices((xTest_S, yTest_S))

# %%
labeled_train_dataset = labeled_train_data.batch(batch_size)
unlabeled_train_dataset = unlabeled_train_data.batch(batch_size)
test_dataset = test_data.batch(batch_size)

# %%
train_dataset = tf.data.Dataset.zip(
        (unlabeled_train_dataset, labeled_train_dataset)
    ).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
print ('labeled_train_dataset : ' , labeled_train_dataset)
print ('labeled_train_dataset 총 batch_size 세트 : ' , len(labeled_train_dataset))
print ('unlabeled_train_dataset : ' , unlabeled_train_dataset)
print ('unlabeled_train_dataset 총 batch_size 세트 : ' , len(unlabeled_train_dataset))
print ('test_dataset : ' , test_dataset)
print ('test_dataset 총 batch_size 세트 : ' , len(test_dataset)) 
print ('train_dataset : ' , train_dataset)
print ('train_dataset 총 batch_size 세트 : ' , len(train_dataset))
# Out:
# labeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# labeled_train_dataset 총 batch_size 세트 :  23
# unlabeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# unlabeled_train_dataset 총 batch_size 세트 :  8
# test_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# test_dataset 총 batch_size 세트 :  8
# train_dataset :  <PrefetchDataset shapes: (((None, 128, 128, 3), (None, 1)), ((None, 128, 128, 3), (None, 1))), types: ((tf.float32, tf.int32), (tf.float32, tf.int32))>
# train_dataset 총 batch_size 세트 :  8

# %% [markdown]
# ## 2-3. Image augmentations and visualize_augmentations

# %%
from tensorflow.keras.layers.experimental import preprocessing

# %%
# Distorts the color distibutions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def call(self, images, training=True):
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images


# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    zoom_factor = 1.0 - tf.sqrt(min_area)
    return tf.keras.Sequential(
        [
            tf.keras.Input(shape=(image_size, image_size, image_channels)),
            #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255),
            tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
            tf.keras.layers.experimental.preprocessing.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
            tf.keras.layers.experimental.preprocessing.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
            RandomColorAffine(brightness, jitter),
        ]
    )


def visualize_augmentations(num_images):
    # Sample a batch from a dataset
    images = next(iter(train_dataset))[0][0][:num_images]
    # Apply augmentations
    augmented_images = zip(
        (images),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255)(images),
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Weakly augmented:",
        "Strongly augmented:",
        "Strongly augmented:",
    ]
    plt.figure(figsize=(num_images * 2.2, 4 * 2.2), dpi=100)
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc="left")
            plt.axis("off")
    plt.tight_layout()

# %%
visualize_augmentations(num_images=8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 3. Network

# %% [markdown]
# ## 3-1. Encoder architecture

# %%
def get_encoder():
    base_model = tf.keras.applications.Xception(
    weights='imagenet',
    include_top=False,
    pooling='avg')
    
    model = keras.Sequential([
    base_model,
    layers.Dense(width, activation="relu"),
    ])
    
    return model

# %% [markdown]
# ## 3-2. Supervised baseline model - original image

# %%
# Baseline supervised training with random initialization
baseline_model_original_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        #get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_original_image",
)

baseline_model_original_image.summary()

baseline_model_original_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "baseline_model_original_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 128)               21123752
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21,148,715
# Trainable params: 21,094,187
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_original_image_history = baseline_model_original_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_original_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 23/23 [==============================] - 18s 313ms/step - loss: 0.3133 - acc: 0.9035 - val_loss: 3.3499 - val_acc: 0.8625
# Epoch 2/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0737 - acc: 0.9812 - val_loss: 5.7931 - val_acc: 0.7625
# Epoch 3/100
# 23/23 [==============================] - 6s 253ms/step - loss: 0.0706 - acc: 0.9854 - val_loss: 34.2829 - val_acc: 0.5375
# Epoch 4/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0300 - acc: 0.9924 - val_loss: 3.9538 - val_acc: 0.8250
# Epoch 5/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0418 - acc: 0.9861 - val_loss: 5.1511 - val_acc: 0.7375
# Epoch 6/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0238 - acc: 0.9924 - val_loss: 4.9230 - val_acc: 0.7750
# Epoch 7/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0129 - acc: 0.9972 - val_loss: 1.2012 - val_acc: 0.8604
# Epoch 8/100
# 23/23 [==============================] - 6s 256ms/step - loss: 0.0027 - acc: 0.9993 - val_loss: 0.9418 - val_acc: 0.9229
# Epoch 9/100
# 23/23 [==============================] - 6s 255ms/step - loss: 2.3765e-04 - acc: 1.0000 - val_loss: 0.4103 - val_acc: 0.9625
# Epoch 10/100
# 23/23 [==============================] - 6s 258ms/step - loss: 5.7578e-05 - acc: 1.0000 - val_loss: 0.2260 - val_acc: 0.9812
# Epoch 11/100
# 23/23 [==============================] - 6s 256ms/step - loss: 3.8309e-05 - acc: 1.0000 - val_loss: 0.1558 - val_acc: 0.9875
# Epoch 12/100
# 23/23 [==============================] - 6s 256ms/step - loss: 2.9642e-05 - acc: 1.0000 - val_loss: 0.1229 - val_acc: 0.9896
# Epoch 13/100
# 23/23 [==============================] - 6s 252ms/step - loss: 2.4215e-05 - acc: 1.0000 - val_loss: 0.1000 - val_acc: 0.9896
# Epoch 14/100
# 23/23 [==============================] - 6s 252ms/step - loss: 2.0376e-05 - acc: 1.0000 - val_loss: 0.0802 - val_acc: 0.9896
# Epoch 15/100
# 23/23 [==============================] - 6s 252ms/step - loss: 1.7502e-05 - acc: 1.0000 - val_loss: 0.0645 - val_acc: 0.9896
# Epoch 16/100
# 23/23 [==============================] - 6s 256ms/step - loss: 1.5264e-05 - acc: 1.0000 - val_loss: 0.0545 - val_acc: 0.9937
# Epoch 17/100
# 23/23 [==============================] - 6s 252ms/step - loss: 1.3471e-05 - acc: 1.0000 - val_loss: 0.0485 - val_acc: 0.9937
# Epoch 18/100
# 23/23 [==============================] - 6s 252ms/step - loss: 1.2009e-05 - acc: 1.0000 - val_loss: 0.0444 - val_acc: 0.9937
# Epoch 19/100
# 23/23 [==============================] - 6s 252ms/step - loss: 1.0793e-05 - acc: 1.0000 - val_loss: 0.0414 - val_acc: 0.9937
# Epoch 20/100
# 23/23 [==============================] - 6s 253ms/step - loss: 9.7695e-06 - acc: 1.0000 - val_loss: 0.0392 - val_acc: 0.9937
# Epoch 21/100
# 23/23 [==============================] - 6s 253ms/step - loss: 8.8975e-06 - acc: 1.0000 - val_loss: 0.0376 - val_acc: 0.9937
# Epoch 22/100
# 23/23 [==============================] - 6s 252ms/step - loss: 8.1450e-06 - acc: 1.0000 - val_loss: 0.0364 - val_acc: 0.9937
# Epoch 23/100
# 23/23 [==============================] - 6s 252ms/step - loss: 7.4908e-06 - acc: 1.0000 - val_loss: 0.0355 - val_acc: 0.9937
# Epoch 24/100
# 23/23 [==============================] - 6s 252ms/step - loss: 6.9193e-06 - acc: 1.0000 - val_loss: 0.0348 - val_acc: 0.9937
# Epoch 25/100
# 23/23 [==============================] - 6s 252ms/step - loss: 6.4118e-06 - acc: 1.0000 - val_loss: 0.0343 - val_acc: 0.9937
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 5.9635e-06 - acc: 1.0000Restoring model weights from the end of the best epoch: 16.
# 23/23 [==============================] - 6s 255ms/step - loss: 5.9635e-06 - acc: 1.0000 - val_loss: 0.0339 - val_acc: 0.9937
# Epoch 00026: early stopping
# Maximal validation accuracy: 99.37%

# %%
baseline_model_original_image_df = pd.DataFrame(baseline_model_original_image_history.history)
baseline_model_original_image_df.to_csv( path_model_result + 'baseline_model_original_image_df.csv' )
baseline_model_original_image_df
# Out:
#         loss       acc   val_loss   val_acc
# 0   0.313267  0.903472   3.349935  0.862500
# 1   0.073731  0.981250   5.793092  0.762500
# 2   0.070614  0.985417  34.282925  0.537500
# 3   0.030049  0.992361   3.953823  0.825000
# 4   0.041821  0.986111   5.151112  0.737500
# 5   0.023754  0.992361   4.923024  0.775000
# 6   0.012929  0.997222   1.201203  0.860417
# 7   0.002725  0.999306   0.941819  0.922917
# 8   0.000238  1.000000   0.410272  0.962500
# 9   0.000058  1.000000   0.225952  0.981250
# 10  0.000038  1.000000   0.155829  0.987500
# 11  0.000030  1.000000   0.122935  0.989583
# 12  0.000024  1.000000   0.100035  0.989583
# 13  0.000020  1.000000   0.080151  0.989583
# 14  0.000018  1.000000   0.064500  0.989583
# 15  0.000015  1.000000   0.054475  0.993750
# 16  0.000013  1.000000   0.048476  0.993750
# 17  0.000012  1.000000   0.044356  0.993750
# 18  0.000011  1.000000   0.041371  0.993750
# 19  0.000010  1.000000   0.039162  0.993750
# 20  0.000009  1.000000   0.037573  0.993750
# 21  0.000008  1.000000   0.036374  0.993750
# 22  0.000007  1.000000   0.035474  0.993750
# 23  0.000007  1.000000   0.034803  0.993750
# 24  0.000006  1.000000   0.034295  0.993750
# 25  0.000006  1.000000   0.033919  0.993750

# %% [markdown]
# ## 3-3. Supervised baseline model - augmenter image

# %%
# Baseline supervised training with random initialization
baseline_model_augmenter_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_augmenter_image",
)

baseline_model_augmenter_image.summary()

baseline_model_augmenter_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Model: "baseline_model_augmenter_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 128, 128, 3)       0
#
#  sequential_5 (Sequential)   (None, 128)               21123752
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21,148,715
# Trainable params: 21,094,187
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_augmenter_image_history = baseline_model_augmenter_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_augmenter_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 23/23 [==============================] - 11s 299ms/step - loss: 0.4551 - acc: 0.8451 - val_loss: 8.6981 - val_acc: 0.7458
# Epoch 2/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.1430 - acc: 0.9604 - val_loss: 2.5976 - val_acc: 0.8313
# Epoch 3/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.1081 - acc: 0.9743 - val_loss: 1.9187 - val_acc: 0.8583
# Epoch 4/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0824 - acc: 0.9826 - val_loss: 2.6914 - val_acc: 0.7333
# Epoch 5/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0943 - acc: 0.9750 - val_loss: 0.6268 - val_acc: 0.9229
# Epoch 6/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0545 - acc: 0.9847 - val_loss: 0.2665 - val_acc: 0.9625
# Epoch 7/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0355 - acc: 0.9875 - val_loss: 0.0572 - val_acc: 0.9833
# Epoch 8/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0538 - acc: 0.9826 - val_loss: 0.0395 - val_acc: 0.9896
# Epoch 9/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0405 - acc: 0.9917 - val_loss: 0.8057 - val_acc: 0.9354
# Epoch 10/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0557 - acc: 0.9861 - val_loss: 0.1354 - val_acc: 0.9688
# Epoch 11/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0242 - acc: 0.9917 - val_loss: 0.0487 - val_acc: 0.9896
# Epoch 12/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0363 - acc: 0.9917 - val_loss: 0.1288 - val_acc: 0.9583
# Epoch 13/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0118 - acc: 0.9979 - val_loss: 0.0286 - val_acc: 0.9937
# Epoch 14/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0329 - acc: 0.9910 - val_loss: 0.1725 - val_acc: 0.9812
# Epoch 15/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0290 - acc: 0.9944 - val_loss: 0.1019 - val_acc: 0.9792
# Epoch 16/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0248 - acc: 0.9931 - val_loss: 0.0443 - val_acc: 0.9896
# Epoch 17/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0063 - acc: 0.9979 - val_loss: 0.0651 - val_acc: 0.9896
# Epoch 18/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0062 - acc: 0.9979 - val_loss: 0.0262 - val_acc: 0.9937
# Epoch 19/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0140 - acc: 0.9958 - val_loss: 0.0189 - val_acc: 0.9958
# Epoch 20/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0498 - acc: 0.9868 - val_loss: 0.3914 - val_acc: 0.9333
# Epoch 21/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0286 - acc: 0.9951 - val_loss: 0.6234 - val_acc: 0.9146
# Epoch 22/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0184 - acc: 0.9944 - val_loss: 0.2427 - val_acc: 0.9750
# Epoch 23/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0235 - acc: 0.9931 - val_loss: 0.4674 - val_acc: 0.9312
# Epoch 24/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0207 - acc: 0.9917 - val_loss: 0.0762 - val_acc: 0.9854
# Epoch 25/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0231 - acc: 0.9924 - val_loss: 0.0693 - val_acc: 0.9854
# Epoch 26/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0039 - acc: 0.9986 - val_loss: 0.0214 - val_acc: 0.9958
# Epoch 27/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0053 - acc: 0.9979 - val_loss: 0.6738 - val_acc: 0.9167
# Epoch 28/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0181 - acc: 0.9958 - val_loss: 0.0362 - val_acc: 0.9937
# Epoch 29/100
# 23/23 [==============================] - 6s 262ms/step - loss: 0.0115 - acc: 0.9972 - val_loss: 0.0066 - val_acc: 0.9979
# Epoch 30/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0107 - acc: 0.9979 - val_loss: 0.0561 - val_acc: 0.9833
# Epoch 31/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0292 - acc: 0.9931 - val_loss: 0.7237 - val_acc: 0.9354
# Epoch 32/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0126 - acc: 0.9965 - val_loss: 0.5524 - val_acc: 0.9375
# Epoch 33/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0148 - acc: 0.9958 - val_loss: 0.0553 - val_acc: 0.9875
# Epoch 34/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0164 - acc: 0.9937 - val_loss: 0.0318 - val_acc: 0.9958
# Epoch 35/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0264 - acc: 0.9924 - val_loss: 0.1730 - val_acc: 0.9667
# Epoch 36/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0301 - acc: 0.9944 - val_loss: 2.9413 - val_acc: 0.9187
# Epoch 37/100
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0300 - acc: 0.9924 - val_loss: 1.5546 - val_acc: 0.8479
# Epoch 38/100
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0190 - acc: 0.9944 - val_loss: 0.1877 - val_acc: 0.9292
# Epoch 39/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0082 - acc: 0.9986Restoring model weights from the end of the best epoch: 29.
# 23/23 [==============================] - 6s 261ms/step - loss: 0.0082 - acc: 0.9986 - val_loss: 0.0553 - val_acc: 0.9833
# Epoch 00039: early stopping
# Maximal validation accuracy: 99.79%

# %%
baseline_model_augmenter_image_df = pd.DataFrame(baseline_model_augmenter_image_history.history)
baseline_model_augmenter_image_df.to_csv( path_model_result + 'baseline_model_augmenter_image_df.csv' )
baseline_model_augmenter_image_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.455148  0.845139  8.698103  0.745833
# 1   0.143037  0.960417  2.597557  0.831250
# 2   0.108113  0.974306  1.918732  0.858333
# 3   0.082396  0.982639  2.691414  0.733333
# 4   0.094334  0.975000  0.626806  0.922917
# 5   0.054528  0.984722  0.266450  0.962500
# 6   0.035535  0.987500  0.057183  0.983333
# 7   0.053813  0.982639  0.039451  0.989583
# 8   0.040527  0.991667  0.805661  0.935417
# 9   0.055728  0.986111  0.135435  0.968750
# 10  0.024221  0.991667  0.048702  0.989583
# 11  0.036317  0.991667  0.128762  0.958333
# 12  0.011800  0.997917  0.028648  0.993750
# 13  0.032914  0.990972  0.172473  0.981250
# 14  0.029005  0.994444  0.101853  0.979167
# 15  0.024822  0.993056  0.044292  0.989583
# 16  0.006286  0.997917  0.065088  0.989583
# 17  0.006220  0.997917  0.026236  0.993750
# 18  0.014005  0.995833  0.018884  0.995833
# 19  0.049789  0.986806  0.391417  0.933333
# 20  0.028645  0.995139  0.623356  0.914583
# 21  0.018400  0.994444  0.242715  0.975000
# 22  0.023507  0.993056  0.467430  0.931250
# 23  0.020732  0.991667  0.076169  0.985417
# 24  0.023119  0.992361  0.069282  0.985417
# 25  0.003934  0.998611  0.021411  0.995833
# 26  0.005304  0.997917  0.673809  0.916667
# 27  0.018081  0.995833  0.036225  0.993750
# 28  0.011542  0.997222  0.006574  0.997917
# 29  0.010685  0.997917  0.056136  0.983333
# 30  0.029163  0.993056  0.723678  0.935417
# 31  0.012557  0.996528  0.552439  0.937500
# 32  0.014785  0.995833  0.055280  0.987500
# 33  0.016355  0.993750  0.031787  0.995833
# 34  0.026413  0.992361  0.172975  0.966667
# 35  0.030078  0.994444  2.941290  0.918750
# 36  0.030032  0.992361  1.554571  0.847917
# 37  0.019035  0.994444  0.187730  0.929167
# 38  0.008219  0.998611  0.055300  0.983333

# %% [markdown]
# ## 3-4. ContrastiveModel - augmenter image

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder = get_encoder()
        # Non-linear MLP as projection head
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(class_num)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(
            name="c_acc"
        )
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        (unlabeled_images, _), (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

# Contrastive pretraining
pretraining_model = ContrastiveModel()
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)

pretraining_history = pretraining_model.fit(
    train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense_8 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 387
# Trainable params: 387
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 8/8 [==============================] - 21s 1s/step - c_loss: 3.8960 - c_acc: 0.1149 - p_loss: 0.9517 - p_acc: 0.5332 - val_p_loss: 0.9379 - val_p_acc: 0.5021
# Epoch 2/100
# 8/8 [==============================] - 8s 975ms/step - c_loss: 2.7464 - c_acc: 0.2767 - p_loss: 0.9376 - p_acc: 0.5273 - val_p_loss: 0.9729 - val_p_acc: 0.5021
# Epoch 3/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 2.2025 - c_acc: 0.3740 - p_loss: 0.9547 - p_acc: 0.5020 - val_p_loss: 1.1600 - val_p_acc: 0.4500
# Epoch 4/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 1.7156 - c_acc: 0.4824 - p_loss: 0.9405 - p_acc: 0.5098 - val_p_loss: 0.9154 - val_p_acc: 0.5688
# Epoch 5/100
# 8/8 [==============================] - 8s 990ms/step - c_loss: 1.5676 - c_acc: 0.5519 - p_loss: 0.7000 - p_acc: 0.6973 - val_p_loss: 0.8285 - val_p_acc: 0.5938
# Epoch 6/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 1.2941 - c_acc: 0.6275 - p_loss: 0.7312 - p_acc: 0.6250 - val_p_loss: 0.7234 - val_p_acc: 0.6583
# Epoch 7/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 1.1240 - c_acc: 0.6981 - p_loss: 0.6787 - p_acc: 0.6953 - val_p_loss: 0.7138 - val_p_acc: 0.7250
# Epoch 8/100
# 8/8 [==============================] - 8s 991ms/step - c_loss: 0.9874 - c_acc: 0.7424 - p_loss: 0.6755 - p_acc: 0.7539 - val_p_loss: 0.6226 - val_p_acc: 0.7667
# Epoch 9/100
# 8/8 [==============================] - 8s 990ms/step - c_loss: 0.8154 - c_acc: 0.7833 - p_loss: 0.5333 - p_acc: 0.7910 - val_p_loss: 0.4625 - val_p_acc: 0.8375
# Epoch 10/100
# 8/8 [==============================] - 8s 991ms/step - c_loss: 0.7681 - c_acc: 0.7984 - p_loss: 0.4676 - p_acc: 0.8203 - val_p_loss: 0.3848 - val_p_acc: 0.8687
# Epoch 11/100
# 8/8 [==============================] - 8s 975ms/step - c_loss: 0.6947 - c_acc: 0.8211 - p_loss: 0.4546 - p_acc: 0.8457 - val_p_loss: 0.4098 - val_p_acc: 0.8375
# Epoch 12/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 0.6435 - c_acc: 0.8407 - p_loss: 0.4537 - p_acc: 0.8457 - val_p_loss: 0.3293 - val_p_acc: 0.8896
# Epoch 13/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 0.6027 - c_acc: 0.8483 - p_loss: 0.3501 - p_acc: 0.8906 - val_p_loss: 0.2957 - val_p_acc: 0.9146
# Epoch 14/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 0.5198 - c_acc: 0.8821 - p_loss: 0.3384 - p_acc: 0.8984 - val_p_loss: 0.2794 - val_p_acc: 0.9375
# Epoch 15/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.4746 - c_acc: 0.9037 - p_loss: 0.3674 - p_acc: 0.8867 - val_p_loss: 0.3100 - val_p_acc: 0.9146
# Epoch 16/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.4341 - c_acc: 0.9168 - p_loss: 0.3728 - p_acc: 0.8809 - val_p_loss: 0.3035 - val_p_acc: 0.9083
# Epoch 17/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.3884 - c_acc: 0.9264 - p_loss: 0.3467 - p_acc: 0.8828 - val_p_loss: 0.3008 - val_p_acc: 0.9271
# Epoch 18/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.3692 - c_acc: 0.9279 - p_loss: 0.3180 - p_acc: 0.9043 - val_p_loss: 0.3114 - val_p_acc: 0.9271
# Epoch 19/100
# 8/8 [==============================] - 8s 975ms/step - c_loss: 0.3224 - c_acc: 0.9385 - p_loss: 0.3173 - p_acc: 0.8965 - val_p_loss: 0.2784 - val_p_acc: 0.9271
# Epoch 20/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.2977 - c_acc: 0.9511 - p_loss: 0.2920 - p_acc: 0.9219 - val_p_loss: 0.2726 - val_p_acc: 0.9333
# Epoch 21/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.2916 - c_acc: 0.9486 - p_loss: 0.3021 - p_acc: 0.9180 - val_p_loss: 0.2966 - val_p_acc: 0.9229
# Epoch 22/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.2520 - c_acc: 0.9577 - p_loss: 0.3123 - p_acc: 0.8926 - val_p_loss: 0.2758 - val_p_acc: 0.9167
# Epoch 23/100
# 8/8 [==============================] - 8s 992ms/step - c_loss: 0.2311 - c_acc: 0.9652 - p_loss: 0.2819 - p_acc: 0.9238 - val_p_loss: 0.2313 - val_p_acc: 0.9438
# Epoch 24/100
# 8/8 [==============================] - 8s 990ms/step - c_loss: 0.2269 - c_acc: 0.9612 - p_loss: 0.2637 - p_acc: 0.9395 - val_p_loss: 0.2386 - val_p_acc: 0.9479
# Epoch 25/100
# 8/8 [==============================] - 8s 993ms/step - c_loss: 0.1939 - c_acc: 0.9743 - p_loss: 0.2713 - p_acc: 0.9219 - val_p_loss: 0.2475 - val_p_acc: 0.9542
# Epoch 26/100
# 8/8 [==============================] - 8s 990ms/step - c_loss: 0.2002 - c_acc: 0.9738 - p_loss: 0.2563 - p_acc: 0.9238 - val_p_loss: 0.2083 - val_p_acc: 0.9750
# Epoch 27/100
# 8/8 [==============================] - 8s 978ms/step - c_loss: 0.1852 - c_acc: 0.9723 - p_loss: 0.2363 - p_acc: 0.9375 - val_p_loss: 0.1858 - val_p_acc: 0.9667
# Epoch 28/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.1694 - c_acc: 0.9788 - p_loss: 0.2135 - p_acc: 0.9473 - val_p_loss: 0.2016 - val_p_acc: 0.9625
# Epoch 29/100
# 8/8 [==============================] - 8s 978ms/step - c_loss: 0.1654 - c_acc: 0.9788 - p_loss: 0.2131 - p_acc: 0.9375 - val_p_loss: 0.1935 - val_p_acc: 0.9521
# Epoch 30/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.1603 - c_acc: 0.9798 - p_loss: 0.2114 - p_acc: 0.9512 - val_p_loss: 0.1803 - val_p_acc: 0.9646
# Epoch 31/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.1570 - c_acc: 0.9814 - p_loss: 0.2083 - p_acc: 0.9395 - val_p_loss: 0.1949 - val_p_acc: 0.9667
# Epoch 32/100
# 8/8 [==============================] - 8s 975ms/step - c_loss: 0.1413 - c_acc: 0.9844 - p_loss: 0.2058 - p_acc: 0.9395 - val_p_loss: 0.1981 - val_p_acc: 0.9604
# Epoch 33/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.1532 - c_acc: 0.9758 - p_loss: 0.2175 - p_acc: 0.9453 - val_p_loss: 0.2060 - val_p_acc: 0.9521
# Epoch 34/100
# 8/8 [==============================] - 8s 977ms/step - c_loss: 0.1417 - c_acc: 0.9829 - p_loss: 0.2216 - p_acc: 0.9336 - val_p_loss: 0.2005 - val_p_acc: 0.9521
# Epoch 35/100
# 8/8 [==============================] - 8s 976ms/step - c_loss: 0.1323 - c_acc: 0.9874 - p_loss: 0.2078 - p_acc: 0.9492 - val_p_loss: 0.2011 - val_p_acc: 0.9604
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - c_loss: 0.1172 - c_acc: 0.9899 - p_loss: 0.2032 - p_acc: 0.9395Restoring model weights from the end of the best epoch: 26.
# 8/8 [==============================] - 8s 987ms/step - c_loss: 0.1172 - c_acc: 0.9899 - p_loss: 0.2032 - p_acc: 0.9395 - val_p_loss: 0.1773 - val_p_acc: 0.9583
# Epoch 00036: early stopping
# Maximal validation accuracy: 97.50%

# %%
pretraining_model_df = pd.DataFrame(pretraining_history.history)
pretraining_model_df.to_csv( path_model_result + 'pretraining_model_df.csv' )
pretraining_model_df
# Out:
#       c_loss     c_acc    p_loss     p_acc  val_p_loss  val_p_acc
# 0   3.896030  0.114919  0.951665  0.533203    0.937870   0.502083
# 1   2.746413  0.276714  0.937595  0.527344    0.972891   0.502083
# 2   2.202453  0.373992  0.954713  0.501953    1.160029   0.450000
# 3   1.715625  0.482359  0.940475  0.509766    0.915364   0.568750
# 4   1.567609  0.551915  0.700001  0.697266    0.828456   0.593750
# 5   1.294068  0.627520  0.731171  0.625000    0.723433   0.658333
# 6   1.123975  0.698085  0.678685  0.695312    0.713840   0.725000
# 7   0.987351  0.742440  0.675477  0.753906    0.622591   0.766667
# 8   0.815418  0.783266  0.533334  0.791016    0.462510   0.837500
# 9   0.768084  0.798387  0.467638  0.820312    0.384785   0.868750
# 10  0.694714  0.821069  0.454624  0.845703    0.409767   0.837500
# 11  0.643519  0.840726  0.453720  0.845703    0.329342   0.889583
# 12  0.602691  0.848286  0.350128  0.890625    0.295741   0.914583
# 13  0.519753  0.882056  0.338369  0.898438    0.279445   0.937500
# 14  0.474553  0.903730  0.367434  0.886719    0.309970   0.914583
# 15  0.434143  0.916835  0.372837  0.880859    0.303475   0.908333
# 16  0.388422  0.926411  0.346703  0.882812    0.300811   0.927083
# 17  0.369240  0.927923  0.317975  0.904297    0.311406   0.927083
# 18  0.322366  0.938508  0.317339  0.896484    0.278410   0.927083
# 19  0.297731  0.951109  0.291974  0.921875    0.272584   0.933333
# 20  0.291615  0.948589  0.302132  0.917969    0.296584   0.922917
# 21  0.251966  0.957661  0.312324  0.892578    0.275827   0.916667
# 22  0.231093  0.965222  0.281922  0.923828    0.231272   0.943750
# 23  0.226899  0.961190  0.263675  0.939453    0.238603   0.947917
# 24  0.193908  0.974294  0.271288  0.921875    0.247465   0.954167
# 25  0.200160  0.973790  0.256309  0.923828    0.208285   0.975000
# 26  0.185229  0.972278  0.236336  0.937500    0.185842   0.966667
# 27  0.169446  0.978831  0.213532  0.947266    0.201605   0.962500
# 28  0.165448  0.978831  0.213133  0.937500    0.193466   0.952083
# 29  0.160259  0.979839  0.211380  0.951172    0.180340   0.964583
# 30  0.157002  0.981351  0.208275  0.939453    0.194857   0.966667
# 31  0.141322  0.984375  0.205829  0.939453    0.198059   0.960417
# 32  0.153225  0.975806  0.217450  0.945312    0.206031   0.952083
# 33  0.141746  0.982863  0.221586  0.933594    0.200490   0.952083
# 34  0.132333  0.987399  0.207765  0.949219    0.201063   0.960417
# 35  0.117192  0.989919  0.203207  0.939453    0.177257   0.958333

# %% [markdown]
# ## 3-5. Finetuning_model - augmenter image

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(class_num),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 0.2632 - acc: 0.9167WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 11s 286ms/step - loss: 0.2632 - acc: 0.9167 - val_loss: 5.5512 - val_acc: 0.7563
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0723 - acc: 0.9799WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0723 - acc: 0.9799 - val_loss: 4.4352 - val_acc: 0.7563
# Epoch 3/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0941 - acc: 0.9812WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0941 - acc: 0.9812 - val_loss: 12.6676 - val_acc: 0.7125
# Epoch 4/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0748 - acc: 0.9764WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0748 - acc: 0.9764 - val_loss: 13.8586 - val_acc: 0.6313
# Epoch 5/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0438 - acc: 0.9910WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0438 - acc: 0.9910 - val_loss: 2.0672 - val_acc: 0.9250
# Epoch 6/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0147 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0147 - acc: 0.9958 - val_loss: 0.2560 - val_acc: 0.9729
# Epoch 7/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0075 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0075 - acc: 0.9979 - val_loss: 0.2109 - val_acc: 0.9812
# Epoch 8/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0419 - acc: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0419 - acc: 0.9875 - val_loss: 0.6890 - val_acc: 0.9688
# Epoch 9/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0309 - acc: 0.9903WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0309 - acc: 0.9903 - val_loss: 0.8024 - val_acc: 0.9333
# Epoch 10/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0557 - acc: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0557 - acc: 0.9875 - val_loss: 8.3069 - val_acc: 0.7021
# Epoch 11/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0531 - acc: 0.9854WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0531 - acc: 0.9854 - val_loss: 7.3587 - val_acc: 0.5521
# Epoch 12/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0420 - acc: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0420 - acc: 0.9875 - val_loss: 3.6754 - val_acc: 0.7479
# Epoch 13/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0251 - acc: 0.9931WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0251 - acc: 0.9931 - val_loss: 0.1751 - val_acc: 0.9667
# Epoch 14/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0140 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0140 - acc: 0.9951 - val_loss: 0.1541 - val_acc: 0.9729
# Epoch 15/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0293 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0293 - acc: 0.9917 - val_loss: 0.2675 - val_acc: 0.9333
# Epoch 16/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0225 - acc: 0.9944WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0225 - acc: 0.9944 - val_loss: 0.1009 - val_acc: 0.9812
# Epoch 17/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0294 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0294 - acc: 0.9917 - val_loss: 0.1428 - val_acc: 0.9708
# Epoch 18/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0199 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0199 - acc: 0.9972 - val_loss: 0.0141 - val_acc: 0.9979
# Epoch 19/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0081 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0081 - acc: 0.9972 - val_loss: 0.0460 - val_acc: 0.9937
# Epoch 20/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0046 - acc: 0.9986 - val_loss: 0.0481 - val_acc: 0.9937
# Epoch 21/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0015 - acc: 0.9993 - val_loss: 0.0272 - val_acc: 0.9937
# Epoch 22/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0053 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0053 - acc: 0.9979 - val_loss: 0.0186 - val_acc: 0.9937
# Epoch 23/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0057 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0057 - acc: 0.9979 - val_loss: 0.2028 - val_acc: 0.9771
# Epoch 24/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0070 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0070 - acc: 0.9972 - val_loss: 0.0229 - val_acc: 0.9958
# Epoch 25/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0061 - acc: 0.9979 - val_loss: 0.0530 - val_acc: 0.9854
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0036 - acc: 0.9993 - val_loss: 0.1920 - val_acc: 0.9583
# Epoch 27/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0017 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0857 - val_acc: 0.9812
# Epoch 28/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0018 - acc: 0.9993 - val_loss: 0.0392 - val_acc: 0.9896
# Epoch 29/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0154 - val_acc: 0.9958
# Epoch 30/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0199 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0199 - acc: 0.9958 - val_loss: 0.0423 - val_acc: 0.9917
# Epoch 31/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0231 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0231 - acc: 0.9951 - val_loss: 0.4804 - val_acc: 0.9354
# Epoch 32/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0494 - acc: 0.9868WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0494 - acc: 0.9868 - val_loss: 0.6757 - val_acc: 0.9250
# Epoch 33/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0499 - acc: 0.9854WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0499 - acc: 0.9854 - val_loss: 0.4300 - val_acc: 0.9292
# Epoch 34/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0723 - acc: 0.9840WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0723 - acc: 0.9840 - val_loss: 0.2315 - val_acc: 0.9667
# Epoch 35/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0200 - acc: 0.9903WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0200 - acc: 0.9903 - val_loss: 0.0201 - val_acc: 0.9958
# Epoch 36/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0107 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0107 - acc: 0.9972 - val_loss: 0.0816 - val_acc: 0.9708
# Epoch 37/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0061 - acc: 0.9979 - val_loss: 0.0210 - val_acc: 0.9917
# Epoch 38/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0039 - acc: 0.9979 - val_loss: 0.0272 - val_acc: 0.9958
# Epoch 39/100
# 23/23 [==============================] - ETA: 0s - loss: 9.8894e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 9.8894e-04 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 0.9937
# Epoch 40/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0038 - acc: 0.9986 - val_loss: 0.0737 - val_acc: 0.9771
# Epoch 41/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0120 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0120 - acc: 0.9986 - val_loss: 0.0186 - val_acc: 0.9958
# Epoch 42/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0055 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0055 - acc: 0.9986 - val_loss: 0.0080 - val_acc: 0.9958
# Epoch 43/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0140 - acc: 0.9951WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0140 - acc: 0.9951 - val_loss: 0.0501 - val_acc: 0.9833
# Epoch 44/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0035 - acc: 0.9993 - val_loss: 0.0079 - val_acc: 0.9979
# Epoch 45/100
# 23/23 [==============================] - ETA: 0s - loss: 6.9437e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 6.9437e-04 - acc: 1.0000 - val_loss: 0.0059 - val_acc: 0.9958
# Epoch 46/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0015 - acc: 0.9993 - val_loss: 0.0123 - val_acc: 0.9937
# Epoch 47/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0040 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0040 - acc: 0.9986 - val_loss: 0.0773 - val_acc: 0.9792
# Epoch 48/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0207 - acc: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0207 - acc: 0.9937 - val_loss: 0.0880 - val_acc: 0.9833
# Epoch 49/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0074 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0074 - acc: 0.9993 - val_loss: 0.1299 - val_acc: 0.9688
# Epoch 50/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 256ms/step - loss: 0.0032 - acc: 0.9979 - val_loss: 0.0105 - val_acc: 0.9958
# Epoch 51/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0010 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0335 - val_acc: 0.9917
# Epoch 52/100
# 23/23 [==============================] - ETA: 0s - loss: 1.6705e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 1.6705e-04 - acc: 1.0000 - val_loss: 0.0328 - val_acc: 0.9896
# Epoch 53/100
# 23/23 [==============================] - ETA: 0s - loss: 6.8292e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 6.8292e-05 - acc: 1.0000 - val_loss: 0.0291 - val_acc: 0.9917
# Epoch 54/100
# 23/23 [==============================] - ETA: 0s - loss: 1.6150e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 1.6150e-04 - acc: 1.0000 - val_loss: 0.0232 - val_acc: 0.9937
# Epoch 55/100
# 23/23 [==============================] - ETA: 0s - loss: 5.4681e-04 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 5.4681e-04 - acc: 0.9993 - val_loss: 0.0170 - val_acc: 0.9937
# Epoch 56/100
# 23/23 [==============================] - ETA: 0s - loss: 2.6863e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 2.6863e-04 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9958
# Epoch 57/100
# 23/23 [==============================] - ETA: 0s - loss: 6.2220e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 6.2220e-05 - acc: 1.0000 - val_loss: 0.0087 - val_acc: 0.9958
# Epoch 58/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0124 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0124 - acc: 0.9979 - val_loss: 0.0171 - val_acc: 0.9937
# Epoch 59/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0267 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0267 - acc: 0.9972 - val_loss: 0.1571 - val_acc: 0.8938
# Epoch 60/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0422 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0422 - acc: 0.9917 - val_loss: 0.0172 - val_acc: 0.9958
# Epoch 61/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0332 - acc: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0332 - acc: 0.9896 - val_loss: 1.3966 - val_acc: 0.8188
# Epoch 62/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0026 - acc: 0.9993 - val_loss: 0.5653 - val_acc: 0.9021
# Epoch 63/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0181 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0181 - acc: 0.9958 - val_loss: 0.9243 - val_acc: 0.8729
# Epoch 64/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0125 - acc: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0125 - acc: 0.9965 - val_loss: 0.0193 - val_acc: 0.9937
# Epoch 65/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0156 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0156 - acc: 0.9958 - val_loss: 0.0847 - val_acc: 0.9729
# Epoch 66/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0260 - acc: 0.9931WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0260 - acc: 0.9931 - val_loss: 0.0119 - val_acc: 0.9979
# Epoch 67/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0141 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0141 - acc: 0.9958 - val_loss: 0.0120 - val_acc: 0.9958
# Epoch 68/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0118 - acc: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0118 - acc: 0.9965 - val_loss: 0.0516 - val_acc: 0.9854
# Epoch 69/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0069 - acc: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0069 - acc: 0.9965 - val_loss: 0.0306 - val_acc: 0.9917
# Epoch 70/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0018 - acc: 0.9993 - val_loss: 0.0877 - val_acc: 0.9896
# Epoch 71/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0052 - acc: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0052 - acc: 0.9972 - val_loss: 0.0251 - val_acc: 0.9917
# Epoch 72/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0059 - acc: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0059 - acc: 0.9965 - val_loss: 0.0336 - val_acc: 0.9937
# Epoch 73/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0111 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0111 - acc: 0.9958 - val_loss: 0.0321 - val_acc: 0.9896
# Epoch 74/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0046 - acc: 0.9979 - val_loss: 0.0141 - val_acc: 0.9958
# Epoch 75/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0016 - acc: 0.9993 - val_loss: 0.0227 - val_acc: 0.9958
# Epoch 76/100
# 23/23 [==============================] - ETA: 0s - loss: 6.3556e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 6.3556e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9937
# Epoch 77/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0021 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0021 - acc: 0.9986 - val_loss: 0.0209 - val_acc: 0.9958
# Epoch 78/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9993WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0015 - acc: 0.9993 - val_loss: 0.0188 - val_acc: 0.9958
# Epoch 79/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0070 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 0.0070 - acc: 0.9986 - val_loss: 0.0175 - val_acc: 0.9937
# Epoch 80/100
# 23/23 [==============================] - ETA: 0s - loss: 8.9663e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 8.9663e-04 - acc: 1.0000 - val_loss: 0.0292 - val_acc: 0.9958
# Epoch 81/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0031 - acc: 0.9986 - val_loss: 0.0109 - val_acc: 0.9958
# Epoch 82/100
# 23/23 [==============================] - ETA: 0s - loss: 5.0222e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 5.0222e-04 - acc: 1.0000 - val_loss: 0.0273 - val_acc: 0.9958
# Epoch 83/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0153 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0153 - acc: 0.9958 - val_loss: 0.0635 - val_acc: 0.9896
# Epoch 84/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0243 - acc: 0.9924WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0243 - acc: 0.9924 - val_loss: 0.0243 - val_acc: 0.9937
# Epoch 85/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.9986WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 0.0051 - acc: 0.9986 - val_loss: 0.0473 - val_acc: 0.9896
# Epoch 86/100
# 23/23 [==============================] - ETA: 0s - loss: 8.3491e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 8.3491e-04 - acc: 1.0000 - val_loss: 0.0178 - val_acc: 0.9958
# Epoch 87/100
# 23/23 [==============================] - ETA: 0s - loss: 5.4952e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 5.4952e-04 - acc: 1.0000 - val_loss: 0.0065 - val_acc: 0.9979
# Epoch 88/100
# 23/23 [==============================] - ETA: 0s - loss: 3.6031e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 3.6031e-04 - acc: 1.0000 - val_loss: 0.0118 - val_acc: 0.9958
# Epoch 89/100
# 23/23 [==============================] - ETA: 0s - loss: 7.0845e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 7.0845e-05 - acc: 1.0000 - val_loss: 0.0111 - val_acc: 0.9958
# Epoch 90/100
# 23/23 [==============================] - ETA: 0s - loss: 1.1106e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 1.1106e-04 - acc: 1.0000 - val_loss: 0.0081 - val_acc: 0.9979
# Epoch 91/100
# 23/23 [==============================] - ETA: 0s - loss: 1.3201e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 1.3201e-04 - acc: 1.0000 - val_loss: 0.0067 - val_acc: 0.9979
# Epoch 92/100
# 23/23 [==============================] - ETA: 0s - loss: 4.5409e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 4.5409e-05 - acc: 1.0000 - val_loss: 0.0065 - val_acc: 0.9979
# Epoch 93/100
# 23/23 [==============================] - ETA: 0s - loss: 3.1760e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 3.1760e-05 - acc: 1.0000 - val_loss: 0.0069 - val_acc: 0.9979
# Epoch 94/100
# 23/23 [==============================] - ETA: 0s - loss: 1.6463e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 1.6463e-05 - acc: 1.0000 - val_loss: 0.0073 - val_acc: 0.9979
# Epoch 95/100
# 23/23 [==============================] - ETA: 0s - loss: 6.5297e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 258ms/step - loss: 6.5297e-05 - acc: 1.0000 - val_loss: 0.0087 - val_acc: 0.9979
# Epoch 96/100
# 23/23 [==============================] - ETA: 0s - loss: 7.6533e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 7.6533e-05 - acc: 1.0000 - val_loss: 0.0091 - val_acc: 0.9979
# Epoch 97/100
# 23/23 [==============================] - ETA: 0s - loss: 3.7890e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 3.7890e-05 - acc: 1.0000 - val_loss: 0.0097 - val_acc: 0.9979
# Epoch 98/100
# 23/23 [==============================] - ETA: 0s - loss: 2.4180e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 2.4180e-05 - acc: 1.0000 - val_loss: 0.0102 - val_acc: 0.9979
# Epoch 99/100
# 23/23 [==============================] - ETA: 0s - loss: 2.0588e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 2.0588e-05 - acc: 1.0000 - val_loss: 0.0107 - val_acc: 0.9979
# Epoch 100/100
# 23/23 [==============================] - ETA: 0s - loss: 3.5660e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 23/23 [==============================] - 6s 257ms/step - loss: 3.5660e-04 - acc: 1.0000 - val_loss: 0.0095 - val_acc: 0.9979
# Maximal validation accuracy: 99.79%

# %%
finetuning_model_df = pd.DataFrame(finetuning_history.history)
finetuning_model_df.to_csv( path_model_result + 'finetuning_model_df.csv' )
finetuning_model_df
# Out:
#         loss       acc   val_loss   val_acc
# 0   0.263161  0.916667   5.551191  0.756250
# 1   0.072327  0.979861   4.435247  0.756250
# 2   0.094113  0.981250  12.667557  0.712500
# 3   0.074849  0.976389  13.858596  0.631250
# 4   0.043759  0.990972   2.067182  0.925000
# ..       ...       ...        ...       ...
# 95  0.000077  1.000000   0.009103  0.997917
# 96  0.000038  1.000000   0.009657  0.997917
# 97  0.000024  1.000000   0.010244  0.997917
# 98  0.000021  1.000000   0.010662  0.997917
# 99  0.000357  1.000000   0.009491  0.997917
#
# [100 rows x 4 columns]

# %% [markdown]
# ## 4. Result Report

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history):
    for metric_key, metric_name in zip(["acc", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_model_original_image_history.history[f"val_{metric_key}"], label="original_image baseline"
        )
        plt.plot(
            baseline_model_augmenter_image_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")

plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history)

# %%
print (max(baseline_model_original_image_history.history["val_acc"]) * 100)
print (max(baseline_model_augmenter_image_history.history["val_acc"]) * 100)
print (max(pretraining_history.history["val_p_acc"]) * 100)
print (max(finetuning_history.history["val_acc"]) * 100)
# Out:
# 99.37499761581421
# 99.79166388511658
# 97.50000238418579
# 99.79166388511658

# %% [markdown]
# ## 5. Model Save

# %%
save_model = keras.Sequential(
    [
        pretraining_model.encoder,
    ],
    name="pretraining_model",
)

save_model.summary()
# Out:
# Model: "pretraining_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 128)               21123752
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.ckpt' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: gdrive/My Drive/Research_3_2_1/model_result/3 - SimCLR_result/pretraining_model_encoder.ckpt/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
