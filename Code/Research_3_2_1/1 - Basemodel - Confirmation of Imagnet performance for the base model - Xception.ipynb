# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 18044125175983050743
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7124133366081585213
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Sat Dec 18 04:23:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'Xception'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 3
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2"
T_all_labels = "T0", "T1", "T2"

#base_path = ''
base_path = 'gdrive/My Drive/Research_3_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_Xception_None S_Xception_imagenet T_Xception_None T_Xception_imagenet
# ['S_Xception_imagenet',
#  'S_Xception_None',
#  'T_Xception_imagenet',
#  'T_Xception_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1440, 128, 128, 3) (1440, 1)
# (480, 128, 128, 3) (480, 1)
# (480, 128, 128, 3) (480, 1)
#
# (1920, 128, 128, 3) (1920, 1)
# (640, 128, 128, 3) (640, 1)
# (640, 128, 128, 3) (640, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1440, 128, 128, 3) (1440, 3)
# (480, 128, 128, 3) (480, 3)
# (480, 128, 128, 3) (480, 3)
#
# (1920, 128, 128, 3) (1920, 3)
# (640, 128, 128, 3) (640, 3)
# (640, 128, 128, 3) (640, 3)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1440
# xTrain_S image Numbers // 10 :  144
# 10

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1920
# xTrain_S image Numbers // 10 :  192
# 10

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 19s 317ms/step - loss: 0.4246 - accuracy: 0.8361 - val_loss: 1.0997 - val_accuracy: 0.2500
# Epoch 2/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.1813 - accuracy: 0.9361 - val_loss: 1.0998 - val_accuracy: 0.2500
# Epoch 3/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.1234 - accuracy: 0.9632 - val_loss: 1.1084 - val_accuracy: 0.2500
# Epoch 4/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0939 - accuracy: 0.9715 - val_loss: 1.1171 - val_accuracy: 0.2500
# Epoch 5/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.1503 - accuracy: 0.9493 - val_loss: 1.1238 - val_accuracy: 0.2500
# Epoch 6/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.1117 - accuracy: 0.9632 - val_loss: 1.1289 - val_accuracy: 0.2500
# Epoch 7/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0526 - accuracy: 0.9868 - val_loss: 1.1345 - val_accuracy: 0.2500
# Epoch 8/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0548 - accuracy: 0.9847 - val_loss: 1.1515 - val_accuracy: 0.2500
# Epoch 9/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0477 - accuracy: 0.9861 - val_loss: 1.1908 - val_accuracy: 0.2500
# Epoch 10/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0309 - accuracy: 0.9944 - val_loss: 1.2652 - val_accuracy: 0.2500
# Epoch 11/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0577 - accuracy: 0.9799 - val_loss: 1.2820 - val_accuracy: 0.2500
# Epoch 12/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0313 - accuracy: 0.9896 - val_loss: 1.4276 - val_accuracy: 0.2500
# Epoch 13/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0546 - accuracy: 0.9847 - val_loss: 1.5417 - val_accuracy: 0.2500
# Epoch 14/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0670 - accuracy: 0.9812 - val_loss: 1.5987 - val_accuracy: 0.2500
# Epoch 15/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0357 - accuracy: 0.9917 - val_loss: 2.1933 - val_accuracy: 0.2500
# Epoch 16/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0317 - accuracy: 0.9910 - val_loss: 2.8471 - val_accuracy: 0.2500
# Epoch 17/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0600 - accuracy: 0.9826 - val_loss: 2.8860 - val_accuracy: 0.2500
# Epoch 18/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0327 - accuracy: 0.9931 - val_loss: 3.1273 - val_accuracy: 0.2500
# Epoch 19/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0151 - accuracy: 0.9958 - val_loss: 4.3991 - val_accuracy: 0.2500
# Epoch 20/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0817 - accuracy: 0.9806 - val_loss: 6.0605 - val_accuracy: 0.2521
# Epoch 21/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0371 - accuracy: 0.9882 - val_loss: 1.3033 - val_accuracy: 0.6187
# Epoch 22/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.7016 - val_accuracy: 0.7812
# Epoch 23/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.9121 - val_accuracy: 0.7500
# Epoch 24/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0038 - accuracy: 0.9979 - val_loss: 0.7398 - val_accuracy: 0.7771
# Epoch 25/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0090 - accuracy: 0.9958 - val_loss: 0.8437 - val_accuracy: 0.7792
# Epoch 26/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0160 - accuracy: 0.9931 - val_loss: 0.5952 - val_accuracy: 0.8813
# Epoch 27/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0596 - accuracy: 0.9875 - val_loss: 0.5963 - val_accuracy: 0.8604
# Epoch 28/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0478 - accuracy: 0.9833 - val_loss: 0.4646 - val_accuracy: 0.8938
# Epoch 29/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0261 - accuracy: 0.9924 - val_loss: 0.9868 - val_accuracy: 0.8917
# Epoch 30/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0156 - accuracy: 0.9944 - val_loss: 0.2446 - val_accuracy: 0.9563
# Epoch 31/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.4541 - val_accuracy: 0.9312
# Epoch 32/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0496 - accuracy: 0.9840 - val_loss: 1.8439 - val_accuracy: 0.7875
# Epoch 33/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0183 - accuracy: 0.9931 - val_loss: 1.3730 - val_accuracy: 0.8271
# Epoch 34/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.4243 - val_accuracy: 0.9104
# Epoch 35/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.5662 - val_accuracy: 0.9042
# Epoch 36/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0193 - accuracy: 0.9910 - val_loss: 1.3852 - val_accuracy: 0.8354
# Epoch 37/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0097 - accuracy: 0.9958 - val_loss: 0.7543 - val_accuracy: 0.8729
# Epoch 38/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.2866 - val_accuracy: 0.9521
# Epoch 39/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.3858 - val_accuracy: 0.9438
# Epoch 40/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0210 - accuracy: 0.9958 - val_loss: 1.1070 - val_accuracy: 0.8083
# Epoch 41/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.6131 - val_accuracy: 0.9000
# Epoch 42/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.3336 - val_accuracy: 0.9354
# Epoch 43/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.4456 - val_accuracy: 0.9375
# Epoch 44/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0209 - accuracy: 0.9944 - val_loss: 0.2379 - val_accuracy: 0.9604
# Epoch 45/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0200 - accuracy: 0.9951 - val_loss: 0.2849 - val_accuracy: 0.9521
# Epoch 46/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.7521 - val_accuracy: 0.8979
# Epoch 47/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.3665 - val_accuracy: 0.9458
# Epoch 48/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.1647 - val_accuracy: 0.9625
# Epoch 49/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0027 - accuracy: 0.9986 - val_loss: 0.1922 - val_accuracy: 0.9688
# Epoch 50/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0107 - accuracy: 0.9979 - val_loss: 0.2814 - val_accuracy: 0.9521
# Epoch 51/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.7382 - val_accuracy: 0.8854
# Epoch 52/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.2791 - val_accuracy: 0.9417
# Epoch 53/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.1748 - val_accuracy: 0.9583
# Epoch 54/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0301 - accuracy: 0.9903 - val_loss: 2.1584 - val_accuracy: 0.7563
# Epoch 55/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 2.3258 - val_accuracy: 0.7688
# Epoch 56/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 2.1925 - val_accuracy: 0.7792
# Epoch 57/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.8917
# Epoch 58/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.0231e-04 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.9646
# Epoch 59/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.3703 - val_accuracy: 0.9167
# Epoch 60/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.2785 - val_accuracy: 0.9417
# Epoch 61/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.2049 - val_accuracy: 0.9688
# Epoch 62/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0163 - accuracy: 0.9931 - val_loss: 1.9326 - val_accuracy: 0.8125
# Epoch 63/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 1.4656 - val_accuracy: 0.8562
# Epoch 64/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.4267 - val_accuracy: 0.9521
# Epoch 65/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.5780 - val_accuracy: 0.9479
# Epoch 66/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.9024 - val_accuracy: 0.8646
# Epoch 67/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0099 - accuracy: 0.9979 - val_loss: 0.8761 - val_accuracy: 0.8729
# Epoch 68/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0976 - val_accuracy: 0.9750
# Epoch 69/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0377 - accuracy: 0.9889 - val_loss: 0.3933 - val_accuracy: 0.9229
# Epoch 70/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 2.8511 - val_accuracy: 0.7021
# Epoch 71/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0062 - accuracy: 0.9965 - val_loss: 0.5719 - val_accuracy: 0.9042
# Epoch 72/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0326 - accuracy: 0.9917 - val_loss: 29.2846 - val_accuracy: 0.2667
# Epoch 73/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0133 - accuracy: 0.9993 - val_loss: 0.7312 - val_accuracy: 0.8792
# Epoch 74/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1853 - val_accuracy: 0.9625
# Epoch 75/100
# 23/23 [==============================] - 6s 246ms/step - loss: 5.2731e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9604
# Epoch 76/100
# 23/23 [==============================] - 6s 246ms/step - loss: 3.7637e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9646
# Epoch 77/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.1176 - val_accuracy: 0.9771
# Epoch 78/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.3617 - val_accuracy: 0.9229
# Epoch 79/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0055 - accuracy: 0.9993 - val_loss: 0.2944 - val_accuracy: 0.9500
# Epoch 80/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.2201 - val_accuracy: 0.9604
# Epoch 81/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.2270 - val_accuracy: 0.9500
# Epoch 82/100
# 23/23 [==============================] - 6s 246ms/step - loss: 6.8261e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9625
# Epoch 83/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.1245 - val_accuracy: 0.9708
# Epoch 84/100
# 23/23 [==============================] - 6s 246ms/step - loss: 9.1333e-04 - accuracy: 0.9993 - val_loss: 0.2298 - val_accuracy: 0.9479
# Epoch 85/100
# 23/23 [==============================] - 6s 247ms/step - loss: 5.2190e-04 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9375
# Epoch 86/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 4.4268 - val_accuracy: 0.4938
# Epoch 87/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7855 - val_accuracy: 0.8792
# Epoch 88/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.9125
# Epoch 89/100
# 23/23 [==============================] - 6s 246ms/step - loss: 1.0385e-04 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.9208
# Epoch 90/100
# 23/23 [==============================] - 6s 246ms/step - loss: 2.7420e-04 - accuracy: 1.0000 - val_loss: 0.4371 - val_accuracy: 0.9271
# Epoch 91/100
# 23/23 [==============================] - 6s 245ms/step - loss: 7.6473e-05 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.9438
# Epoch 92/100
# 23/23 [==============================] - 6s 246ms/step - loss: 3.5232e-05 - accuracy: 1.0000 - val_loss: 0.2474 - val_accuracy: 0.9563
# Epoch 93/100
# 23/23 [==============================] - 6s 246ms/step - loss: 3.4202e-05 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9646
# Epoch 94/100
# 23/23 [==============================] - 6s 246ms/step - loss: 8.5532e-05 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9729
# Epoch 95/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.3155e-05 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9750
# Epoch 96/100
# 23/23 [==============================] - 6s 245ms/step - loss: 4.1444e-05 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9750
# Epoch 97/100
# 23/23 [==============================] - 6s 245ms/step - loss: 6.1169e-05 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9708
# Epoch 98/100
# 23/23 [==============================] - 6s 246ms/step - loss: 1.6734e-05 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9708
# Epoch 99/100
# 23/23 [==============================] - 6s 246ms/step - loss: 2.9352e-05 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9708
# Epoch 100/100
# 23/23 [==============================] - 6s 246ms/step - loss: 1.7452e-05 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9708
# Maximal validation accuracy: 97.71%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.424581  0.836111  1.099674      0.250000
# 1   0.181317  0.936111  1.099840      0.250000
# 2   0.123359  0.963194  1.108360      0.250000
# 3   0.093926  0.971528  1.117142      0.250000
# 4   0.150265  0.949306  1.123841      0.250000
# ..       ...       ...       ...           ...
# 95  0.000041  1.000000  0.146110      0.975000
# 96  0.000061  1.000000  0.134743      0.970833
# 97  0.000017  1.000000  0.132833      0.970833
# 98  0.000029  1.000000  0.131546      0.970833
# 99  0.000017  1.000000  0.130653      0.970833
#
# [100 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.09762082248926163
# Maximum validation accuracy: 0.9770833253860474

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 29ms/step - loss: 0.0665 - accuracy: 0.9896
# test loss, test acc: [0.06652709096670151, 0.9895833134651184]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 15/15 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 11s 287ms/step - loss: 0.2611 - accuracy: 0.9097 - val_loss: 5.0308 - val_accuracy: 0.7646
# Epoch 2/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0668 - accuracy: 0.9861 - val_loss: 2.1892 - val_accuracy: 0.8896
# Epoch 3/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0484 - accuracy: 0.9826 - val_loss: 0.9240 - val_accuracy: 0.9458
# Epoch 4/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0639 - accuracy: 0.9840 - val_loss: 1.5252 - val_accuracy: 0.9771
# Epoch 5/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0209 - accuracy: 0.9917 - val_loss: 2.1725 - val_accuracy: 0.8438
# Epoch 6/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0500 - accuracy: 0.9896 - val_loss: 0.3523 - val_accuracy: 0.9750
# Epoch 7/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 2.3755 - val_accuracy: 0.7521
# Epoch 8/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0233 - accuracy: 0.9931 - val_loss: 1.5664 - val_accuracy: 0.8208
# Epoch 9/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0785 - val_accuracy: 0.9792
# Epoch 10/100
# 23/23 [==============================] - 6s 250ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0453 - val_accuracy: 0.9875
# Epoch 11/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0712 - val_accuracy: 0.9792
# Epoch 12/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 0.1351 - val_accuracy: 0.9771
# Epoch 13/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.0635 - val_accuracy: 0.9812
# Epoch 14/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9937
# Epoch 15/100
# 23/23 [==============================] - 6s 251ms/step - loss: 1.3077e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9958
# Epoch 16/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.7039e-04 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9958
# Epoch 17/100
# 23/23 [==============================] - 6s 246ms/step - loss: 3.8463e-05 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9958
# Epoch 18/100
# 23/23 [==============================] - 6s 247ms/step - loss: 6.5972e-05 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9958
# Epoch 19/100
# 23/23 [==============================] - 6s 246ms/step - loss: 2.3275e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9958
# Epoch 20/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.0190e-05 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9958
# Epoch 21/100
# 23/23 [==============================] - 6s 246ms/step - loss: 1.3784e-05 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9958
# Epoch 22/100
# 23/23 [==============================] - 6s 246ms/step - loss: 7.0846e-06 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9958
# Epoch 23/100
# 23/23 [==============================] - 6s 246ms/step - loss: 7.3388e-06 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9958
# Epoch 24/100
# 23/23 [==============================] - 6s 246ms/step - loss: 2.9055e-06 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9958
# Epoch 25/100
# 23/23 [==============================] - 6s 246ms/step - loss: 9.6860e-06 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9958
# Epoch 26/100
# 23/23 [==============================] - 6s 247ms/step - loss: 2.0015e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9958
# Epoch 27/100
# 23/23 [==============================] - 6s 246ms/step - loss: 6.4876e-06 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9958
# Epoch 28/100
# 23/23 [==============================] - 6s 247ms/step - loss: 2.9647e-05 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9958
# Epoch 29/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.0984e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9937
# Epoch 30/100
# 23/23 [==============================] - 6s 247ms/step - loss: 6.9806e-06 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9937
# Epoch 31/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.2874e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9937
# Epoch 32/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.0449e-05 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9958
# Epoch 33/100
# 23/23 [==============================] - 6s 246ms/step - loss: 3.5199e-06 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9958
# Epoch 34/100
# 23/23 [==============================] - 6s 246ms/step - loss: 1.8998e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9958
# Epoch 35/100
# 23/23 [==============================] - ETA: 0s - loss: 1.3332e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 15.
# 23/23 [==============================] - 6s 250ms/step - loss: 1.3332e-05 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9958
# Epoch 00035: early stopping
# Maximal validation accuracy: 99.58%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.261144  0.909722  5.030758      0.764583
# 1   0.066753  0.986111  2.189220      0.889583
# 2   0.048438  0.982639  0.924036      0.945833
# 3   0.063865  0.984028  1.525197      0.977083
# 4   0.020910  0.991667  2.172457      0.843750
# 5   0.049989  0.989583  0.352251      0.975000
# 6   0.023116  0.992361  2.375533      0.752083
# 7   0.023333  0.993056  1.566447      0.820833
# 8   0.003405  0.999306  0.078481      0.979167
# 9   0.002062  0.999306  0.045312      0.987500
# 10  0.010565  0.997222  0.071189      0.979167
# 11  0.013799  0.996528  0.135104      0.977083
# 12  0.008268  0.998611  0.063511      0.981250
# 13  0.003046  1.000000  0.020816      0.993750
# 14  0.000131  1.000000  0.017918      0.995833
# 15  0.000470  1.000000  0.019397      0.995833
# 16  0.000038  1.000000  0.021363      0.995833
# 17  0.000066  1.000000  0.022488      0.995833
# 18  0.000023  1.000000  0.023584      0.995833
# 19  0.000010  1.000000  0.024588      0.995833
# 20  0.000014  1.000000  0.025065      0.995833
# 21  0.000007  1.000000  0.025406      0.995833
# 22  0.000007  1.000000  0.026120      0.995833
# 23  0.000003  1.000000  0.026736      0.995833
# 24  0.000010  1.000000  0.027161      0.995833
# 25  0.000020  1.000000  0.027623      0.995833
# 26  0.000006  1.000000  0.027664      0.995833
# 27  0.000030  1.000000  0.028391      0.995833
# 28  0.000110  1.000000  0.028123      0.993750
# 29  0.000007  1.000000  0.026102      0.993750
# 30  0.000004  1.000000  0.025587      0.993750
# 31  0.000040  1.000000  0.025528      0.995833
# 32  0.000004  1.000000  0.025300      0.995833
# 33  0.000019  1.000000  0.024920      0.995833
# 34  0.000013  1.000000  0.025031      0.995833

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.017918089404702187
# Maximum validation accuracy: 0.9958333373069763

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 29ms/step - loss: 0.0147 - accuracy: 0.9979
# test loss, test acc: [0.014725325629115105, 0.9979166388511658]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 15/15 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 12s 282ms/step - loss: 0.7050 - accuracy: 0.7151 - val_loss: 1.0970 - val_accuracy: 0.2500
# Epoch 2/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.4589 - accuracy: 0.8250 - val_loss: 1.0970 - val_accuracy: 0.2500
# Epoch 3/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.3329 - accuracy: 0.8698 - val_loss: 1.0926 - val_accuracy: 0.5000
# Epoch 4/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.2308 - accuracy: 0.9177 - val_loss: 1.1008 - val_accuracy: 0.2500
# Epoch 5/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.2141 - accuracy: 0.9260 - val_loss: 1.1005 - val_accuracy: 0.2500
# Epoch 6/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1125 - accuracy: 0.9620 - val_loss: 1.1260 - val_accuracy: 0.2500
# Epoch 7/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.1493 - accuracy: 0.9495 - val_loss: 1.1522 - val_accuracy: 0.2500
# Epoch 8/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1352 - accuracy: 0.9505 - val_loss: 1.1870 - val_accuracy: 0.2500
# Epoch 9/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1196 - accuracy: 0.9646 - val_loss: 1.4622 - val_accuracy: 0.2500
# Epoch 10/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0674 - accuracy: 0.9740 - val_loss: 1.5284 - val_accuracy: 0.2500
# Epoch 11/100
# 30/30 [==============================] - 7s 249ms/step - loss: 0.0968 - accuracy: 0.9625 - val_loss: 1.6156 - val_accuracy: 0.2500
# Epoch 12/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0652 - accuracy: 0.9766 - val_loss: 1.8891 - val_accuracy: 0.2500
# Epoch 13/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 2.4848 - val_accuracy: 0.2500
# Epoch 14/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0317 - accuracy: 0.9854 - val_loss: 2.7784 - val_accuracy: 0.2500
# Epoch 15/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1068 - accuracy: 0.9641 - val_loss: 3.0319 - val_accuracy: 0.2500
# Epoch 16/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0848 - accuracy: 0.9724 - val_loss: 2.6495 - val_accuracy: 0.3016
# Epoch 17/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0347 - accuracy: 0.9865 - val_loss: 2.4961 - val_accuracy: 0.4062
# Epoch 18/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0248 - accuracy: 0.9896 - val_loss: 3.6094 - val_accuracy: 0.3266
# Epoch 19/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0817 - accuracy: 0.9724 - val_loss: 4.6975 - val_accuracy: 0.2797
# Epoch 20/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0585 - accuracy: 0.9792 - val_loss: 1.0513 - val_accuracy: 0.7484
# Epoch 21/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0287 - accuracy: 0.9880 - val_loss: 1.6356 - val_accuracy: 0.6938
# Epoch 22/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0163 - accuracy: 0.9953 - val_loss: 1.4256 - val_accuracy: 0.7812
# Epoch 23/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0458 - accuracy: 0.9875 - val_loss: 2.8098 - val_accuracy: 0.7250
# Epoch 24/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0354 - accuracy: 0.9870 - val_loss: 1.0063 - val_accuracy: 0.8781
# Epoch 25/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0152 - accuracy: 0.9943 - val_loss: 1.2831 - val_accuracy: 0.8203
# Epoch 26/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0105 - accuracy: 0.9958 - val_loss: 0.6822 - val_accuracy: 0.8766
# Epoch 27/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.9194 - val_accuracy: 0.8656
# Epoch 28/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0359 - accuracy: 0.9870 - val_loss: 1.6991 - val_accuracy: 0.7672
# Epoch 29/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0227 - accuracy: 0.9911 - val_loss: 1.0411 - val_accuracy: 0.8297
# Epoch 30/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0189 - accuracy: 0.9917 - val_loss: 1.7285 - val_accuracy: 0.8078
# Epoch 31/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0451 - accuracy: 0.9844 - val_loss: 1.2402 - val_accuracy: 0.8078
# Epoch 32/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.7144 - val_accuracy: 0.8609
# Epoch 33/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0364 - accuracy: 0.9865 - val_loss: 2.1767 - val_accuracy: 0.6844
# Epoch 34/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0443 - accuracy: 0.9839 - val_loss: 2.1112 - val_accuracy: 0.7297
# Epoch 35/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0598 - accuracy: 0.9786 - val_loss: 1.4174 - val_accuracy: 0.8016
# Epoch 36/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0215 - accuracy: 0.9927 - val_loss: 2.7567 - val_accuracy: 0.6953
# Epoch 37/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.6297 - val_accuracy: 0.9000
# Epoch 38/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 1.8065 - val_accuracy: 0.7609
# Epoch 39/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0233 - accuracy: 0.9932 - val_loss: 1.4005 - val_accuracy: 0.8203
# Epoch 40/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0163 - accuracy: 0.9937 - val_loss: 0.8825 - val_accuracy: 0.8672
# Epoch 41/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0117 - accuracy: 0.9974 - val_loss: 0.6281 - val_accuracy: 0.9016
# Epoch 42/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.6951 - val_accuracy: 0.8922
# Epoch 43/100
# 30/30 [==============================] - 8s 251ms/step - loss: 7.0487e-04 - accuracy: 1.0000 - val_loss: 0.5837 - val_accuracy: 0.9016
# Epoch 44/100
# 30/30 [==============================] - 7s 251ms/step - loss: 3.7472e-04 - accuracy: 1.0000 - val_loss: 0.9144 - val_accuracy: 0.8547
# Epoch 45/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.7039 - val_accuracy: 0.8813
# Epoch 46/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 1.0442 - val_accuracy: 0.8250
# Epoch 47/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0562 - accuracy: 0.9833 - val_loss: 2.6636 - val_accuracy: 0.7734
# Epoch 48/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0468 - accuracy: 0.9859 - val_loss: 0.8448 - val_accuracy: 0.8359
# Epoch 49/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 1.1417 - val_accuracy: 0.8344
# Epoch 50/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 0.8794 - val_accuracy: 0.8313
# Epoch 51/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.8831 - val_accuracy: 0.8656
# Epoch 52/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.6210 - val_accuracy: 0.8953
# Epoch 53/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9207 - val_accuracy: 0.8578
# Epoch 54/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 1.6458 - val_accuracy: 0.8031
# Epoch 55/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0460 - accuracy: 0.9885 - val_loss: 3.0285 - val_accuracy: 0.7047
# Epoch 56/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0943 - accuracy: 0.9708 - val_loss: 5.4234 - val_accuracy: 0.5594
# Epoch 57/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0365 - accuracy: 0.9880 - val_loss: 7.4993 - val_accuracy: 0.6469
# Epoch 58/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 3.5102 - val_accuracy: 0.6938
# Epoch 59/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 2.5180 - val_accuracy: 0.6938
# Epoch 60/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.5993 - val_accuracy: 0.9141
# Epoch 61/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 1.7459 - val_accuracy: 0.7937
# Epoch 62/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0329 - accuracy: 0.9901 - val_loss: 0.8544 - val_accuracy: 0.8719
# Epoch 63/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 1.5338 - val_accuracy: 0.8172
# Epoch 64/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.8158 - val_accuracy: 0.8562
# Epoch 65/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0075 - accuracy: 0.9964 - val_loss: 1.2881 - val_accuracy: 0.8313
# Epoch 66/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.6482 - val_accuracy: 0.8844
# Epoch 67/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.5878 - val_accuracy: 0.8969
# Epoch 68/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0034 - accuracy: 0.9984 - val_loss: 1.0376 - val_accuracy: 0.8578
# Epoch 69/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0094 - accuracy: 0.9984 - val_loss: 0.7951 - val_accuracy: 0.8656
# Epoch 70/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0365 - accuracy: 0.9885 - val_loss: 3.0001 - val_accuracy: 0.6062
# Epoch 71/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0136 - accuracy: 0.9943 - val_loss: 0.8162 - val_accuracy: 0.8281
# Epoch 72/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0189 - accuracy: 0.9943 - val_loss: 0.9582 - val_accuracy: 0.8578
# Epoch 73/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0199 - accuracy: 0.9927 - val_loss: 0.9537 - val_accuracy: 0.8344
# Epoch 74/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 1.2054 - val_accuracy: 0.8406
# Epoch 75/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.8324 - val_accuracy: 0.8453
# Epoch 76/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 1.4685 - val_accuracy: 0.7969
# Epoch 77/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 2.5672 - val_accuracy: 0.7469
# Epoch 78/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0645 - accuracy: 0.9823 - val_loss: 6.5842 - val_accuracy: 0.6812
# Epoch 79/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 1.1231 - val_accuracy: 0.8469
# Epoch 80/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 1.4273 - val_accuracy: 0.7125
# Epoch 81/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.6492 - val_accuracy: 0.8766
# Epoch 82/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.5708 - val_accuracy: 0.8719
# Epoch 83/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0251 - accuracy: 0.9927 - val_loss: 2.1691 - val_accuracy: 0.7984
# Epoch 84/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 1.3863 - val_accuracy: 0.8188
# Epoch 85/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0179 - accuracy: 0.9917 - val_loss: 3.4005 - val_accuracy: 0.6672
# Epoch 86/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.7405 - val_accuracy: 0.8797
# Epoch 87/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0171 - accuracy: 0.9917 - val_loss: 1.9777 - val_accuracy: 0.7484
# Epoch 88/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 0.8252 - val_accuracy: 0.8484
# Epoch 89/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0276 - accuracy: 0.9917 - val_loss: 1.0244 - val_accuracy: 0.8406
# Epoch 90/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9964Restoring model weights from the end of the best epoch: 60.
# 30/30 [==============================] - 8s 253ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 1.8099 - val_accuracy: 0.7641
# Epoch 00090: early stopping
# Maximal validation accuracy: 91.41%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.704957  0.715104  1.097041      0.250000
# 1   0.458915  0.825000  1.096978      0.250000
# 2   0.332870  0.869792  1.092595      0.500000
# 3   0.230788  0.917708  1.100804      0.250000
# 4   0.214064  0.926042  1.100451      0.250000
# ..       ...       ...       ...           ...
# 85  0.018710  0.994271  0.740517      0.879687
# 86  0.017072  0.991667  1.977711      0.748438
# 87  0.013497  0.994792  0.825239      0.848437
# 88  0.027587  0.991667  1.024437      0.840625
# 89  0.010001  0.996354  1.809915      0.764063
#
# [90 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.5708101987838745
# Maximum validation accuracy: 0.9140625

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 28ms/step - loss: 0.6304 - accuracy: 0.9078
# test loss, test acc: [0.6303907632827759, 0.9078124761581421]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 20/20 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 12s 282ms/step - loss: 0.4325 - accuracy: 0.8250 - val_loss: 21.8471 - val_accuracy: 0.5125
# Epoch 2/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.1130 - accuracy: 0.9661 - val_loss: 9.1499 - val_accuracy: 0.5297
# Epoch 3/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.0596 - accuracy: 0.9854 - val_loss: 4.0537 - val_accuracy: 0.7312
# Epoch 4/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0641 - accuracy: 0.9833 - val_loss: 0.6586 - val_accuracy: 0.8391
# Epoch 5/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.0520 - accuracy: 0.9865 - val_loss: 0.4171 - val_accuracy: 0.9516
# Epoch 6/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0446 - accuracy: 0.9875 - val_loss: 0.9363 - val_accuracy: 0.8828
# Epoch 7/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 1.2280 - val_accuracy: 0.8328
# Epoch 8/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0527 - accuracy: 0.9859 - val_loss: 2.4864 - val_accuracy: 0.8000
# Epoch 9/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0512 - accuracy: 0.9833 - val_loss: 0.5469 - val_accuracy: 0.9078
# Epoch 10/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.8091 - val_accuracy: 0.9000
# Epoch 11/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9578
# Epoch 12/100
# 30/30 [==============================] - 8s 253ms/step - loss: 6.8494e-04 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9719
# Epoch 13/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0687 - accuracy: 0.9865 - val_loss: 6.9211 - val_accuracy: 0.5844
# Epoch 14/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0599 - accuracy: 0.9802 - val_loss: 0.2636 - val_accuracy: 0.9344
# Epoch 15/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0592 - accuracy: 0.9844 - val_loss: 1.2823 - val_accuracy: 0.8750
# Epoch 16/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0346 - accuracy: 0.9911 - val_loss: 0.2746 - val_accuracy: 0.9500
# Epoch 17/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0664 - accuracy: 0.9859 - val_loss: 0.2896 - val_accuracy: 0.9563
# Epoch 18/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 0.4594 - val_accuracy: 0.9375
# Epoch 19/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 0.2387 - val_accuracy: 0.9578
# Epoch 20/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.2044 - val_accuracy: 0.9531
# Epoch 21/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1731 - val_accuracy: 0.9641
# Epoch 22/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.5395 - val_accuracy: 0.9125
# Epoch 23/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.1794 - val_accuracy: 0.9734
# Epoch 24/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.2093 - val_accuracy: 0.9641
# Epoch 25/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1365 - val_accuracy: 0.9719
# Epoch 26/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.1543 - val_accuracy: 0.9688
# Epoch 27/100
# 30/30 [==============================] - 7s 250ms/step - loss: 1.2677e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9688
# Epoch 28/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.1823 - val_accuracy: 0.9703
# Epoch 29/100
# 30/30 [==============================] - 7s 249ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.1303 - val_accuracy: 0.9703
# Epoch 30/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.3552 - val_accuracy: 0.9453
# Epoch 31/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.6171 - val_accuracy: 0.9234
# Epoch 32/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0188 - accuracy: 0.9958 - val_loss: 0.3276 - val_accuracy: 0.9344
# Epoch 33/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0274 - accuracy: 0.9948 - val_loss: 91.6641 - val_accuracy: 0.6766
# Epoch 34/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.7702 - val_accuracy: 0.8703
# Epoch 35/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.4353 - val_accuracy: 0.9359
# Epoch 36/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.1380 - val_accuracy: 0.9703
# Epoch 37/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.2967 - val_accuracy: 0.9406
# Epoch 38/100
# 30/30 [==============================] - 7s 250ms/step - loss: 6.8834e-04 - accuracy: 1.0000 - val_loss: 0.4274 - val_accuracy: 0.9281
# Epoch 39/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0189 - accuracy: 0.9958 - val_loss: 0.2379 - val_accuracy: 0.9547
# Epoch 40/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0933 - val_accuracy: 0.9734
# Epoch 41/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0073 - accuracy: 0.9969 - val_loss: 0.2842 - val_accuracy: 0.9531
# Epoch 42/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.6861 - val_accuracy: 0.9094
# Epoch 43/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9927Restoring model weights from the end of the best epoch: 23.
# 30/30 [==============================] - 8s 253ms/step - loss: 0.0202 - accuracy: 0.9927 - val_loss: 0.3400 - val_accuracy: 0.9391
# Epoch 00043: early stopping
# Maximal validation accuracy: 97.34%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.432486  0.825000  21.847107      0.512500
# 1   0.112967  0.966146   9.149940      0.529688
# 2   0.059642  0.985417   4.053676      0.731250
# 3   0.064083  0.983333   0.658625      0.839063
# 4   0.051988  0.986458   0.417071      0.951563
# 5   0.044571  0.987500   0.936273      0.882812
# 6   0.016154  0.995833   1.228030      0.832812
# 7   0.052709  0.985937   2.486416      0.800000
# 8   0.051203  0.983333   0.546914      0.907812
# 9   0.024676  0.993750   0.809143      0.900000
# 10  0.003767  1.000000   0.287413      0.957812
# 11  0.000685  1.000000   0.182904      0.971875
# 12  0.068705  0.986458   6.921146      0.584375
# 13  0.059902  0.980208   0.263599      0.934375
# 14  0.059228  0.984375   1.282256      0.875000
# 15  0.034648  0.991146   0.274602      0.950000
# 16  0.066397  0.985937   0.289590      0.956250
# 17  0.027165  0.992708   0.459413      0.937500
# 18  0.019174  0.994271   0.238725      0.957812
# 19  0.005966  0.998438   0.204429      0.953125
# 20  0.001256  0.999479   0.173063      0.964063
# 21  0.011155  0.998438   0.539546      0.912500
# 22  0.011819  0.996354   0.179352      0.973437
# 23  0.003521  0.998438   0.209319      0.964063
# 24  0.001462  0.999479   0.136489      0.971875
# 25  0.001348  0.999479   0.154264      0.968750
# 26  0.000127  1.000000   0.146326      0.968750
# 27  0.004170  0.998958   0.182299      0.970312
# 28  0.010899  0.996875   0.130266      0.970312
# 29  0.015660  0.994792   0.355178      0.945312
# 30  0.023923  0.993750   0.617131      0.923437
# 31  0.018781  0.995833   0.327572      0.934375
# 32  0.027363  0.994792  91.664139      0.676562
# 33  0.021928  0.992708   0.770239      0.870313
# 34  0.013272  0.996875   0.435284      0.935938
# 35  0.009442  0.997396   0.137963      0.970312
# 36  0.004072  0.998438   0.296726      0.940625
# 37  0.000688  1.000000   0.427365      0.928125
# 38  0.018925  0.995833   0.237904      0.954687
# 39  0.005354  0.997917   0.093310      0.973437
# 40  0.007302  0.996875   0.284173      0.953125
# 41  0.029411  0.990625   0.686082      0.909375
# 42  0.020177  0.992708   0.339968      0.939062

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.09330984205007553
# Maximum validation accuracy: 0.973437488079071

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0724 - accuracy: 0.9859
# test loss, test acc: [0.07239928841590881, 0.9859374761581421]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 20/20 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_Xception_None
# test loss, test acc: [0.06652709096670151, 0.9895833134651184]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_Xception_imagenet
# test loss, test acc: [0.014725325629115105, 0.9979166388511658]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_Xception_None
# test loss, test acc: [0.6303907632827759, 0.9078124761581421]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_Xception_imagenet
# test loss, test acc: [0.07239928841590881, 0.9859374761581421]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_Xception_None →→→ Target Test
# 20/20 [==============================] - 1s 29ms/step - loss: 5.8934 - accuracy: 0.3719
# test loss, test acc: [5.893405437469482, 0.37187498807907104]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_Xception_imagenet →→→ Target Test
# 20/20 [==============================] - 1s 29ms/step - loss: 2.7959 - accuracy: 0.4141
# test loss, test acc: [2.7959113121032715, 0.4140625]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_Xception_None →→→ Source Test
# 15/15 [==============================] - 0s 28ms/step - loss: 7.2676 - accuracy: 0.4604
# test loss, test acc: [7.2675557136535645, 0.46041667461395264]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_Xception_imagenet →→→ Source Test
# 15/15 [==============================] - 0s 28ms/step - loss: 2.1752 - accuracy: 0.6104
# test loss, test acc: [2.1752424240112305, 0.6104166507720947]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
