# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
from keras.utils import np_utils
import tensorflow as tf
import pandas as pd
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
import tqdm

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11671562230929882108
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17798959563120227845
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Mon Dec 13 23:02:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    33W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 2
imagenet_patience_num = 30

#base_path = ''
base_path = 'gdrive/My Drive/Research_1_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/4 - SimCLR + DANN_result - 1/'
model_path = path_model_result + 'model_'

basemodel_load = tf.keras.models.load_model( 'gdrive/My Drive/Research_1_1_1/model_result/3 - SimCLR_result/pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Data Setting

# %% [markdown]
# ## 2-1. Data Load

# %%
combined_train_imgs = np.load(path_data + 'combined_train_imgs.npy')
combined_train_labels = np.load(path_data + 'combined_train_labels.npy')
combined_train_domain = np.load(path_data + 'combined_train_domain.npy')

combined_Valid_imgs = np.load(path_data + 'combined_Valid_imgs.npy')
combined_Valid_labels = np.load(path_data + 'combined_Valid_labels.npy')
combined_Valid_domain = np.load(path_data + 'combined_Valid_domain.npy')

combined_test_imgs = np.load(path_data + 'combined_test_imgs.npy')
combined_test_labels = np.load(path_data + 'combined_test_labels.npy')
combined_test_domain = np.load(path_data + 'combined_test_domain.npy')

# %%
sample_weights_class_label = np.load(path_data + 'sample_weights_class_label.npy')
sample_weights_domain_label = np.load(path_data + 'sample_weights_domain_label.npy')

# %%
print(combined_train_imgs.shape)
print(combined_train_labels.shape)
print(combined_train_domain.shape)
print()
print(combined_Valid_imgs.shape)
print(combined_Valid_labels.shape)
print(combined_Valid_domain.shape)
print()
print(sample_weights_class_label.shape)
print(sample_weights_domain_label.shape)
# Out:
# (3360, 128, 128, 3)
# (3360, 2)
# (3360, 2)
#
# (1120, 128, 128, 3)
# (1120, 2)
# (1120, 2)
#
# (3360,)
# (3360,)

# %%
xValid_S = np.load(path_data + 'xValid_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')

xValid_T = np.load(path_data + 'xValid_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')

Valid_S_domain = np.load(path_data + 'Valid_S_domain.npy')
Valid_T_domain = np.load(path_data + 'Valid_T_domain.npy')

xValid_S = xValid_S.astype('float32')/255
yValid_S = np_utils.to_categorical(yValid_S, class_num)

xValid_T = xValid_T.astype('float32')/255
yValid_T = np_utils.to_categorical(yValid_T, class_num)

# %%
print(xValid_S.shape, yValid_S.shape)
print(xValid_T.shape, yValid_T.shape)
print()
print(Valid_S_domain.shape)
print(Valid_T_domain.shape)
# Out:
# (640, 128, 128, 3) (640, 2)
# (480, 128, 128, 3) (480, 2)
#
# (640, 2)
# (480, 2)

# %%
xTest_S = np.load(path_data + 'xTest_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTest_T = np.load(path_data + 'xTest_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

test_S_domain = np.load(path_data + 'test_S_domain.npy')
test_T_domain = np.load(path_data + 'test_T_domain.npy')

xTest_S = xTest_S.astype('float32')/255
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTest_T = xTest_T.astype('float32')/255
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTest_S.shape, yTest_S.shape)
print(xTest_T.shape, yTest_T.shape)
print()
print(test_S_domain.shape)
print(test_T_domain.shape)
# Out:
# (640, 128, 128, 3) (640, 2)
# (480, 128, 128, 3) (480, 2)
#
# (640, 2)
# (480, 2)

# %% [markdown]
# # 3. DANN Network

# %% [markdown]
# ## 3-1. DANN Setting

# %%
@tf.custom_gradient
def GradientReversalOperator(x):
    def grad(dy):
        return -1 * dy
    return x, grad

class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()
    def call(self, inputs):
        return GradientReversalOperator(inputs)

def classifier(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(64, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out) 
    return classifier_output

def discriminator(inp):
    out = Dense(32, activation="relu")(inp)
    discriminator_output = Dense(2, activation="softmax", name="discriminator_output")(out)
    return discriminator_output

def dann():    
    inp = Input(shape=(image_size, image_size, image_channels))
    feature_output = basemodel_load(inp)
    classifier_output = classifier(feature_output)
    grl_layer = GradientReversalLayer()(feature_output)
    discriminator_output = discriminator(grl_layer)
    model = tf.keras.models.Model(inputs=inp, outputs=[discriminator_output,classifier_output])
    return model

# %% [markdown]
# ## 3-2. Model Training

# %%
model = dann()
#print(S_dann_model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step

# %%
model.compile(optimizer='adam', 
              loss={'discriminator_output': 'binary_crossentropy',
                    'classifier_output': 'categorical_crossentropy'},
              metrics = ['accuracy'])


ES = EarlyStopping(monitor='val_classifier_output_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)
MC = ModelCheckpoint( path_model_result + 'model_{epoch}.h5', monitor='val_classifier_output_accuracy', mode='max', verbose=1, save_best_only=False, save_freq='epoch')


dann_model = model.fit(combined_train_imgs,[combined_train_domain,combined_train_labels], 
                        sample_weight=[sample_weights_domain_label, sample_weights_class_label],
                        epochs=num_epochs, batch_size=batch_size, validation_data=(combined_Valid_imgs,[combined_Valid_domain,combined_Valid_labels]), callbacks=[ES, MC])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(dann_model.history["val_classifier_output_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 53/53 [==============================] - ETA: 0s - loss: 1.4803 - discriminator_output_loss: 1.3076 - classifier_output_loss: 0.1728 - discriminator_output_accuracy: 0.2848 - classifier_output_accuracy: 0.7637
# Epoch 00001: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 53/53 [==============================] - 30s 310ms/step - loss: 1.4803 - discriminator_output_loss: 1.3076 - classifier_output_loss: 0.1728 - discriminator_output_accuracy: 0.2848 - classifier_output_accuracy: 0.7637 - val_loss: 74.8522 - val_discriminator_output_loss: 32.9062 - val_classifier_output_loss: 41.9460 - val_discriminator_output_accuracy: 0.5491 - val_classifier_output_accuracy: 0.5393
# Epoch 2/100
# 53/53 [==============================] - ETA: 0s - loss: 1.3271 - discriminator_output_loss: 1.2681 - classifier_output_loss: 0.0590 - discriminator_output_accuracy: 0.3080 - classifier_output_accuracy: 0.9149
# Epoch 00002: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# 53/53 [==============================] - 15s 277ms/step - loss: 1.3271 - discriminator_output_loss: 1.2681 - classifier_output_loss: 0.0590 - discriminator_output_accuracy: 0.3080 - classifier_output_accuracy: 0.9149 - val_loss: 8.6015 - val_discriminator_output_loss: 3.9729 - val_classifier_output_loss: 4.6286 - val_discriminator_output_accuracy: 0.4679 - val_classifier_output_accuracy: 0.8848
# Epoch 3/100
# 53/53 [==============================] - ETA: 0s - loss: 0.8340 - discriminator_output_loss: 0.7673 - classifier_output_loss: 0.0667 - discriminator_output_accuracy: 0.4134 - classifier_output_accuracy: 0.8682
# Epoch 00003: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# 53/53 [==============================] - 15s 276ms/step - loss: 0.7088 - discriminator_output_loss: 0.7085 - classifier_output_loss: 2.8127e-04 - discriminator_output_accuracy: 0.5437 - classifier_output_accuracy: 0.8470 - val_loss: 3.0826 - val_discriminator_output_loss: 1.7988 - val_classifier_output_loss: 1.2839 - val_discriminator_output_accuracy: 0.4893 - val_classifier_output_accuracy: 0.8277
# Epoch 31/100
# 53/53 [==============================] - ETA: 0s - loss: 0.7250 - discriminator_output_loss: 0.7115 - classifier_output_loss: 0.0134 - discriminator_output_accuracy: 0.5568 - classifier_output_accuracy: 0.8411
# Epoch 00031: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# 53/53 [==============================] - 15s 275ms/step - loss: 0.7250 - discriminator_output_loss: 0.7115 - classifier_output_loss: 0.0134 - discriminator_output_accuracy: 0.5568 - classifier_output_accuracy: 0.8411 - val_loss: 9.1457 - val_discriminator_output_loss: 0.6751 - val_classifier_output_loss: 8.4706 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.8214
# Epoch 32/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6976 - discriminator_output_loss: 0.6795 - classifier_output_loss: 0.0181 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7854
# Epoch 00032: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# 53/53 [==============================] - 15s 276ms/step - loss: 0.6976 - discriminator_output_loss: 0.6795 - classifier_output_loss: 0.0181 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7854 - val_loss: 137.4167 - val_discriminator_output_loss: 0.6842 - val_classifier_output_loss: 136.7326 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.6571
# Epoch 33/100
# 53/53 [==============================] - ETA: 0s - loss: 0.7989 - discriminator_output_loss: 0.6836 - classifier_output_loss: 0.1152 - discriminator_output_accuracy: 0.5747 - classifier_output_accuracy: 0.7810Restoring model weights from the end of the best epoch: 3.
#
# Epoch 00033: saving model to gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# 53/53 [==============================] - 15s 278ms/step - loss: 0.7989 - discriminator_output_loss: 0.6836 - classifier_output_loss: 0.1152 - discriminator_output_accuracy: 0.5747 - classifier_output_accuracy: 0.7810 - val_loss: 8956.0469 - val_discriminator_output_loss: 0.6828 - val_classifier_output_loss: 8955.3623 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.5000
# Epoch 00033: early stopping
# Maximal validation accuracy: 91.79%

# %%
dann_model_df = pd.DataFrame(dann_model.history)
dann_model_df.to_csv( path_model_result + 'history_df.csv' )
dann_model_df
# Out:
#         loss  ...  val_classifier_output_accuracy
# 0   1.480348  ...                        0.539286
# 1   1.327088  ...                        0.884821
# 2   0.833999  ...                        0.917857
# 3   0.697929  ...                        0.893750
# 4   0.791263  ...                        0.756250
# 5   0.727546  ...                        0.816071
# 6   0.759136  ...                        0.853571
# 7   0.783665  ...                        0.716071
# 8   0.729838  ...                        0.865179
# 9   0.689457  ...                        0.848214
# 10  0.697976  ...                        0.661607
# 11  0.702382  ...                        0.766964
# 12  0.687291  ...                        0.751786
# 13  0.685800  ...                        0.801786
# 14  0.715869  ...                        0.810714
# 15  0.692034  ...                        0.781250
# 16  0.690142  ...                        0.887500
# 17  0.685709  ...                        0.858036
# 18  0.689359  ...                        0.738393
# 19  0.686350  ...                        0.801786
# 20  0.688217  ...                        0.808036
# 21  0.682945  ...                        0.853571
# 22  0.701456  ...                        0.894643
# 23  0.686632  ...                        0.839286
# 24  0.690775  ...                        0.814286
# 25  0.685866  ...                        0.885714
# 26  0.690946  ...                        0.833929
# 27  0.682965  ...                        0.838393
# 28  0.682602  ...                        0.843750
# 29  0.708774  ...                        0.827679
# 30  0.724958  ...                        0.821429
# 31  0.697612  ...                        0.657143
# 32  0.798882  ...                        0.500000
#
# [33 rows x 10 columns]

# %%
dann_model_df.loc[:, ['loss', 'discriminator_output_loss', 'classifier_output_loss', 'val_loss']].plot();
plt.savefig(path_model_result + 'loss,val_loss.png')
dann_model_df.loc[:, ['discriminator_output_accuracy', 'classifier_output_accuracy', 'val_discriminator_output_accuracy', 'val_classifier_output_accuracy']].plot();
plt.savefig(path_model_result + 'accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(dann_model_df['val_loss'].min()))
print("Maximum val_classifier_output_accuracy: {}".format(dann_model_df['val_classifier_output_accuracy'].max()))
# Out:
# Minimum validation loss: 1.3264392614364624
# Maximum val_classifier_output_accuracy: 0.9178571701049805

# %%
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 31ms/step - loss: 1.3580 - discriminator_output_loss: 0.6527 - classifier_output_loss: 0.7053 - discriminator_output_accuracy: 0.9641 - classifier_output_accuracy: 0.9375
# dann_source_acc : 93.75 %

# %%
print("Evaluate on test data")
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 15/15 [==============================] - 0s 29ms/step - loss: 46.7029 - discriminator_output_loss: 0.7399 - classifier_output_loss: 45.9630 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8750
# dann_target_acc : 87.5 %

# %% [markdown]
# ## 3-3. Load_weights and epoch_train,epoch_evaluate

# %%
def epoch_train():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xValid_S,[Valid_S_domain, yValid_S] )
        target_acc = model.evaluate( xValid_T,[Valid_T_domain, yValid_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_train_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_train_df.to_csv( path_model_result + 'epoch_train_df_df.csv' )
    epoch_train_df

    return ()

# %%
epoch_train()
# Out:
# 33
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 26.2748 - discriminator_output_loss: 0.5635 - classifier_output_loss: 25.7113 - discriminator_output_accuracy: 0.9516 - classifier_output_accuracy: 0.5641
# 15/15 [==============================] - 0s 30ms/step - loss: 139.6221 - discriminator_output_loss: 76.0299 - classifier_output_loss: 63.5922 - discriminator_output_accuracy: 0.0125 - classifier_output_accuracy: 0.5063
# dann_source_acc : 56.40625 %
# dann_target_acc : 50.625 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 10.7989 - discriminator_output_loss: 6.4306 - classifier_output_loss: 4.3683 - discriminator_output_accuracy: 0.4781 - classifier_output_accuracy: 0.9078
# 15/15 [==============================] - 0s 29ms/step - loss: 5.6717 - discriminator_output_loss: 0.6960 - classifier_output_loss: 4.9757 - discriminator_output_accuracy: 0.4542 - classifier_output_accuracy: 0.8542
# dann_source_acc : 90.78125 %
# dann_target_acc : 85.41667 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 1.2199 - discriminator_output_loss: 0.6523 - classifier_output_loss: 0.5676 - discriminator_output_accuracy: 0.9719 - classifier_output_accuracy: 0.9609
# 15/15 [==============================] - 0s 31ms/step - loss: 59.2726 - discriminator_output_loss: 0.7397 - classifier_output_loss: 58.5329 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8604
# dann_source_acc : 96.09375 %
# dann_target_acc : 86.04167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_4.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_4.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 2.2156 - discriminator_output_loss: 2.1384 - classifier_output_loss: 0.0773 - discriminator_output_accuracy: 0.4984 - classifier_output_accuracy: 0.9781
# 15/15 [==============================] - 0s 31ms/step - loss: 3.3886 - discriminator_output_loss: 0.5516 - classifier_output_loss: 2.8370 - discriminator_output_accuracy: 0.8875 - classifier_output_accuracy: 0.7812
# dann_source_acc : 97.8125 %
# dann_target_acc : 78.125 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_5.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_5.h5
# 20/20 [==============================] - 1s 30ms/step - loss:
- discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.4375
# dann_source_acc : 98.75 %
# dann_target_acc : 43.75 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_14.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_14.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6140 - discriminator_output_loss: 0.5788 - classifier_output_loss: 0.0352 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9891
# 15/15 [==============================] - 0s 30ms/step - loss: 3.0626 - discriminator_output_loss: 0.8139 - classifier_output_loss: 2.2487 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5521
# dann_source_acc : 98.90625 %
# dann_target_acc : 55.20833 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_15.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_15.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7837 - discriminator_output_loss: 0.7358 - classifier_output_loss: 0.0478 - discriminator_output_accuracy: 0.8219 - classifier_output_accuracy: 0.9828
# 15/15 [==============================] - 0s 29ms/step - loss: 2.1598 - discriminator_output_loss: 0.8242 - classifier_output_loss: 1.3356 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5813
# dann_source_acc : 98.28125 %
# dann_target_acc : 58.125 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_16.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_16.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6607 - discriminator_output_loss: 0.5681 - classifier_output_loss: 0.0926 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9734
# 15/15 [==============================] - 0s 30ms/step - loss: 2.3305 - discriminator_output_loss: 0.8352 - classifier_output_loss: 1.4953 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5250
# dann_source_acc : 97.34375 %
# dann_target_acc : 52.5 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_17.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_17.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7087 - discriminator_output_loss: 0.5666 - classifier_output_loss: 0.1421 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9750
# 15/15 [==============================] - 0s 29ms/step - loss: 2.1501 - discriminator_output_loss: 0.8371 - classifier_output_loss: 1.3130 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7708
# dann_source_acc : 97.5 %
# dann_target_acc : 77.08333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.7133 - discriminator_output_loss: 0.5658 - classifier_output_loss: 0.1475 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9656
# 15/15 [==============================] - 0s 30ms/step - loss: 2.3649 - discriminator_output_loss: 0.8380 - classifier_output_loss: 1.5269 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7146
# dann_source_acc : 96.5625 %
# dann_target_acc : 71.45833 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7483 - discriminator_output_loss: 0.5660 - classifier_output_loss: 0.1823 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9563
# 15/15 [==============================] - 0s 29ms/step - loss: 4.8004 - discriminator_output_loss: 0.8380 - classifier_output_loss: 3.9624 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.4479
# dann_source_acc : 95.625 %
# dann_target_acc : 44.79167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6037 - discriminator_output_loss: 0.5640 - classifier_output_loss: 0.0398 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9906
# 15/15 [==============================] - 0s 30ms/step - loss: 4.6817 - discriminator_output_loss: 0.8411 - classifier_output_loss: 3.8406 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5500
# dann_source_acc : 99.0625 %
# dann_target_acc : 55.0 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6264 - discriminator_output_loss: 0.5652 - classifier_output_loss: 0.0612 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9750
# 15/15 [==============================] - 0s 30ms/step - loss: 7.6504 - discriminator_output_loss: 0.8395 - classifier_output_loss: 6.8109 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5854
# dann_source_acc : 97.5 %
# dann_target_acc : 58.54167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.5955 - discriminator_output_loss: 0.5740 - classifier_output_loss: 0.0215 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9922
# 15/15 [==============================] - 0s 30ms/step - loss: 4.9982 - discriminator_output_loss: 0.8069 - classifier_output_loss: 4.1913 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6687
# dann_source_acc : 99.21875 %
# dann_target_acc : 66.875 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6171 - discriminator_output_loss: 0.5594 - classifier_output_loss: 0.0577 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9844
# 15/15 [==============================] - 0s 30ms/step - loss: 4.5951 - discriminator_output_loss: 0.8473 - classifier_output_loss: 3.7477 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7750
# dann_source_acc : 98.4375 %
# dann_target_acc : 77.5 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7008 - discriminator_output_loss: 0.5607 - classifier_output_loss: 0.1401 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9812
# 15/15 [==============================] - 0s 30ms/step - loss: 5.4763 - discriminator_output_loss: 0.8459 - classifier_output_loss: 4.6304 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6500
# dann_source_acc : 98.125 %
# dann_target_acc : 65.0 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6763 - discriminator_output_loss: 0.5599 - classifier_output_loss: 0.1164 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9719
# 15/15 [==============================] - 0s 30ms/step - loss: 4.9162 - discriminator_output_loss: 0.8459 - classifier_output_loss: 4.0703 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6042
# dann_source_acc : 97.1875 %
# dann_target_acc : 60.41667 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6175 - discriminator_output_loss: 0.5601 - classifier_output_loss: 0.0574 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9922
# 15/15 [==============================] - 0s 29ms/step - loss: 2.7669 - discriminator_output_loss: 0.8457 - classifier_output_loss: 1.9212 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7437
# dann_source_acc : 99.21875 %
# dann_target_acc : 74.375 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6015 - discriminator_output_loss: 0.5601 - classifier_output_loss: 0.0415 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9844
# 15/15 [==============================] - 0s 30ms/step - loss: 3.3761 - discriminator_output_loss: 0.8448 - classifier_output_loss: 2.5313 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6333
# dann_source_acc : 98.4375 %
# dann_target_acc : 63.33333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.5804 - discriminator_output_loss: 0.5593 - classifier_output_loss: 0.0212 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9875
# 15/15 [==============================] - 0s 30ms/step - loss: 3.7111 - discriminator_output_loss: 0.8409 - classifier_output_loss: 2.8703 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6396
# dann_source_acc : 98.75 %
# dann_target_acc : 63.95833 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6001 - discriminator_output_loss: 0.5791 - classifier_output_loss: 0.0211 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9922
# 15/15 [==============================] - 0s 30ms/step - loss: 3.7499 - discriminator_output_loss: 0.7764 - classifier_output_loss: 2.9735 - discriminator_output_accuracy: 0.1667 - classifier_output_accuracy: 0.6458
# dann_source_acc : 99.21875 %
# dann_target_acc : 64.58333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 2.6863 - discriminator_output_loss: 2.5952 - classifier_output_loss: 0.0910 - discriminator_output_accuracy: 0.4828 - classifier_output_accuracy: 0.9844
# 15/15 [==============================] - 0s 31ms/step - loss: 3.6111 - discriminator_output_loss: 0.7368 - classifier_output_loss: 2.8744 - discriminator_output_accuracy: 0.4979 - classifier_output_accuracy: 0.6187
# dann_source_acc : 98.4375 %
# dann_target_acc : 61.875 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 1.1700 - discriminator_output_loss: 0.5397 - classifier_output_loss: 0.6303 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9812
# 15/15 [==============================] - 0s 30ms/step - loss: 19.7800 - discriminator_output_loss: 0.8557 - classifier_output_loss: 18.9243 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6083
# dann_source_acc : 98.125 %
# dann_target_acc : 60.83333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 67.9337 - discriminator_output_loss: 0.5598 - classifier_output_loss: 67.3739 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.7703
# 15/15 [==============================] - 0s 30ms/step - loss: 230.0609 - discriminator_output_loss: 0.8500 - classifier_output_loss: 229.2109 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5063
# dann_source_acc : 77.03125 %
# dann_target_acc : 50.625 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 1.2199 - discriminator_output_loss: 0.6523 - classifier_output_loss: 0.5676 - discriminator_output_accuracy: 0.9719 - classifier_output_accuracy: 0.9609
# 15/15 [==============================] - 0s 30ms/step - loss: 59.2726 - discriminator_output_loss: 0.7397 - classifier_output_loss: 58.5329 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8604
# dann_source_acc : 96.09375 %
# dann_target_acc : 86.04167 %
# ()

# %%
def epoch_evaluate():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
        target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_evaluate_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_evaluate_df.to_csv( path_model_result + 'epoch_evaluate_df.csv' )
    epoch_evaluate_df

    return ()

# %%
epoch_evaluate()
# Out:
# 33
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_1.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 26.4066 - discriminator_output_loss: 0.5460 - classifier_output_loss: 25.8606 - discriminator_output_accuracy: 0.9563 - classifier_output_accuracy: 0.5562
# 15/15 [==============================] - 0s 30ms/step - loss: 139.7666 - discriminator_output_loss: 77.3970 - classifier_output_loss: 62.3696 - discriminator_output_accuracy: 0.0146 - classifier_output_accuracy: 0.5021
# dann_source_acc : 55.625 %
# dann_target_acc : 50.20834 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_2.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 10.7030 - discriminator_output_loss: 6.2408 - classifier_output_loss: 4.4622 - discriminator_output_accuracy: 0.4969 - classifier_output_accuracy: 0.9062
# 15/15 [==============================] - 0s 29ms/step - loss: 5.1318 - discriminator_output_loss: 0.6879 - classifier_output_loss: 4.4439 - discriminator_output_accuracy: 0.4979 - classifier_output_accuracy: 0.8771
# dann_source_acc : 90.625 %
# dann_target_acc : 87.70834 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_3.h5
# 20/20 [==============================] - 1s 29ms/step - loss: 1.3580 - discriminator_output_loss: 0.6527 - classifier_output_loss: 0.7053 - discriminator_output_accuracy: 0.9641 - classifier_output_accuracy: 0.9375
# 15/15 [==============================] - 0s 30ms/step - loss: 46.7029 - discriminator_output_loss: 0.7399 - classifier_output_loss: 45.9630 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8750
# dann_source_acc : 93.75 %
# dann_target_acc : 87.5 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_4.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_4.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 2.3259 - discriminator_output_loss: 2.1676 - classifier_output_loss: 0.1583 - discriminator_output_accuracy: 0.5078 - classifier_output_accuracy: 0.9766
# 15/15 [==============================] - 0s 30ms/step - loss: 2.6984 - discriminator_output_loss: 0.5547 - classifier_output_loss: 2.1437 - discriminator_output_accuracy: 0.8917 - classifier_output_accuracy: 0.7792
# dann_source_acc : 97.65625 %
# dann_target_acc : 77.91666 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_5.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_5.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 1.2350 - discriminator_output_loss: 1.0337 - classifier_output_loss: 0.2013 - discriminator_output_accuracy: 0.7812 - classifier_output_accuracy: 0.9375
# 15/15 [==============================] - 0s 29ms/step - loss: 17.4596 - discriminator_output_loss: 0.7613 - classifier_output_loss: 16.6983 - discriminator_output_accuracy: 0.0083 - classifier_output_accuracy: 0.5292
# dann_source_acc : 93.75 %
# dann_target_acc : 52.91666 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_6.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_6.h5
# 20/20 [==============================] - 1s 29ms/step - loss: 1.2189 - discriminator_output_loss: 0.6219 - classifier_output_loss: 0.5970 - discriminator_output_accuracy: 0.9937 - classifier_output_accuracy: 0.9453
# 15/15 [==============================] - 0s 30ms/step - loss: 4.2849 - discriminator_output_loss: 0.7659 - classifier_output_loss: 3.5190 - discriminator_output_accuracy: 0.0292 - classifier_output_accuracy: 0.6625
# dann_source_acc : 94.53125 %
# dann_target_acc : 66.25 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_7.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_7.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 1.0393 - discriminator_output_loss: 0.6297 - classifier_output_loss: 0.4096 - discriminator_output_accuracy: 0.9250 - classifier_output_accuracy: 0.9312
# 15/15 [==============================] - 0s 30ms/step - loss: 1.8442 - discriminator_output_loss: 0.7685 - classifier_output_loss: 1.0757 - discriminator_output_accuracy: 0.0396 - classifier_output_accuracy: 0.7167
# dann_source_acc : 93.125 %
# dann_target_acc : 71.66666 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_8.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_8.h5
# 20/20 [==============================] - 1s 30ms/step - loss:
- discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7688
# dann_source_acc : 98.125 %
# dann_target_acc : 76.875 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_18.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6907 - discriminator_output_loss: 0.5659 - classifier_output_loss: 0.1248 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9563
# 15/15 [==============================] - 0s 30ms/step - loss: 2.3164 - discriminator_output_loss: 0.8377 - classifier_output_loss: 1.4787 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7167
# dann_source_acc : 95.625 %
# dann_target_acc : 71.66666 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_19.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7827 - discriminator_output_loss: 0.5661 - classifier_output_loss: 0.2166 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9500
# 15/15 [==============================] - 0s 29ms/step - loss: 4.9803 - discriminator_output_loss: 0.8383 - classifier_output_loss: 4.1420 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.4187
# dann_source_acc : 95.0 %
# dann_target_acc : 41.875 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_20.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6086 - discriminator_output_loss: 0.5640 - classifier_output_loss: 0.0446 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9922
# 15/15 [==============================] - 0s 30ms/step - loss: 4.7339 - discriminator_output_loss: 0.8410 - classifier_output_loss: 3.8929 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5208
# dann_source_acc : 99.21875 %
# dann_target_acc : 52.08333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_21.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6245 - discriminator_output_loss: 0.5650 - classifier_output_loss: 0.0595 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9812
# 15/15 [==============================] - 0s 30ms/step - loss: 6.8081 - discriminator_output_loss: 0.8400 - classifier_output_loss: 5.9681 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5708
# dann_source_acc : 98.125 %
# dann_target_acc : 57.08333 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_22.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6101 - discriminator_output_loss: 0.5735 - classifier_output_loss: 0.0366 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9922
# 15/15 [==============================] - 0s 30ms/step - loss: 4.4713 - discriminator_output_loss: 0.8031 - classifier_output_loss: 3.6682 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6375
# dann_source_acc : 99.21875 %
# dann_target_acc : 63.75 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_23.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.5899 - discriminator_output_loss: 0.5593 - classifier_output_loss: 0.0306 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9906
# 15/15 [==============================] - 0s 30ms/step - loss: 3.9754 - discriminator_output_loss: 0.8472 - classifier_output_loss: 3.1282 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7604
# dann_source_acc : 99.0625 %
# dann_target_acc : 76.04167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_24.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.7096 - discriminator_output_loss: 0.5610 - classifier_output_loss: 0.1486 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9750
# 15/15 [==============================] - 0s 30ms/step - loss: 4.5850 - discriminator_output_loss: 0.8463 - classifier_output_loss: 3.7388 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6479
# dann_source_acc : 97.5 %
# dann_target_acc : 64.79167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_25.h5
# 20/20 [==============================] - 1s 29ms/step - loss: 0.6731 - discriminator_output_loss: 0.5600 - classifier_output_loss: 0.1132 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9734
# 15/15 [==============================] - 0s 30ms/step - loss: 4.6383 - discriminator_output_loss: 0.8460 - classifier_output_loss: 3.7923 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6000
# dann_source_acc : 97.34375 %
# dann_target_acc : 60.0 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_26.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.5981 - discriminator_output_loss: 0.5602 - classifier_output_loss: 0.0380 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9969
# 15/15 [==============================] - 0s 30ms/step - loss: 2.6979 - discriminator_output_loss: 0.8456 - classifier_output_loss: 1.8523 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.7146
# dann_source_acc : 99.6875 %
# dann_target_acc : 71.45833 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_27.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6061 - discriminator_output_loss: 0.5598 - classifier_output_loss: 0.0463 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9953
# 15/15 [==============================] - 0s 30ms/step - loss: 3.5667 - discriminator_output_loss: 0.8451 - classifier_output_loss: 2.7216 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5750
# dann_source_acc : 99.53125 %
# dann_target_acc : 57.5 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_28.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.5980 - discriminator_output_loss: 0.5589 - classifier_output_loss: 0.0390 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9937
# 15/15 [==============================] - 0s 31ms/step - loss: 3.5945 - discriminator_output_loss: 0.8397 - classifier_output_loss: 2.7548 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.6104
# dann_source_acc : 99.375 %
# dann_target_acc : 61.04167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_29.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.6193 - discriminator_output_loss: 0.5792 - classifier_output_loss: 0.0401 - discriminator_output_accuracy: 0.9984 - classifier_output_accuracy: 0.9937
# 15/15 [==============================] - 0s 29ms/step - loss: 3.6165 - discriminator_output_loss: 0.7748 - classifier_output_loss: 2.8417 - discriminator_output_accuracy: 0.1854 - classifier_output_accuracy: 0.6271
# dann_source_acc : 99.375 %
# dann_target_acc : 62.70834 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_30.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 2.8900 - discriminator_output_loss: 2.7775 - classifier_output_loss: 0.1125 - discriminator_output_accuracy: 0.4563 - classifier_output_accuracy: 0.9875
# 15/15 [==============================] - 0s 30ms/step - loss: 3.4921 - discriminator_output_loss: 0.7298 - classifier_output_loss: 2.7623 - discriminator_output_accuracy: 0.5042 - classifier_output_accuracy: 0.6354
# dann_source_acc : 98.75 %
# dann_target_acc : 63.54167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_31.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 0.9235 - discriminator_output_loss: 0.5401 - classifier_output_loss: 0.3834 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9828
# 15/15 [==============================] - 0s 30ms/step - loss: 23.9694 - discriminator_output_loss: 0.8560 - classifier_output_loss: 23.1134 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5854
# dann_source_acc : 98.28125 %
# dann_target_acc : 58.54167 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_32.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 73.5423 - discriminator_output_loss: 0.5608 - classifier_output_loss: 72.9815 - discriminator_output_accuracy: 0.9984 - classifier_output_accuracy: 0.7672
# 15/15 [==============================] - 0s 30ms/step - loss: 224.5561 - discriminator_output_loss: 0.8517 - classifier_output_loss: 223.7044 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5063
# dann_source_acc : 76.71875 %
# dann_target_acc : 50.625 %
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_model_result - 1/model_33.h5
# 20/20 [==============================] - 1s 30ms/step - loss: 1.3580 - discriminator_output_loss: 0.6527 - classifier_output_loss: 0.7053 - discriminator_output_accuracy: 0.9641 - classifier_output_accuracy: 0.9375
# 15/15 [==============================] - 0s 30ms/step - loss: 46.7029 - discriminator_output_loss: 0.7399 - classifier_output_loss: 45.9630 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8750
# dann_source_acc : 93.75 %
# dann_target_acc : 87.5 %
# ()

# %%
model.load_weights('gdrive/My Drive/Research_1_1_1/model_result/4 - SimCLR + DANN_result - 1/model_33.h5')
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_target_acc :',round(source_acc [-1]*100,5),'%')
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 31ms/step - loss: 1.3580 - discriminator_output_loss: 0.6527 - classifier_output_loss: 0.7053 - discriminator_output_accuracy: 0.9641 - classifier_output_accuracy: 0.9375
# dann_target_acc : 93.75 %
# 15/15 [==============================] - 0s 30ms/step - loss: 46.7029 - discriminator_output_loss: 0.7399 - classifier_output_loss: 45.9630 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.8750
# dann_target_acc : 87.5 %

# %% [markdown]
# # 4. Result Report

# %%
print( 'dann_model' + " →→→ Target Test")
print('target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# dann_model →→→ Target Test
# target_acc : 87.5 %

# %% [markdown]
# # 5. Model Save

# %%
model.save( path_model_result + 'dann_model_last.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %% [markdown]
# ## 기타 - TSNE 확인

# %%
def plot_embedding1(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def plot_embedding2(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(30,30))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
TSNE_model_none = dann()

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 1642.65it/s]

# %%
feature_model = Model(model.input, model.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 4487.22it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 4724.86it/s]

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 2262.56it/s]

# %%
feature_model = Model(model.input, model.get_layer('feature').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 4920.13it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 2197.57it/s]
