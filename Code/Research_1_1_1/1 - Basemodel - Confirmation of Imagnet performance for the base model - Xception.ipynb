# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5703328054405389326
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13693768620917784623
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Tue Dec 14 04:16:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'Xception'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 2
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1"
T_all_labels = "T0", "T1"

#base_path = ''
base_path = 'gdrive/My Drive/Research_1_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_Xception_None S_Xception_imagenet T_Xception_None T_Xception_imagenet
# ['S_Xception_imagenet',
#  'S_Xception_None',
#  'T_Xception_imagenet',
#  'T_Xception_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1920, 128, 128, 3) (1920, 1)
# (640, 128, 128, 3) (640, 1)
# (640, 128, 128, 3) (640, 1)
#
# (1440, 128, 128, 3) (1440, 1)
# (480, 128, 128, 3) (480, 1)
# (480, 128, 128, 3) (480, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1920, 128, 128, 3) (1920, 2)
# (640, 128, 128, 3) (640, 2)
# (640, 128, 128, 3) (640, 2)
#
# (1440, 128, 128, 3) (1440, 2)
# (480, 128, 128, 3) (480, 2)
# (480, 128, 128, 3) (480, 2)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1920
# xTrain_S image Numbers // 10 :  192
# 10

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1440
# xTrain_S image Numbers // 10 :  144
# 10

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 21s 287ms/step - loss: 0.4816 - accuracy: 0.7839 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.2671 - accuracy: 0.8917 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.2413 - accuracy: 0.8974 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.1983 - accuracy: 0.9182 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 5/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1173 - accuracy: 0.9563 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 6/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0827 - accuracy: 0.9688 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 7/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0722 - accuracy: 0.9672 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 8/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0441 - accuracy: 0.9839 - val_loss: 0.7051 - val_accuracy: 0.5000
# Epoch 9/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.1219 - accuracy: 0.9510 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 10/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0481 - accuracy: 0.9823 - val_loss: 0.6898 - val_accuracy: 0.5000
# Epoch 11/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0172 - accuracy: 0.9932 - val_loss: 0.6845 - val_accuracy: 0.5312
# Epoch 12/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0747 - accuracy: 0.9729 - val_loss: 0.6640 - val_accuracy: 0.6609
# Epoch 13/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0592 - accuracy: 0.9797 - val_loss: 0.6626 - val_accuracy: 0.5000
# Epoch 14/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0365 - accuracy: 0.9870 - val_loss: 0.7544 - val_accuracy: 0.5000
# Epoch 15/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 0.5593 - val_accuracy: 0.6969
# Epoch 16/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7530 - val_accuracy: 0.5609
# Epoch 17/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 1.0314 - val_accuracy: 0.5484
# Epoch 18/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.7501 - val_accuracy: 0.6766
# Epoch 19/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0482 - accuracy: 0.9828 - val_loss: 4.9585 - val_accuracy: 0.5516
# Epoch 20/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0361 - accuracy: 0.9854 - val_loss: 2.1800 - val_accuracy: 0.6187
# Epoch 21/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.4542 - val_accuracy: 0.9016
# Epoch 22/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.3505 - val_accuracy: 0.9391
# Epoch 23/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0272 - accuracy: 0.9885 - val_loss: 0.4936 - val_accuracy: 0.9281
# Epoch 24/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.3733 - val_accuracy: 0.9547
# Epoch 25/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 1.0337 - val_accuracy: 0.8813
# Epoch 26/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 1.6843 - val_accuracy: 0.8062
# Epoch 27/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.5406 - val_accuracy: 0.9234
# Epoch 28/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0824 - accuracy: 0.9760 - val_loss: 4.3273 - val_accuracy: 0.7828
# Epoch 29/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0353 - accuracy: 0.9891 - val_loss: 4.1566 - val_accuracy: 0.7828
# Epoch 30/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0226 - accuracy: 0.9911 - val_loss: 6.6056 - val_accuracy: 0.6594
# Epoch 31/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0372 - accuracy: 0.9875 - val_loss: 1.6605 - val_accuracy: 0.8188
# Epoch 32/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 1.0436 - val_accuracy: 0.8594
# Epoch 33/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.8343 - val_accuracy: 0.8438
# Epoch 34/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.3525 - val_accuracy: 0.9328
# Epoch 35/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.3726 - val_accuracy: 0.9469
# Epoch 36/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.3809 - val_accuracy: 0.9266
# Epoch 37/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0343 - accuracy: 0.9870 - val_loss: 5.8086 - val_accuracy: 0.6734
# Epoch 38/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0149 - accuracy: 0.9958 - val_loss: 2.3969 - val_accuracy: 0.7625
# Epoch 39/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.0170 - accuracy: 0.9953 - val_loss: 0.2353 - val_accuracy: 0.9594
# Epoch 40/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 1.0407 - val_accuracy: 0.8109
# Epoch 41/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3194 - val_accuracy: 0.9375
# Epoch 42/100
# 30/30 [==============================] - 8s 251ms/step - loss: 2.1684e-04 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9563
# Epoch 43/100
# 30/30 [==============================] - 8s 254ms/step - loss: 9.0375e-04 - accuracy: 0.9995 - val_loss: 0.1235 - val_accuracy: 0.9688
# Epoch 44/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 1.0350 - val_accuracy: 0.8219
# Epoch 45/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0143 - accuracy: 0.9969 - val_loss: 0.3943 - val_accuracy: 0.9547
# Epoch 46/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0089 - accuracy: 0.9964 - val_loss: 1.2985 - val_accuracy: 0.8547
# Epoch 47/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.6154 - val_accuracy: 0.9078
# Epoch 48/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.3204 - val_accuracy: 0.9516
# Epoch 49/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0132 - accuracy: 0.9943 - val_loss: 0.9216 - val_accuracy: 0.8656
# Epoch 50/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.5552 - val_accuracy: 0.8984
# Epoch 51/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.6736 - val_accuracy: 0.8938
# Epoch 52/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.2064 - val_accuracy: 0.9609
# Epoch 53/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.2691 - val_accuracy: 0.9484
# Epoch 54/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.4294 - val_accuracy: 0.9312
# Epoch 55/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.8219 - val_accuracy: 0.8813
# Epoch 56/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.4127 - val_accuracy: 0.9281
# Epoch 57/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 1.8319 - val_accuracy: 0.8406
# Epoch 58/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0207 - accuracy: 0.9964 - val_loss: 0.4408 - val_accuracy: 0.9438
# Epoch 59/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.2920 - val_accuracy: 0.9547
# Epoch 60/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.3169 - val_accuracy: 0.9500
# Epoch 61/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.3818 - val_accuracy: 0.9516
# Epoch 62/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 1.1314 - val_accuracy: 0.8391
# Epoch 63/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0336 - accuracy: 0.9901 - val_loss: 2.3037 - val_accuracy: 0.7547
# Epoch 64/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0273 - accuracy: 0.9911 - val_loss: 1.0279 - val_accuracy: 0.8578
# Epoch 65/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.4077 - val_accuracy: 0.9312
# Epoch 66/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 1.1825 - val_accuracy: 0.8906
# Epoch 67/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 1.0478 - val_accuracy: 0.8766
# Epoch 68/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 2.0371 - val_accuracy: 0.7906
# Epoch 69/100
# 30/30 [==============================] - 7s 251ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 3.4295 - val_accuracy: 0.7937
# Epoch 70/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0300 - accuracy: 0.9911 - val_loss: 2.4622 - val_accuracy: 0.7453
# Epoch 71/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 1.4143 - val_accuracy: 0.8813
# Epoch 72/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 1.6009 - val_accuracy: 0.8406
# Epoch 73/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9969Restoring model weights from the end of the best epoch: 43.
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0057 - accuracy: 0.9969 - val_loss: 2.2892 - val_accuracy: 0.8219
# Epoch 00073: early stopping
# Maximal validation accuracy: 96.88%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.481589  0.783854  0.693153      0.500000
# 1   0.267083  0.891667  0.693147      0.500000
# 2   0.241344  0.897396  0.693171      0.500000
# 3   0.198328  0.918229  0.693394      0.500000
# 4   0.117309  0.956250  0.693324      0.500000
# ..       ...       ...       ...           ...
# 68  0.003991  0.998958  3.429455      0.793750
# 69  0.029965  0.991146  2.462205      0.745313
# 70  0.026671  0.991146  1.414296      0.881250
# 71  0.005875  0.997917  1.600861      0.840625
# 72  0.005714  0.996875  2.289239      0.821875
#
# [73 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.12354757636785507
# Maximum validation accuracy: 0.96875

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 2s 34ms/step - loss: 0.2087 - accuracy: 0.9625
# test loss, test acc: [0.20872509479522705, 0.9624999761581421]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 20/20 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 13s 285ms/step - loss: 0.2315 - accuracy: 0.9125 - val_loss: 6.3531 - val_accuracy: 0.7328
# Epoch 2/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0682 - accuracy: 0.9844 - val_loss: 4.5440 - val_accuracy: 0.7109
# Epoch 3/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0516 - accuracy: 0.9849 - val_loss: 3.6859 - val_accuracy: 0.6141
# Epoch 4/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0213 - accuracy: 0.9927 - val_loss: 1.8924 - val_accuracy: 0.7531
# Epoch 5/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0300 - accuracy: 0.9885 - val_loss: 0.5382 - val_accuracy: 0.9156
# Epoch 6/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 1.5455 - val_accuracy: 0.8172
# Epoch 7/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.1812 - val_accuracy: 0.9563
# Epoch 8/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0925 - val_accuracy: 0.9797
# Epoch 9/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0167 - accuracy: 0.9964 - val_loss: 0.6962 - val_accuracy: 0.8781
# Epoch 10/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0308 - accuracy: 0.9937 - val_loss: 0.0941 - val_accuracy: 0.9750
# Epoch 11/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0527 - accuracy: 0.9823 - val_loss: 1.1469 - val_accuracy: 0.8672
# Epoch 12/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.1104 - val_accuracy: 0.9672
# Epoch 13/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.3724 - val_accuracy: 0.9062
# Epoch 14/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0793 - val_accuracy: 0.9922
# Epoch 15/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1325 - val_accuracy: 0.9844
# Epoch 16/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0412 - accuracy: 0.9896 - val_loss: 0.3506 - val_accuracy: 0.9125
# Epoch 17/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 0.1333 - val_accuracy: 0.9656
# Epoch 18/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0087 - accuracy: 0.9995 - val_loss: 0.0574 - val_accuracy: 0.9828
# Epoch 19/100
# 30/30 [==============================] - 8s 255ms/step - loss: 9.6629e-04 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9969
# Epoch 20/100
# 30/30 [==============================] - 8s 252ms/step - loss: 2.9792e-04 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9953
# Epoch 21/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0410 - val_accuracy: 0.9906
# Epoch 22/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0271 - accuracy: 0.9922 - val_loss: 0.4942 - val_accuracy: 0.9203
# Epoch 23/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0063 - accuracy: 0.9969 - val_loss: 0.0519 - val_accuracy: 0.9859
# Epoch 24/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.1733 - val_accuracy: 0.9688
# Epoch 25/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.0646 - val_accuracy: 0.9828
# Epoch 26/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0529 - val_accuracy: 0.9875
# Epoch 27/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.1611 - val_accuracy: 0.9797
# Epoch 28/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 0.3052 - val_accuracy: 0.9578
# Epoch 29/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 0.1221 - val_accuracy: 0.9797
# Epoch 30/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.2030 - val_accuracy: 0.9672
# Epoch 31/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1901 - val_accuracy: 0.9672
# Epoch 32/100
# 30/30 [==============================] - 8s 251ms/step - loss: 5.1414e-04 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9828
# Epoch 33/100
# 30/30 [==============================] - 8s 251ms/step - loss: 1.1818e-04 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9875
# Epoch 34/100
# 30/30 [==============================] - 8s 252ms/step - loss: 2.6389e-04 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9937
# Epoch 35/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0472 - val_accuracy: 0.9891
# Epoch 36/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.1137 - val_accuracy: 0.9781
# Epoch 37/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.1075 - val_accuracy: 0.9859
# Epoch 38/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.0219 - accuracy: 0.9932 - val_loss: 15.9953 - val_accuracy: 0.5750
# Epoch 39/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9958Restoring model weights from the end of the best epoch: 19.
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0209 - accuracy: 0.9958 - val_loss: 1.3844 - val_accuracy: 0.9359
# Epoch 00039: early stopping
# Maximal validation accuracy: 99.69%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.231461  0.912500   6.353051      0.732813
# 1   0.068206  0.984375   4.543973      0.710938
# 2   0.051599  0.984896   3.685930      0.614062
# 3   0.021290  0.992708   1.892431      0.753125
# 4   0.029992  0.988542   0.538242      0.915625
# 5   0.009805  0.997396   1.545455      0.817187
# 6   0.009857  0.996875   0.181233      0.956250
# 7   0.002199  0.998958   0.092482      0.979688
# 8   0.016749  0.996354   0.696182      0.878125
# 9   0.030774  0.993750   0.094140      0.975000
# 10  0.052723  0.982292   1.146880      0.867188
# 11  0.007498  0.998438   0.110397      0.967188
# 12  0.014481  0.995833   0.372433      0.906250
# 13  0.010233  0.996875   0.079295      0.992188
# 14  0.001943  0.999479   0.132530      0.984375
# 15  0.041150  0.989583   0.350578      0.912500
# 16  0.013993  0.994792   0.133318      0.965625
# 17  0.008713  0.999479   0.057378      0.982813
# 18  0.000966  1.000000   0.018010      0.996875
# 19  0.000298  1.000000   0.021841      0.995313
# 20  0.001731  0.999479   0.040951      0.990625
# 21  0.027065  0.992188   0.494248      0.920313
# 22  0.006329  0.996875   0.051912      0.985937
# 23  0.005530  0.997917   0.173337      0.968750
# 24  0.006168  0.998958   0.064563      0.982813
# 25  0.008841  0.997396   0.052906      0.987500
# 26  0.011491  0.996354   0.161074      0.979688
# 27  0.015877  0.995313   0.305180      0.957812
# 28  0.018065  0.994792   0.122051      0.979688
# 29  0.013162  0.995833   0.202978      0.967188
# 30  0.003426  0.998958   0.190144      0.967188
# 31  0.000514  1.000000   0.079994      0.982813
# 32  0.000118  1.000000   0.043294      0.987500
# 33  0.000264  1.000000   0.026928      0.993750
# 34  0.001446  0.999479   0.047180      0.989062
# 35  0.019163  0.993229   0.113687      0.978125
# 36  0.010469  0.996875   0.107479      0.985937
# 37  0.021911  0.993229  15.995275      0.575000
# 38  0.020892  0.995833   1.384409      0.935938

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.018009517341852188
# Maximum validation accuracy: 0.996874988079071

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 29ms/step - loss: 0.0689 - accuracy: 0.9875
# test loss, test acc: [0.06890507787466049, 0.987500011920929]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 20/20 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 11s 302ms/step - loss: 0.3047 - accuracy: 0.8556 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0612 - accuracy: 0.9785 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 3/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0577 - accuracy: 0.9799 - val_loss: 0.6964 - val_accuracy: 0.5000
# Epoch 4/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0515 - accuracy: 0.9819 - val_loss: 0.7030 - val_accuracy: 0.5000
# Epoch 5/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0255 - accuracy: 0.9882 - val_loss: 0.7161 - val_accuracy: 0.5000
# Epoch 6/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0497 - accuracy: 0.9826 - val_loss: 0.7264 - val_accuracy: 0.5000
# Epoch 7/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0301 - accuracy: 0.9903 - val_loss: 0.7401 - val_accuracy: 0.5000
# Epoch 8/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0185 - accuracy: 0.9917 - val_loss: 0.7831 - val_accuracy: 0.5000
# Epoch 9/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.8977 - val_accuracy: 0.5000
# Epoch 10/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0139 - accuracy: 0.9944 - val_loss: 1.0233 - val_accuracy: 0.5000
# Epoch 11/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0241 - accuracy: 0.9931 - val_loss: 1.1254 - val_accuracy: 0.5000
# Epoch 12/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 1.5084 - val_accuracy: 0.5000
# Epoch 13/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 1.9069 - val_accuracy: 0.5000
# Epoch 14/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0365 - accuracy: 0.9882 - val_loss: 1.9300 - val_accuracy: 0.5000
# Epoch 15/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0102 - accuracy: 0.9951 - val_loss: 2.5842 - val_accuracy: 0.5000
# Epoch 16/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 3.1579 - val_accuracy: 0.5000
# Epoch 17/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 3.8881 - val_accuracy: 0.5000
# Epoch 18/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 4.3394 - val_accuracy: 0.5000
# Epoch 19/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0239 - accuracy: 0.9944 - val_loss: 3.4877 - val_accuracy: 0.5000
# Epoch 20/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 4.3740 - val_accuracy: 0.5000
# Epoch 21/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0050 - accuracy: 0.9972 - val_loss: 4.3695 - val_accuracy: 0.5000
# Epoch 22/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 3.1746 - val_accuracy: 0.5292
# Epoch 23/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 1.0022 - val_accuracy: 0.6750
# Epoch 24/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.3794 - val_accuracy: 0.9042
# Epoch 25/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.2088 - val_accuracy: 0.9458
# Epoch 26/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9500
# Epoch 27/100
# 23/23 [==============================] - 6s 251ms/step - loss: 2.1523e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9688
# Epoch 28/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.2024 - val_accuracy: 0.9646
# Epoch 29/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.1276 - val_accuracy: 0.9667
# Epoch 30/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0097 - accuracy: 0.9958 - val_loss: 0.1674 - val_accuracy: 0.9583
# Epoch 31/100
# 23/23 [==============================] - 6s 251ms/step - loss: 0.0050 - accuracy: 0.9972 - val_loss: 0.1595 - val_accuracy: 0.9750
# Epoch 32/100
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1210 - val_accuracy: 0.9812
# Epoch 33/100
# 23/23 [==============================] - 6s 252ms/step - loss: 6.9459e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9854
# Epoch 34/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.3888 - val_accuracy: 0.9292
# Epoch 35/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 1.3628 - val_accuracy: 0.8583
# Epoch 36/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0086 - accuracy: 0.9979 - val_loss: 0.7473 - val_accuracy: 0.9062
# Epoch 37/100
# 23/23 [==============================] - 6s 246ms/step - loss: 0.0034 - accuracy: 0.9979 - val_loss: 0.1391 - val_accuracy: 0.9729
# Epoch 38/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.1051 - val_accuracy: 0.9833
# Epoch 39/100
# 23/23 [==============================] - 6s 247ms/step - loss: 6.1361e-04 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9854
# Epoch 40/100
# 23/23 [==============================] - 6s 251ms/step - loss: 1.8135e-04 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9875
# Epoch 41/100
# 23/23 [==============================] - 6s 246ms/step - loss: 5.0914e-05 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9875
# Epoch 42/100
# 23/23 [==============================] - 6s 247ms/step - loss: 9.3962e-05 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9875
# Epoch 43/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.6513e-04 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9812
# Epoch 44/100
# 23/23 [==============================] - 6s 246ms/step - loss: 4.8092e-05 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9812
# Epoch 45/100
# 23/23 [==============================] - 6s 247ms/step - loss: 9.2460e-04 - accuracy: 0.9993 - val_loss: 0.0623 - val_accuracy: 0.9854
# Epoch 46/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.0937 - val_accuracy: 0.9792
# Epoch 47/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.4739 - val_accuracy: 0.9187
# Epoch 48/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 5.0282 - val_accuracy: 0.7125
# Epoch 49/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.9824 - val_accuracy: 0.9146
# Epoch 50/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0140 - accuracy: 0.9937 - val_loss: 18.3855 - val_accuracy: 0.5750
# Epoch 51/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0188 - accuracy: 0.9958 - val_loss: 0.3523 - val_accuracy: 0.9458
# Epoch 52/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9688
# Epoch 53/100
# 23/23 [==============================] - 6s 247ms/step - loss: 7.2534e-04 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9812
# Epoch 54/100
# 23/23 [==============================] - 6s 247ms/step - loss: 2.7174e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9812
# Epoch 55/100
# 23/23 [==============================] - 6s 248ms/step - loss: 4.0437e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9771
# Epoch 56/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0042 - accuracy: 0.9979 - val_loss: 0.6515 - val_accuracy: 0.9146
# Epoch 57/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 1.1258 - val_accuracy: 0.8438
# Epoch 58/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.1721 - val_accuracy: 0.9750
# Epoch 59/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0132 - accuracy: 0.9937 - val_loss: 7.9410 - val_accuracy: 0.5771
# Epoch 60/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 3.3262 - val_accuracy: 0.7604
# Epoch 61/100
# 23/23 [==============================] - 6s 248ms/step - loss: 5.7757e-04 - accuracy: 1.0000 - val_loss: 1.3529 - val_accuracy: 0.8417
# Epoch 62/100
# 23/23 [==============================] - 6s 248ms/step - loss: 3.0248e-04 - accuracy: 1.0000 - val_loss: 0.6192 - val_accuracy: 0.9083
# Epoch 63/100
# 23/23 [==============================] - 6s 248ms/step - loss: 2.9189e-04 - accuracy: 1.0000 - val_loss: 0.3801 - val_accuracy: 0.9354
# Epoch 64/100
# 23/23 [==============================] - 6s 248ms/step - loss: 8.4146e-05 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9604
# Epoch 65/100
# 23/23 [==============================] - 6s 247ms/step - loss: 4.6585e-05 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9875
# Epoch 66/100
# 23/23 [==============================] - 6s 252ms/step - loss: 6.3411e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9896
# Epoch 67/100
# 23/23 [==============================] - 6s 251ms/step - loss: 7.4627e-05 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9917
# Epoch 68/100
# 23/23 [==============================] - 6s 247ms/step - loss: 2.4062e-05 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9896
# Epoch 69/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.4655e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9917
# Epoch 70/100
# 23/23 [==============================] - 6s 247ms/step - loss: 3.6812e-05 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 0.9896
# Epoch 71/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.1363e-05 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9875
# Epoch 72/100
# 23/23 [==============================] - 6s 247ms/step - loss: 4.3352e-05 - accuracy: 1.0000 - val_loss: 0.0554 - val_accuracy: 0.9854
# Epoch 73/100
# 23/23 [==============================] - 6s 247ms/step - loss: 2.4498e-04 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9854
# Epoch 74/100
# 23/23 [==============================] - 6s 248ms/step - loss: 2.5458e-04 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9812
# Epoch 75/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.2109 - val_accuracy: 0.9771
# Epoch 76/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.8214 - val_accuracy: 0.8938
# Epoch 77/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0380 - accuracy: 0.9868 - val_loss: 0.2375 - val_accuracy: 0.9521
# Epoch 78/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.3103 - val_accuracy: 0.9458
# Epoch 79/100
# 23/23 [==============================] - 6s 247ms/step - loss: 5.2335e-04 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9667
# Epoch 80/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.0747e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9771
# Epoch 81/100
# 23/23 [==============================] - 6s 248ms/step - loss: 9.5402e-04 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9604
# Epoch 82/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0026 - accuracy: 0.9986 - val_loss: 0.1529 - val_accuracy: 0.9750
# Epoch 83/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0011 - accuracy: 0.9993 - val_loss: 0.1405 - val_accuracy: 0.9708
# Epoch 84/100
# 23/23 [==============================] - 6s 247ms/step - loss: 1.4355e-04 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9854
# Epoch 85/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0038 - accuracy: 0.9972 - val_loss: 0.1887 - val_accuracy: 0.9771
# Epoch 86/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0190 - accuracy: 0.9924 - val_loss: 1.1630 - val_accuracy: 0.9062
# Epoch 87/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0144 - accuracy: 0.9931 - val_loss: 4.6377 - val_accuracy: 0.8042
# Epoch 88/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 3.6529 - val_accuracy: 0.7521
# Epoch 89/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9563
# Epoch 90/100
# 23/23 [==============================] - 6s 247ms/step - loss: 4.4470e-04 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9729
# Epoch 91/100
# 23/23 [==============================] - 6s 248ms/step - loss: 7.0918e-04 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9583
# Epoch 92/100
# 23/23 [==============================] - 6s 248ms/step - loss: 8.5903e-05 - accuracy: 1.0000 - val_loss: 1.7879 - val_accuracy: 0.8292
# Epoch 93/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0011 - accuracy: 0.9993 - val_loss: 0.2995 - val_accuracy: 0.9396
# Epoch 94/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.2791 - val_accuracy: 0.9438
# Epoch 95/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0135 - accuracy: 0.9972 - val_loss: 1.8374 - val_accuracy: 0.8417
# Epoch 96/100
# 23/23 [==============================] - 6s 247ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.1255 - val_accuracy: 0.9708
# Epoch 97/100
# 23/23 [==============================] - ETA: 0s - loss: 5.9672e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 67.
# 23/23 [==============================] - 6s 252ms/step - loss: 5.9672e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9604
# Epoch 00097: early stopping
# Maximal validation accuracy: 99.17%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.304723  0.855556  0.693230      0.500000
# 1   0.061192  0.978472  0.694174      0.500000
# 2   0.057711  0.979861  0.696360      0.500000
# 3   0.051510  0.981944  0.702970      0.500000
# 4   0.025533  0.988194  0.716144      0.500000
# ..       ...       ...       ...           ...
# 92  0.001107  0.999306  0.299489      0.939583
# 93  0.006893  0.997222  0.279104      0.943750
# 94  0.013521  0.997222  1.837427      0.841667
# 95  0.005129  0.997917  0.125504      0.970833
# 96  0.000597  1.000000  0.228079      0.960417
#
# [97 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.034562136977910995
# Maximum validation accuracy: 0.9916666746139526

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 29ms/step - loss: 0.0877 - accuracy: 0.9833
# test loss, test acc: [0.08772878348827362, 0.9833333492279053]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 15/15 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 11s 293ms/step - loss: 0.1919 - accuracy: 0.9278 - val_loss: 0.9834 - val_accuracy: 0.9167
# Epoch 2/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0254 - accuracy: 0.9958 - val_loss: 3.8417 - val_accuracy: 0.8583
# Epoch 3/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0539 - accuracy: 0.9889 - val_loss: 1.6070 - val_accuracy: 0.8938
# Epoch 4/100
# 23/23 [==============================] - 6s 253ms/step - loss: 0.0203 - accuracy: 0.9931 - val_loss: 0.2299 - val_accuracy: 0.9812
# Epoch 5/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0364 - accuracy: 0.9924 - val_loss: 0.6500 - val_accuracy: 0.8542
# Epoch 6/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0338 - accuracy: 0.9889 - val_loss: 18.6170 - val_accuracy: 0.7042
# Epoch 7/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0207 - accuracy: 0.9917 - val_loss: 4.6098 - val_accuracy: 0.8521
# Epoch 8/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 1.7816 - val_accuracy: 0.8833
# Epoch 9/100
# 23/23 [==============================] - 6s 248ms/step - loss: 6.1063e-04 - accuracy: 1.0000 - val_loss: 0.6266 - val_accuracy: 0.9333
# Epoch 10/100
# 23/23 [==============================] - 6s 253ms/step - loss: 5.4652e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9896
# Epoch 11/100
# 23/23 [==============================] - 6s 253ms/step - loss: 0.0020 - accuracy: 0.9986 - val_loss: 0.0421 - val_accuracy: 0.9937
# Epoch 12/100
# 23/23 [==============================] - 6s 249ms/step - loss: 8.0522e-04 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9937
# Epoch 13/100
# 23/23 [==============================] - 6s 248ms/step - loss: 2.3942e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9937
# Epoch 14/100
# 23/23 [==============================] - 6s 252ms/step - loss: 1.8649e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9958
# Epoch 15/100
# 23/23 [==============================] - 6s 253ms/step - loss: 4.3972e-05 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 16/100
# 23/23 [==============================] - 6s 249ms/step - loss: 3.8240e-05 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9979
# Epoch 17/100
# 23/23 [==============================] - 6s 249ms/step - loss: 1.4493e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9979
# Epoch 18/100
# 23/23 [==============================] - 6s 254ms/step - loss: 3.3646e-04 - accuracy: 1.0000 - val_loss: 4.0696e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 23/23 [==============================] - 6s 249ms/step - loss: 1.6012e-05 - accuracy: 1.0000 - val_loss: 2.2148e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 23/23 [==============================] - 6s 249ms/step - loss: 1.8788e-05 - accuracy: 1.0000 - val_loss: 5.0847e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0097 - accuracy: 0.9979 - val_loss: 0.0367 - val_accuracy: 0.9937
# Epoch 22/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9958
# Epoch 23/100
# 23/23 [==============================] - 6s 249ms/step - loss: 3.1782e-04 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9917
# Epoch 24/100
# 23/23 [==============================] - 6s 248ms/step - loss: 1.2026e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9958
# Epoch 25/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0281 - accuracy: 0.9931 - val_loss: 2.6491 - val_accuracy: 0.7854
# Epoch 26/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 7.5410 - val_accuracy: 0.6979
# Epoch 27/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0260 - accuracy: 0.9910 - val_loss: 1.7746 - val_accuracy: 0.8708
# Epoch 28/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0246 - accuracy: 0.9944 - val_loss: 3.5197 - val_accuracy: 0.7750
# Epoch 29/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.0910 - val_accuracy: 0.9708
# Epoch 30/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.1729 - val_accuracy: 0.9688
# Epoch 31/100
# 23/23 [==============================] - 6s 249ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0456 - val_accuracy: 0.9833
# Epoch 32/100
# 23/23 [==============================] - 6s 248ms/step - loss: 4.0742e-04 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9875
# Epoch 33/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0253 - val_accuracy: 0.9958
# Epoch 34/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.0189 - val_accuracy: 0.9979
# Epoch 35/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0369 - val_accuracy: 0.9979
# Epoch 36/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9958
# Epoch 37/100
# 23/23 [==============================] - 6s 248ms/step - loss: 0.0077 - accuracy: 0.9993 - val_loss: 0.1943 - val_accuracy: 0.9854
# Epoch 38/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9993Restoring model weights from the end of the best epoch: 18.
# 23/23 [==============================] - 6s 252ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.0157 - val_accuracy: 0.9937
# Epoch 00038: early stopping
# Maximal validation accuracy: 100.00%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.191917  0.927778   0.983352      0.916667
# 1   0.025387  0.995833   3.841712      0.858333
# 2   0.053857  0.988889   1.606965      0.893750
# 3   0.020277  0.993056   0.229865      0.981250
# 4   0.036362  0.992361   0.649964      0.854167
# 5   0.033812  0.988889  18.616953      0.704167
# 6   0.020702  0.991667   4.609793      0.852083
# 7   0.006518  0.997917   1.781639      0.883333
# 8   0.000611  1.000000   0.626556      0.933333
# 9   0.000547  1.000000   0.065441      0.989583
# 10  0.001959  0.998611   0.042124      0.993750
# 11  0.000805  1.000000   0.058817      0.993750
# 12  0.000239  1.000000   0.042207      0.993750
# 13  0.000186  1.000000   0.026465      0.995833
# 14  0.000044  1.000000   0.019224      0.997917
# 15  0.000038  1.000000   0.016186      0.997917
# 16  0.000145  1.000000   0.002518      0.997917
# 17  0.000336  1.000000   0.000407      1.000000
# 18  0.000016  1.000000   0.000221      1.000000
# 19  0.000019  1.000000   0.000508      1.000000
# 20  0.009707  0.997917   0.036691      0.993750
# 21  0.002909  1.000000   0.032773      0.995833
# 22  0.000318  1.000000   0.030254      0.991667
# 23  0.000120  1.000000   0.023141      0.995833
# 24  0.028090  0.993056   2.649065      0.785417
# 25  0.008319  0.997222   7.541018      0.697917
# 26  0.025980  0.990972   1.774559      0.870833
# 27  0.024649  0.994444   3.519668      0.775000
# 28  0.005304  0.997917   0.091048      0.970833
# 29  0.013599  0.997917   0.172854      0.968750
# 30  0.003503  0.998611   0.045605      0.983333
# 31  0.000407  1.000000   0.030053      0.987500
# 32  0.004751  0.998611   0.025292      0.995833
# 33  0.004306  0.999306   0.018878      0.997917
# 34  0.003890  0.998611   0.036901      0.997917
# 35  0.001112  1.000000   0.043115      0.995833
# 36  0.007735  0.999306   0.194290      0.985417
# 37  0.006833  0.999306   0.015653      0.993750

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.00022147972777020186
# Maximum validation accuracy: 1.0

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 29ms/step - loss: 2.9984e-04 - accuracy: 1.0000
# test loss, test acc: [0.0002998356067109853, 1.0]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 15/15 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_Xception_None
# test loss, test acc: [0.20872509479522705, 0.9624999761581421]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_Xception_imagenet
# test loss, test acc: [0.06890507787466049, 0.987500011920929]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_Xception_None
# test loss, test acc: [0.08772878348827362, 0.9833333492279053]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_Xception_imagenet
# test loss, test acc: [0.0002998356067109853, 1.0]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_Xception_None →→→ Target Test
# 15/15 [==============================] - 0s 29ms/step - loss: 3.1155 - accuracy: 0.5833
# test loss, test acc: [3.11548113822937, 0.5833333134651184]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_Xception_imagenet →→→ Target Test
# 15/15 [==============================] - 0s 29ms/step - loss: 2.4501 - accuracy: 0.6896
# test loss, test acc: [2.450143575668335, 0.6895833611488342]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_Xception_None →→→ Source Test
# 20/20 [==============================] - 1s 29ms/step - loss: 2.6819 - accuracy: 0.6109
# test loss, test acc: [2.6819145679473877, 0.6109374761581421]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_Xception_imagenet →→→ Source Test
# 20/20 [==============================] - 1s 29ms/step - loss: 2.6619 - accuracy: 0.6797
# test loss, test acc: [2.661888837814331, 0.6796875]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
