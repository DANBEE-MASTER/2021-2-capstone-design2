# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14678892239041980656
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 531325610138471868
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 20:28:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    31W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'InceptionV3'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_InceptionV3_None S_InceptionV3_imagenet T_InceptionV3_None T_InceptionV3_imagenet
# ['S_InceptionV3_imagenet',
#  'S_InceptionV3_None',
#  'T_InceptionV3_imagenet',
#  'T_InceptionV3_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)
#
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)
#
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.InceptionV3 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.InceptionV3 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 22s 179ms/step - loss: 1.4547 - accuracy: 0.4727 - val_loss: 1.9468 - val_accuracy: 0.1848
# Epoch 2/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.8763 - accuracy: 0.6925 - val_loss: 2.2388 - val_accuracy: 0.1155
# Epoch 3/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.7652 - accuracy: 0.7483 - val_loss: 2.7862 - val_accuracy: 0.1848
# Epoch 4/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.7093 - accuracy: 0.7640 - val_loss: 4.8503 - val_accuracy: 0.1085
# Epoch 5/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.5762 - accuracy: 0.8048 - val_loss: 6.0613 - val_accuracy: 0.1975
# Epoch 6/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.5209 - accuracy: 0.8195 - val_loss: 8.2208 - val_accuracy: 0.1848
# Epoch 7/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.4455 - accuracy: 0.8437 - val_loss: 3.6025 - val_accuracy: 0.2194
# Epoch 8/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.3963 - accuracy: 0.8487 - val_loss: 5.1713 - val_accuracy: 0.1490
# Epoch 9/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.4270 - accuracy: 0.8557 - val_loss: 5.2079 - val_accuracy: 0.1905
# Epoch 10/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.4040 - accuracy: 0.8637 - val_loss: 3.7032 - val_accuracy: 0.3303
# Epoch 11/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.3738 - accuracy: 0.8645 - val_loss: 4.2543 - val_accuracy: 0.3025
# Epoch 12/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.3198 - accuracy: 0.8861 - val_loss: 1.3722 - val_accuracy: 0.6143
# Epoch 13/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.3206 - accuracy: 0.8872 - val_loss: 1.5702 - val_accuracy: 0.6120
# Epoch 14/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.2751 - accuracy: 0.8984 - val_loss: 1.1415 - val_accuracy: 0.7136
# Epoch 15/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.2686 - accuracy: 0.8992 - val_loss: 1.4991 - val_accuracy: 0.6524
# Epoch 16/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2981 - accuracy: 0.8915 - val_loss: 1.3026 - val_accuracy: 0.6293
# Epoch 17/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.2327 - accuracy: 0.9076 - val_loss: 1.1698 - val_accuracy: 0.7483
# Epoch 18/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6230 - accuracy: 0.8006 - val_loss: 151.2591 - val_accuracy: 0.1848
# Epoch 19/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6531 - accuracy: 0.7995 - val_loss: 1343.9009 - val_accuracy: 0.1848
# Epoch 20/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.6690 - accuracy: 0.7617 - val_loss: 251.8233 - val_accuracy: 0.0600
# Epoch 21/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.4225 - accuracy: 0.8430 - val_loss: 24.7818 - val_accuracy: 0.3129
# Epoch 22/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.3106 - accuracy: 0.8853 - val_loss: 2.1854 - val_accuracy: 0.5831
# Epoch 23/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.2950 - accuracy: 0.8849 - val_loss: 0.7108 - val_accuracy: 0.7968
# Epoch 24/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.2676 - accuracy: 0.8938 - val_loss: 1.2101 - val_accuracy: 0.7113
# Epoch 25/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2898 - accuracy: 0.8968 - val_loss: 1.5877 - val_accuracy: 0.6224
# Epoch 26/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2198 - accuracy: 0.9092 - val_loss: 1.2081 - val_accuracy: 0.7079
# Epoch 27/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.2239 - accuracy: 0.9092 - val_loss: 2.0058 - val_accuracy: 0.5831
# Epoch 28/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.2190 - accuracy: 0.9188 - val_loss: 1.1626 - val_accuracy: 0.7171
# Epoch 29/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2206 - accuracy: 0.9165 - val_loss: 1.2097 - val_accuracy: 0.7506
# Epoch 30/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.2094 - accuracy: 0.9149 - val_loss: 1.0250 - val_accuracy: 0.7575
# Epoch 31/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1457 - accuracy: 0.9407 - val_loss: 0.6804 - val_accuracy: 0.8360
# Epoch 32/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1700 - accuracy: 0.9269 - val_loss: 0.7301 - val_accuracy: 0.8083
# Epoch 33/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1859 - accuracy: 0.9257 - val_loss: 0.8628 - val_accuracy: 0.7829
# Epoch 34/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.2563 - accuracy: 0.9080 - val_loss: 6.2930 - val_accuracy: 0.1767
# Epoch 35/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1962 - accuracy: 0.9215 - val_loss: 1.3146 - val_accuracy: 0.6813
# Epoch 36/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1959 - accuracy: 0.9276 - val_loss: 14.5531 - val_accuracy: 0.4630
# Epoch 37/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1505 - accuracy: 0.9423 - val_loss: 1.6494 - val_accuracy: 0.6547
# Epoch 38/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1926 - accuracy: 0.9261 - val_loss: 24.6964 - val_accuracy: 0.1998
# Epoch 39/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1512 - accuracy: 0.9419 - val_loss: 0.6552 - val_accuracy: 0.8176
# Epoch 40/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1509 - accuracy: 0.9400 - val_loss: 0.8087 - val_accuracy: 0.7748
# Epoch 41/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1262 - accuracy: 0.9496 - val_loss: 1.4211 - val_accuracy: 0.7252
# Epoch 42/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1202 - accuracy: 0.9546 - val_loss: 0.6227 - val_accuracy: 0.8406
# Epoch 43/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0752 - accuracy: 0.9669 - val_loss: 0.4400 - val_accuracy: 0.8822
# Epoch 44/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0759 - accuracy: 0.9711 - val_loss: 1.7019 - val_accuracy: 0.7032
# Epoch 45/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1176 - accuracy: 0.9534 - val_loss: 2.6375 - val_accuracy: 0.6120
# Epoch 46/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1382 - accuracy: 0.9534 - val_loss: 0.6104 - val_accuracy: 0.8245
# Epoch 47/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1010 - accuracy: 0.9665 - val_loss: 0.6356 - val_accuracy: 0.8406
# Epoch 48/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0960 - accuracy: 0.9646 - val_loss: 0.6531 - val_accuracy: 0.8279
# Epoch 49/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1068 - accuracy: 0.9604 - val_loss: 1.6350 - val_accuracy: 0.7009
# Epoch 50/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1027 - accuracy: 0.9642 - val_loss: 0.9475 - val_accuracy: 0.8048
# Epoch 51/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1033 - accuracy: 0.9657 - val_loss: 2.2035 - val_accuracy: 0.6224
# Epoch 52/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1424 - accuracy: 0.9554 - val_loss: 0.5823 - val_accuracy: 0.8360
# Epoch 53/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0837 - accuracy: 0.9738 - val_loss: 0.7577 - val_accuracy: 0.8349
# Epoch 54/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0854 - accuracy: 0.9734 - val_loss: 1.6096 - val_accuracy: 0.6721
# Epoch 55/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0721 - accuracy: 0.9765 - val_loss: 0.9012 - val_accuracy: 0.8164
# Epoch 56/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0718 - accuracy: 0.9734 - val_loss: 3.4956 - val_accuracy: 0.5935
# Epoch 57/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1338 - accuracy: 0.9523 - val_loss: 2.2670 - val_accuracy: 0.6478
# Epoch 58/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0780 - accuracy: 0.9754 - val_loss: 0.6066 - val_accuracy: 0.8545
# Epoch 59/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0411 - accuracy: 0.9869 - val_loss: 1.0812 - val_accuracy: 0.7898
# Epoch 60/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0741 - accuracy: 0.9788 - val_loss: 1.1532 - val_accuracy: 0.7333
# Epoch 61/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 0.5796 - val_accuracy: 0.8730
# Epoch 62/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0407 - accuracy: 0.9858 - val_loss: 0.5489 - val_accuracy: 0.8603
# Epoch 63/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0946 - accuracy: 0.9754 - val_loss: 2.5992 - val_accuracy: 0.5681
# Epoch 64/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0635 - accuracy: 0.9788 - val_loss: 0.9916 - val_accuracy: 0.7968
# Epoch 65/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0506 - accuracy: 0.9823 - val_loss: 1.0291 - val_accuracy: 0.7968
# Epoch 66/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0728 - accuracy: 0.9792 - val_loss: 1.2452 - val_accuracy: 0.7598
# Epoch 67/100
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0623 - accuracy: 0.9815 - val_loss: 0.7273 - val_accuracy: 0.8337
# Epoch 68/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0637 - accuracy: 0.9777 - val_loss: 1.1391 - val_accuracy: 0.7529
# Epoch 69/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0964 - accuracy: 0.9746 - val_loss: 1.9880 - val_accuracy: 0.5727
# Epoch 70/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0797 - accuracy: 0.9758 - val_loss: 1.1218 - val_accuracy: 0.7286
# Epoch 71/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0848 - accuracy: 0.9754 - val_loss: 0.7960 - val_accuracy: 0.8314
# Epoch 72/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0702 - accuracy: 0.9769 - val_loss: 1.3420 - val_accuracy: 0.7413
# Epoch 73/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9815Restoring model weights from the end of the best epoch: 43.
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0650 - accuracy: 0.9815 - val_loss: 0.9948 - val_accuracy: 0.7945
# Epoch 00073: early stopping
# Maximal validation accuracy: 88.22%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.454738  0.472671  1.946766      0.184758
# 1   0.876343  0.692456  2.238846      0.115473
# 2   0.765159  0.748268  2.786233      0.184758
# 3   0.709251  0.764049  4.850286      0.108545
# 4   0.576222  0.804850  6.061348      0.197460
# ..       ...       ...       ...           ...
# 68  0.096382  0.974596  1.988024      0.572748
# 69  0.079652  0.975751  1.121806      0.728637
# 70  0.084758  0.975366  0.796030      0.831409
# 71  0.070246  0.976905  1.342018      0.741340
# 72  0.065002  0.981524  0.994774      0.794457
#
# [73 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.44000300765037537
# Maximum validation accuracy: 0.8822171092033386

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 33ms/step - loss: 0.5139 - accuracy: 0.8661
# test loss, test acc: [0.5138561725616455, 0.8660507798194885]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 2s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 12s 153ms/step - loss: 0.8617 - accuracy: 0.6998 - val_loss: 9.3587 - val_accuracy: 0.2806
# Epoch 2/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.4053 - accuracy: 0.8641 - val_loss: 8.5950 - val_accuracy: 0.2898
# Epoch 3/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.2838 - accuracy: 0.9026 - val_loss: 9.6275 - val_accuracy: 0.2921
# Epoch 4/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1949 - accuracy: 0.9361 - val_loss: 3.2839 - val_accuracy: 0.5069
# Epoch 5/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.1798 - accuracy: 0.9477 - val_loss: 1.0774 - val_accuracy: 0.7483
# Epoch 6/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1139 - accuracy: 0.9619 - val_loss: 1.8889 - val_accuracy: 0.7379
# Epoch 7/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1393 - accuracy: 0.9565 - val_loss: 1.7074 - val_accuracy: 0.6536
# Epoch 8/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1482 - accuracy: 0.9546 - val_loss: 0.8805 - val_accuracy: 0.7933
# Epoch 9/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1088 - accuracy: 0.9677 - val_loss: 0.7665 - val_accuracy: 0.8118
# Epoch 10/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.1259 - accuracy: 0.9665 - val_loss: 0.6322 - val_accuracy: 0.8372
# Epoch 11/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.1029 - accuracy: 0.9734 - val_loss: 2.7386 - val_accuracy: 0.6109
# Epoch 12/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1352 - accuracy: 0.9584 - val_loss: 1.2765 - val_accuracy: 0.7402
# Epoch 13/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.1013 - accuracy: 0.9681 - val_loss: 0.9025 - val_accuracy: 0.8095
# Epoch 14/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0644 - accuracy: 0.9823 - val_loss: 1.1308 - val_accuracy: 0.7483
# Epoch 15/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0635 - accuracy: 0.9800 - val_loss: 0.4127 - val_accuracy: 0.8995
# Epoch 16/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0683 - accuracy: 0.9796 - val_loss: 1.3799 - val_accuracy: 0.7794
# Epoch 17/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0617 - accuracy: 0.9804 - val_loss: 0.5504 - val_accuracy: 0.8545
# Epoch 18/100
# 41/41 [==============================] - 5s 120ms/step - loss: 0.0396 - accuracy: 0.9892 - val_loss: 0.3630 - val_accuracy: 0.9157
# Epoch 19/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0570 - accuracy: 0.9850 - val_loss: 0.6949 - val_accuracy: 0.8418
# Epoch 20/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0317 - accuracy: 0.9900 - val_loss: 0.4969 - val_accuracy: 0.8811
# Epoch 21/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0439 - accuracy: 0.9858 - val_loss: 0.3807 - val_accuracy: 0.9030
# Epoch 22/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0726 - accuracy: 0.9796 - val_loss: 5.2134 - val_accuracy: 0.5831
# Epoch 23/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0621 - accuracy: 0.9842 - val_loss: 2.4181 - val_accuracy: 0.5658
# Epoch 24/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0407 - accuracy: 0.9881 - val_loss: 1.0114 - val_accuracy: 0.7898
# Epoch 25/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.7097 - val_accuracy: 0.8522
# Epoch 26/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 3.1213 - val_accuracy: 0.6744
# Epoch 27/100
# 41/41 [==============================] - 5s 116ms/step - loss: 0.0552 - accuracy: 0.9858 - val_loss: 0.5949 - val_accuracy: 0.8695
# Epoch 28/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0220 - accuracy: 0.9923 - val_loss: 0.8596 - val_accuracy: 0.8222
# Epoch 29/100
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.3448 - val_accuracy: 0.9203
# Epoch 30/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0382 - accuracy: 0.9888 - val_loss: 0.3301 - val_accuracy: 0.9134
# Epoch 31/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.8305 - val_accuracy: 0.8395
# Epoch 32/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.6144 - val_accuracy: 0.9042
# Epoch 33/100
# 41/41 [==============================] - 5s 121ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.2379 - val_accuracy: 0.9492
# Epoch 34/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.3746 - val_accuracy: 0.9157
# Epoch 35/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0522 - accuracy: 0.9877 - val_loss: 0.6176 - val_accuracy: 0.8430
# Epoch 36/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0253 - accuracy: 0.9927 - val_loss: 0.3669 - val_accuracy: 0.9203
# Epoch 37/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0072 - accuracy: 0.9992 - val_loss: 0.2974 - val_accuracy: 0.9249
# Epoch 38/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.9090 - val_accuracy: 0.7933
# Epoch 39/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.7654 - val_accuracy: 0.8626
# Epoch 40/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0344 - accuracy: 0.9881 - val_loss: 1.4132 - val_accuracy: 0.7575
# Epoch 41/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0366 - accuracy: 0.9888 - val_loss: 0.7921 - val_accuracy: 0.8326
# Epoch 42/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0379 - accuracy: 0.9908 - val_loss: 1.1345 - val_accuracy: 0.7598
# Epoch 43/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0444 - accuracy: 0.9865 - val_loss: 2.2708 - val_accuracy: 0.6975
# Epoch 44/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0556 - accuracy: 0.9846 - val_loss: 1.1145 - val_accuracy: 0.7875
# Epoch 45/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0824 - accuracy: 0.9761 - val_loss: 0.5832 - val_accuracy: 0.8741
# Epoch 46/100
# 41/41 [==============================] - 5s 117ms/step - loss: 0.0477 - accuracy: 0.9858 - val_loss: 2.4251 - val_accuracy: 0.6559
# Epoch 47/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 0.6237 - val_accuracy: 0.8822
# Epoch 48/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0372 - accuracy: 0.9915 - val_loss: 0.5918 - val_accuracy: 0.8811
# Epoch 49/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0295 - accuracy: 0.9919 - val_loss: 0.9094 - val_accuracy: 0.8152
# Epoch 50/100
# 41/41 [==============================] - 5s 118ms/step - loss: 0.0167 - accuracy: 0.9954 - val_loss: 0.5733 - val_accuracy: 0.8741
# Epoch 51/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.3871 - val_accuracy: 0.9088
# Epoch 52/100
# 41/41 [==============================] - 5s 119ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.3903 - val_accuracy: 0.9215
# Epoch 53/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9988Restoring model weights from the end of the best epoch: 33.
# 41/41 [==============================] - 5s 122ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.7342 - val_accuracy: 0.8649
# Epoch 00053: early stopping
# Maximal validation accuracy: 94.92%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.861674  0.699769  9.358743      0.280600
# 1   0.405305  0.864126  8.595035      0.289838
# 2   0.283753  0.902617  9.627546      0.292148
# 3   0.194929  0.936105  3.283947      0.506928
# 4   0.179777  0.947652  1.077398      0.748268
# 5   0.113922  0.961894  1.888868      0.737875
# 6   0.139279  0.956505  1.707351      0.653580
# 7   0.148241  0.954580  0.880542      0.793303
# 8   0.108838  0.967667  0.766467      0.811778
# 9   0.125875  0.966513  0.632185      0.837182
# 10  0.102859  0.973441  2.738583      0.610855
# 11  0.135238  0.958430  1.276477      0.740185
# 12  0.101320  0.968052  0.902477      0.809469
# 13  0.064372  0.982294  1.130799      0.748268
# 14  0.063452  0.979985  0.412749      0.899538
# 15  0.068305  0.979600  1.379864      0.779446
# 16  0.061678  0.980370  0.550446      0.854503
# 17  0.039592  0.989222  0.363014      0.915704
# 18  0.057021  0.984988  0.694936      0.841801
# 19  0.031703  0.989992  0.496880      0.881062
# 20  0.043876  0.985758  0.380676      0.903002
# 21  0.072598  0.979600  5.213365      0.583141
# 22  0.062064  0.984219  2.418099      0.565820
# 23  0.040685  0.988068  1.011444      0.789838
# 24  0.020691  0.994611  0.709705      0.852194
# 25  0.034120  0.988838  3.121292      0.674365
# 26  0.055186  0.985758  0.594911      0.869515
# 27  0.022014  0.992302  0.859643      0.822171
# 28  0.019173  0.994226  0.344801      0.920323
# 29  0.038243  0.988838  0.330144      0.913395
# 30  0.021281  0.993841  0.830525      0.839492
# 31  0.009641  0.996921  0.614361      0.904157
# 32  0.008505  0.998460  0.237873      0.949192
# 33  0.008113  0.997691  0.374631      0.915704
# 34  0.052213  0.987683  0.617622      0.842956
# 35  0.025254  0.992687  0.366879      0.920323
# 36  0.007166  0.999230  0.297376      0.924942
# 37  0.021267  0.993456  0.908974      0.793303
# 38  0.024499  0.992302  0.765351      0.862587
# 39  0.034427  0.988068  1.413223      0.757506
# 40  0.036584  0.988838  0.792147      0.832564
# 41  0.037857  0.990762  1.134473      0.759815
# 42  0.044368  0.986528  2.270803      0.697460
# 43  0.055643  0.984604  1.114544      0.787529
# 44  0.082407  0.976135  0.583215      0.874134
# 45  0.047657  0.985758  2.425141      0.655889
# 46  0.026203  0.991532  0.623726      0.882217
# 47  0.037171  0.991532  0.591811      0.881062
# 48  0.029513  0.991917  0.909439      0.815242
# 49  0.016707  0.995381  0.573335      0.874134
# 50  0.004229  0.999230  0.387052      0.908776
# 51  0.002244  0.999230  0.390259      0.921478
# 52  0.004795  0.998845  0.734231      0.864896

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.23787300288677216
# Maximum validation accuracy: 0.949191689491272

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 27ms/step - loss: 0.2994 - accuracy: 0.9319
# test loss, test acc: [0.29940730333328247, 0.931870698928833]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 13s 185ms/step - loss: 1.4544 - accuracy: 0.4822 - val_loss: 1.9174 - val_accuracy: 0.3053
# Epoch 2/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.8705 - accuracy: 0.7087 - val_loss: 2.0128 - val_accuracy: 0.1310
# Epoch 3/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.7552 - accuracy: 0.7477 - val_loss: 7.6196 - val_accuracy: 0.0560
# Epoch 4/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.5052 - accuracy: 0.8342 - val_loss: 12.2922 - val_accuracy: 0.0560
# Epoch 5/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.4336 - accuracy: 0.8630 - val_loss: 4.7633 - val_accuracy: 0.0865
# Epoch 6/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.4171 - accuracy: 0.8694 - val_loss: 5.7975 - val_accuracy: 0.3257
# Epoch 7/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.3569 - accuracy: 0.8927 - val_loss: 6.6130 - val_accuracy: 0.1310
# Epoch 8/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.2846 - accuracy: 0.9080 - val_loss: 2.7002 - val_accuracy: 0.3041
# Epoch 9/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.2454 - accuracy: 0.9266 - val_loss: 3.4043 - val_accuracy: 0.3562
# Epoch 10/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.3021 - accuracy: 0.9075 - val_loss: 4.5701 - val_accuracy: 0.2761
# Epoch 11/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.2469 - accuracy: 0.9266 - val_loss: 6.0562 - val_accuracy: 0.2074
# Epoch 12/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.2542 - accuracy: 0.9194 - val_loss: 5.3349 - val_accuracy: 0.3142
# Epoch 13/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.1495 - accuracy: 0.9550 - val_loss: 2.2620 - val_accuracy: 0.5598
# Epoch 14/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1940 - accuracy: 0.9415 - val_loss: 2.1181 - val_accuracy: 0.5242
# Epoch 15/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.1969 - accuracy: 0.9330 - val_loss: 0.8721 - val_accuracy: 0.8282
# Epoch 16/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0959 - accuracy: 0.9695 - val_loss: 0.6478 - val_accuracy: 0.8690
# Epoch 17/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.2157 - accuracy: 0.9351 - val_loss: 1.3998 - val_accuracy: 0.7137
# Epoch 18/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1301 - accuracy: 0.9665 - val_loss: 1.2031 - val_accuracy: 0.7850
# Epoch 19/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.2011 - accuracy: 0.9436 - val_loss: 1.0006 - val_accuracy: 0.7964
# Epoch 20/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1351 - accuracy: 0.9627 - val_loss: 0.6273 - val_accuracy: 0.8499
# Epoch 21/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1601 - accuracy: 0.9500 - val_loss: 1.1035 - val_accuracy: 0.7990
# Epoch 22/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1487 - accuracy: 0.9559 - val_loss: 0.6028 - val_accuracy: 0.8601
# Epoch 23/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1631 - accuracy: 0.9546 - val_loss: 3.3557 - val_accuracy: 0.5471
# Epoch 24/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1088 - accuracy: 0.9669 - val_loss: 0.8096 - val_accuracy: 0.8257
# Epoch 25/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1092 - accuracy: 0.9661 - val_loss: 0.6621 - val_accuracy: 0.8537
# Epoch 26/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1273 - accuracy: 0.9665 - val_loss: 0.7489 - val_accuracy: 0.8486
# Epoch 27/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0886 - accuracy: 0.9729 - val_loss: 0.5619 - val_accuracy: 0.8893
# Epoch 28/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1248 - accuracy: 0.9648 - val_loss: 0.8403 - val_accuracy: 0.8168
# Epoch 29/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1035 - accuracy: 0.9686 - val_loss: 1.0387 - val_accuracy: 0.8053
# Epoch 30/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0842 - accuracy: 0.9767 - val_loss: 1.2416 - val_accuracy: 0.8028
# Epoch 31/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0525 - accuracy: 0.9873 - val_loss: 0.7387 - val_accuracy: 0.8499
# Epoch 32/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0943 - accuracy: 0.9746 - val_loss: 1.3838 - val_accuracy: 0.7290
# Epoch 33/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0781 - accuracy: 0.9792 - val_loss: 0.3382 - val_accuracy: 0.9020
# Epoch 34/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0950 - accuracy: 0.9750 - val_loss: 1.0058 - val_accuracy: 0.7748
# Epoch 35/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0976 - accuracy: 0.9716 - val_loss: 1.4453 - val_accuracy: 0.7468
# Epoch 36/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0730 - accuracy: 0.9767 - val_loss: 1.4117 - val_accuracy: 0.7366
# Epoch 37/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0334 - accuracy: 0.9902 - val_loss: 0.5782 - val_accuracy: 0.8690
# Epoch 38/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0859 - accuracy: 0.9775 - val_loss: 0.6892 - val_accuracy: 0.8384
# Epoch 39/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0510 - accuracy: 0.9873 - val_loss: 0.6801 - val_accuracy: 0.8461
# Epoch 40/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0968 - accuracy: 0.9741 - val_loss: 0.6723 - val_accuracy: 0.8359
# Epoch 41/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0500 - accuracy: 0.9864 - val_loss: 0.4539 - val_accuracy: 0.8855
# Epoch 42/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0314 - accuracy: 0.9907 - val_loss: 0.4677 - val_accuracy: 0.8855
# Epoch 43/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0441 - accuracy: 0.9869 - val_loss: 0.6128 - val_accuracy: 0.8677
# Epoch 44/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0578 - accuracy: 0.9835 - val_loss: 1.6490 - val_accuracy: 0.7112
# Epoch 45/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0698 - accuracy: 0.9839 - val_loss: 0.4568 - val_accuracy: 0.8906
# Epoch 46/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0494 - accuracy: 0.9881 - val_loss: 0.5051 - val_accuracy: 0.8830
# Epoch 47/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0588 - accuracy: 0.9852 - val_loss: 0.8099 - val_accuracy: 0.8257
# Epoch 48/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0627 - accuracy: 0.9835 - val_loss: 0.7794 - val_accuracy: 0.8410
# Epoch 49/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0581 - accuracy: 0.9818 - val_loss: 0.8039 - val_accuracy: 0.8486
# Epoch 50/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0500 - accuracy: 0.9860 - val_loss: 0.8766 - val_accuracy: 0.8244
# Epoch 51/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0730 - accuracy: 0.9796 - val_loss: 0.4725 - val_accuracy: 0.8919
# Epoch 52/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.2290 - val_accuracy: 0.9377
# Epoch 53/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0620 - accuracy: 0.9839 - val_loss: 1.3237 - val_accuracy: 0.7303
# Epoch 54/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0656 - accuracy: 0.9805 - val_loss: 0.8003 - val_accuracy: 0.8499
# Epoch 55/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0452 - accuracy: 0.9839 - val_loss: 0.4379 - val_accuracy: 0.8957
# Epoch 56/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0220 - accuracy: 0.9945 - val_loss: 0.3667 - val_accuracy: 0.9097
# Epoch 57/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0302 - accuracy: 0.9936 - val_loss: 1.4825 - val_accuracy: 0.7570
# Epoch 58/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0399 - accuracy: 0.9873 - val_loss: 1.7564 - val_accuracy: 0.7188
# Epoch 59/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.9948 - val_accuracy: 0.8321
# Epoch 60/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0522 - accuracy: 0.9869 - val_loss: 3.5568 - val_accuracy: 0.4911
# Epoch 61/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1037 - accuracy: 0.9733 - val_loss: 1.3243 - val_accuracy: 0.7316
# Epoch 62/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0520 - accuracy: 0.9856 - val_loss: 1.1592 - val_accuracy: 0.7774
# Epoch 63/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0622 - accuracy: 0.9813 - val_loss: 0.4718 - val_accuracy: 0.8982
# Epoch 64/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.6585 - val_accuracy: 0.8601
# Epoch 65/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0198 - accuracy: 0.9958 - val_loss: 0.5554 - val_accuracy: 0.8842
# Epoch 66/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0368 - accuracy: 0.9869 - val_loss: 0.5840 - val_accuracy: 0.8740
# Epoch 67/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0869 - accuracy: 0.9733 - val_loss: 1.0113 - val_accuracy: 0.8117
# Epoch 68/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0877 - accuracy: 0.9801 - val_loss: 0.9180 - val_accuracy: 0.8282
# Epoch 69/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0604 - accuracy: 0.9826 - val_loss: 0.7553 - val_accuracy: 0.8270
# Epoch 70/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0746 - accuracy: 0.9775 - val_loss: 0.5679 - val_accuracy: 0.8690
# Epoch 71/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0418 - accuracy: 0.9890 - val_loss: 0.4685 - val_accuracy: 0.8766
# Epoch 72/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0440 - accuracy: 0.9864 - val_loss: 0.6381 - val_accuracy: 0.8473
# Epoch 73/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0357 - accuracy: 0.9881 - val_loss: 0.3699 - val_accuracy: 0.9033
# Epoch 74/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0301 - accuracy: 0.9915 - val_loss: 0.5128 - val_accuracy: 0.9033
# Epoch 75/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.6010 - val_accuracy: 0.8842
# Epoch 76/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.5788 - val_accuracy: 0.8664
# Epoch 77/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0417 - accuracy: 0.9877 - val_loss: 1.1638 - val_accuracy: 0.7646
# Epoch 78/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.6781 - val_accuracy: 0.8626
# Epoch 79/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0441 - accuracy: 0.9869 - val_loss: 0.9714 - val_accuracy: 0.8028
# Epoch 80/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.2915 - val_accuracy: 0.9249
# Epoch 81/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0512 - accuracy: 0.9856 - val_loss: 0.9427 - val_accuracy: 0.8321
# Epoch 82/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9915Restoring model weights from the end of the best epoch: 52.
# 37/37 [==============================] - 5s 123ms/step - loss: 0.0397 - accuracy: 0.9915 - val_loss: 0.4220 - val_accuracy: 0.9148
# Epoch 00082: early stopping
# Maximal validation accuracy: 93.77%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   1.454353  0.482188   1.917353      0.305344
# 1   0.870481  0.708651   2.012839      0.131043
# 2   0.755242  0.747667   7.619561      0.055980
# 3   0.505225  0.834181  12.292184      0.055980
# 4   0.433646  0.863020   4.763274      0.086514
# ..       ...       ...        ...           ...
# 77  0.025134  0.991518   0.678070      0.862595
# 78  0.044076  0.986853   0.971405      0.802799
# 79  0.029831  0.991094   0.291489      0.924936
# 80  0.051214  0.985581   0.942723      0.832061
# 81  0.039668  0.991518   0.422010      0.914758
#
# [82 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.2290193736553192
# Maximum validation accuracy: 0.9376590251922607

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 26ms/step - loss: 0.3587 - accuracy: 0.9249
# test loss, test acc: [0.3586992621421814, 0.9249364137649536]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 2s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 12s 157ms/step - loss: 0.9134 - accuracy: 0.6879 - val_loss: 47.8468 - val_accuracy: 0.1527
# Epoch 2/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.3132 - accuracy: 0.9092 - val_loss: 9.0261 - val_accuracy: 0.2824
# Epoch 3/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.1607 - accuracy: 0.9550 - val_loss: 1.9954 - val_accuracy: 0.6921
# Epoch 4/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1702 - accuracy: 0.9555 - val_loss: 3.4625 - val_accuracy: 0.5852
# Epoch 5/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.1551 - accuracy: 0.9559 - val_loss: 0.7609 - val_accuracy: 0.7952
# Epoch 6/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1277 - accuracy: 0.9597 - val_loss: 2.0763 - val_accuracy: 0.6056
# Epoch 7/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.1013 - accuracy: 0.9720 - val_loss: 3.2148 - val_accuracy: 0.6094
# Epoch 8/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0507 - accuracy: 0.9852 - val_loss: 0.5403 - val_accuracy: 0.8791
# Epoch 9/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0942 - accuracy: 0.9767 - val_loss: 2.8955 - val_accuracy: 0.5700
# Epoch 10/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.1202 - accuracy: 0.9652 - val_loss: 1.3416 - val_accuracy: 0.7964
# Epoch 11/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0894 - accuracy: 0.9746 - val_loss: 1.7772 - val_accuracy: 0.6463
# Epoch 12/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0991 - accuracy: 0.9754 - val_loss: 3.1733 - val_accuracy: 0.7761
# Epoch 13/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.1243 - accuracy: 0.9652 - val_loss: 12.3986 - val_accuracy: 0.5496
# Epoch 14/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0909 - accuracy: 0.9771 - val_loss: 1.8007 - val_accuracy: 0.7990
# Epoch 15/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0756 - accuracy: 0.9784 - val_loss: 1.3480 - val_accuracy: 0.8219
# Epoch 16/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0423 - accuracy: 0.9885 - val_loss: 0.4617 - val_accuracy: 0.8880
# Epoch 17/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0359 - accuracy: 0.9894 - val_loss: 0.3564 - val_accuracy: 0.9033
# Epoch 18/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0339 - accuracy: 0.9898 - val_loss: 0.1381 - val_accuracy: 0.9644
# Epoch 19/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0304 - accuracy: 0.9928 - val_loss: 0.5554 - val_accuracy: 0.8728
# Epoch 20/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0281 - accuracy: 0.9928 - val_loss: 0.5010 - val_accuracy: 0.8855
# Epoch 21/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.2449 - val_accuracy: 0.9466
# Epoch 22/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.2311 - val_accuracy: 0.9440
# Epoch 23/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0317 - accuracy: 0.9915 - val_loss: 0.4417 - val_accuracy: 0.8957
# Epoch 24/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0495 - accuracy: 0.9911 - val_loss: 0.6554 - val_accuracy: 0.8791
# Epoch 25/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0555 - accuracy: 0.9843 - val_loss: 0.4649 - val_accuracy: 0.8817
# Epoch 26/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0306 - accuracy: 0.9894 - val_loss: 1.1150 - val_accuracy: 0.7735
# Epoch 27/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.7843 - val_accuracy: 0.8690
# Epoch 28/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0279 - accuracy: 0.9919 - val_loss: 0.3024 - val_accuracy: 0.9453
# Epoch 29/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0143 - accuracy: 0.9966 - val_loss: 0.4573 - val_accuracy: 0.9148
# Epoch 30/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0268 - accuracy: 0.9911 - val_loss: 0.3069 - val_accuracy: 0.9237
# Epoch 31/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0355 - accuracy: 0.9898 - val_loss: 1.1990 - val_accuracy: 0.8244
# Epoch 32/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0987 - accuracy: 0.9750 - val_loss: 3.5689 - val_accuracy: 0.4631
# Epoch 33/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0346 - accuracy: 0.9919 - val_loss: 1.1755 - val_accuracy: 0.7774
# Epoch 34/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0426 - accuracy: 0.9869 - val_loss: 0.9057 - val_accuracy: 0.8270
# Epoch 35/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0268 - accuracy: 0.9949 - val_loss: 0.6826 - val_accuracy: 0.8626
# Epoch 36/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.8995 - val_accuracy: 0.8206
# Epoch 37/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.0314 - accuracy: 0.9945 - val_loss: 0.2622 - val_accuracy: 0.9326
# Epoch 38/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9953Restoring model weights from the end of the best epoch: 18.
# 37/37 [==============================] - 4s 121ms/step - loss: 0.0190 - accuracy: 0.9953 - val_loss: 0.5943 - val_accuracy: 0.8982
# Epoch 00038: early stopping
# Maximal validation accuracy: 96.44%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.913355  0.687871  47.846832      0.152672
# 1   0.313152  0.909245   9.026115      0.282443
# 2   0.160729  0.955047   1.995376      0.692112
# 3   0.170245  0.955471   3.462548      0.585242
# 4   0.155136  0.955895   0.760903      0.795165
# 5   0.127701  0.959712   2.076323      0.605598
# 6   0.101322  0.972010   3.214759      0.609415
# 7   0.050730  0.985157   0.540339      0.879135
# 8   0.094214  0.976675   2.895492      0.569975
# 9   0.120236  0.965225   1.341598      0.796438
# 10  0.089419  0.974555   1.777155      0.646310
# 11  0.099068  0.975403   3.173312      0.776081
# 12  0.124317  0.965225  12.398593      0.549618
# 13  0.090897  0.977099   1.800748      0.798982
# 14  0.075592  0.978372   1.348046      0.821883
# 15  0.042250  0.988550   0.461702      0.888041
# 16  0.035919  0.989398   0.356381      0.903308
# 17  0.033921  0.989822   0.138144      0.964377
# 18  0.030406  0.992791   0.555370      0.872774
# 19  0.028147  0.992791   0.500958      0.885496
# 20  0.007610  0.997880   0.244928      0.946565
# 21  0.009117  0.997031   0.231068      0.944020
# 22  0.031656  0.991518   0.441708      0.895674
# 23  0.049478  0.991094   0.655394      0.879135
# 24  0.055476  0.984309   0.464946      0.881679
# 25  0.030594  0.989398   1.114996      0.773537
# 26  0.015977  0.996183   0.784298      0.868957
# 27  0.027926  0.991942   0.302428      0.945293
# 28  0.014275  0.996607   0.457290      0.914758
# 29  0.026765  0.991094   0.306911      0.923664
# 30  0.035492  0.989822   1.198975      0.824427
# 31  0.098653  0.974979   3.568871      0.463104
# 32  0.034567  0.991942   1.175538      0.777354
# 33  0.042571  0.986853   0.905663      0.826972
# 34  0.026804  0.994911   0.682629      0.862595
# 35  0.015472  0.994487   0.899548      0.820611
# 36  0.031431  0.994487   0.262230      0.932570
# 37  0.018979  0.995335   0.594307      0.898219

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.1381440907716751
# Maximum validation accuracy: 0.9643765687942505

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 27ms/step - loss: 0.1840 - accuracy: 0.9453
# test loss, test acc: [0.1840342879295349, 0.945292592048645]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 2s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_InceptionV3_None
# test loss, test acc: [0.5138561725616455, 0.8660507798194885]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_InceptionV3_imagenet
# test loss, test acc: [0.29940730333328247, 0.931870698928833]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_InceptionV3_None
# test loss, test acc: [0.3586992621421814, 0.9249364137649536]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_InceptionV3_imagenet
# test loss, test acc: [0.1840342879295349, 0.945292592048645]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_InceptionV3_None →→→ Target Test
# 25/25 [==============================] - 1s 27ms/step - loss: 5.3562 - accuracy: 0.2341
# test loss, test acc: [5.356244087219238, 0.2340966910123825]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_InceptionV3_imagenet →→→ Target Test
# 25/25 [==============================] - 1s 27ms/step - loss: 5.0601 - accuracy: 0.1934
# test loss, test acc: [5.060129642486572, 0.19338423013687134]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_InceptionV3_None →→→ Source Test
# 28/28 [==============================] - 1s 27ms/step - loss: 5.1183 - accuracy: 0.1905
# test loss, test acc: [5.118306636810303, 0.1905311793088913]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_InceptionV3_imagenet →→→ Source Test
# 28/28 [==============================] - 1s 26ms/step - loss: 4.5332 - accuracy: 0.1628
# test loss, test acc: [4.533163547515869, 0.1628175526857376]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
