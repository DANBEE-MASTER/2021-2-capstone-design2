# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13812966155356885989
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11629440151136772732
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Sat Dec 18 01:07:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    33W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'Xception'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_Xception_None S_Xception_imagenet T_Xception_None T_Xception_imagenet
# ['S_Xception_imagenet',
#  'S_Xception_None',
#  'T_Xception_imagenet',
#  'T_Xception_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)
#
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)
#
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.Xception (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 27s 307ms/step - loss: 1.2192 - accuracy: 0.5327 - val_loss: 1.9319 - val_accuracy: 0.1848
# Epoch 2/100
# 41/41 [==============================] - 10s 254ms/step - loss: 0.8423 - accuracy: 0.6894 - val_loss: 1.9124 - val_accuracy: 0.2771
# Epoch 3/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.7646 - accuracy: 0.7375 - val_loss: 1.8953 - val_accuracy: 0.1848
# Epoch 4/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.6556 - accuracy: 0.7652 - val_loss: 1.8715 - val_accuracy: 0.1848
# Epoch 5/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.4999 - accuracy: 0.8091 - val_loss: 1.8671 - val_accuracy: 0.2771
# Epoch 6/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.3872 - accuracy: 0.8553 - val_loss: 1.9165 - val_accuracy: 0.1848
# Epoch 7/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.3547 - accuracy: 0.8676 - val_loss: 2.2459 - val_accuracy: 0.1848
# Epoch 8/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.3203 - accuracy: 0.8799 - val_loss: 2.8017 - val_accuracy: 0.1848
# Epoch 9/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.2950 - accuracy: 0.8938 - val_loss: 2.8747 - val_accuracy: 0.1848
# Epoch 10/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.2160 - accuracy: 0.9215 - val_loss: 4.5265 - val_accuracy: 0.1848
# Epoch 11/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.1821 - accuracy: 0.9303 - val_loss: 3.8824 - val_accuracy: 0.1871
# Epoch 12/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.2521 - accuracy: 0.9061 - val_loss: 3.9688 - val_accuracy: 0.2506
# Epoch 13/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.2326 - accuracy: 0.9134 - val_loss: 2.8376 - val_accuracy: 0.3464
# Epoch 14/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.2051 - accuracy: 0.9261 - val_loss: 3.0661 - val_accuracy: 0.4573
# Epoch 15/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.1687 - accuracy: 0.9407 - val_loss: 1.6162 - val_accuracy: 0.6536
# Epoch 16/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.1430 - accuracy: 0.9515 - val_loss: 1.1564 - val_accuracy: 0.7125
# Epoch 17/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.1563 - accuracy: 0.9461 - val_loss: 1.7413 - val_accuracy: 0.7044
# Epoch 18/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.1474 - accuracy: 0.9507 - val_loss: 1.0745 - val_accuracy: 0.7818
# Epoch 19/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0937 - accuracy: 0.9688 - val_loss: 1.0314 - val_accuracy: 0.7864
# Epoch 20/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0842 - accuracy: 0.9742 - val_loss: 3.3333 - val_accuracy: 0.6374
# Epoch 21/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.1279 - accuracy: 0.9607 - val_loss: 4.2899 - val_accuracy: 0.5242
# Epoch 22/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.1161 - accuracy: 0.9634 - val_loss: 1.8417 - val_accuracy: 0.6605
# Epoch 23/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0585 - accuracy: 0.9815 - val_loss: 3.0801 - val_accuracy: 0.5901
# Epoch 24/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 2.2234 - val_accuracy: 0.6420
# Epoch 25/100
# 41/41 [==============================] - 10s 253ms/step - loss: 0.0309 - accuracy: 0.9896 - val_loss: 0.9352 - val_accuracy: 0.8152
# Epoch 26/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0351 - accuracy: 0.9858 - val_loss: 2.0705 - val_accuracy: 0.6628
# Epoch 27/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0739 - accuracy: 0.9769 - val_loss: 1.4836 - val_accuracy: 0.7356
# Epoch 28/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0838 - accuracy: 0.9715 - val_loss: 1.6535 - val_accuracy: 0.7367
# Epoch 29/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0521 - accuracy: 0.9819 - val_loss: 1.5544 - val_accuracy: 0.7367
# Epoch 30/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0442 - accuracy: 0.9861 - val_loss: 1.5681 - val_accuracy: 0.7691
# Epoch 31/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.1202 - accuracy: 0.9615 - val_loss: 4.8348 - val_accuracy: 0.4908
# Epoch 32/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0860 - accuracy: 0.9734 - val_loss: 2.2784 - val_accuracy: 0.6351
# Epoch 33/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0450 - accuracy: 0.9823 - val_loss: 1.4667 - val_accuracy: 0.7691
# Epoch 34/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0309 - accuracy: 0.9911 - val_loss: 1.0664 - val_accuracy: 0.8118
# Epoch 35/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0285 - accuracy: 0.9923 - val_loss: 1.2175 - val_accuracy: 0.7771
# Epoch 36/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 0.8495 - val_accuracy: 0.8268
# Epoch 37/100
# 41/41 [==============================] - 10s 251ms/step - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.8128 - val_accuracy: 0.8406
# Epoch 38/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 1.0014 - val_accuracy: 0.8256
# Epoch 39/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0211 - accuracy: 0.9908 - val_loss: 1.0662 - val_accuracy: 0.8141
# Epoch 40/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0505 - accuracy: 0.9831 - val_loss: 1.2769 - val_accuracy: 0.7864
# Epoch 41/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0519 - accuracy: 0.9842 - val_loss: 1.2584 - val_accuracy: 0.7979
# Epoch 42/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0406 - accuracy: 0.9892 - val_loss: 1.3121 - val_accuracy: 0.7783
# Epoch 43/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0357 - accuracy: 0.9869 - val_loss: 5.3637 - val_accuracy: 0.4561
# Epoch 44/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 1.0257 - val_accuracy: 0.8303
# Epoch 45/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0622 - accuracy: 0.9823 - val_loss: 3.0156 - val_accuracy: 0.6721
# Epoch 46/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0539 - accuracy: 0.9854 - val_loss: 3.1282 - val_accuracy: 0.6132
# Epoch 47/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 2.5908 - val_accuracy: 0.6212
# Epoch 48/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0449 - accuracy: 0.9865 - val_loss: 1.9032 - val_accuracy: 0.7148
# Epoch 49/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0374 - accuracy: 0.9873 - val_loss: 3.6442 - val_accuracy: 0.6143
# Epoch 50/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0354 - accuracy: 0.9877 - val_loss: 1.8884 - val_accuracy: 0.7356
# Epoch 51/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.9568 - val_accuracy: 0.8268
# Epoch 52/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.7605 - val_accuracy: 0.8684
# Epoch 53/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 2.1040 - val_accuracy: 0.6767
# Epoch 54/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0078 - accuracy: 0.9962 - val_loss: 0.8988 - val_accuracy: 0.8279
# Epoch 55/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 1.0695 - val_accuracy: 0.8106
# Epoch 56/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0173 - accuracy: 0.9962 - val_loss: 1.8393 - val_accuracy: 0.7667
# Epoch 57/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 1.4037 - val_accuracy: 0.7979
# Epoch 58/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0185 - accuracy: 0.9927 - val_loss: 1.4000 - val_accuracy: 0.7956
# Epoch 59/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0495 - accuracy: 0.9869 - val_loss: 4.9217 - val_accuracy: 0.6224
# Epoch 60/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0437 - accuracy: 0.9846 - val_loss: 1.4363 - val_accuracy: 0.7714
# Epoch 61/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0312 - accuracy: 0.9873 - val_loss: 1.4940 - val_accuracy: 0.7714
# Epoch 62/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0632 - accuracy: 0.9823 - val_loss: 7.5872 - val_accuracy: 0.4457
# Epoch 63/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0462 - accuracy: 0.9873 - val_loss: 1.3914 - val_accuracy: 0.7552
# Epoch 64/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0266 - accuracy: 0.9908 - val_loss: 0.8750 - val_accuracy: 0.8406
# Epoch 65/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 2.1412 - val_accuracy: 0.6986
# Epoch 66/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.9854 - val_accuracy: 0.8210
# Epoch 67/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 1.9224 - val_accuracy: 0.7483
# Epoch 68/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 1.6156 - val_accuracy: 0.7702
# Epoch 69/100
# 41/41 [==============================] - 10s 248ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.8464 - val_accuracy: 0.8614
# Epoch 70/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.8689 - val_accuracy: 0.8672
# Epoch 71/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 3.4354 - val_accuracy: 0.6074
# Epoch 72/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0332 - accuracy: 0.9915 - val_loss: 1.5531 - val_accuracy: 0.7979
# Epoch 73/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0290 - accuracy: 0.9915 - val_loss: 1.2985 - val_accuracy: 0.7829
# Epoch 74/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0145 - accuracy: 0.9973 - val_loss: 1.7341 - val_accuracy: 0.7275
# Epoch 75/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0243 - accuracy: 0.9938 - val_loss: 1.1082 - val_accuracy: 0.7471
# Epoch 76/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0326 - accuracy: 0.9923 - val_loss: 1.1415 - val_accuracy: 0.8083
# Epoch 77/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 1.7719 - val_accuracy: 0.7263
# Epoch 78/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0401 - accuracy: 0.9877 - val_loss: 1.3874 - val_accuracy: 0.7691
# Epoch 79/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0230 - accuracy: 0.9908 - val_loss: 0.8547 - val_accuracy: 0.8406
# Epoch 80/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0268 - accuracy: 0.9896 - val_loss: 1.8659 - val_accuracy: 0.7529
# Epoch 81/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0394 - accuracy: 0.9881 - val_loss: 1.5500 - val_accuracy: 0.7575
# Epoch 82/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9915Restoring model weights from the end of the best epoch: 52.
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 1.1719 - val_accuracy: 0.8072
# Epoch 00082: early stopping
# Maximal validation accuracy: 86.84%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.219247  0.532717  1.931945      0.184758
# 1   0.842315  0.689376  1.912421      0.277136
# 2   0.764593  0.737490  1.895284      0.184758
# 3   0.655635  0.765204  1.871461      0.184758
# 4   0.499943  0.809084  1.867078      0.277136
# ..       ...       ...       ...           ...
# 77  0.040111  0.987683  1.387445      0.769053
# 78  0.022995  0.990762  0.854726      0.840647
# 79  0.026782  0.989607  1.865939      0.752887
# 80  0.039401  0.988068  1.549988      0.757506
# 81  0.027722  0.991532  1.171944      0.807159
#
# [82 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.7605363130569458
# Maximum validation accuracy: 0.8683602809906006

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 32ms/step - loss: 0.9374 - accuracy: 0.8256
# test loss, test acc: [0.9373801350593567, 0.8256350755691528]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 16s 278ms/step - loss: 0.7058 - accuracy: 0.7625 - val_loss: 4.1458 - val_accuracy: 0.6524
# Epoch 2/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.2452 - accuracy: 0.9172 - val_loss: 0.8428 - val_accuracy: 0.8233
# Epoch 3/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.1892 - accuracy: 0.9388 - val_loss: 1.0060 - val_accuracy: 0.8187
# Epoch 4/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.1539 - accuracy: 0.9511 - val_loss: 1.4692 - val_accuracy: 0.7933
# Epoch 5/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.1079 - accuracy: 0.9650 - val_loss: 2.8073 - val_accuracy: 0.7379
# Epoch 6/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.1162 - accuracy: 0.9707 - val_loss: 0.9276 - val_accuracy: 0.8510
# Epoch 7/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0584 - accuracy: 0.9792 - val_loss: 0.3225 - val_accuracy: 0.9215
# Epoch 8/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0459 - accuracy: 0.9865 - val_loss: 0.8571 - val_accuracy: 0.8406
# Epoch 9/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.1068 - accuracy: 0.9754 - val_loss: 1.0630 - val_accuracy: 0.8453
# Epoch 10/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0801 - accuracy: 0.9784 - val_loss: 0.9455 - val_accuracy: 0.8314
# Epoch 11/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0732 - accuracy: 0.9834 - val_loss: 0.7214 - val_accuracy: 0.8672
# Epoch 12/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0430 - accuracy: 0.9846 - val_loss: 0.4965 - val_accuracy: 0.8868
# Epoch 13/100
# 41/41 [==============================] - 10s 248ms/step - loss: 0.0365 - accuracy: 0.9885 - val_loss: 0.4337 - val_accuracy: 0.9145
# Epoch 14/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.5892 - val_accuracy: 0.8857
# Epoch 15/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0188 - accuracy: 0.9954 - val_loss: 0.8803 - val_accuracy: 0.8857
# Epoch 16/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0227 - accuracy: 0.9946 - val_loss: 0.7443 - val_accuracy: 0.8926
# Epoch 17/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0395 - accuracy: 0.9877 - val_loss: 0.4173 - val_accuracy: 0.9122
# Epoch 18/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 2.1811 - val_accuracy: 0.7852
# Epoch 19/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0438 - accuracy: 0.9873 - val_loss: 0.4359 - val_accuracy: 0.9053
# Epoch 20/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0572 - accuracy: 0.9881 - val_loss: 0.7797 - val_accuracy: 0.8903
# Epoch 21/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0495 - accuracy: 0.9877 - val_loss: 0.9890 - val_accuracy: 0.8083
# Epoch 22/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0436 - accuracy: 0.9904 - val_loss: 0.4027 - val_accuracy: 0.9203
# Epoch 23/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.3496 - val_accuracy: 0.9388
# Epoch 24/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0445 - accuracy: 0.9888 - val_loss: 0.9216 - val_accuracy: 0.8811
# Epoch 25/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.6649 - val_accuracy: 0.8684
# Epoch 26/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0265 - accuracy: 0.9927 - val_loss: 0.3429 - val_accuracy: 0.9203
# Epoch 27/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.3183 - val_accuracy: 0.9353
# Epoch 28/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0747 - accuracy: 0.9800 - val_loss: 0.5423 - val_accuracy: 0.8764
# Epoch 29/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0659 - accuracy: 0.9834 - val_loss: 1.1265 - val_accuracy: 0.8291
# Epoch 30/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0262 - accuracy: 0.9942 - val_loss: 0.3412 - val_accuracy: 0.9296
# Epoch 31/100
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.2485 - val_accuracy: 0.9469
# Epoch 32/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.5952 - val_accuracy: 0.8661
# Epoch 33/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.4226 - val_accuracy: 0.9284
# Epoch 34/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0185 - accuracy: 0.9950 - val_loss: 1.8450 - val_accuracy: 0.7956
# Epoch 35/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0333 - accuracy: 0.9911 - val_loss: 0.5088 - val_accuracy: 0.9284
# Epoch 36/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0416 - accuracy: 0.9923 - val_loss: 0.4173 - val_accuracy: 0.9180
# Epoch 37/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0230 - accuracy: 0.9935 - val_loss: 0.4931 - val_accuracy: 0.9018
# Epoch 38/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0665 - accuracy: 0.9834 - val_loss: 0.5958 - val_accuracy: 0.8788
# Epoch 39/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0439 - accuracy: 0.9888 - val_loss: 2.2966 - val_accuracy: 0.8499
# Epoch 40/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0347 - accuracy: 0.9896 - val_loss: 0.3266 - val_accuracy: 0.9226
# Epoch 41/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0258 - accuracy: 0.9946 - val_loss: 0.3497 - val_accuracy: 0.9215
# Epoch 42/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.7324 - val_accuracy: 0.8718
# Epoch 43/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.5608 - val_accuracy: 0.9065
# Epoch 44/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0240 - accuracy: 0.9942 - val_loss: 0.4495 - val_accuracy: 0.9134
# Epoch 45/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0363 - accuracy: 0.9915 - val_loss: 0.7457 - val_accuracy: 0.8684
# Epoch 46/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0489 - accuracy: 0.9888 - val_loss: 0.4177 - val_accuracy: 0.9088
# Epoch 47/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 0.4778 - val_accuracy: 0.9042
# Epoch 48/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.4443 - val_accuracy: 0.9249
# Epoch 49/100
# 41/41 [==============================] - 10s 249ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.4198 - val_accuracy: 0.9353
# Epoch 50/100
# 41/41 [==============================] - 10s 250ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.3878 - val_accuracy: 0.9330
# Epoch 51/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9969Restoring model weights from the end of the best epoch: 31.
# 41/41 [==============================] - 10s 252ms/step - loss: 0.0174 - accuracy: 0.9969 - val_loss: 0.4272 - val_accuracy: 0.9180
# Epoch 00051: early stopping
# Maximal validation accuracy: 94.69%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.705823  0.762510  4.145803      0.652425
# 1   0.245211  0.917244  0.842785      0.823326
# 2   0.189246  0.938799  1.006019      0.818707
# 3   0.153901  0.951116  1.469174      0.793303
# 4   0.107887  0.964973  2.807309      0.737875
# 5   0.116229  0.970747  0.927642      0.851039
# 6   0.058432  0.979215  0.322499      0.921478
# 7   0.045912  0.986528  0.857132      0.840647
# 8   0.106769  0.975366  1.062978      0.845266
# 9   0.080061  0.978445  0.945457      0.831409
# 10  0.073205  0.983449  0.721396      0.867206
# 11  0.042952  0.984604  0.496499      0.886836
# 12  0.036546  0.988453  0.433696      0.914550
# 13  0.030313  0.991532  0.589221      0.885681
# 14  0.018803  0.995381  0.880329      0.885681
# 15  0.022715  0.994611  0.744340      0.892610
# 16  0.039527  0.987683  0.417260      0.912240
# 17  0.021700  0.993072  2.181073      0.785219
# 18  0.043849  0.987298  0.435937      0.905312
# 19  0.057170  0.988068  0.779697      0.890300
# 20  0.049533  0.987683  0.989039      0.808314
# 21  0.043603  0.990377  0.402711      0.920323
# 22  0.017209  0.993841  0.349556      0.938799
# 23  0.044521  0.988838  0.921573      0.881062
# 24  0.032522  0.989992  0.664917      0.868360
# 25  0.026529  0.992687  0.342931      0.920323
# 26  0.007924  0.996921  0.318320      0.935335
# 27  0.074651  0.979985  0.542334      0.876443
# 28  0.065908  0.983449  1.126541      0.829099
# 29  0.026212  0.994226  0.341211      0.929561
# 30  0.004525  0.999230  0.248539      0.946882
# 31  0.005025  0.998075  0.595157      0.866051
# 32  0.005381  0.998845  0.422575      0.928406
# 33  0.018477  0.994996  1.845019      0.795612
# 34  0.033339  0.991147  0.508777      0.928406
# 35  0.041613  0.992302  0.417329      0.918014
# 36  0.023024  0.993456  0.493123      0.901848
# 37  0.066470  0.983449  0.595776      0.878753
# 38  0.043860  0.988838  2.296617      0.849885
# 39  0.034669  0.989607  0.326589      0.922633
# 40  0.025804  0.994611  0.349741      0.921478
# 41  0.030221  0.989992  0.732351      0.871825
# 42  0.017084  0.994611  0.560808      0.906466
# 43  0.024008  0.994226  0.449473      0.913395
# 44  0.036266  0.991532  0.745714      0.868360
# 45  0.048856  0.988838  0.417677      0.908776
# 46  0.013898  0.996151  0.477805      0.904157
# 47  0.004481  0.998845  0.444318      0.924942
# 48  0.002005  0.999615  0.419825      0.935335
# 49  0.011362  0.998460  0.387768      0.933025
# 50  0.017379  0.996921  0.427172      0.918014

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.24853895604610443
# Maximum validation accuracy: 0.9468821883201599

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2887 - accuracy: 0.9376
# test loss, test acc: [0.28873252868652344, 0.937644362449646]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 2s 29ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 18s 305ms/step - loss: 1.1674 - accuracy: 0.5916 - val_loss: 1.9404 - val_accuracy: 0.0865
# Epoch 2/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.7148 - accuracy: 0.7566 - val_loss: 1.9405 - val_accuracy: 0.1272
# Epoch 3/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.4970 - accuracy: 0.8312 - val_loss: 1.9362 - val_accuracy: 0.1272
# Epoch 4/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.3756 - accuracy: 0.8762 - val_loss: 1.9564 - val_accuracy: 0.1272
# Epoch 5/100
# 37/37 [==============================] - 9s 253ms/step - loss: 0.3125 - accuracy: 0.9012 - val_loss: 2.0019 - val_accuracy: 0.1221
# Epoch 6/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.2348 - accuracy: 0.9203 - val_loss: 2.0704 - val_accuracy: 0.1272
# Epoch 7/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.1878 - accuracy: 0.9470 - val_loss: 2.1593 - val_accuracy: 0.1260
# Epoch 8/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.1492 - accuracy: 0.9487 - val_loss: 2.2842 - val_accuracy: 0.1476
# Epoch 9/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.1648 - accuracy: 0.9457 - val_loss: 2.9553 - val_accuracy: 0.0560
# Epoch 10/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.1192 - accuracy: 0.9623 - val_loss: 2.7310 - val_accuracy: 0.0560
# Epoch 11/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.1394 - accuracy: 0.9534 - val_loss: 3.7419 - val_accuracy: 0.0560
# Epoch 12/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0866 - accuracy: 0.9716 - val_loss: 5.7902 - val_accuracy: 0.0560
# Epoch 13/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.1102 - accuracy: 0.9635 - val_loss: 5.0999 - val_accuracy: 0.0827
# Epoch 14/100
# 37/37 [==============================] - 9s 252ms/step - loss: 0.1228 - accuracy: 0.9618 - val_loss: 5.5288 - val_accuracy: 0.1298
# Epoch 15/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0456 - accuracy: 0.9864 - val_loss: 3.3745 - val_accuracy: 0.3244
# Epoch 16/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0409 - accuracy: 0.9898 - val_loss: 3.1166 - val_accuracy: 0.3359
# Epoch 17/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0975 - accuracy: 0.9686 - val_loss: 0.9017 - val_accuracy: 0.7735
# Epoch 18/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0772 - accuracy: 0.9767 - val_loss: 3.2002 - val_accuracy: 0.4975
# Epoch 19/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0777 - accuracy: 0.9746 - val_loss: 2.4940 - val_accuracy: 0.6705
# Epoch 20/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0493 - accuracy: 0.9835 - val_loss: 0.5657 - val_accuracy: 0.8740
# Epoch 21/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0355 - accuracy: 0.9877 - val_loss: 3.6780 - val_accuracy: 0.6120
# Epoch 22/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0451 - accuracy: 0.9873 - val_loss: 2.2567 - val_accuracy: 0.6310
# Epoch 23/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0552 - accuracy: 0.9809 - val_loss: 1.2587 - val_accuracy: 0.7875
# Epoch 24/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 2.0297 - val_accuracy: 0.6908
# Epoch 25/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0363 - accuracy: 0.9885 - val_loss: 0.6114 - val_accuracy: 0.8842
# Epoch 26/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0333 - accuracy: 0.9915 - val_loss: 2.0102 - val_accuracy: 0.7888
# Epoch 27/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0612 - accuracy: 0.9813 - val_loss: 2.2742 - val_accuracy: 0.6934
# Epoch 28/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0741 - accuracy: 0.9763 - val_loss: 1.6458 - val_accuracy: 0.7532
# Epoch 29/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0460 - accuracy: 0.9822 - val_loss: 1.6072 - val_accuracy: 0.7150
# Epoch 30/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0512 - accuracy: 0.9847 - val_loss: 2.0240 - val_accuracy: 0.6781
# Epoch 31/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0501 - accuracy: 0.9843 - val_loss: 0.7195 - val_accuracy: 0.8359
# Epoch 32/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.8046 - val_accuracy: 0.8155
# Epoch 33/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 2.2701 - val_accuracy: 0.7163
# Epoch 34/100
# 37/37 [==============================] - 9s 254ms/step - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.4999 - val_accuracy: 0.8969
# Epoch 35/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.5772 - val_accuracy: 0.8639
# Epoch 36/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.4910 - val_accuracy: 0.8702
# Epoch 37/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.6257 - val_accuracy: 0.8651
# Epoch 38/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0109 - accuracy: 0.9958 - val_loss: 0.9757 - val_accuracy: 0.8066
# Epoch 39/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0435 - accuracy: 0.9864 - val_loss: 2.0687 - val_accuracy: 0.6997
# Epoch 40/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.1084 - accuracy: 0.9695 - val_loss: 2.2610 - val_accuracy: 0.7214
# Epoch 41/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0328 - accuracy: 0.9877 - val_loss: 1.3212 - val_accuracy: 0.8130
# Epoch 42/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0309 - accuracy: 0.9898 - val_loss: 2.8373 - val_accuracy: 0.7036
# Epoch 43/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0210 - accuracy: 0.9911 - val_loss: 1.4676 - val_accuracy: 0.8117
# Epoch 44/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.6453 - val_accuracy: 0.8893
# Epoch 45/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.8821 - val_accuracy: 0.8448
# Epoch 46/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0281 - accuracy: 0.9936 - val_loss: 2.9503 - val_accuracy: 0.7239
# Epoch 47/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0471 - accuracy: 0.9818 - val_loss: 2.9743 - val_accuracy: 0.6107
# Epoch 48/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0415 - accuracy: 0.9869 - val_loss: 1.5533 - val_accuracy: 0.7532
# Epoch 49/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0273 - accuracy: 0.9928 - val_loss: 1.7251 - val_accuracy: 0.7366
# Epoch 50/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.6412 - val_accuracy: 0.8690
# Epoch 51/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0188 - accuracy: 0.9928 - val_loss: 0.7566 - val_accuracy: 0.8575
# Epoch 52/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0194 - accuracy: 0.9962 - val_loss: 1.4851 - val_accuracy: 0.7901
# Epoch 53/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0066 - accuracy: 0.9970 - val_loss: 0.6316 - val_accuracy: 0.8842
# Epoch 54/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.6100 - val_accuracy: 0.8868
# Epoch 55/100
# 37/37 [==============================] - 9s 253ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.4186 - val_accuracy: 0.9020
# Epoch 56/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.8020 - val_accuracy: 0.8270
# Epoch 57/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.5640 - val_accuracy: 0.8779
# Epoch 58/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0294 - accuracy: 0.9928 - val_loss: 1.3764 - val_accuracy: 0.7786
# Epoch 59/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0331 - accuracy: 0.9877 - val_loss: 2.8589 - val_accuracy: 0.6565
# Epoch 60/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0619 - accuracy: 0.9809 - val_loss: 1.9629 - val_accuracy: 0.7405
# Epoch 61/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0424 - accuracy: 0.9864 - val_loss: 2.0533 - val_accuracy: 0.7087
# Epoch 62/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0279 - accuracy: 0.9915 - val_loss: 1.5053 - val_accuracy: 0.7405
# Epoch 63/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0469 - accuracy: 0.9864 - val_loss: 2.3582 - val_accuracy: 0.6870
# Epoch 64/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0275 - accuracy: 0.9919 - val_loss: 1.2766 - val_accuracy: 0.8168
# Epoch 65/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0315 - accuracy: 0.9928 - val_loss: 0.4574 - val_accuracy: 0.8919
# Epoch 66/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0310 - accuracy: 0.9915 - val_loss: 1.7532 - val_accuracy: 0.7087
# Epoch 67/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0233 - accuracy: 0.9932 - val_loss: 1.0885 - val_accuracy: 0.8003
# Epoch 68/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0277 - accuracy: 0.9924 - val_loss: 0.5037 - val_accuracy: 0.9008
# Epoch 69/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.6114 - val_accuracy: 0.8715
# Epoch 70/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0091 - accuracy: 0.9962 - val_loss: 1.0052 - val_accuracy: 0.7952
# Epoch 71/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 2.1699 - val_accuracy: 0.7226
# Epoch 72/100
# 37/37 [==============================] - 9s 253ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.4424 - val_accuracy: 0.9122
# Epoch 73/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.7069 - val_accuracy: 0.8728
# Epoch 74/100
# 37/37 [==============================] - 9s 252ms/step - loss: 0.0030 - accuracy: 0.9983 - val_loss: 0.3146 - val_accuracy: 0.9275
# Epoch 75/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.3738 - val_accuracy: 0.9059
# Epoch 76/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.4696 - val_accuracy: 0.8944
# Epoch 77/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 3.3288 - val_accuracy: 0.5649
# Epoch 78/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0485 - accuracy: 0.9864 - val_loss: 1.4103 - val_accuracy: 0.7583
# Epoch 79/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0726 - accuracy: 0.9792 - val_loss: 4.4713 - val_accuracy: 0.5102
# Epoch 80/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0762 - accuracy: 0.9758 - val_loss: 2.6319 - val_accuracy: 0.7443
# Epoch 81/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.9065 - val_accuracy: 0.8702
# Epoch 82/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0088 - accuracy: 0.9983 - val_loss: 1.1302 - val_accuracy: 0.7875
# Epoch 83/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.4443 - val_accuracy: 0.9046
# Epoch 84/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.4578 - val_accuracy: 0.9033
# Epoch 85/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.7229 - val_accuracy: 0.8651
# Epoch 86/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 2.6281 - val_accuracy: 0.6043
# Epoch 87/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 1.0184 - val_accuracy: 0.8219
# Epoch 88/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.4455 - val_accuracy: 0.9033
# Epoch 89/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0242 - accuracy: 0.9941 - val_loss: 1.6338 - val_accuracy: 0.7265
# Epoch 90/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.9122 - val_accuracy: 0.8282
# Epoch 91/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0183 - accuracy: 0.9932 - val_loss: 1.1485 - val_accuracy: 0.7786
# Epoch 92/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.8395 - val_accuracy: 0.8193
# Epoch 93/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.4096 - val_accuracy: 0.9008
# Epoch 94/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.9443 - val_accuracy: 0.8232
# Epoch 95/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 0.5135 - val_accuracy: 0.9186
# Epoch 96/100
# 37/37 [==============================] - 9s 250ms/step - loss: 0.0326 - accuracy: 0.9911 - val_loss: 2.7298 - val_accuracy: 0.6387
# Epoch 97/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.9378 - val_accuracy: 0.8295
# Epoch 98/100
# 37/37 [==============================] - 9s 251ms/step - loss: 0.0233 - accuracy: 0.9936 - val_loss: 2.0153 - val_accuracy: 0.6934
# Epoch 99/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9885

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
