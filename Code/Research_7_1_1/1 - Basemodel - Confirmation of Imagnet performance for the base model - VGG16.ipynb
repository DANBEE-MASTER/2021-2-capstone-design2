# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16968330945332356847
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10013577842168449355
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Sat Dec 18 00:35:53 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    34W / 250W |    375MiB / 16280MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'VGG16'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_VGG16_None S_VGG16_imagenet T_VGG16_None T_VGG16_imagenet
# ['S_VGG16_imagenet', 'S_VGG16_None', 'T_VGG16_imagenet', 'T_VGG16_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)
#
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)
#
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.VGG16 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.VGG16 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 22s 253ms/step - loss: 1.9310 - accuracy: 0.1994 - val_loss: 1.8310 - val_accuracy: 0.2771
# Epoch 2/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8302 - accuracy: 0.2771 - val_loss: 1.8222 - val_accuracy: 0.2771
# Epoch 3/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8217 - accuracy: 0.2775 - val_loss: 1.8303 - val_accuracy: 0.2771
# Epoch 4/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8298 - accuracy: 0.2771 - val_loss: 1.8268 - val_accuracy: 0.2771
# Epoch 5/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8280 - accuracy: 0.2771 - val_loss: 1.8220 - val_accuracy: 0.2771
# Epoch 6/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8262 - accuracy: 0.2771 - val_loss: 1.8280 - val_accuracy: 0.2771
# Epoch 7/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8269 - accuracy: 0.2771 - val_loss: 1.8219 - val_accuracy: 0.2771
# Epoch 8/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8241 - val_accuracy: 0.2771
# Epoch 9/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8238 - accuracy: 0.2771 - val_loss: 1.8235 - val_accuracy: 0.2771
# Epoch 10/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8239 - accuracy: 0.2771 - val_loss: 1.8233 - val_accuracy: 0.2771
# Epoch 11/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8226 - accuracy: 0.2771 - val_loss: 1.8220 - val_accuracy: 0.2771
# Epoch 12/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8233 - accuracy: 0.2771 - val_loss: 1.8213 - val_accuracy: 0.2771
# Epoch 13/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8223 - accuracy: 0.2771 - val_loss: 1.8214 - val_accuracy: 0.2771
# Epoch 14/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8233 - accuracy: 0.2771 - val_loss: 1.8218 - val_accuracy: 0.2771
# Epoch 15/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8242 - accuracy: 0.2771 - val_loss: 1.8221 - val_accuracy: 0.2771
# Epoch 16/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8226 - accuracy: 0.2771 - val_loss: 1.8216 - val_accuracy: 0.2771
# Epoch 17/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8238 - accuracy: 0.2771 - val_loss: 1.8216 - val_accuracy: 0.2771
# Epoch 18/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8230 - accuracy: 0.2771 - val_loss: 1.8226 - val_accuracy: 0.2771
# Epoch 19/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8243 - accuracy: 0.2771 - val_loss: 1.8259 - val_accuracy: 0.2771
# Epoch 20/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8254 - accuracy: 0.2771 - val_loss: 1.8223 - val_accuracy: 0.2771
# Epoch 21/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8217 - val_accuracy: 0.2771
# Epoch 22/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8216 - val_accuracy: 0.2771
# Epoch 23/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8215 - val_accuracy: 0.2771
# Epoch 24/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8229 - accuracy: 0.2771 - val_loss: 1.8227 - val_accuracy: 0.2771
# Epoch 25/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8227 - accuracy: 0.2771 - val_loss: 1.8254 - val_accuracy: 0.2771
# Epoch 26/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8216 - val_accuracy: 0.2771
# Epoch 27/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8223 - accuracy: 0.2771 - val_loss: 1.8227 - val_accuracy: 0.2771
# Epoch 28/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8247 - accuracy: 0.2771 - val_loss: 1.8233 - val_accuracy: 0.2771
# Epoch 29/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8243 - accuracy: 0.2771 - val_loss: 1.8259 - val_accuracy: 0.2771
# Epoch 30/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.8237 - accuracy: 0.2771 - val_loss: 1.8215 - val_accuracy: 0.2771
# Epoch 31/100
# 41/41 [==============================] - ETA: 0s - loss: 1.8232 - accuracy: 0.2771Restoring model weights from the end of the best epoch: 1.
# 41/41 [==============================] - 6s 147ms/step - loss: 1.8232 - accuracy: 0.2771 - val_loss: 1.8216 - val_accuracy: 0.2771
# Epoch 00031: early stopping
# Maximal validation accuracy: 27.71%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.930955  0.199384  1.831007      0.277136
# 1   1.830177  0.277136  1.822154      0.277136
# 2   1.821663  0.277521  1.830281      0.277136
# 3   1.829808  0.277136  1.826775      0.277136
# 4   1.827972  0.277136  1.822001      0.277136
# 5   1.826221  0.277136  1.827973      0.277136
# 6   1.826917  0.277136  1.821949      0.277136
# 7   1.823157  0.277136  1.824108      0.277136
# 8   1.823824  0.277136  1.823480      0.277136
# 9   1.823891  0.277136  1.823327      0.277136
# 10  1.822634  0.277136  1.821985      0.277136
# 11  1.823275  0.277136  1.821298      0.277136
# 12  1.822261  0.277136  1.821447      0.277136
# 13  1.823311  0.277136  1.821766      0.277136
# 14  1.824204  0.277136  1.822135      0.277136
# 15  1.822647  0.277136  1.821619      0.277136
# 16  1.823780  0.277136  1.821565      0.277136
# 17  1.823031  0.277136  1.822591      0.277136
# 18  1.824344  0.277136  1.825863      0.277136
# 19  1.825441  0.277136  1.822267      0.277136
# 20  1.823222  0.277136  1.821677      0.277136
# 21  1.823169  0.277136  1.821615      0.277136
# 22  1.823236  0.277136  1.821460      0.277136
# 23  1.822894  0.277136  1.822682      0.277136
# 24  1.822702  0.277136  1.825422      0.277136
# 25  1.823180  0.277136  1.821634      0.277136
# 26  1.822325  0.277136  1.822659      0.277136
# 27  1.824682  0.277136  1.823316      0.277136
# 28  1.824336  0.277136  1.825875      0.277136
# 29  1.823713  0.277136  1.821473      0.277136
# 30  1.823204  0.277136  1.821635      0.277136

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 1.8212981224060059
# Maximum validation accuracy: 0.27713626623153687

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 2s 32ms/step - loss: 1.8310 - accuracy: 0.2771
# test loss, test acc: [1.8310121297836304, 0.27713626623153687]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 8s 158ms/step - loss: 2.0877 - accuracy: 0.2129 - val_loss: 1.8375 - val_accuracy: 0.2771
# Epoch 2/100
# 41/41 [==============================] - 6s 147ms/step - loss: 1.8298 - accuracy: 0.2560 - val_loss: 1.7925 - val_accuracy: 0.2771
# Epoch 3/100
# 41/41 [==============================] - 6s 147ms/step - loss: 1.7448 - accuracy: 0.2968 - val_loss: 1.6863 - val_accuracy: 0.2956
# Epoch 4/100
# 41/41 [==============================] - 6s 147ms/step - loss: 1.5537 - accuracy: 0.3645 - val_loss: 1.3955 - val_accuracy: 0.4180
# Epoch 5/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.5412 - accuracy: 0.3830 - val_loss: 1.4363 - val_accuracy: 0.4088
# Epoch 6/100
# 41/41 [==============================] - 6s 148ms/step - loss: 1.4446 - accuracy: 0.4176 - val_loss: 1.4074 - val_accuracy: 0.4411
# Epoch 7/100
# 41/41 [==============================] - 6s 147ms/step - loss: 1.3590 - accuracy: 0.4719 - val_loss: 1.3338 - val_accuracy: 0.4965
# Epoch 8/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.3383 - accuracy: 0.4881 - val_loss: 1.2678 - val_accuracy: 0.4815
# Epoch 9/100
# 41/41 [==============================] - 6s 148ms/step - loss: 1.2664 - accuracy: 0.5154 - val_loss: 1.2182 - val_accuracy: 0.5473
# Epoch 10/100
# 41/41 [==============================] - 6s 148ms/step - loss: 1.1155 - accuracy: 0.5804 - val_loss: 1.0071 - val_accuracy: 0.6316
# Epoch 11/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.0785 - accuracy: 0.5843 - val_loss: 1.1238 - val_accuracy: 0.5624
# Epoch 12/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.9894 - accuracy: 0.6236 - val_loss: 0.9216 - val_accuracy: 0.6582
# Epoch 13/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.8996 - accuracy: 0.6632 - val_loss: 0.8859 - val_accuracy: 0.6732
# Epoch 14/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.8665 - accuracy: 0.6682 - val_loss: 0.7504 - val_accuracy: 0.7286
# Epoch 15/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.7818 - accuracy: 0.7063 - val_loss: 0.9775 - val_accuracy: 0.6721
# Epoch 16/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.7660 - accuracy: 0.7156 - val_loss: 0.6685 - val_accuracy: 0.7656
# Epoch 17/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.8638 - accuracy: 0.6663 - val_loss: 0.6843 - val_accuracy: 0.7448
# Epoch 18/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.6342 - accuracy: 0.7637 - val_loss: 0.5724 - val_accuracy: 0.7979
# Epoch 19/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.5749 - accuracy: 0.7891 - val_loss: 0.5008 - val_accuracy: 0.8176
# Epoch 20/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.5208 - accuracy: 0.8014 - val_loss: 0.5549 - val_accuracy: 0.8002
# Epoch 21/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.4744 - accuracy: 0.8237 - val_loss: 0.6069 - val_accuracy: 0.7564
# Epoch 22/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.4847 - accuracy: 0.8191 - val_loss: 0.6279 - val_accuracy: 0.7771
# Epoch 23/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.4933 - accuracy: 0.8075 - val_loss: 0.5324 - val_accuracy: 0.7945
# Epoch 24/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.4303 - accuracy: 0.8380 - val_loss: 0.5321 - val_accuracy: 0.8037
# Epoch 25/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.4180 - accuracy: 0.8464 - val_loss: 0.5559 - val_accuracy: 0.7794
# Epoch 26/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.3503 - accuracy: 0.8634 - val_loss: 0.6545 - val_accuracy: 0.7864
# Epoch 27/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.3619 - accuracy: 0.8668 - val_loss: 0.5450 - val_accuracy: 0.8210
# Epoch 28/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.3655 - accuracy: 0.8676 - val_loss: 0.4444 - val_accuracy: 0.8406
# Epoch 29/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.2432 - accuracy: 0.9022 - val_loss: 0.6441 - val_accuracy: 0.8072
# Epoch 30/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.3461 - accuracy: 0.8741 - val_loss: 0.5712 - val_accuracy: 0.8279
# Epoch 31/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.2879 - accuracy: 0.8965 - val_loss: 0.5214 - val_accuracy: 0.8256
# Epoch 32/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.2113 - accuracy: 0.9176 - val_loss: 0.4921 - val_accuracy: 0.8406
# Epoch 33/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1839 - accuracy: 0.9303 - val_loss: 0.5726 - val_accuracy: 0.8176
# Epoch 34/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.2995 - accuracy: 0.8888 - val_loss: 0.6212 - val_accuracy: 0.7725
# Epoch 35/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2754 - accuracy: 0.8961 - val_loss: 0.4664 - val_accuracy: 0.8487
# Epoch 36/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1879 - accuracy: 0.9242 - val_loss: 0.5295 - val_accuracy: 0.8303
# Epoch 37/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1201 - accuracy: 0.9523 - val_loss: 0.6153 - val_accuracy: 0.8314
# Epoch 38/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.1543 - accuracy: 0.9415 - val_loss: 0.5286 - val_accuracy: 0.8487
# Epoch 39/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.1382 - accuracy: 0.9484 - val_loss: 0.7971 - val_accuracy: 0.7771
# Epoch 40/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.2840 - accuracy: 0.8968 - val_loss: 0.5521 - val_accuracy: 0.8303
# Epoch 41/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1367 - accuracy: 0.9469 - val_loss: 0.5801 - val_accuracy: 0.8372
# Epoch 42/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0977 - accuracy: 0.9657 - val_loss: 0.6998 - val_accuracy: 0.8060
# Epoch 43/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0880 - accuracy: 0.9758 - val_loss: 0.7090 - val_accuracy: 0.8233
# Epoch 44/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1638 - accuracy: 0.9376 - val_loss: 0.5446 - val_accuracy: 0.8395
# Epoch 45/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0754 - accuracy: 0.9781 - val_loss: 0.6938 - val_accuracy: 0.8372
# Epoch 46/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1157 - accuracy: 0.9607 - val_loss: 0.5995 - val_accuracy: 0.8464
# Epoch 47/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1700 - accuracy: 0.9442 - val_loss: 0.6829 - val_accuracy: 0.8383
# Epoch 48/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0561 - accuracy: 0.9796 - val_loss: 0.6202 - val_accuracy: 0.8326
# Epoch 49/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.7267 - val_accuracy: 0.8476
# Epoch 50/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0179 - accuracy: 0.9931 - val_loss: 0.9997 - val_accuracy: 0.8430
# Epoch 51/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.0480 - accuracy: 0.9823 - val_loss: 0.9873 - val_accuracy: 0.8210
# Epoch 52/100
# 41/41 [==============================] - 6s 146ms/step - loss: 0.1706 - accuracy: 0.9411 - val_loss: 0.6690 - val_accuracy: 0.8141
# Epoch 53/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0957 - accuracy: 0.9684 - val_loss: 0.7055 - val_accuracy: 0.8256
# Epoch 54/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0251 - accuracy: 0.9950 - val_loss: 0.6769 - val_accuracy: 0.8557
# Epoch 55/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.7928 - val_accuracy: 0.8568
# Epoch 56/100
# 41/41 [==============================] - 6s 147ms/step - loss: 9.5201e-04 - accuracy: 1.0000 - val_loss: 0.8201 - val_accuracy: 0.8522
# Epoch 57/100
# 41/41 [==============================] - 6s 147ms/step - loss: 3.3440e-04 - accuracy: 1.0000 - val_loss: 0.8515 - val_accuracy: 0.8557
# Epoch 58/100
# 41/41 [==============================] - 6s 147ms/step - loss: 2.2951e-04 - accuracy: 1.0000 - val_loss: 0.8723 - val_accuracy: 0.8545
# Epoch 59/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.7742e-04 - accuracy: 1.0000 - val_loss: 0.8931 - val_accuracy: 0.8522
# Epoch 60/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.4488e-04 - accuracy: 1.0000 - val_loss: 0.9093 - val_accuracy: 0.8510
# Epoch 61/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.2097e-04 - accuracy: 1.0000 - val_loss: 0.9267 - val_accuracy: 0.8522
# Epoch 62/100
# 41/41 [==============================] - 6s 146ms/step - loss: 1.0181e-04 - accuracy: 1.0000 - val_loss: 0.9401 - val_accuracy: 0.8533
# Epoch 63/100
# 41/41 [==============================] - 6s 146ms/step - loss: 8.7118e-05 - accuracy: 1.0000 - val_loss: 0.9562 - val_accuracy: 0.8545
# Epoch 64/100
# 41/41 [==============================] - 6s 146ms/step - loss: 7.4468e-05 - accuracy: 1.0000 - val_loss: 0.9778 - val_accuracy: 0.8510
# Epoch 65/100
# 41/41 [==============================] - 6s 146ms/step - loss: 6.3733e-05 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.8476
# Epoch 66/100
# 41/41 [==============================] - 6s 146ms/step - loss: 5.6467e-05 - accuracy: 1.0000 - val_loss: 1.0068 - val_accuracy: 0.8522
# Epoch 67/100
# 41/41 [==============================] - 6s 146ms/step - loss: 5.0111e-05 - accuracy: 1.0000 - val_loss: 1.0231 - val_accuracy: 0.8499
# Epoch 68/100
# 41/41 [==============================] - 6s 147ms/step - loss: 4.4099e-05 - accuracy: 1.0000 - val_loss: 1.0529 - val_accuracy: 0.8487
# Epoch 69/100
# 41/41 [==============================] - 6s 147ms/step - loss: 3.9815e-05 - accuracy: 1.0000 - val_loss: 1.0662 - val_accuracy: 0.8499
# Epoch 70/100
# 41/41 [==============================] - 6s 146ms/step - loss: 3.5061e-05 - accuracy: 1.0000 - val_loss: 1.0854 - val_accuracy: 0.8453
# Epoch 71/100
# 41/41 [==============================] - 6s 146ms/step - loss: 3.2455e-05 - accuracy: 1.0000 - val_loss: 1.0648 - val_accuracy: 0.8499
# Epoch 72/100
# 41/41 [==============================] - 6s 146ms/step - loss: 2.9061e-05 - accuracy: 1.0000 - val_loss: 1.1006 - val_accuracy: 0.8453
# Epoch 73/100
# 41/41 [==============================] - 6s 147ms/step - loss: 2.6717e-05 - accuracy: 1.0000 - val_loss: 1.1141 - val_accuracy: 0.8476
# Epoch 74/100
# 41/41 [==============================] - 6s 147ms/step - loss: 2.4202e-05 - accuracy: 1.0000 - val_loss: 1.1247 - val_accuracy: 0.8453
# Epoch 75/100
# 41/41 [==============================] - ETA: 0s - loss: 2.2656e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 55.
# 41/41 [==============================] - 6s 147ms/step - loss: 2.2656e-05 - accuracy: 1.0000 - val_loss: 1.1314 - val_accuracy: 0.8464
# Epoch 00075: early stopping
# Maximal validation accuracy: 85.68%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   2.087715  0.212856  1.837471      0.277136
# 1   1.829805  0.255966  1.792525      0.277136
# 2   1.744770  0.296767  1.686269      0.295612
# 3   1.553657  0.364511  1.395498      0.418014
# 4   1.541202  0.382987  1.436287      0.408776
# ..       ...       ...       ...           ...
# 70  0.000032  1.000000  1.064819      0.849885
# 71  0.000029  1.000000  1.100553      0.845266
# 72  0.000027  1.000000  1.114146      0.847575
# 73  0.000024  1.000000  1.124669      0.845266
# 74  0.000023  1.000000  1.131381      0.846420
#
# [75 rows x 4 columns]

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.444448858499527
# Maximum validation accuracy: 0.8568129539489746

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 23ms/step - loss: 0.8225 - accuracy: 0.8476
# test loss, test acc: [0.8224896788597107, 0.8475750684738159]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 11s 254ms/step - loss: 2.1881 - accuracy: 0.2706 - val_loss: 1.8507 - val_accuracy: 0.3053
# Epoch 2/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8348 - accuracy: 0.3053 - val_loss: 1.8260 - val_accuracy: 0.3053
# Epoch 3/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8336 - accuracy: 0.3053 - val_loss: 1.8353 - val_accuracy: 0.3053
# Epoch 4/100
# 37/37 [==============================] - 5s 146ms/step - loss: 1.8323 - accuracy: 0.3053 - val_loss: 1.8266 - val_accuracy: 0.3053
# Epoch 5/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8296 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 6/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8302 - accuracy: 0.3053 - val_loss: 1.8262 - val_accuracy: 0.3053
# Epoch 7/100
# 37/37 [==============================] - 5s 146ms/step - loss: 1.8294 - accuracy: 0.3053 - val_loss: 1.8262 - val_accuracy: 0.3053
# Epoch 8/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8279 - accuracy: 0.3053 - val_loss: 1.8267 - val_accuracy: 0.3053
# Epoch 9/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8276 - accuracy: 0.3053 - val_loss: 1.8257 - val_accuracy: 0.3053
# Epoch 10/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8285 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 11/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8283 - accuracy: 0.3053 - val_loss: 1.8268 - val_accuracy: 0.3053
# Epoch 12/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8286 - accuracy: 0.3053 - val_loss: 1.8270 - val_accuracy: 0.3053
# Epoch 13/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8282 - accuracy: 0.3053 - val_loss: 1.8267 - val_accuracy: 0.3053
# Epoch 14/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.8282 - accuracy: 0.3053 - val_loss: 1.8260 - val_accuracy: 0.3053
# Epoch 15/100
# 37/37 [==============================] - 5s 146ms/step - loss: 1.8278 - accuracy: 0.3053 - val_loss: 1.8267 - val_accuracy: 0.3053
# Epoch 16/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8278 - accuracy: 0.3053 - val_loss: 1.8261 - val_accuracy: 0.3053
# Epoch 17/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8270 - accuracy: 0.3053 - val_loss: 1.8279 - val_accuracy: 0.3053
# Epoch 18/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8282 - accuracy: 0.3053 - val_loss: 1.8286 - val_accuracy: 0.3053
# Epoch 19/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8280 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 20/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8272 - accuracy: 0.3053 - val_loss: 1.8261 - val_accuracy: 0.3053
# Epoch 21/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8282 - accuracy: 0.3053 - val_loss: 1.8265 - val_accuracy: 0.3053
# Epoch 22/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8277 - accuracy: 0.3053 - val_loss: 1.8273 - val_accuracy: 0.3053
# Epoch 23/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8329 - accuracy: 0.3053 - val_loss: 1.8268 - val_accuracy: 0.3053
# Epoch 24/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8276 - accuracy: 0.3053 - val_loss: 1.8309 - val_accuracy: 0.3053
# Epoch 25/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8302 - accuracy: 0.3053 - val_loss: 1.8262 - val_accuracy: 0.3053
# Epoch 26/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8302 - accuracy: 0.3053 - val_loss: 1.8341 - val_accuracy: 0.3053
# Epoch 27/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8315 - accuracy: 0.3053 - val_loss: 1.8256 - val_accuracy: 0.3053
# Epoch 28/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8266 - accuracy: 0.3053 - val_loss: 1.8275 - val_accuracy: 0.3053
# Epoch 29/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8270 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 30/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8269 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 31/100
# 37/37 [==============================] - ETA: 0s - loss: 1.8275 - accuracy: 0.3053Restoring model weights from the end of the best epoch: 1.
# 37/37 [==============================] - 5s 148ms/step - loss: 1.8275 - accuracy: 0.3053 - val_loss: 1.8259 - val_accuracy: 0.3053
# Epoch 00031: early stopping
# Maximal validation accuracy: 30.53%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   2.188071  0.270568  1.850691      0.305344
# 1   1.834816  0.305344  1.826032      0.305344
# 2   1.833610  0.305344  1.835261      0.305344
# 3   1.832261  0.305344  1.826591      0.305344
# 4   1.829583  0.305344  1.825878      0.305344
# 5   1.830160  0.305344  1.826164      0.305344
# 6   1.829370  0.305344  1.826246      0.305344
# 7   1.827871  0.305344  1.826657      0.305344
# 8   1.827609  0.305344  1.825704      0.305344
# 9   1.828516  0.305344  1.825886      0.305344
# 10  1.828308  0.305344  1.826848      0.305344
# 11  1.828646  0.305344  1.827028      0.305344
# 12  1.828203  0.305344  1.826694      0.305344
# 13  1.828161  0.305344  1.825975      0.305344
# 14  1.827799  0.305344  1.826702      0.305344
# 15  1.827797  0.305344  1.826074      0.305344
# 16  1.826994  0.305344  1.827934      0.305344
# 17  1.828199  0.305344  1.828583      0.305344
# 18  1.828013  0.305344  1.825942      0.305344
# 19  1.827204  0.305344  1.826067      0.305344
# 20  1.828197  0.305344  1.826537      0.305344
# 21  1.827717  0.305344  1.827270      0.305344
# 22  1.832891  0.305344  1.826796      0.305344
# 23  1.827570  0.305344  1.830934      0.305344
# 24  1.830181  0.305344  1.826186      0.305344
# 25  1.830242  0.305344  1.834102      0.305344
# 26  1.831485  0.305344  1.825569      0.305344
# 27  1.826587  0.305344  1.827455      0.305344
# 28  1.827046  0.305344  1.825861      0.305344
# 29  1.826928  0.305344  1.825896      0.305344
# 30  1.827548  0.305344  1.825853      0.305344

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 1.8255685567855835
# Maximum validation accuracy: 0.30534350872039795

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 25ms/step - loss: 1.8507 - accuracy: 0.3053
# test loss, test acc: [1.8506914377212524, 0.30534350872039795]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 7s 159ms/step - loss: 2.3875 - accuracy: 0.2752 - val_loss: 1.8179 - val_accuracy: 0.3053
# Epoch 2/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8284 - accuracy: 0.2913 - val_loss: 1.8627 - val_accuracy: 0.3053
# Epoch 3/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.8479 - accuracy: 0.2956 - val_loss: 1.8316 - val_accuracy: 0.3053
# Epoch 4/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8266 - accuracy: 0.3053 - val_loss: 1.8163 - val_accuracy: 0.3053
# Epoch 5/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.8211 - accuracy: 0.3053 - val_loss: 1.8007 - val_accuracy: 0.3053
# Epoch 6/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.7503 - accuracy: 0.3414 - val_loss: 1.7663 - val_accuracy: 0.3817
# Epoch 7/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.6236 - accuracy: 0.3851 - val_loss: 1.5395 - val_accuracy: 0.4109
# Epoch 8/100
# 37/37 [==============================] - 5s 149ms/step - loss: 1.4629 - accuracy: 0.4631 - val_loss: 1.4056 - val_accuracy: 0.4898
# Epoch 9/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.4184 - accuracy: 0.4656 - val_loss: 1.3008 - val_accuracy: 0.5280
# Epoch 10/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.3902 - accuracy: 0.4796 - val_loss: 1.2811 - val_accuracy: 0.5267
# Epoch 11/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.3358 - accuracy: 0.5021 - val_loss: 1.2694 - val_accuracy: 0.5407
# Epoch 12/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.1491 - accuracy: 0.5581 - val_loss: 1.1742 - val_accuracy: 0.5789
# Epoch 13/100
# 37/37 [==============================] - 5s 149ms/step - loss: 1.0931 - accuracy: 0.5912 - val_loss: 1.0048 - val_accuracy: 0.6132
# Epoch 14/100
# 37/37 [==============================] - 5s 148ms/step - loss: 1.0182 - accuracy: 0.6132 - val_loss: 0.9123 - val_accuracy: 0.6527
# Epoch 15/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.9226 - accuracy: 0.6416 - val_loss: 0.8103 - val_accuracy: 0.6794
# Epoch 16/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.8421 - accuracy: 0.6764 - val_loss: 1.4565 - val_accuracy: 0.5738
# Epoch 17/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.8844 - accuracy: 0.6815 - val_loss: 0.7917 - val_accuracy: 0.7201
# Epoch 18/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.7411 - accuracy: 0.7349 - val_loss: 0.7612 - val_accuracy: 0.7023
# Epoch 19/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.5708 - accuracy: 0.7930 - val_loss: 0.6559 - val_accuracy: 0.7468
# Epoch 20/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.5716 - accuracy: 0.7846 - val_loss: 0.4913 - val_accuracy: 0.7990
# Epoch 21/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.5105 - accuracy: 0.8100 - val_loss: 0.4954 - val_accuracy: 0.8092
# Epoch 22/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.4532 - accuracy: 0.8372 - val_loss: 0.5246 - val_accuracy: 0.7952
# Epoch 23/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.4610 - accuracy: 0.8295 - val_loss: 0.6207 - val_accuracy: 0.7723
# Epoch 24/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.4874 - accuracy: 0.8159 - val_loss: 0.4489 - val_accuracy: 0.8346
# Epoch 25/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.3416 - accuracy: 0.8757 - val_loss: 0.4430 - val_accuracy: 0.8219
# Epoch 26/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.3220 - accuracy: 0.8897 - val_loss: 0.4695 - val_accuracy: 0.8015
# Epoch 27/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.3837 - accuracy: 0.8668 - val_loss: 0.3780 - val_accuracy: 0.8677
# Epoch 28/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.2419 - accuracy: 0.9122 - val_loss: 0.3397 - val_accuracy: 0.8715
# Epoch 29/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.2168 - accuracy: 0.9177 - val_loss: 0.3788 - val_accuracy: 0.8550
# Epoch 30/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.2904 - accuracy: 0.8889 - val_loss: 0.3423 - val_accuracy: 0.8842
# Epoch 31/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.2146 - accuracy: 0.9232 - val_loss: 0.3458 - val_accuracy: 0.8740
# Epoch 32/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.1428 - accuracy: 0.9534 - val_loss: 0.3147 - val_accuracy: 0.8931
# Epoch 33/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1637 - accuracy: 0.9457 - val_loss: 0.4283 - val_accuracy: 0.8601
# Epoch 34/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1273 - accuracy: 0.9584 - val_loss: 0.3710 - val_accuracy: 0.8766
# Epoch 35/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1192 - accuracy: 0.9593 - val_loss: 0.3511 - val_accuracy: 0.8919
# Epoch 36/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1642 - accuracy: 0.9508 - val_loss: 0.3341 - val_accuracy: 0.8830
# Epoch 37/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.2503 - accuracy: 0.9169 - val_loss: 0.3026 - val_accuracy: 0.8982
# Epoch 38/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0953 - accuracy: 0.9729 - val_loss: 0.3170 - val_accuracy: 0.8931
# Epoch 39/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1130 - accuracy: 0.9635 - val_loss: 0.4159 - val_accuracy: 0.8830
# Epoch 40/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1269 - accuracy: 0.9597 - val_loss: 0.4232 - val_accuracy: 0.8575
# Epoch 41/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0999 - accuracy: 0.9656 - val_loss: 0.6970 - val_accuracy: 0.8397
# Epoch 42/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0867 - accuracy: 0.9707 - val_loss: 0.3848 - val_accuracy: 0.9008
# Epoch 43/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0747 - accuracy: 0.9813 - val_loss: 0.4568 - val_accuracy: 0.8702
# Epoch 44/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1117 - accuracy: 0.9627 - val_loss: 0.3648 - val_accuracy: 0.8957
# Epoch 45/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0496 - accuracy: 0.9839 - val_loss: 0.3971 - val_accuracy: 0.8804
# Epoch 46/100
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0262 - accuracy: 0.9915 - val_loss: 0.4467 - val_accuracy: 0.9084
# Epoch 47/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0745 - accuracy: 0.9754 - val_loss: 0.5997 - val_accuracy: 0.8524
# Epoch 48/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0997 - accuracy: 0.9652 - val_loss: 0.5009 - val_accuracy: 0.8613
# Epoch 49/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0923 - accuracy: 0.9682 - val_loss: 0.3822 - val_accuracy: 0.9059
# Epoch 50/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1189 - accuracy: 0.9648 - val_loss: 0.3413 - val_accuracy: 0.9008
# Epoch 51/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0287 - accuracy: 0.9919 - val_loss: 0.4055 - val_accuracy: 0.9020
# Epoch 52/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0632 - accuracy: 0.9809 - val_loss: 0.4054 - val_accuracy: 0.8931
# Epoch 53/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0416 - accuracy: 0.9847 - val_loss: 0.4192 - val_accuracy: 0.9046
# Epoch 54/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0460 - accuracy: 0.9847 - val_loss: 0.3927 - val_accuracy: 0.9059
# Epoch 55/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.3810 - val_accuracy: 0.9160
# Epoch 56/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.4656 - val_accuracy: 0.9008
# Epoch 57/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0064 - accuracy: 0.9996 - val_loss: 0.4583 - val_accuracy: 0.9084
# Epoch 58/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0994 - accuracy: 0.9741 - val_loss: 0.5578 - val_accuracy: 0.8397
# Epoch 59/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.1165 - accuracy: 0.9656 - val_loss: 0.4454 - val_accuracy: 0.8957
# Epoch 60/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.2070 - accuracy: 0.9419 - val_loss: 0.6071 - val_accuracy: 0.8486
# Epoch 61/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1446 - accuracy: 0.9538 - val_loss: 0.3669 - val_accuracy: 0.9020
# Epoch 62/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0561 - accuracy: 0.9813 - val_loss: 0.4795 - val_accuracy: 0.8817
# Epoch 63/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0342 - accuracy: 0.9911 - val_loss: 0.4612 - val_accuracy: 0.8969
# Epoch 64/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0217 - accuracy: 0.9924 - val_loss: 0.4755 - val_accuracy: 0.9008
# Epoch 65/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0518 - accuracy: 0.9860 - val_loss: 0.4463 - val_accuracy: 0.8830
# Epoch 66/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0137 - accuracy: 0.9966 - val_loss: 0.3976 - val_accuracy: 0.9186
# Epoch 67/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.5013 - val_accuracy: 0.9008
# Epoch 68/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 0.6055 - val_accuracy: 0.9008
# Epoch 69/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0411 - accuracy: 0.9873 - val_loss: 0.4668 - val_accuracy: 0.8982
# Epoch 70/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0628 - accuracy: 0.9767 - val_loss: 0.5276 - val_accuracy: 0.8728
# Epoch 71/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1542 - accuracy: 0.9504 - val_loss: 0.4071 - val_accuracy: 0.8919
# Epoch 72/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0541 - accuracy: 0.9852 - val_loss: 0.5233 - val_accuracy: 0.8550
# Epoch 73/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0440 - accuracy: 0.9856 - val_loss: 0.3844 - val_accuracy: 0.8919
# Epoch 74/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0380 - accuracy: 0.9869 - val_loss: 0.3451 - val_accuracy: 0.9148
# Epoch 75/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.3875 - val_accuracy: 0.9249
# Epoch 76/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.4709 - val_accuracy: 0.9071
# Epoch 77/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0235 - accuracy: 0.9902 - val_loss: 0.4044 - val_accuracy: 0.8982
# Epoch 78/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.5220 - val_accuracy: 0.9109
# Epoch 79/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.4558 - val_accuracy: 0.8982
# Epoch 80/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0728 - accuracy: 0.9771 - val_loss: 0.4311 - val_accuracy: 0.8931
# Epoch 81/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.5014 - val_accuracy: 0.9020
# Epoch 82/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0972 - accuracy: 0.9703 - val_loss: 0.3407 - val_accuracy: 0.9135
# Epoch 83/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1151 - accuracy: 0.9623 - val_loss: 0.3760 - val_accuracy: 0.8906
# Epoch 84/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.4552 - val_accuracy: 0.9173
# Epoch 85/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0472 - accuracy: 0.9873 - val_loss: 0.4076 - val_accuracy: 0.9148
# Epoch 86/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.4382 - val_accuracy: 0.9122
# Epoch 87/100
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.5011 - val_accuracy: 0.9122
# Epoch 88/100
# 37/37 [==============================] - 5s 149ms/step - loss: 5.0330e-04 - accuracy: 1.0000 - val_loss: 0.4438 - val_accuracy: 0.9300
# Epoch 89/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.4645e-04 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.9262
# Epoch 90/100
# 37/37 [==============================] - 5s 147ms/step - loss: 7.3811e-05 - accuracy: 1.0000 - val_loss: 0.5499 - val_accuracy: 0.9300
# Epoch 91/100
# 37/37 [==============================] - 5s 147ms/step - loss: 4.3652e-05 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.9288
# Epoch 92/100
# 37/37 [==============================] - 5s 147ms/step - loss: 2.8161e-05 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.9275
# Epoch 93/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.6851e-05 - accuracy: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.9237
# Epoch 94/100
# 37/37 [==============================] - 5s 147ms/step - loss: 1.0384e-05 - accuracy: 1.0000 - val_loss: 0.7603 - val_accuracy: 0.9237
# Epoch 95/100
# 37/37 [==============================] - 5s 147ms/step - loss: 6.7105e-06 - accuracy: 1.0000 - val_loss: 0.8170 - val_accuracy: 0.9224
# Epoch 96/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.7459 - val_accuracy: 0.8906
# Epoch 97/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0390 - accuracy: 0.9890 - val_loss: 1.1790 - val_accuracy: 0.8053
# Epoch 98/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1771 - accuracy: 0.9436 - val_loss: 0.4337 - val_accuracy: 0.8919
# Epoch 99/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.2484 - accuracy: 0.9283 - val_loss: 0.4844 - val_accuracy: 0.8588
# Epoch 100/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.1706 - accuracy: 0.9440 - val_loss: 0.4648 - val_accuracy: 0.8868
# Maximal validation accuracy: 93.00%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   2.387528  0.275233  1.817876      0.305344
# 1   1.828433  0.291349  1.862670      0.305344
# 2   1.847900  0.295589  1.831639      0.305344
# 3   1.826576  0.305344  1.816269      0.305344
# 4   1.821060  0.305344  1.800702      0.305344
# ..       ...       ...       ...           ...
# 95  0.001347  0.999576  0.745922      0.890585
# 96  0.039031  0.988974  1.179003      0.805344
# 97  0.177134  0.943596  0.433719      0.891858
# 98  0.248400  0.928329  0.484417      0.858779
# 99  0.170572  0.944020  0.464773      0.886768
#
# [100 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.3025679588317871
# Maximum validation accuracy: 0.9300254583358765

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5076 - accuracy: 0.8677
# test loss, test acc: [0.5075597167015076, 0.8676844835281372]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_VGG16_None
# test loss, test acc: [1.8310121297836304, 0.27713626623153687]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_VGG16_imagenet
# test loss, test acc: [0.8224896788597107, 0.8475750684738159]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_VGG16_None
# test loss, test acc: [1.8506914377212524, 0.30534350872039795]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_VGG16_imagenet
# test loss, test acc: [0.5075597167015076, 0.8676844835281372]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_VGG16_None →→→ Target Test
# 25/25 [==============================] - 1s 24ms/step - loss: 1.8478 - accuracy: 0.3053
# test loss, test acc: [1.8478474617004395, 0.30534350872039795]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_VGG16_imagenet →→→ Target Test
# 25/25 [==============================] - 1s 24ms/step - loss: 11.7212 - accuracy: 0.2621
# test loss, test acc: [11.721165657043457, 0.26208651065826416]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_VGG16_None →→→ Source Test
# 28/28 [==============================] - 1s 23ms/step - loss: 1.8512 - accuracy: 0.2771
# test loss, test acc: [1.851205587387085, 0.27713626623153687]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_VGG16_imagenet →→→ Source Test
# 28/28 [==============================] - 1s 24ms/step - loss: 5.0108 - accuracy: 0.1582
# test loss, test acc: [5.010765075683594, 0.15819860994815826]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
