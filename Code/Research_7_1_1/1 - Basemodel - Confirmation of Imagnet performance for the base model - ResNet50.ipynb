# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5454476356765646196
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10955030462727832531
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 23:52:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    34W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'ResNet50'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_ResNet50_None S_ResNet50_imagenet T_ResNet50_None T_ResNet50_imagenet
# ['S_ResNet50_imagenet',
#  'S_ResNet50_None',
#  'T_ResNet50_imagenet',
#  'T_ResNet50_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)
#
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)
#
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.ResNet50 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.ResNet50 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 20s 180ms/step - loss: 1.7116 - accuracy: 0.3884 - val_loss: 2.0026 - val_accuracy: 0.1155
# Epoch 2/100
# 41/41 [==============================] - 6s 135ms/step - loss: 1.1137 - accuracy: 0.5947 - val_loss: 3.1167 - val_accuracy: 0.1155
# Epoch 3/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.9193 - accuracy: 0.6832 - val_loss: 3.6184 - val_accuracy: 0.1155
# Epoch 4/100
# 41/41 [==============================] - 6s 136ms/step - loss: 0.7793 - accuracy: 0.7329 - val_loss: 7.4035 - val_accuracy: 0.1155
# Epoch 5/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.7545 - accuracy: 0.7379 - val_loss: 6.5878 - val_accuracy: 0.1155
# Epoch 6/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.6103 - accuracy: 0.7895 - val_loss: 7.0388 - val_accuracy: 0.1212
# Epoch 7/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.5351 - accuracy: 0.8102 - val_loss: 2.9452 - val_accuracy: 0.2771
# Epoch 8/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.5505 - accuracy: 0.8064 - val_loss: 5.8379 - val_accuracy: 0.3187
# Epoch 9/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.4956 - accuracy: 0.8256 - val_loss: 4.2606 - val_accuracy: 0.2633
# Epoch 10/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.4544 - accuracy: 0.8368 - val_loss: 3.2318 - val_accuracy: 0.3845
# Epoch 11/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.3677 - accuracy: 0.8653 - val_loss: 3.2329 - val_accuracy: 0.3868
# Epoch 12/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.3180 - accuracy: 0.8838 - val_loss: 4.3699 - val_accuracy: 0.3210
# Epoch 13/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.2621 - accuracy: 0.9045 - val_loss: 1.4479 - val_accuracy: 0.6120
# Epoch 14/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.2970 - accuracy: 0.9053 - val_loss: 4.2375 - val_accuracy: 0.4053
# Epoch 15/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.2383 - accuracy: 0.9153 - val_loss: 1.6542 - val_accuracy: 0.6005
# Epoch 16/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1678 - accuracy: 0.9461 - val_loss: 2.5186 - val_accuracy: 0.5346
# Epoch 17/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.1911 - accuracy: 0.9338 - val_loss: 1.5614 - val_accuracy: 0.6363
# Epoch 18/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.2755 - accuracy: 0.9049 - val_loss: 4.6324 - val_accuracy: 0.2818
# Epoch 19/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1957 - accuracy: 0.9323 - val_loss: 4.0457 - val_accuracy: 0.4076
# Epoch 20/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.1319 - accuracy: 0.9550 - val_loss: 1.2780 - val_accuracy: 0.6917
# Epoch 21/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1083 - accuracy: 0.9623 - val_loss: 1.3127 - val_accuracy: 0.6894
# Epoch 22/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1261 - accuracy: 0.9546 - val_loss: 3.0407 - val_accuracy: 0.4827
# Epoch 23/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0936 - accuracy: 0.9681 - val_loss: 2.1426 - val_accuracy: 0.6467
# Epoch 24/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0764 - accuracy: 0.9773 - val_loss: 0.8227 - val_accuracy: 0.8002
# Epoch 25/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1066 - accuracy: 0.9692 - val_loss: 2.5682 - val_accuracy: 0.4988
# Epoch 26/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1487 - accuracy: 0.9488 - val_loss: 2.2903 - val_accuracy: 0.5727
# Epoch 27/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.2130 - accuracy: 0.9296 - val_loss: 437.8746 - val_accuracy: 0.1143
# Epoch 28/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1322 - accuracy: 0.9577 - val_loss: 1.9553 - val_accuracy: 0.6894
# Epoch 29/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0775 - accuracy: 0.9750 - val_loss: 1.0800 - val_accuracy: 0.7575
# Epoch 30/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1062 - accuracy: 0.9684 - val_loss: 3.5373 - val_accuracy: 0.5404
# Epoch 31/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0814 - accuracy: 0.9765 - val_loss: 3.3501 - val_accuracy: 0.4965
# Epoch 32/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0620 - accuracy: 0.9788 - val_loss: 3.0967 - val_accuracy: 0.5878
# Epoch 33/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0913 - accuracy: 0.9715 - val_loss: 2.4422 - val_accuracy: 0.5462
# Epoch 34/100
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0665 - accuracy: 0.9800 - val_loss: 0.8372 - val_accuracy: 0.8083
# Epoch 35/100
# 41/41 [==============================] - 5s 134ms/step - loss: 0.0628 - accuracy: 0.9784 - val_loss: 1.3257 - val_accuracy: 0.6928
# Epoch 36/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0368 - accuracy: 0.9885 - val_loss: 2.1904 - val_accuracy: 0.6767
# Epoch 37/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0576 - accuracy: 0.9815 - val_loss: 4.1148 - val_accuracy: 0.4688
# Epoch 38/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0677 - accuracy: 0.9769 - val_loss: 1.8341 - val_accuracy: 0.5970
# Epoch 39/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0877 - accuracy: 0.9669 - val_loss: 2.7962 - val_accuracy: 0.5416
# Epoch 40/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 5.9558 - val_accuracy: 0.4042
# Epoch 41/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0933 - accuracy: 0.9704 - val_loss: 2.6366 - val_accuracy: 0.5866
# Epoch 42/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0800 - accuracy: 0.9719 - val_loss: 2.4852 - val_accuracy: 0.6236
# Epoch 43/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0847 - accuracy: 0.9750 - val_loss: 1.3539 - val_accuracy: 0.6998
# Epoch 44/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0561 - accuracy: 0.9811 - val_loss: 2.1953 - val_accuracy: 0.6594
# Epoch 45/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0345 - accuracy: 0.9904 - val_loss: 1.8499 - val_accuracy: 0.6432
# Epoch 46/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0418 - accuracy: 0.9861 - val_loss: 0.9730 - val_accuracy: 0.7702
# Epoch 47/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 1.0220 - val_accuracy: 0.7679
# Epoch 48/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 1.3183 - val_accuracy: 0.7656
# Epoch 49/100
# 41/41 [==============================] - 5s 134ms/step - loss: 0.0162 - accuracy: 0.9954 - val_loss: 0.9948 - val_accuracy: 0.8072
# Epoch 50/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0189 - accuracy: 0.9946 - val_loss: 1.1606 - val_accuracy: 0.7564
# Epoch 51/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0420 - accuracy: 0.9854 - val_loss: 4.1774 - val_accuracy: 0.4792
# Epoch 52/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0655 - accuracy: 0.9792 - val_loss: 1.7157 - val_accuracy: 0.6363
# Epoch 53/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0468 - accuracy: 0.9846 - val_loss: 2.3659 - val_accuracy: 0.6305
# Epoch 54/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0522 - accuracy: 0.9838 - val_loss: 1.6528 - val_accuracy: 0.7206
# Epoch 55/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0661 - accuracy: 0.9784 - val_loss: 1.3334 - val_accuracy: 0.7621
# Epoch 56/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0860 - accuracy: 0.9738 - val_loss: 1.7467 - val_accuracy: 0.6871
# Epoch 57/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0534 - accuracy: 0.9834 - val_loss: 5.4586 - val_accuracy: 0.4988
# Epoch 58/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0536 - accuracy: 0.9865 - val_loss: 2.6985 - val_accuracy: 0.6212
# Epoch 59/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0373 - accuracy: 0.9888 - val_loss: 1.9063 - val_accuracy: 0.6767
# Epoch 60/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0314 - accuracy: 0.9927 - val_loss: 3.4172 - val_accuracy: 0.5831
# Epoch 61/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0274 - accuracy: 0.9908 - val_loss: 1.3418 - val_accuracy: 0.7575
# Epoch 62/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 1.0901 - val_accuracy: 0.7806
# Epoch 63/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 1.2504 - val_accuracy: 0.7413
# Epoch 64/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9823Restoring model weights from the end of the best epoch: 34.
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0540 - accuracy: 0.9823 - val_loss: 3.4633 - val_accuracy: 0.5497
# Epoch 00064: early stopping
# Maximal validation accuracy: 80.83%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.711565  0.388376  2.002617      0.115473
# 1   1.113731  0.594688  3.116688      0.115473
# 2   0.919288  0.683218  3.618385      0.115473
# 3   0.779311  0.732871  7.403484      0.115473
# 4   0.754526  0.737875  6.587787      0.115473
# ..       ...       ...       ...           ...
# 59  0.031415  0.992687  3.417184      0.583141
# 60  0.027447  0.990762  1.341795      0.757506
# 61  0.029041  0.990762  1.090104      0.780600
# 62  0.023543  0.991917  1.250396      0.741340
# 63  0.053982  0.982294  3.463282      0.549654
#
# [64 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.8226686120033264
# Maximum validation accuracy: 0.8083140850067139

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 29ms/step - loss: 0.9878 - accuracy: 0.7945
# test loss, test acc: [0.9877968430519104, 0.7944572567939758]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 12s 164ms/step - loss: 0.7719 - accuracy: 0.7598 - val_loss: 857.3438 - val_accuracy: 0.2771
# Epoch 2/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.4459 - accuracy: 0.8584 - val_loss: 1168.4226 - val_accuracy: 0.0785
# Epoch 3/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.2403 - accuracy: 0.9165 - val_loss: 418.5526 - val_accuracy: 0.1848
# Epoch 4/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1749 - accuracy: 0.9373 - val_loss: 218.3102 - val_accuracy: 0.1848
# Epoch 5/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1337 - accuracy: 0.9515 - val_loss: 3.2485 - val_accuracy: 0.1848
# Epoch 6/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1392 - accuracy: 0.9565 - val_loss: 6.6834 - val_accuracy: 0.1848
# Epoch 7/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1106 - accuracy: 0.9630 - val_loss: 9.9868 - val_accuracy: 0.1848
# Epoch 8/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.1223 - accuracy: 0.9654 - val_loss: 72.2221 - val_accuracy: 0.1848
# Epoch 9/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0767 - accuracy: 0.9765 - val_loss: 9.2926 - val_accuracy: 0.1848
# Epoch 10/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0709 - accuracy: 0.9769 - val_loss: 3.5467 - val_accuracy: 0.1767
# Epoch 11/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0843 - accuracy: 0.9715 - val_loss: 3.7251 - val_accuracy: 0.0531
# Epoch 12/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0647 - accuracy: 0.9788 - val_loss: 4.8056 - val_accuracy: 0.1155
# Epoch 13/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0323 - accuracy: 0.9904 - val_loss: 3.4945 - val_accuracy: 0.1848
# Epoch 14/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0354 - accuracy: 0.9904 - val_loss: 3.1080 - val_accuracy: 0.1848
# Epoch 15/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0829 - accuracy: 0.9727 - val_loss: 2.9103 - val_accuracy: 0.2402
# Epoch 16/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0227 - accuracy: 0.9938 - val_loss: 2.5804 - val_accuracy: 0.1721
# Epoch 17/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 9.4419 - val_accuracy: 0.1836
# Epoch 18/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 3.1777 - val_accuracy: 0.1697
# Epoch 19/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 2.9489 - val_accuracy: 0.2517
# Epoch 20/100
# 41/41 [==============================] - 6s 135ms/step - loss: 0.0189 - accuracy: 0.9927 - val_loss: 4.7218 - val_accuracy: 0.1836
# Epoch 21/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9885Restoring model weights from the end of the best epoch: 1.
# 41/41 [==============================] - 6s 138ms/step - loss: 0.0417 - accuracy: 0.9885 - val_loss: 5.4012 - val_accuracy: 0.2275
# Epoch 00021: early stopping
# Maximal validation accuracy: 27.71%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy     val_loss  val_accuracy
# 0   0.771899  0.759815   857.343811      0.277136
# 1   0.445933  0.858353  1168.422607      0.078522
# 2   0.240301  0.916474   418.552551      0.184758
# 3   0.174881  0.937259   218.310196      0.184758
# 4   0.133702  0.951501     3.248546      0.184758
# 5   0.139225  0.956505     6.683439      0.184758
# 6   0.110564  0.963049     9.986845      0.184758
# 7   0.122254  0.965358    72.222092      0.184758
# 8   0.076691  0.976520     9.292645      0.184758
# 9   0.070947  0.976905     3.546724      0.176674
# 10  0.084271  0.971517     3.725093      0.053118
# 11  0.064702  0.978830     4.805565      0.115473
# 12  0.032258  0.990377     3.494490      0.184758
# 13  0.035381  0.990377     3.108037      0.184758
# 14  0.082893  0.972671     2.910285      0.240185
# 15  0.022675  0.993841     2.580366      0.172055
# 16  0.006357  0.998460     9.441947      0.183603
# 17  0.004972  0.998460     3.177654      0.169746
# 18  0.014378  0.995381     2.948880      0.251732
# 19  0.018915  0.992687     4.721756      0.183603
# 20  0.041701  0.988453     5.401244      0.227483

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 2.5803656578063965
# Maximum validation accuracy: 0.27713626623153687

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 26ms/step - loss: 857.0129 - accuracy: 0.2771
# test loss, test acc: [857.012939453125, 0.27713626623153687]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 12s 182ms/step - loss: 1.7510 - accuracy: 0.4245 - val_loss: 1.9737 - val_accuracy: 0.1272
# Epoch 2/100
# 37/37 [==============================] - 5s 136ms/step - loss: 1.0558 - accuracy: 0.6399 - val_loss: 2.8145 - val_accuracy: 0.1272
# Epoch 3/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.7569 - accuracy: 0.7388 - val_loss: 3.2709 - val_accuracy: 0.1272
# Epoch 4/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.5515 - accuracy: 0.8121 - val_loss: 3.6719 - val_accuracy: 0.1527
# Epoch 5/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.5366 - accuracy: 0.8206 - val_loss: 2.5947 - val_accuracy: 0.1972
# Epoch 6/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.6171 - accuracy: 0.7905 - val_loss: 740.3983 - val_accuracy: 0.1527
# Epoch 7/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.5160 - accuracy: 0.8270 - val_loss: 7.5922 - val_accuracy: 0.0763
# Epoch 8/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3788 - accuracy: 0.8702 - val_loss: 3.3071 - val_accuracy: 0.1730
# Epoch 9/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.3572 - accuracy: 0.8757 - val_loss: 2.9965 - val_accuracy: 0.2595
# Epoch 10/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.3407 - accuracy: 0.8791 - val_loss: 1.7867 - val_accuracy: 0.3690
# Epoch 11/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3341 - accuracy: 0.8948 - val_loss: 3.8531 - val_accuracy: 0.2405
# Epoch 12/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3236 - accuracy: 0.8991 - val_loss: 2.9129 - val_accuracy: 0.3524
# Epoch 13/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2422 - accuracy: 0.9173 - val_loss: 3.0370 - val_accuracy: 0.3384
# Epoch 14/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1609 - accuracy: 0.9491 - val_loss: 4.4806 - val_accuracy: 0.2379
# Epoch 15/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.1725 - accuracy: 0.9394 - val_loss: 1.5280 - val_accuracy: 0.6310
# Epoch 16/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1613 - accuracy: 0.9432 - val_loss: 2.2168 - val_accuracy: 0.5560
# Epoch 17/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1095 - accuracy: 0.9695 - val_loss: 1.4912 - val_accuracy: 0.6209
# Epoch 18/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0929 - accuracy: 0.9716 - val_loss: 0.6652 - val_accuracy: 0.8270
# Epoch 19/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1417 - accuracy: 0.9525 - val_loss: 1.9641 - val_accuracy: 0.5814
# Epoch 20/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1293 - accuracy: 0.9567 - val_loss: 1.5445 - val_accuracy: 0.6489
# Epoch 21/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.1202 - accuracy: 0.9614 - val_loss: 0.4761 - val_accuracy: 0.8562
# Epoch 22/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0729 - accuracy: 0.9758 - val_loss: 0.8599 - val_accuracy: 0.7901
# Epoch 23/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0521 - accuracy: 0.9860 - val_loss: 3.9219 - val_accuracy: 0.3562
# Epoch 24/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0434 - accuracy: 0.9881 - val_loss: 0.8136 - val_accuracy: 0.8015
# Epoch 25/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0322 - accuracy: 0.9902 - val_loss: 1.3417 - val_accuracy: 0.7188
# Epoch 26/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0634 - accuracy: 0.9826 - val_loss: 0.9791 - val_accuracy: 0.7672
# Epoch 27/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0991 - accuracy: 0.9690 - val_loss: 6.6484 - val_accuracy: 0.2608
# Epoch 28/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0593 - accuracy: 0.9826 - val_loss: 1.8737 - val_accuracy: 0.7010
# Epoch 29/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0715 - accuracy: 0.9771 - val_loss: 0.8125 - val_accuracy: 0.8117
# Epoch 30/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0742 - accuracy: 0.9779 - val_loss: 1.6838 - val_accuracy: 0.6489
# Epoch 31/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0599 - accuracy: 0.9792 - val_loss: 3.0269 - val_accuracy: 0.4885
# Epoch 32/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0611 - accuracy: 0.9784 - val_loss: 2.9077 - val_accuracy: 0.5776
# Epoch 33/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0428 - accuracy: 0.9856 - val_loss: 1.4431 - val_accuracy: 0.7023
# Epoch 34/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0469 - accuracy: 0.9860 - val_loss: 0.3853 - val_accuracy: 0.9046
# Epoch 35/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0473 - accuracy: 0.9839 - val_loss: 2.7621 - val_accuracy: 0.6145
# Epoch 36/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0256 - accuracy: 0.9932 - val_loss: 2.9867 - val_accuracy: 0.4962
# Epoch 37/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0397 - accuracy: 0.9873 - val_loss: 0.9191 - val_accuracy: 0.7990
# Epoch 38/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0550 - accuracy: 0.9852 - val_loss: 2.2575 - val_accuracy: 0.5611
# Epoch 39/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0391 - accuracy: 0.9881 - val_loss: 3.7582 - val_accuracy: 0.4936
# Epoch 40/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0510 - accuracy: 0.9813 - val_loss: 0.6134 - val_accuracy: 0.8651
# Epoch 41/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0463 - accuracy: 0.9839 - val_loss: 0.6718 - val_accuracy: 0.8550
# Epoch 42/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0646 - accuracy: 0.9775 - val_loss: 2.1091 - val_accuracy: 0.6132
# Epoch 43/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0856 - accuracy: 0.9699 - val_loss: 2.5973 - val_accuracy: 0.5827
# Epoch 44/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0566 - accuracy: 0.9809 - val_loss: 2.4873 - val_accuracy: 0.6120
# Epoch 45/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0566 - accuracy: 0.9801 - val_loss: 1.9882 - val_accuracy: 0.6756
# Epoch 46/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0403 - accuracy: 0.9881 - val_loss: 0.8050 - val_accuracy: 0.8295
# Epoch 47/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0352 - accuracy: 0.9869 - val_loss: 4.4709 - val_accuracy: 0.4771
# Epoch 48/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0225 - accuracy: 0.9936 - val_loss: 1.9381 - val_accuracy: 0.6310
# Epoch 49/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0476 - accuracy: 0.9869 - val_loss: 146.5908 - val_accuracy: 0.1692
# Epoch 50/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1942 - accuracy: 0.9453 - val_loss: 109.0691 - val_accuracy: 0.1667
# Epoch 51/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1248 - accuracy: 0.9606 - val_loss: 3.4689 - val_accuracy: 0.6170
# Epoch 52/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0532 - accuracy: 0.9830 - val_loss: 1.7302 - val_accuracy: 0.7277
# Epoch 53/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0243 - accuracy: 0.9928 - val_loss: 1.1531 - val_accuracy: 0.7723
# Epoch 54/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.9157 - val_accuracy: 0.8003
# Epoch 55/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.5110 - val_accuracy: 0.8957
# Epoch 56/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.5987 - val_accuracy: 0.8664
# Epoch 57/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0299 - accuracy: 0.9894 - val_loss: 0.7115 - val_accuracy: 0.8295
# Epoch 58/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.6058 - val_accuracy: 0.8601
# Epoch 59/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0320 - accuracy: 0.9885 - val_loss: 3.4415 - val_accuracy: 0.5394
# Epoch 60/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0267 - accuracy: 0.9949 - val_loss: 1.2972 - val_accuracy: 0.7392
# Epoch 61/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0504 - accuracy: 0.9843 - val_loss: 1.0906 - val_accuracy: 0.7850
# Epoch 62/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0810 - accuracy: 0.9746 - val_loss: 2.9502 - val_accuracy: 0.5929
# Epoch 63/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0521 - accuracy: 0.9830 - val_loss: 2.0155 - val_accuracy: 0.6616
# Epoch 64/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9805Restoring model weights from the end of the best epoch: 34.
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0585 - accuracy: 0.9805 - val_loss: 2.0104 - val_accuracy: 0.6870
# Epoch 00064: early stopping
# Maximal validation accuracy: 90.46%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.750957  0.424512  1.973711      0.127226
# 1   1.055838  0.639949  2.814454      0.127226
# 2   0.756949  0.738762  3.270944      0.127226
# 3   0.551481  0.812129  3.671859      0.152672
# 4   0.536563  0.820611  2.594709      0.197201
# ..       ...       ...       ...           ...
# 59  0.026661  0.994911  1.297200      0.739186
# 60  0.050368  0.984309  1.090604      0.784987
# 61  0.080987  0.974555  2.950214      0.592875
# 62  0.052116  0.983036  2.015459      0.661578
# 63  0.058525  0.980492  2.010408      0.687023
#
# [64 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.3852926790714264
# Maximum validation accuracy: 0.9045801758766174

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5152 - accuracy: 0.8906
# test loss, test acc: [0.5151686668395996, 0.8905852437019348]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 11s 167ms/step - loss: 0.6327 - accuracy: 0.7930 - val_loss: 317.8250 - val_accuracy: 0.1527
# Epoch 2/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3654 - accuracy: 0.8728 - val_loss: 775.2245 - val_accuracy: 0.1527
# Epoch 3/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2045 - accuracy: 0.9245 - val_loss: 2937.2031 - val_accuracy: 0.1527
# Epoch 4/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2164 - accuracy: 0.9288 - val_loss: 5.8526 - val_accuracy: 0.1527
# Epoch 5/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1723 - accuracy: 0.9427 - val_loss: 6.5900 - val_accuracy: 0.1527
# Epoch 6/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1385 - accuracy: 0.9559 - val_loss: 7.2582 - val_accuracy: 0.1527
# Epoch 7/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1037 - accuracy: 0.9690 - val_loss: 28.3346 - val_accuracy: 0.1527
# Epoch 8/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0783 - accuracy: 0.9758 - val_loss: 12.2511 - val_accuracy: 0.1527
# Epoch 9/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0668 - accuracy: 0.9809 - val_loss: 4.1812 - val_accuracy: 0.1132
# Epoch 10/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0373 - accuracy: 0.9898 - val_loss: 5.1901 - val_accuracy: 0.1527
# Epoch 11/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0308 - accuracy: 0.9907 - val_loss: 6.2664 - val_accuracy: 0.1527
# Epoch 12/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 6.4917 - val_accuracy: 0.0560
# Epoch 13/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0292 - accuracy: 0.9890 - val_loss: 13.3774 - val_accuracy: 0.1527
# Epoch 14/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0468 - accuracy: 0.9852 - val_loss: 24.4583 - val_accuracy: 0.1527
# Epoch 15/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1190 - accuracy: 0.9640 - val_loss: 15.5587 - val_accuracy: 0.0814
# Epoch 16/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0987 - accuracy: 0.9707 - val_loss: 19.6720 - val_accuracy: 0.1527
# Epoch 17/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1085 - accuracy: 0.9678 - val_loss: 18.4951 - val_accuracy: 0.1527
# Epoch 18/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.1124 - accuracy: 0.9695 - val_loss: 9.4487 - val_accuracy: 0.0941
# Epoch 19/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0775 - accuracy: 0.9737 - val_loss: 5.1777 - val_accuracy: 0.1285
# Epoch 20/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0330 - accuracy: 0.9885 - val_loss: 5.5606 - val_accuracy: 0.1539
# Epoch 21/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 4.6510 - val_accuracy: 0.1628
# Epoch 22/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0136 - accuracy: 0.9941 - val_loss: 6.6986 - val_accuracy: 0.1692
# Epoch 23/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0250 - accuracy: 0.9907 - val_loss: 3.9674 - val_accuracy: 0.2481
# Epoch 24/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0256 - accuracy: 0.9941 - val_loss: 4.9060 - val_accuracy: 0.1959
# Epoch 25/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0165 - accuracy: 0.9958 - val_loss: 4.5187 - val_accuracy: 0.2570
# Epoch 26/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 4.2703 - val_accuracy: 0.3435
# Epoch 27/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 1.1042 - val_accuracy: 0.7112
# Epoch 28/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.8957 - val_accuracy: 0.7926
# Epoch 29/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 2.1139 - val_accuracy: 0.5725
# Epoch 30/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0390 - accuracy: 0.9890 - val_loss: 1.1832 - val_accuracy: 0.7532
# Epoch 31/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0291 - accuracy: 0.9928 - val_loss: 0.7863 - val_accuracy: 0.8359
# Epoch 32/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0330 - accuracy: 0.9864 - val_loss: 1.0910 - val_accuracy: 0.8308
# Epoch 33/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0329 - accuracy: 0.9894 - val_loss: 0.8492 - val_accuracy: 0.7990
# Epoch 34/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0164 - accuracy: 0.9962 - val_loss: 0.6374 - val_accuracy: 0.8842
# Epoch 35/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0228 - accuracy: 0.9928 - val_loss: 2.0731 - val_accuracy: 0.7303
# Epoch 36/100
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0347 - accuracy: 0.9902 - val_loss: 0.7710 - val_accuracy: 0.8855
# Epoch 37/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0405 - accuracy: 0.9881 - val_loss: 0.7508 - val_accuracy: 0.8333
# Epoch 38/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0302 - accuracy: 0.9915 - val_loss: 2.4074 - val_accuracy: 0.6832
# Epoch 39/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0273 - accuracy: 0.9911 - val_loss: 1.0778 - val_accuracy: 0.7939
# Epoch 40/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0198 - accuracy: 0.9945 - val_loss: 0.1520 - val_accuracy: 0.9491
# Epoch 41/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0146 - accuracy: 0.9962 - val_loss: 0.5057 - val_accuracy: 0.8919
# Epoch 42/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.2661 - val_accuracy: 0.9262
# Epoch 43/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.3227 - val_accuracy: 0.9211
# Epoch 44/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1680 - val_accuracy: 0.9580
# Epoch 45/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 1.0886 - val_accuracy: 0.8066
# Epoch 46/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0152 - accuracy: 0.9941 - val_loss: 1.0689 - val_accuracy: 0.7850
# Epoch 47/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0390 - accuracy: 0.9890 - val_loss: 2.2526 - val_accuracy: 0.6247
# Epoch 48/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 2.7155 - val_accuracy: 0.7010
# Epoch 49/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.3045 - val_accuracy: 0.9173
# Epoch 50/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.1565 - val_accuracy: 0.9567
# Epoch 51/100
# 37/37 [==============================] - 5s 140ms/step - loss: 7.9307e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9669
# Epoch 52/100
# 37/37 [==============================] - 5s 140ms/step - loss: 4.5394e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9720
# Epoch 53/100
# 37/37 [==============================] - 5s 137ms/step - loss: 4.6403e-04 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9720
# Epoch 54/100
# 37/37 [==============================] - 5s 140ms/step - loss: 3.3397e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9758
# Epoch 55/100
# 37/37 [==============================] - 5s 140ms/step - loss: 1.0188e-04 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9796
# Epoch 56/100
# 37/37 [==============================] - 5s 139ms/step - loss: 1.2337e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9822
# Epoch 57/100
# 37/37 [==============================] - 5s 136ms/step - loss: 4.3946e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9784
# Epoch 58/100
# 37/37 [==============================] - 5s 136ms/step - loss: 3.9824e-04 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9746
# Epoch 59/100
# 37/37 [==============================] - 5s 136ms/step - loss: 1.7360e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9746
# Epoch 60/100
# 37/37 [==============================] - 5s 136ms/step - loss: 6.4479e-05 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9758
# Epoch 61/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.3776 - val_accuracy: 0.9109
# Epoch 62/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0033 - accuracy: 0.9983 - val_loss: 0.1888 - val_accuracy: 0.9466
# Epoch 63/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0114 - accuracy: 0.9945 - val_loss: 2.0963 - val_accuracy: 0.6858
# Epoch 64/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0850 - accuracy: 0.9779 - val_loss: 1.9075 - val_accuracy: 0.7023
# Epoch 65/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0846 - accuracy: 0.9741 - val_loss: 10.5520 - val_accuracy: 0.3613
# Epoch 66/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 3.0904 - val_accuracy: 0.6387
# Epoch 67/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.7690 - val_accuracy: 0.8346
# Epoch 68/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.7384 - val_accuracy: 0.8410
# Epoch 69/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 1.1055 - val_accuracy: 0.8053
# Epoch 70/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 0.7878 - val_accuracy: 0.8588
# Epoch 71/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0199 - accuracy: 0.9953 - val_loss: 0.3283 - val_accuracy: 0.9275
# Epoch 72/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 1.2274 - val_accuracy: 0.8155
# Epoch 73/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.4396 - val_accuracy: 0.9059
# Epoch 74/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.7743 - val_accuracy: 0.8397
# Epoch 75/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 2.0853 - val_accuracy: 0.7150
# Epoch 76/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9826Restoring model weights from the end of the best epoch: 56.
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0736 - accuracy: 0.9826 - val_loss: 4.3917 - val_accuracy: 0.5000
# Epoch 00076: early stopping
# Maximal validation accuracy: 98.22%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy     val_loss  val_accuracy
# 0   0.632696  0.793045   317.824982      0.152672
# 1   0.365425  0.872774   775.224548      0.152672
# 2   0.204492  0.924512  2937.203125      0.152672
# 3   0.216448  0.928753     5.852614      0.152672
# 4   0.172303  0.942748     6.589989      0.152672
# ..       ...       ...          ...           ...
# 71  0.019027  0.994063     1.227376      0.815522
# 72  0.005489  0.997880     0.439636      0.905852
# 73  0.010259  0.995759     0.774299      0.839695
# 74  0.017531  0.994487     2.085313      0.715013
# 75  0.073635  0.982612     4.391661      0.500000
#
# [76 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.07294382899999619
# Maximum validation accuracy: 0.9821882843971252

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 27ms/step - loss: 0.1468 - accuracy: 0.9580
# test loss, test acc: [0.1468484252691269, 0.9580152630805969]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 1s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_ResNet50_None
# test loss, test acc: [0.9877968430519104, 0.7944572567939758]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_ResNet50_imagenet
# test loss, test acc: [857.012939453125, 0.27713626623153687]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_ResNet50_None
# test loss, test acc: [0.5151686668395996, 0.8905852437019348]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_ResNet50_imagenet
# test loss, test acc: [0.1468484252691269, 0.9580152630805969]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_ResNet50_None →→→ Target Test
# 25/25 [==============================] - 1s 26ms/step - loss: 5.7460 - accuracy: 0.2137
# test loss, test acc: [5.746048927307129, 0.21374045312404633]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_ResNet50_imagenet →→→ Target Test
# 25/25 [==============================] - 1s 26ms/step - loss: 844.3282 - accuracy: 0.3053
# test loss, test acc: [844.3282470703125, 0.30534350872039795]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_ResNet50_None →→→ Source Test
# 28/28 [==============================] - 1s 26ms/step - loss: 5.5446 - accuracy: 0.1570
# test loss, test acc: [5.544619560241699, 0.15704387426376343]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_ResNet50_imagenet →→→ Source Test
# 28/28 [==============================] - 1s 26ms/step - loss: 6.7990 - accuracy: 0.1975
# test loss, test acc: [6.798989772796631, 0.19745957851409912]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
