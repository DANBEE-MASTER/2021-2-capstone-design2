# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9715625597555439982
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3156449470135017290
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 18:52:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    33W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'DenseNet121'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_DenseNet121_None S_DenseNet121_imagenet T_DenseNet121_None T_DenseNet121_imagenet
# ['S_DenseNet121_imagenet',
#  'S_DenseNet121_None',
#  'T_DenseNet121_imagenet',
#  'T_DenseNet121_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)
#
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)
#
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 28s 228ms/step - loss: 1.1255 - accuracy: 0.5916 - val_loss: 2.0242 - val_accuracy: 0.1328
# Epoch 2/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.7603 - accuracy: 0.7290 - val_loss: 2.8554 - val_accuracy: 0.2044
# Epoch 3/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.6605 - accuracy: 0.7594 - val_loss: 8.1201 - val_accuracy: 0.1155
# Epoch 4/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.5763 - accuracy: 0.7895 - val_loss: 7.0200 - val_accuracy: 0.1305
# Epoch 5/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.5280 - accuracy: 0.8037 - val_loss: 3.6571 - val_accuracy: 0.2714
# Epoch 6/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.4636 - accuracy: 0.8287 - val_loss: 4.3542 - val_accuracy: 0.1790
# Epoch 7/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.4281 - accuracy: 0.8433 - val_loss: 3.2201 - val_accuracy: 0.3453
# Epoch 8/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.4118 - accuracy: 0.8499 - val_loss: 3.8837 - val_accuracy: 0.2702
# Epoch 9/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.3844 - accuracy: 0.8580 - val_loss: 3.5704 - val_accuracy: 0.2737
# Epoch 10/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.3264 - accuracy: 0.8772 - val_loss: 3.2284 - val_accuracy: 0.3626
# Epoch 11/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.3212 - accuracy: 0.8795 - val_loss: 2.0154 - val_accuracy: 0.4677
# Epoch 12/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2948 - accuracy: 0.8795 - val_loss: 4.1397 - val_accuracy: 0.2564
# Epoch 13/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2986 - accuracy: 0.8811 - val_loss: 4.5503 - val_accuracy: 0.2529
# Epoch 14/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.2957 - accuracy: 0.8834 - val_loss: 3.0518 - val_accuracy: 0.4527
# Epoch 15/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.2376 - accuracy: 0.9103 - val_loss: 1.6640 - val_accuracy: 0.6420
# Epoch 16/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2073 - accuracy: 0.9161 - val_loss: 4.8414 - val_accuracy: 0.3256
# Epoch 17/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2249 - accuracy: 0.9084 - val_loss: 1.8275 - val_accuracy: 0.5289
# Epoch 18/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.1909 - accuracy: 0.9261 - val_loss: 1.4093 - val_accuracy: 0.6536
# Epoch 19/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.2397 - accuracy: 0.9084 - val_loss: 2.9988 - val_accuracy: 0.5196
# Epoch 20/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.1767 - accuracy: 0.9346 - val_loss: 1.4399 - val_accuracy: 0.6801
# Epoch 21/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.1636 - accuracy: 0.9330 - val_loss: 1.1858 - val_accuracy: 0.6928
# Epoch 22/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1206 - accuracy: 0.9542 - val_loss: 2.6549 - val_accuracy: 0.5843
# Epoch 23/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1705 - accuracy: 0.9365 - val_loss: 2.7722 - val_accuracy: 0.5289
# Epoch 24/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1267 - accuracy: 0.9519 - val_loss: 2.5849 - val_accuracy: 0.5808
# Epoch 25/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1932 - accuracy: 0.9265 - val_loss: 2.5673 - val_accuracy: 0.5416
# Epoch 26/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.2010 - accuracy: 0.9273 - val_loss: 2.5527 - val_accuracy: 0.5346
# Epoch 27/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1872 - accuracy: 0.9357 - val_loss: 4.6834 - val_accuracy: 0.4007
# Epoch 28/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1216 - accuracy: 0.9569 - val_loss: 1.6212 - val_accuracy: 0.5912
# Epoch 29/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0896 - accuracy: 0.9654 - val_loss: 1.4067 - val_accuracy: 0.6801
# Epoch 30/100
# 41/41 [==============================] - 6s 147ms/step - loss: 0.1034 - accuracy: 0.9650 - val_loss: 2.8185 - val_accuracy: 0.5104
# Epoch 31/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0755 - accuracy: 0.9673 - val_loss: 1.7426 - val_accuracy: 0.7009
# Epoch 32/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0722 - accuracy: 0.9765 - val_loss: 0.8058 - val_accuracy: 0.7898
# Epoch 33/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0706 - accuracy: 0.9696 - val_loss: 1.3483 - val_accuracy: 0.6894
# Epoch 34/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0704 - accuracy: 0.9731 - val_loss: 2.0800 - val_accuracy: 0.6085
# Epoch 35/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0692 - accuracy: 0.9765 - val_loss: 0.8422 - val_accuracy: 0.8002
# Epoch 36/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1040 - accuracy: 0.9634 - val_loss: 1.1326 - val_accuracy: 0.7229
# Epoch 37/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0890 - accuracy: 0.9673 - val_loss: 1.4916 - val_accuracy: 0.6882
# Epoch 38/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1030 - accuracy: 0.9615 - val_loss: 4.0888 - val_accuracy: 0.3684
# Epoch 39/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0687 - accuracy: 0.9750 - val_loss: 1.0581 - val_accuracy: 0.7702
# Epoch 40/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0504 - accuracy: 0.9823 - val_loss: 1.0037 - val_accuracy: 0.8314
# Epoch 41/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0563 - accuracy: 0.9792 - val_loss: 1.0370 - val_accuracy: 0.7910
# Epoch 42/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0359 - accuracy: 0.9885 - val_loss: 0.9152 - val_accuracy: 0.7991
# Epoch 43/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0442 - accuracy: 0.9854 - val_loss: 2.5242 - val_accuracy: 0.5450
# Epoch 44/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.1007 - accuracy: 0.9681 - val_loss: 1.3147 - val_accuracy: 0.7471
# Epoch 45/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0613 - accuracy: 0.9831 - val_loss: 0.8924 - val_accuracy: 0.7771
# Epoch 46/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0291 - accuracy: 0.9904 - val_loss: 1.2331 - val_accuracy: 0.7148
# Epoch 47/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 1.0785 - val_accuracy: 0.7621
# Epoch 48/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0759 - accuracy: 0.9734 - val_loss: 3.9200 - val_accuracy: 0.5485
# Epoch 49/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0755 - accuracy: 0.9746 - val_loss: 1.5749 - val_accuracy: 0.6917
# Epoch 50/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0622 - accuracy: 0.9777 - val_loss: 1.3955 - val_accuracy: 0.7113
# Epoch 51/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0510 - accuracy: 0.9796 - val_loss: 2.4161 - val_accuracy: 0.6732
# Epoch 52/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0640 - accuracy: 0.9784 - val_loss: 1.1028 - val_accuracy: 0.7806
# Epoch 53/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0731 - accuracy: 0.9765 - val_loss: 2.6712 - val_accuracy: 0.5589
# Epoch 54/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0624 - accuracy: 0.9761 - val_loss: 2.3045 - val_accuracy: 0.6940
# Epoch 55/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 1.5115 - val_accuracy: 0.6940
# Epoch 56/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0347 - accuracy: 0.9900 - val_loss: 0.9598 - val_accuracy: 0.7933
# Epoch 57/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 1.4853 - val_accuracy: 0.7263
# Epoch 58/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0355 - accuracy: 0.9865 - val_loss: 2.2439 - val_accuracy: 0.6386
# Epoch 59/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 2.0444 - val_accuracy: 0.6559
# Epoch 60/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0506 - accuracy: 0.9800 - val_loss: 0.5339 - val_accuracy: 0.8707
# Epoch 61/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0354 - accuracy: 0.9877 - val_loss: 1.4631 - val_accuracy: 0.7517
# Epoch 62/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 0.8464 - val_accuracy: 0.8072
# Epoch 63/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0172 - accuracy: 0.9962 - val_loss: 2.1446 - val_accuracy: 0.6767
# Epoch 64/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0247 - accuracy: 0.9908 - val_loss: 0.9029 - val_accuracy: 0.7829
# Epoch 65/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0199 - accuracy: 0.9927 - val_loss: 1.0774 - val_accuracy: 0.7725
# Epoch 66/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 1.2462 - val_accuracy: 0.7436
# Epoch 67/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0290 - accuracy: 0.9904 - val_loss: 2.4367 - val_accuracy: 0.5878
# Epoch 68/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0472 - accuracy: 0.9846 - val_loss: 2.3019 - val_accuracy: 0.6201
# Epoch 69/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 1.5529 - val_accuracy: 0.7448
# Epoch 70/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0686 - accuracy: 0.9765 - val_loss: 1.5023 - val_accuracy: 0.7229
# Epoch 71/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0561 - accuracy: 0.9819 - val_loss: 2.2830 - val_accuracy: 0.6016
# Epoch 72/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0403 - accuracy: 0.9900 - val_loss: 2.0013 - val_accuracy: 0.6328
# Epoch 73/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.4739 - val_accuracy: 0.8949
# Epoch 74/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.8406 - val_accuracy: 0.8349
# Epoch 75/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.5922 - val_accuracy: 0.8799
# Epoch 76/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 2.3621 - val_accuracy: 0.6651
# Epoch 77/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0247 - accuracy: 0.9915 - val_loss: 5.4467 - val_accuracy: 0.4411
# Epoch 78/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0533 - accuracy: 0.9831 - val_loss: 5.0960 - val_accuracy: 0.4700
# Epoch 79/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0322 - accuracy: 0.9873 - val_loss: 2.8418 - val_accuracy: 0.6409
# Epoch 80/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0527 - accuracy: 0.9823 - val_loss: 4.0764 - val_accuracy: 0.5624
# Epoch 81/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0770 - accuracy: 0.9734 - val_loss: 2.7509 - val_accuracy: 0.6120
# Epoch 82/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0534 - accuracy: 0.9842 - val_loss: 2.8255 - val_accuracy: 0.6143
# Epoch 83/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 1.1359 - val_accuracy: 0.7702
# Epoch 84/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.9811 - val_accuracy: 0.7991
# Epoch 85/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.6299 - val_accuracy: 0.8707
# Epoch 86/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.5216 - val_accuracy: 0.8984
# Epoch 87/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.8000 - val_accuracy: 0.8476
# Epoch 88/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0066 - accuracy: 0.9969 - val_loss: 1.3476 - val_accuracy: 0.7656
# Epoch 89/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 1.4554 - val_accuracy: 0.7610
# Epoch 90/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0263 - accuracy: 0.9915 - val_loss: 0.8978 - val_accuracy: 0.8360
# Epoch 91/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0207 - accuracy: 0.9919 - val_loss: 1.8521 - val_accuracy: 0.6975
# Epoch 92/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0554 - accuracy: 0.9796 - val_loss: 1.3669 - val_accuracy: 0.8002
# Epoch 93/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0462 - accuracy: 0.9888 - val_loss: 1.1720 - val_accuracy: 0.7852
# Epoch 94/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.6006 - val_accuracy: 0.8707
# Epoch 95/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0310 - accuracy: 0.9881 - val_loss: 2.8403 - val_accuracy: 0.5497
# Epoch 96/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0203 - accuracy: 0.9938 - val_loss: 1.9655 - val_accuracy: 0.6975
# Epoch 97/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0340 - accuracy: 0.9908 - val_loss: 3.4414 - val_accuracy: 0.5497
# Epoch 98/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 1.6064 - val_accuracy: 0.7217
# Epoch 99/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 2.4594 - val_accuracy: 0.6166
# Epoch 100/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0281 - accuracy: 0.9900 - val_loss: 2.6502 - val_accuracy: 0.6212
# Maximal validation accuracy: 89.84%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.125540  0.591609  2.024155      0.132794
# 1   0.760332  0.729022  2.855359      0.204388
# 2   0.660458  0.759430  8.120054      0.115473
# 3   0.576325  0.789453  7.020037      0.130485
# 4   0.527974  0.803695  3.657122      0.271363
# ..       ...       ...       ...           ...
# 95  0.020270  0.993841  1.965497      0.697460
# 96  0.033963  0.990762  3.441414      0.549654
# 97  0.014189  0.995381  1.606390      0.721709
# 98  0.011566  0.995766  2.459378      0.616628
# 99  0.028117  0.989992  2.650177      0.621247
#
# [100 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.47394347190856934
# Maximum validation accuracy: 0.898383378982544

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 36ms/step - loss: 3.0992 - accuracy: 0.6120
# test loss, test acc: [3.0992157459259033, 0.6120092272758484]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 18s 197ms/step - loss: 0.6137 - accuracy: 0.7844 - val_loss: 23.9784 - val_accuracy: 0.0935
# Epoch 2/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.2304 - accuracy: 0.9099 - val_loss: 6.3661 - val_accuracy: 0.2217
# Epoch 3/100
# 41/41 [==============================] - 6s 151ms/step - loss: 0.2178 - accuracy: 0.9211 - val_loss: 2.4935 - val_accuracy: 0.5104
# Epoch 4/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.1474 - accuracy: 0.9503 - val_loss: 5.3715 - val_accuracy: 0.5312
# Epoch 5/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.1019 - accuracy: 0.9638 - val_loss: 1.5665 - val_accuracy: 0.7517
# Epoch 6/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0878 - accuracy: 0.9688 - val_loss: 3.8650 - val_accuracy: 0.6755
# Epoch 7/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.1039 - accuracy: 0.9646 - val_loss: 0.7218 - val_accuracy: 0.8187
# Epoch 8/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0732 - accuracy: 0.9742 - val_loss: 1.0093 - val_accuracy: 0.7506
# Epoch 9/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0849 - accuracy: 0.9754 - val_loss: 0.9375 - val_accuracy: 0.8152
# Epoch 10/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.1055 - accuracy: 0.9665 - val_loss: 1.7403 - val_accuracy: 0.7494
# Epoch 11/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.1017 - accuracy: 0.9673 - val_loss: 2.5518 - val_accuracy: 0.6363
# Epoch 12/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0643 - accuracy: 0.9815 - val_loss: 0.3067 - val_accuracy: 0.9203
# Epoch 13/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0371 - accuracy: 0.9892 - val_loss: 0.6058 - val_accuracy: 0.8811
# Epoch 14/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.7527 - val_accuracy: 0.8441
# Epoch 15/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0290 - accuracy: 0.9896 - val_loss: 1.2450 - val_accuracy: 0.8037
# Epoch 16/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1024 - accuracy: 0.9696 - val_loss: 1.4881 - val_accuracy: 0.7298
# Epoch 17/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.5331 - val_accuracy: 0.8764
# Epoch 18/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0491 - accuracy: 0.9838 - val_loss: 1.1424 - val_accuracy: 0.8337
# Epoch 19/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0864 - accuracy: 0.9731 - val_loss: 3.2807 - val_accuracy: 0.6397
# Epoch 20/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0513 - accuracy: 0.9823 - val_loss: 0.7214 - val_accuracy: 0.8222
# Epoch 21/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.3787 - val_accuracy: 0.9088
# Epoch 22/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 1.0581 - val_accuracy: 0.7979
# Epoch 23/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.4447 - val_accuracy: 0.8799
# Epoch 24/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.4152 - val_accuracy: 0.8961
# Epoch 25/100
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.2800 - val_accuracy: 0.9457
# Epoch 26/100
# 41/41 [==============================] - 6s 150ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.2590 - val_accuracy: 0.9400
# Epoch 27/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.2371 - val_accuracy: 0.9446
# Epoch 28/100
# 41/41 [==============================] - 6s 153ms/step - loss: 6.9395e-04 - accuracy: 1.0000 - val_loss: 0.2378 - val_accuracy: 0.9469
# Epoch 29/100
# 41/41 [==============================] - 6s 152ms/step - loss: 3.6403e-04 - accuracy: 1.0000 - val_loss: 0.2388 - val_accuracy: 0.9538
# Epoch 30/100
# 41/41 [==============================] - 6s 152ms/step - loss: 3.1899e-04 - accuracy: 1.0000 - val_loss: 0.2364 - val_accuracy: 0.9573
# Epoch 31/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.9273e-04 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9573
# Epoch 32/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.8170e-04 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9561
# Epoch 33/100
# 41/41 [==============================] - 6s 152ms/step - loss: 2.5215e-04 - accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.9584
# Epoch 34/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.9040e-04 - accuracy: 1.0000 - val_loss: 0.2401 - val_accuracy: 0.9561
# Epoch 35/100
# 41/41 [==============================] - 6s 148ms/step - loss: 2.3705e-04 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9550
# Epoch 36/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.2534e-04 - accuracy: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9561
# Epoch 37/100
# 41/41 [==============================] - 6s 148ms/step - loss: 1.0949e-04 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9550
# Epoch 38/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.1997e-04 - accuracy: 1.0000 - val_loss: 0.2425 - val_accuracy: 0.9527
# Epoch 39/100
# 41/41 [==============================] - 6s 148ms/step - loss: 4.7482e-05 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9538
# Epoch 40/100
# 41/41 [==============================] - 6s 148ms/step - loss: 6.2615e-05 - accuracy: 1.0000 - val_loss: 0.2409 - val_accuracy: 0.9538
# Epoch 41/100
# 41/41 [==============================] - 6s 149ms/step - loss: 5.1261e-05 - accuracy: 1.0000 - val_loss: 0.2418 - val_accuracy: 0.9527
# Epoch 42/100
# 41/41 [==============================] - 6s 148ms/step - loss: 6.3663e-05 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9561
# Epoch 43/100
# 41/41 [==============================] - 6s 148ms/step - loss: 4.5704e-05 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9561
# Epoch 44/100
# 41/41 [==============================] - 6s 149ms/step - loss: 6.3403e-05 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9573
# Epoch 45/100
# 41/41 [==============================] - 6s 148ms/step - loss: 5.6915e-05 - accuracy: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9550
# Epoch 46/100
# 41/41 [==============================] - 6s 148ms/step - loss: 3.4973e-05 - accuracy: 1.0000 - val_loss: 0.2427 - val_accuracy: 0.9550
# Epoch 47/100
# 41/41 [==============================] - 6s 152ms/step - loss: 4.0344e-05 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9607
# Epoch 48/100
# 41/41 [==============================] - 6s 149ms/step - loss: 4.0644e-05 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9573
# Epoch 49/100
# 41/41 [==============================] - 6s 148ms/step - loss: 3.2455e-05 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9550
# Epoch 50/100
# 41/41 [==============================] - 6s 149ms/step - loss: 3.8111e-05 - accuracy: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9573
# Epoch 51/100
# 41/41 [==============================] - 6s 148ms/step - loss: 5.7555e-05 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9561
# Epoch 52/100
# 41/41 [==============================] - 6s 149ms/step - loss: 4.3039e-05 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9550
# Epoch 53/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.3565e-05 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9561
# Epoch 54/100
# 41/41 [==============================] - 6s 149ms/step - loss: 3.3264e-05 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9550
# Epoch 55/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.0842e-05 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9550
# Epoch 56/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.0736e-05 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9573
# Epoch 57/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.6342e-05 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9573
# Epoch 58/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.1384e-05 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9561
# Epoch 59/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.2040e-05 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9561
# Epoch 60/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.9963e-05 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9550
# Epoch 61/100
# 41/41 [==============================] - 6s 148ms/step - loss: 2.6834e-05 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9573
# Epoch 62/100
# 41/41 [==============================] - 6s 151ms/step - loss: 4.5164e-05 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9619
# Epoch 63/100
# 41/41 [==============================] - 6s 149ms/step - loss: 2.5648e-05 - accuracy: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9619
# Epoch 64/100
# 41/41 [==============================] - 6s 149ms/step - loss: 1.2690e-05 - accuracy: 1.0000 - val_loss: 0.2524 - val_accuracy: 0.9619
# Epoch 65/100
# 41/41 [==============================] - 6s 148ms/step - loss: 2.3980e-05 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9619
# Epoch 66/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.6834 - val_accuracy: 0.8926
# Epoch 67/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.4151 - accuracy: 0.8818 - val_loss: 179.4720 - val_accuracy: 0.1848
# Epoch 68/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.4114 - accuracy: 0.8553 - val_loss: 26.3414 - val_accuracy: 0.2552
# Epoch 69/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.2110 - accuracy: 0.9169 - val_loss: 2.6414 - val_accuracy: 0.6605
# Epoch 70/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.1872 - accuracy: 0.9323 - val_loss: 30.1457 - val_accuracy: 0.3441
# Epoch 71/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.1038 - accuracy: 0.9638 - val_loss: 1.5029 - val_accuracy: 0.7413
# Epoch 72/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0488 - accuracy: 0.9827 - val_loss: 1.2222 - val_accuracy: 0.8118
# Epoch 73/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0869 - accuracy: 0.9684 - val_loss: 1.2020 - val_accuracy: 0.7436
# Epoch 74/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0720 - accuracy: 0.9742 - val_loss: 0.6501 - val_accuracy: 0.8395
# Epoch 75/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0393 - accuracy: 0.9881 - val_loss: 0.8522 - val_accuracy: 0.8037
# Epoch 76/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0253 - accuracy: 0.9927 - val_loss: 0.3914 - val_accuracy: 0.8995
# Epoch 77/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.8603 - val_accuracy: 0.8199
# Epoch 78/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0109 - accuracy: 0.9973 - val_loss: 0.4086 - val_accuracy: 0.8915
# Epoch 79/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.5927 - val_accuracy: 0.8661
# Epoch 80/100
# 41/41 [==============================] - 6s 148ms/step - loss: 0.0310 - accuracy: 0.9911 - val_loss: 0.5459 - val_accuracy: 0.8730
# Epoch 81/100
# 41/41 [==============================] - 6s 149ms/step - loss: 0.0302 - accuracy: 0.9923 - val_loss: 0.3467 - val_accuracy: 0.9169
# Epoch 82/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9911Restoring model weights from the end of the best epoch: 62.
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.3639 - val_accuracy: 0.9203
# Epoch 00082: early stopping
# Maximal validation accuracy: 96.19%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   0.613723  0.784450  23.978388      0.093533
# 1   0.230399  0.909931   6.366113      0.221709
# 2   0.217807  0.921093   2.493459      0.510393
# 3   0.147420  0.950346   5.371480      0.531178
# 4   0.101917  0.963818   1.566493      0.751732
# ..       ...       ...        ...           ...
# 77  0.010934  0.997306   0.408603      0.891455
# 78  0.030911  0.990762   0.592663      0.866051
# 79  0.030980  0.991147   0.545881      0.872979
# 80  0.030151  0.992302   0.346701      0.916859
# 81  0.028658  0.991147   0.363925      0.920323
#
# [82 rows x 4 columns]

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.23394976556301117
# Maximum validation accuracy: 0.9618937373161316

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 27ms/step - loss: 0.3013 - accuracy: 0.9457
# test loss, test acc: [0.30134546756744385, 0.9457274675369263]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 28/28 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 18s 235ms/step - loss: 1.0448 - accuracy: 0.6285 - val_loss: 2.1581 - val_accuracy: 0.1272
# Epoch 2/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.6159 - accuracy: 0.7867 - val_loss: 3.6276 - val_accuracy: 0.1527
# Epoch 3/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4912 - accuracy: 0.8363 - val_loss: 6.6182 - val_accuracy: 0.1527
# Epoch 4/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3706 - accuracy: 0.8668 - val_loss: 3.6535 - val_accuracy: 0.1132
# Epoch 5/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.3748 - accuracy: 0.8664 - val_loss: 9.3997 - val_accuracy: 0.0560
# Epoch 6/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3700 - accuracy: 0.8745 - val_loss: 4.2983 - val_accuracy: 0.0573
# Epoch 7/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3054 - accuracy: 0.8961 - val_loss: 4.1751 - val_accuracy: 0.1387
# Epoch 8/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.2788 - accuracy: 0.9016 - val_loss: 3.7733 - val_accuracy: 0.1565
# Epoch 9/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2514 - accuracy: 0.9075 - val_loss: 8.0780 - val_accuracy: 0.1489
# Epoch 10/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2291 - accuracy: 0.9224 - val_loss: 6.8127 - val_accuracy: 0.1018
# Epoch 11/100
# 37/37 [==============================] - 6s 154ms/step - loss: 0.1794 - accuracy: 0.9381 - val_loss: 3.2031 - val_accuracy: 0.2939
# Epoch 12/100
# 37/37 [==============================] - 6s 154ms/step - loss: 0.1857 - accuracy: 0.9288 - val_loss: 2.4419 - val_accuracy: 0.4733
# Epoch 13/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1734 - accuracy: 0.9368 - val_loss: 5.7442 - val_accuracy: 0.1705
# Epoch 14/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.1893 - accuracy: 0.9385 - val_loss: 2.0201 - val_accuracy: 0.5611
# Epoch 15/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.1128 - accuracy: 0.9584 - val_loss: 1.0465 - val_accuracy: 0.7723
# Epoch 16/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1185 - accuracy: 0.9601 - val_loss: 1.8510 - val_accuracy: 0.6005
# Epoch 17/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1015 - accuracy: 0.9652 - val_loss: 6.4857 - val_accuracy: 0.2761
# Epoch 18/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1113 - accuracy: 0.9572 - val_loss: 1.2862 - val_accuracy: 0.7112
# Epoch 19/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1089 - accuracy: 0.9623 - val_loss: 1.0514 - val_accuracy: 0.7455
# Epoch 20/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.1239 - accuracy: 0.9546 - val_loss: 1.1542 - val_accuracy: 0.7506
# Epoch 21/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1126 - accuracy: 0.9593 - val_loss: 4.3806 - val_accuracy: 0.3486
# Epoch 22/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.1088 - accuracy: 0.9640 - val_loss: 3.0265 - val_accuracy: 0.4466
# Epoch 23/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0917 - accuracy: 0.9703 - val_loss: 1.9003 - val_accuracy: 0.6043
# Epoch 24/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0802 - accuracy: 0.9707 - val_loss: 3.8071 - val_accuracy: 0.4338
# Epoch 25/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0686 - accuracy: 0.9754 - val_loss: 1.0339 - val_accuracy: 0.7621
# Epoch 26/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 1.7155 - val_accuracy: 0.6845
# Epoch 27/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1055 - accuracy: 0.9673 - val_loss: 2.9544 - val_accuracy: 0.4695
# Epoch 28/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0493 - accuracy: 0.9830 - val_loss: 2.6690 - val_accuracy: 0.5191
# Epoch 29/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.3723 - val_accuracy: 0.8944
# Epoch 30/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0335 - accuracy: 0.9885 - val_loss: 11.0440 - val_accuracy: 0.2443
# Epoch 31/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.1095 - accuracy: 0.9678 - val_loss: 1.4179 - val_accuracy: 0.7036
# Epoch 32/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0778 - accuracy: 0.9784 - val_loss: 3.0831 - val_accuracy: 0.5496
# Epoch 33/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0524 - accuracy: 0.9826 - val_loss: 1.2882 - val_accuracy: 0.7137
# Epoch 34/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0331 - accuracy: 0.9911 - val_loss: 1.2716 - val_accuracy: 0.7150
# Epoch 35/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0152 - accuracy: 0.9941 - val_loss: 0.7579 - val_accuracy: 0.8486
# Epoch 36/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0252 - accuracy: 0.9911 - val_loss: 1.0048 - val_accuracy: 0.7570
# Epoch 37/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0328 - accuracy: 0.9907 - val_loss: 2.7036 - val_accuracy: 0.6081
# Epoch 38/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0789 - accuracy: 0.9733 - val_loss: 1.1348 - val_accuracy: 0.7506
# Epoch 39/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0768 - accuracy: 0.9737 - val_loss: 2.0566 - val_accuracy: 0.6603
# Epoch 40/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0644 - accuracy: 0.9792 - val_loss: 1.6351 - val_accuracy: 0.7494
# Epoch 41/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0284 - accuracy: 0.9928 - val_loss: 1.0007 - val_accuracy: 0.7672
# Epoch 42/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.8075 - val_accuracy: 0.8117
# Epoch 43/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0216 - accuracy: 0.9928 - val_loss: 0.5156 - val_accuracy: 0.8830
# Epoch 44/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 1.1453 - val_accuracy: 0.7748
# Epoch 45/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0156 - accuracy: 0.9962 - val_loss: 0.8791 - val_accuracy: 0.7977
# Epoch 46/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0552 - accuracy: 0.9822 - val_loss: 2.5979 - val_accuracy: 0.5840
# Epoch 47/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0494 - accuracy: 0.9843 - val_loss: 2.7261 - val_accuracy: 0.5509
# Epoch 48/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0452 - accuracy: 0.9843 - val_loss: 4.2172 - val_accuracy: 0.5700
# Epoch 49/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0371 - accuracy: 0.9873 - val_loss: 1.5663 - val_accuracy: 0.7226
# Epoch 50/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0339 - accuracy: 0.9915 - val_loss: 0.8650 - val_accuracy: 0.7875
# Epoch 51/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0497 - accuracy: 0.9856 - val_loss: 1.6225 - val_accuracy: 0.6934
# Epoch 52/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0460 - accuracy: 0.9852 - val_loss: 1.8536 - val_accuracy: 0.6387
# Epoch 53/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0258 - accuracy: 0.9928 - val_loss: 0.9607 - val_accuracy: 0.8066
# Epoch 54/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 4.2445 - val_accuracy: 0.5178
# Epoch 55/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0289 - accuracy: 0.9911 - val_loss: 7.4544 - val_accuracy: 0.2494
# Epoch 56/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0389 - accuracy: 0.9873 - val_loss: 3.1773 - val_accuracy: 0.5153
# Epoch 57/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0649 - accuracy: 0.9771 - val_loss: 3.6131 - val_accuracy: 0.4809
# Epoch 58/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0414 - accuracy: 0.9860 - val_loss: 2.6051 - val_accuracy: 0.6043
# Epoch 59/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9894Restoring model weights from the end of the best epoch: 29.
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 1.4336 - val_accuracy: 0.7608
# Epoch 00059: early stopping
# Maximal validation accuracy: 89.44%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy   val_loss  val_accuracy
# 0   1.044818  0.628499   2.158104      0.127226
# 1   0.615903  0.786684   3.627562      0.152672
# 2   0.491222  0.836302   6.618205      0.152672
# 3   0.370637  0.866836   3.653530      0.113232
# 4   0.374846  0.866412   9.399688      0.055980
# 5   0.370007  0.874470   4.298261      0.057252
# 6   0.305365  0.896098   4.175093      0.138677
# 7   0.278760  0.901612   3.773306      0.156489
# 8   0.251390  0.907549   8.078000      0.148855
# 9   0.229135  0.922392   6.812681      0.101781
# 10  0.179366  0.938083   3.203077      0.293893
# 11  0.185732  0.928753   2.441859      0.473282
# 12  0.173393  0.936811   5.744249      0.170483
# 13  0.189264  0.938507   2.020105      0.561069
# 14  0.112786  0.958439   1.046548      0.772265
# 15  0.118452  0.960136   1.851049      0.600509
# 16  0.101491  0.965225   6.485686      0.276081
# 17  0.111327  0.957167   1.286197      0.711196
# 18  0.108850  0.962256   1.051365      0.745547
# 19  0.123857  0.954623   1.154226      0.750636
# 20  0.112588  0.959288   4.380577      0.348601
# 21  0.108842  0.963952   3.026533      0.446565
# 22  0.091722  0.970314   1.900313      0.604326
# 23  0.080175  0.970738   3.807098      0.433842
# 24  0.068649  0.975403   1.033913      0.762087
# 25  0.061684  0.978796   1.715510      0.684478
# 26  0.105550  0.967345   2.954351      0.469466
# 27  0.049341  0.983036   2.668971      0.519084
# 28  0.032897  0.988550   0.372258      0.894402
# 29  0.033488  0.988550  11.044027      0.244275
# 30  0.109547  0.967769   1.417897      0.703562
# 31  0.077811  0.978372   3.083125      0.549618
# 32  0.052367  0.982612   1.288185      0.713740
# 33  0.033117  0.991094   1.271561      0.715013
# 34  0.015204  0.994063   0.757907      0.848601
# 35  0.025182  0.991094   1.004806      0.756997
# 36  0.032835  0.990670   2.703647      0.608142
# 37  0.078917  0.973282   1.134814      0.750636
# 38  0.076778  0.973707   2.056595      0.660305
# 39  0.064401  0.979220   1.635101      0.749364
# 40  0.028389  0.992791   1.000681      0.767176
# 41  0.035068  0.988974   0.807456      0.811705
# 42  0.021610  0.992791   0.515637      0.882952
# 43  0.021058  0.994063   1.145304      0.774809
# 44  0.015607  0.996183   0.879061      0.797710
# 45  0.055189  0.982188   2.597881      0.583969
# 46  0.049386  0.984309   2.726103      0.550891
# 47  0.045186  0.984309   4.217244      0.569975
# 48  0.037104  0.987277   1.566281      0.722646
# 49  0.033918  0.991518   0.865045      0.787532
# 50  0.049690  0.985581   1.622483      0.693384
# 51  0.046026  0.985157   1.853558      0.638677
# 52  0.025761  0.992791   0.960679      0.806616
# 53  0.021266  0.992791   4.244474      0.517812
# 54  0.028889  0.991094   7.454393      0.249364
# 55  0.038900  0.987277   3.177319      0.515267
# 56  0.064909  0.977099   3.613121      0.480916
# 57  0.041361  0.986005   2.605111      0.604326
# 58  0.036198  0.989398   1.433592      0.760814

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.37225818634033203
# Maximum validation accuracy: 0.894402027130127

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 27ms/step - loss: 0.3155 - accuracy: 0.9109
# test loss, test acc: [0.3154749572277069, 0.910941481590271]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 2s 24ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 17s 201ms/step - loss: 0.5414 - accuracy: 0.8240 - val_loss: 3.1087 - val_accuracy: 0.3766
# Epoch 2/100
# 37/37 [==============================] - 6s 152ms/step - loss: 0.1733 - accuracy: 0.9355 - val_loss: 4.8127 - val_accuracy: 0.5076
# Epoch 3/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0938 - accuracy: 0.9699 - val_loss: 9.7159 - val_accuracy: 0.2901
# Epoch 4/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.1101 - accuracy: 0.9644 - val_loss: 0.3638 - val_accuracy: 0.8893
# Epoch 5/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0597 - accuracy: 0.9856 - val_loss: 0.8615 - val_accuracy: 0.8155
# Epoch 6/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0539 - accuracy: 0.9822 - val_loss: 1.4751 - val_accuracy: 0.6654
# Epoch 7/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0530 - accuracy: 0.9839 - val_loss: 0.6207 - val_accuracy: 0.8626
# Epoch 8/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0473 - accuracy: 0.9843 - val_loss: 0.2206 - val_accuracy: 0.9326
# Epoch 9/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0609 - accuracy: 0.9822 - val_loss: 0.1076 - val_accuracy: 0.9796
# Epoch 10/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0207 - accuracy: 0.9945 - val_loss: 0.1825 - val_accuracy: 0.9606
# Epoch 11/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.2252 - val_accuracy: 0.9517
# Epoch 12/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0490 - accuracy: 0.9902 - val_loss: 0.7517 - val_accuracy: 0.8715
# Epoch 13/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0797 - accuracy: 0.9788 - val_loss: 3.3282 - val_accuracy: 0.6921
# Epoch 14/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0738 - accuracy: 0.9792 - val_loss: 2.0535 - val_accuracy: 0.7023
# Epoch 15/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0705 - accuracy: 0.9779 - val_loss: 1.6980 - val_accuracy: 0.7583
# Epoch 16/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0384 - accuracy: 0.9877 - val_loss: 1.5571 - val_accuracy: 0.7290
# Epoch 17/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0395 - accuracy: 0.9864 - val_loss: 0.6407 - val_accuracy: 0.8588
# Epoch 18/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0565 - accuracy: 0.9839 - val_loss: 0.6376 - val_accuracy: 0.8893
# Epoch 19/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0248 - accuracy: 0.9919 - val_loss: 0.4100 - val_accuracy: 0.9173
# Epoch 20/100
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0260 - accuracy: 0.9898 - val_loss: 0.8179 - val_accuracy: 0.8817
# Epoch 21/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 0.3548 - val_accuracy: 0.9084
# Epoch 22/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.1033 - val_accuracy: 0.9695
# Epoch 23/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0923 - val_accuracy: 0.9746
# Epoch 24/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0141 - accuracy: 0.9970 - val_loss: 0.6306 - val_accuracy: 0.8728
# Epoch 25/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0222 - accuracy: 0.9953 - val_loss: 0.5621 - val_accuracy: 0.8550
# Epoch 26/100
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.1041 - val_accuracy: 0.9669
# Epoch 27/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0261 - accuracy: 0.9945 - val_loss: 0.2047 - val_accuracy: 0.9542
# Epoch 28/100
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.2651 - val_accuracy: 0.9288
# Epoch 29/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9924Restoring model weights from the end of the best epoch: 9.
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.5760 - val_accuracy: 0.8842
# Epoch 00029: early stopping
# Maximal validation accuracy: 97.96%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.541350  0.824003  3.108680      0.376590
# 1   0.173308  0.935539  4.812701      0.507634
# 2   0.093800  0.969890  9.715936      0.290076
# 3   0.110066  0.964377  0.363822      0.889313
# 4   0.059731  0.985581  0.861501      0.815522
# 5   0.053869  0.982188  1.475111      0.665394
# 6   0.053015  0.983885  0.620660      0.862595
# 7   0.047280  0.984309  0.220571      0.932570
# 8   0.060855  0.982188  0.107627      0.979644
# 9   0.020715  0.994487  0.182466      0.960560
# 10  0.018383  0.994063  0.225244      0.951654
# 11  0.048971  0.990246  0.751738      0.871501
# 12  0.079689  0.978796  3.328192      0.692112
# 13  0.073805  0.979220  2.053536      0.702290
# 14  0.070529  0.977947  1.698016      0.758270
# 15  0.038442  0.987701  1.557144      0.729008
# 16  0.039454  0.986429  0.640732      0.858779
# 17  0.056471  0.983885  0.637619      0.889313
# 18  0.024819  0.991942  0.410005      0.917303
# 19  0.026007  0.989822  0.817918      0.881679
# 20  0.019177  0.994911  0.354803      0.908397
# 21  0.013459  0.997880  0.103295      0.969466
# 22  0.015245  0.995335  0.092316      0.974555
# 23  0.014135  0.997031  0.630633      0.872774
# 24  0.022201  0.995335  0.562148      0.854962
# 25  0.019857  0.994063  0.104136      0.966921
# 26  0.026072  0.994487  0.204723      0.954198
# 27  0.029228  0.991094  0.265130      0.928753
# 28  0.033245  0.992366  0.576011      0.884224

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.09231621026992798
# Maximum validation accuracy: 0.9796437621116638

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 27ms/step - loss: 0.1766 - accuracy: 0.9453
# test loss, test acc: [0.1766311228275299, 0.945292592048645]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 25/25 [==============================] - 2s 23ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_DenseNet121_None
# test loss, test acc: [3.0992157459259033, 0.6120092272758484]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_DenseNet121_imagenet
# test loss, test acc: [0.30134546756744385, 0.9457274675369263]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_DenseNet121_None
# test loss, test acc: [0.3154749572277069, 0.910941481590271]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_DenseNet121_imagenet
# test loss, test acc: [0.1766311228275299, 0.945292592048645]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_DenseNet121_None →→→ Target Test
# 25/25 [==============================] - 1s 27ms/step - loss: 10.0591 - accuracy: 0.2672
# test loss, test acc: [10.05906867980957, 0.2671755850315094]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_DenseNet121_imagenet →→→ Target Test
# 25/25 [==============================] - 1s 27ms/step - loss: 6.6317 - accuracy: 0.2226
# test loss, test acc: [6.631680011749268, 0.2226463109254837]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_DenseNet121_None →→→ Source Test
# 28/28 [==============================] - 1s 27ms/step - loss: 5.5188 - accuracy: 0.1432
# test loss, test acc: [5.518758773803711, 0.14318706095218658]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_DenseNet121_imagenet →→→ Source Test
# 28/28 [==============================] - 1s 27ms/step - loss: 4.7041 - accuracy: 0.2483
# test loss, test acc: [4.7041096687316895, 0.24826790392398834]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
