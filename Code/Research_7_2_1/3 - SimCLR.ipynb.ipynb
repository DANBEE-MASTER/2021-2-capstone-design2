# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import pandas as pd
import os

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6206338566766969864
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16077977838721165416
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Wed Dec 15 14:32:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    34W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. Hyperparameter setup

# %%
# Dataset hyperparameters
image_size = 128
image_channels = 3

# Algorithm hyperparameters
num_epochs = 100
patience_num = 15
class_num = 7
batch_size = 64  
width = 128
temperature = 0.1

# Stronger augmentations for contrastive, weaker ones for supervised training
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2}
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/3 - SimCLR_result/'

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
# Out:
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

# %% [markdown]
# ## 2-2. Dataset

# %%
labeled_train_data = tf.data.Dataset.from_tensor_slices((xTrain_S, yTrain_S))
unlabeled_train_data = tf.data.Dataset.from_tensor_slices((xValid_S, yValid_S))
test_data = tf.data.Dataset.from_tensor_slices((xTest_S, yTest_S))

# %%
labeled_train_dataset = labeled_train_data.batch(batch_size)
unlabeled_train_dataset = unlabeled_train_data.batch(batch_size)
test_dataset = test_data.batch(batch_size)

# %%
train_dataset = tf.data.Dataset.zip(
        (unlabeled_train_dataset, labeled_train_dataset)
    ).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
print ('labeled_train_dataset : ' , labeled_train_dataset)
print ('labeled_train_dataset 총 batch_size 세트 : ' , len(labeled_train_dataset))
print ('unlabeled_train_dataset : ' , unlabeled_train_dataset)
print ('unlabeled_train_dataset 총 batch_size 세트 : ' , len(unlabeled_train_dataset))
print ('test_dataset : ' , test_dataset)
print ('test_dataset 총 batch_size 세트 : ' , len(test_dataset)) 
print ('train_dataset : ' , train_dataset)
print ('train_dataset 총 batch_size 세트 : ' , len(train_dataset))
# Out:
# labeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# labeled_train_dataset 총 batch_size 세트 :  37
# unlabeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# unlabeled_train_dataset 총 batch_size 세트 :  13
# test_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# test_dataset 총 batch_size 세트 :  13
# train_dataset :  <PrefetchDataset shapes: (((None, 128, 128, 3), (None, 1)), ((None, 128, 128, 3), (None, 1))), types: ((tf.float32, tf.int32), (tf.float32, tf.int32))>
# train_dataset 총 batch_size 세트 :  13

# %% [markdown]
# ## 2-3. Image augmentations and visualize_augmentations

# %%
from tensorflow.keras.layers.experimental import preprocessing

# %%
# Distorts the color distibutions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def call(self, images, training=True):
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images


# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    zoom_factor = 1.0 - tf.sqrt(min_area)
    return tf.keras.Sequential(
        [
            tf.keras.Input(shape=(image_size, image_size, image_channels)),
            #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255),
            tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
            tf.keras.layers.experimental.preprocessing.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
            tf.keras.layers.experimental.preprocessing.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
            RandomColorAffine(brightness, jitter),
        ]
    )


def visualize_augmentations(num_images):
    # Sample a batch from a dataset
    images = next(iter(train_dataset))[0][0][:num_images]
    # Apply augmentations
    augmented_images = zip(
        (images),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255)(images),
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Weakly augmented:",
        "Strongly augmented:",
        "Strongly augmented:",
    ]
    plt.figure(figsize=(num_images * 2.2, 4 * 2.2), dpi=100)
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc="left")
            plt.axis("off")
    plt.tight_layout()

# %%
visualize_augmentations(num_images=8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 3. Network

# %% [markdown]
# ## 3-1. Encoder architecture

# %%
def get_encoder():
    base_model = tf.keras.applications.Xception(
    weights='imagenet',
    include_top=False,
    pooling='avg')
    
    model = keras.Sequential([
    base_model,
    layers.Dense(width, activation="relu"),
    ])
    
    return model

# %% [markdown]
# ## 3-2. Supervised baseline model - original image

# %%
# Baseline supervised training with random initialization
baseline_model_original_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        #get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_original_image",
)

baseline_model_original_image.summary()

baseline_model_original_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "baseline_model_original_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 128)               21123752
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 21,148,975
# Trainable params: 21,094,447
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_original_image_history = baseline_model_original_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_original_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 37/37 [==============================] - 23s 301ms/step - loss: 0.9664 - acc: 0.6628 - val_loss: 8.6993 - val_acc: 0.5636
# Epoch 2/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.2183 - acc: 0.9351 - val_loss: 13.4696 - val_acc: 0.5102
# Epoch 3/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.1107 - acc: 0.9703 - val_loss: 0.7123 - val_acc: 0.8677
# Epoch 4/100
# 37/37 [==============================] - 10s 260ms/step - loss: 0.0825 - acc: 0.9792 - val_loss: 0.5753 - val_acc: 0.9122
# Epoch 5/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0489 - acc: 0.9860 - val_loss: 2.5552 - val_acc: 0.7875
# Epoch 6/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.0773 - acc: 0.9826 - val_loss: 0.4107 - val_acc: 0.9402
# Epoch 7/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.0455 - acc: 0.9873 - val_loss: 0.4154 - val_acc: 0.9249
# Epoch 8/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0618 - acc: 0.9856 - val_loss: 0.4463 - val_acc: 0.9109
# Epoch 9/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0362 - acc: 0.9932 - val_loss: 3.5359 - val_acc: 0.7481
# Epoch 10/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.0507 - acc: 0.9902 - val_loss: 0.6605 - val_acc: 0.9008
# Epoch 11/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.0680 - acc: 0.9826 - val_loss: 0.9178 - val_acc: 0.8969
# Epoch 12/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0725 - acc: 0.9860 - val_loss: 5.6820 - val_acc: 0.6718
# Epoch 13/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.0382 - acc: 0.9919 - val_loss: 0.4972 - val_acc: 0.9059
# Epoch 14/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0111 - acc: 0.9966 - val_loss: 0.4017 - val_acc: 0.9300
# Epoch 15/100
# 37/37 [==============================] - 10s 259ms/step - loss: 0.0107 - acc: 0.9962 - val_loss: 0.1702 - val_acc: 0.9618
# Epoch 16/100
# 37/37 [==============================] - 9s 256ms/step - loss: 0.0189 - acc: 0.9949 - val_loss: 0.6422 - val_acc: 0.9135
# Epoch 17/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0244 - acc: 0.9928 - val_loss: 0.3574 - val_acc: 0.9351
# Epoch 18/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0137 - acc: 0.9966 - val_loss: 0.2630 - val_acc: 0.9440
# Epoch 19/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0345 - acc: 0.9919 - val_loss: 0.5534 - val_acc: 0.8957
# Epoch 20/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0177 - acc: 0.9962 - val_loss: 0.3577 - val_acc: 0.9351
# Epoch 21/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0226 - acc: 0.9970 - val_loss: 0.2808 - val_acc: 0.9491
# Epoch 22/100
# 37/37 [==============================] - 9s 257ms/step - loss: 0.0034 - acc: 0.9996 - val_loss: 0.2162 - val_acc: 0.9606
# Epoch 23/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.5415e-04 - acc: 1.0000 - val_loss: 0.1746 - val_acc: 0.9618
# Epoch 24/100
# 37/37 [==============================] - 10s 259ms/step - loss: 8.6440e-05 - acc: 1.0000 - val_loss: 0.1533 - val_acc: 0.9656
# Epoch 25/100
# 37/37 [==============================] - 9s 257ms/step - loss: 6.5539e-05 - acc: 1.0000 - val_loss: 0.1488 - val_acc: 0.9656
# Epoch 26/100
# 37/37 [==============================] - 10s 260ms/step - loss: 5.3021e-05 - acc: 1.0000 - val_loss: 0.1461 - val_acc: 0.9669
# Epoch 27/100
# 37/37 [==============================] - 10s 260ms/step - loss: 4.4407e-05 - acc: 1.0000 - val_loss: 0.1442 - val_acc: 0.9682
# Epoch 28/100
# 37/37 [==============================] - 10s 260ms/step - loss: 3.8079e-05 - acc: 1.0000 - val_loss: 0.1437 - val_acc: 0.9695
# Epoch 29/100
# 37/37 [==============================] - 9s 257ms/step - loss: 3.3206e-05 - acc: 1.0000 - val_loss: 0.1445 - val_acc: 0.9695
# Epoch 30/100
# 37/37 [==============================] - 9s 257ms/step - loss: 2.9342e-05 - acc: 1.0000 - val_loss: 0.1457 - val_acc: 0.9695
# Epoch 31/100
# 37/37 [==============================] - 9s 257ms/step - loss: 2.6197e-05 - acc: 1.0000 - val_loss: 0.1470 - val_acc: 0.9695
# Epoch 32/100
# 37/37 [==============================] - 9s 257ms/step - loss: 2.3588e-05 - acc: 1.0000 - val_loss: 0.1481 - val_acc: 0.9682
# Epoch 33/100
# 37/37 [==============================] - 9s 256ms/step - loss: 2.1391e-05 - acc: 1.0000 - val_loss: 0.1492 - val_acc: 0.9682
# Epoch 34/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.9514e-05 - acc: 1.0000 - val_loss: 0.1501 - val_acc: 0.9682
# Epoch 35/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.7896e-05 - acc: 1.0000 - val_loss: 0.1510 - val_acc: 0.9682
# Epoch 36/100
# 37/37 [==============================] - 10s 258ms/step - loss: 1.6485e-05 - acc: 1.0000 - val_loss: 0.1518 - val_acc: 0.9682
# Epoch 37/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.5243e-05 - acc: 1.0000 - val_loss: 0.1526 - val_acc: 0.9682
# Epoch 38/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.4144e-05 - acc: 1.0000 - val_loss: 0.1533 - val_acc: 0.9682
# Epoch 39/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.3163e-05 - acc: 1.0000 - val_loss: 0.1539 - val_acc: 0.9682
# Epoch 40/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.2288e-05 - acc: 1.0000 - val_loss: 0.1546 - val_acc: 0.9682
# Epoch 41/100
# 37/37 [==============================] - 9s 257ms/step - loss: 1.1501e-05 - acc: 1.0000 - val_loss: 0.1552 - val_acc: 0.9682
# Epoch 42/100
# 37/37 [==============================] - 9s 255ms/step - loss: 1.0790e-05 - acc: 1.0000 - val_loss: 0.1558 - val_acc: 0.9682
# Epoch 43/100
# 37/37 [==============================] - ETA: 0s - loss: 1.0145e-05 - acc: 1.0000Restoring model weights from the end of the best epoch: 28.
# 37/37 [==============================] - 10s 260ms/step - loss: 1.0145e-05 - acc: 1.0000 - val_loss: 0.1563 - val_acc: 0.9682
# Epoch 00043: early stopping
# Maximal validation accuracy: 96.95%

# %%
baseline_model_original_image_df = pd.DataFrame(baseline_model_original_image_history.history)
baseline_model_original_image_df.to_csv( path_model_result + 'baseline_model_original_image_df.csv' )
baseline_model_original_image_df
# Out:
#         loss       acc   val_loss   val_acc
# 0   0.966430  0.662850   8.699309  0.563613
# 1   0.218274  0.935115  13.469582  0.510178
# 2   0.110734  0.970314   0.712269  0.867684
# 3   0.082528  0.979220   0.575306  0.912214
# 4   0.048895  0.986005   2.555203  0.787532
# 5   0.077251  0.982612   0.410653  0.940204
# 6   0.045482  0.987277   0.415406  0.924936
# 7   0.061827  0.985581   0.446275  0.910941
# 8   0.036163  0.993215   3.535915  0.748092
# 9   0.050736  0.990246   0.660532  0.900763
# 10  0.068048  0.982612   0.917802  0.896947
# 11  0.072474  0.986005   5.682039  0.671756
# 12  0.038240  0.991942   0.497233  0.905852
# 13  0.011148  0.996607   0.401714  0.930025
# 14  0.010653  0.996183   0.170159  0.961832
# 15  0.018945  0.994911   0.642161  0.913486
# 16  0.024375  0.992791   0.357401  0.935115
# 17  0.013740  0.996607   0.262986  0.944020
# 18  0.034509  0.991942   0.553404  0.895674
# 19  0.017721  0.996183   0.357679  0.935115
# 20  0.022577  0.997031   0.280761  0.949109
# 21  0.003365  0.999576   0.216247  0.960560
# 22  0.000154  1.000000   0.174607  0.961832
# 23  0.000086  1.000000   0.153280  0.965649
# 24  0.000066  1.000000   0.148841  0.965649
# 25  0.000053  1.000000   0.146133  0.966921
# 26  0.000044  1.000000   0.144156  0.968193
# 27  0.000038  1.000000   0.143689  0.969466
# 28  0.000033  1.000000   0.144489  0.969466
# 29  0.000029  1.000000   0.145708  0.969466
# 30  0.000026  1.000000   0.146957  0.969466
# 31  0.000024  1.000000   0.148117  0.968193
# 32  0.000021  1.000000   0.149174  0.968193
# 33  0.000020  1.000000   0.150134  0.968193
# 34  0.000018  1.000000   0.151008  0.968193
# 35  0.000016  1.000000   0.151811  0.968193
# 36  0.000015  1.000000   0.152556  0.968193
# 37  0.000014  1.000000   0.153257  0.968193
# 38  0.000013  1.000000   0.153922  0.968193
# 39  0.000012  1.000000   0.154559  0.968193
# 40  0.000012  1.000000   0.155169  0.968193
# 41  0.000011  1.000000   0.155758  0.968193
# 42  0.000010  1.000000   0.156323  0.968193

# %% [markdown]
# ## 3-3. Supervised baseline model - augmenter image

# %%
# Baseline supervised training with random initialization
baseline_model_augmenter_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_augmenter_image",
)

baseline_model_augmenter_image.summary()

baseline_model_augmenter_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Model: "baseline_model_augmenter_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 128, 128, 3)       0
#
#  sequential_5 (Sequential)   (None, 128)               21123752
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 21,148,975
# Trainable params: 21,094,447
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_augmenter_image_history = baseline_model_augmenter_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_augmenter_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 37/37 [==============================] - 15s 288ms/step - loss: 0.6980 - acc: 0.7676 - val_loss: 3.3448 - val_acc: 0.5891
# Epoch 2/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.2698 - acc: 0.9169 - val_loss: 3.1007 - val_acc: 0.6209
# Epoch 3/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.2113 - acc: 0.9385 - val_loss: 1.4664 - val_acc: 0.7583
# Epoch 4/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.1455 - acc: 0.9559 - val_loss: 2.4765 - val_acc: 0.7977
# Epoch 5/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0999 - acc: 0.9763 - val_loss: 0.9318 - val_acc: 0.8715
# Epoch 6/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0782 - acc: 0.9805 - val_loss: 0.3152 - val_acc: 0.9186
# Epoch 7/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0767 - acc: 0.9805 - val_loss: 0.4519 - val_acc: 0.8982
# Epoch 8/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.1034 - acc: 0.9750 - val_loss: 0.3262 - val_acc: 0.9135
# Epoch 9/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0660 - acc: 0.9830 - val_loss: 0.7735 - val_acc: 0.8562
# Epoch 10/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0623 - acc: 0.9813 - val_loss: 0.3097 - val_acc: 0.9377
# Epoch 11/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0609 - acc: 0.9818 - val_loss: 0.4862 - val_acc: 0.8830
# Epoch 12/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0579 - acc: 0.9835 - val_loss: 0.1830 - val_acc: 0.9542
# Epoch 13/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0650 - acc: 0.9839 - val_loss: 1.1277 - val_acc: 0.8244
# Epoch 14/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0852 - acc: 0.9792 - val_loss: 2.5866 - val_acc: 0.7010
# Epoch 15/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0804 - acc: 0.9809 - val_loss: 0.4088 - val_acc: 0.8982
# Epoch 16/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.0535 - acc: 0.9843 - val_loss: 0.3454 - val_acc: 0.9160
# Epoch 17/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0515 - acc: 0.9847 - val_loss: 0.4658 - val_acc: 0.9059
# Epoch 18/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0480 - acc: 0.9869 - val_loss: 0.5034 - val_acc: 0.8753
# Epoch 19/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0301 - acc: 0.9894 - val_loss: 0.1564 - val_acc: 0.9555
# Epoch 20/100
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0378 - acc: 0.9915 - val_loss: 0.1388 - val_acc: 0.9567
# Epoch 21/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0330 - acc: 0.9915 - val_loss: 0.1766 - val_acc: 0.9580
# Epoch 22/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0509 - acc: 0.9852 - val_loss: 0.4562 - val_acc: 0.9160
# Epoch 23/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0416 - acc: 0.9894 - val_loss: 0.5011 - val_acc: 0.8842
# Epoch 24/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0446 - acc: 0.9898 - val_loss: 0.5429 - val_acc: 0.9033
# Epoch 25/100
# 37/37 [==============================] - 10s 261ms/step - loss: 0.0221 - acc: 0.9936 - val_loss: 0.2524 - val_acc: 0.9491
# Epoch 26/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0404 - acc: 0.9902 - val_loss: 0.2364 - val_acc: 0.9478
# Epoch 27/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0321 - acc: 0.9919 - val_loss: 0.5876 - val_acc: 0.9160
# Epoch 28/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0787 - acc: 0.9788 - val_loss: 0.5244 - val_acc: 0.9020
# Epoch 29/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0530 - acc: 0.9873 - val_loss: 0.4368 - val_acc: 0.8893
# Epoch 30/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0548 - acc: 0.9856 - val_loss: 1.2894 - val_acc: 0.8130
# Epoch 31/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0471 - acc: 0.9894 - val_loss: 0.6501 - val_acc: 0.9033
# Epoch 32/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0366 - acc: 0.9919 - val_loss: 0.9035 - val_acc: 0.8753
# Epoch 33/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.0300 - acc: 0.9894 - val_loss: 7.1178 - val_acc: 0.7252
# Epoch 34/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0239 - acc: 0.9932 - val_loss: 0.3586 - val_acc: 0.9275
# Epoch 35/100
# 37/37 [==============================] - 10s 262ms/step - loss: 0.0312 - acc: 0.9911 - val_loss: 0.2362 - val_acc: 0.9453
# Epoch 36/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0269 - acc: 0.9936Restoring model weights from the end of the best epoch: 21.
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0269 - acc: 0.9936 - val_loss: 0.3054 - val_acc: 0.9313
# Epoch 00036: early stopping
# Maximal validation accuracy: 95.80%

# %%
baseline_model_augmenter_image_df = pd.DataFrame(baseline_model_augmenter_image_history.history)
baseline_model_augmenter_image_df.to_csv( path_model_result + 'baseline_model_augmenter_image_df.csv' )
baseline_model_augmenter_image_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.697990  0.767600  3.344841  0.589059
# 1   0.269793  0.916879  3.100733  0.620865
# 2   0.211252  0.938507  1.466354  0.758270
# 3   0.145529  0.955895  2.476458  0.797710
# 4   0.099859  0.976251  0.931826  0.871501
# 5   0.078186  0.980492  0.315216  0.918575
# 6   0.076739  0.980492  0.451919  0.898219
# 7   0.103355  0.974979  0.326205  0.913486
# 8   0.066008  0.983036  0.773532  0.856234
# 9   0.062345  0.981340  0.309656  0.937659
# 10  0.060916  0.981764  0.486154  0.882952
# 11  0.057911  0.983461  0.182972  0.954198
# 12  0.065045  0.983885  1.127704  0.824427
# 13  0.085204  0.979220  2.586618  0.701018
# 14  0.080434  0.980916  0.408844  0.898219
# 15  0.053474  0.984309  0.345352  0.916031
# 16  0.051475  0.984733  0.465766  0.905852
# 17  0.048041  0.986853  0.503405  0.875318
# 18  0.030117  0.989398  0.156421  0.955471
# 19  0.037763  0.991518  0.138779  0.956743
# 20  0.032961  0.991518  0.176594  0.958015
# 21  0.050895  0.985157  0.456207  0.916031
# 22  0.041636  0.989398  0.501130  0.884224
# 23  0.044601  0.989822  0.542943  0.903308
# 24  0.022078  0.993639  0.252401  0.949109
# 25  0.040389  0.990246  0.236387  0.947837
# 26  0.032092  0.991942  0.587645  0.916031
# 27  0.078661  0.978796  0.524437  0.902036
# 28  0.052995  0.987277  0.436769  0.889313
# 29  0.054791  0.985581  1.289368  0.812977
# 30  0.047061  0.989398  0.650125  0.903308
# 31  0.036607  0.991942  0.903483  0.875318
# 32  0.030037  0.989398  7.117785  0.725191
# 33  0.023931  0.993215  0.358622  0.927481
# 34  0.031213  0.991094  0.236152  0.945293
# 35  0.026916  0.993639  0.305357  0.931298

# %% [markdown]
# ## 3-4. ContrastiveModel - augmenter image

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder = get_encoder()
        # Non-linear MLP as projection head
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(class_num)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(
            name="c_acc"
        )
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        (unlabeled_images, _), (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

# Contrastive pretraining
pretraining_model = ContrastiveModel()
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)

pretraining_history = pretraining_model.fit(
    train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense_8 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 903
# Trainable params: 903
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 26s 1s/step - c_loss: 3.3063 - c_acc: 0.2222 - p_loss: 2.4589 - p_acc: 0.1719 - val_p_loss: 2.4917 - val_p_acc: 0.1743
# Epoch 2/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 2.0564 - c_acc: 0.4261 - p_loss: 2.3256 - p_acc: 0.1562 - val_p_loss: 1.9056 - val_p_acc: 0.2010
# Epoch 3/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 1.5501 - c_acc: 0.5442 - p_loss: 1.7542 - p_acc: 0.2837 - val_p_loss: 1.7208 - val_p_acc: 0.3372
# Epoch 4/100
# 13/13 [==============================] - 13s 987ms/step - c_loss: 1.3056 - c_acc: 0.6316 - p_loss: 1.6519 - p_acc: 0.3522 - val_p_loss: 1.5879 - val_p_acc: 0.3779
# Epoch 5/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 1.0857 - c_acc: 0.7052 - p_loss: 1.6020 - p_acc: 0.3834 - val_p_loss: 1.6033 - val_p_acc: 0.4186
# Epoch 6/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.9524 - c_acc: 0.7379 - p_loss: 1.5136 - p_acc: 0.4339 - val_p_loss: 1.4233 - val_p_acc: 0.4720
# Epoch 7/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.8566 - c_acc: 0.7664 - p_loss: 1.4591 - p_acc: 0.4519 - val_p_loss: 1.3970 - val_p_acc: 0.4644
# Epoch 8/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 0.7109 - c_acc: 0.8140 - p_loss: 1.3411 - p_acc: 0.4892 - val_p_loss: 1.2523 - val_p_acc: 0.5407
# Epoch 9/100
# 13/13 [==============================] - 13s 991ms/step - c_loss: 0.6133 - c_acc: 0.8477 - p_loss: 1.1693 - p_acc: 0.5793 - val_p_loss: 1.1027 - val_p_acc: 0.5852
# Epoch 10/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.5668 - c_acc: 0.8619 - p_loss: 1.0010 - p_acc: 0.6587 - val_p_loss: 0.9295 - val_p_acc: 0.6908
# Epoch 11/100
# 13/13 [==============================] - 13s 987ms/step - c_loss: 0.4990 - c_acc: 0.8823 - p_loss: 0.8937 - p_acc: 0.7103 - val_p_loss: 0.8771 - val_p_acc: 0.7316
# Epoch 12/100
# 13/13 [==============================] - 13s 983ms/step - c_loss: 0.4643 - c_acc: 0.8897 - p_loss: 0.8968 - p_acc: 0.7200 - val_p_loss: 0.9468 - val_p_acc: 0.6628
# Epoch 13/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.4175 - c_acc: 0.9082 - p_loss: 0.8684 - p_acc: 0.6971 - val_p_loss: 0.8627 - val_p_acc: 0.6947
# Epoch 14/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.3644 - c_acc: 0.9277 - p_loss: 0.8443 - p_acc: 0.7103 - val_p_loss: 0.9046 - val_p_acc: 0.6921
# Epoch 15/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.3420 - c_acc: 0.9354 - p_loss: 0.7804 - p_acc: 0.7548 - val_p_loss: 0.7744 - val_p_acc: 0.7481
# Epoch 16/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.3239 - c_acc: 0.9388 - p_loss: 0.6657 - p_acc: 0.7921 - val_p_loss: 0.6419 - val_p_acc: 0.7913
# Epoch 17/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.2757 - c_acc: 0.9540 - p_loss: 0.6056 - p_acc: 0.8161 - val_p_loss: 0.6665 - val_p_acc: 0.7850
# Epoch 18/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.2705 - c_acc: 0.9524 - p_loss: 0.6595 - p_acc: 0.7837 - val_p_loss: 0.6719 - val_p_acc: 0.7824
# Epoch 19/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.2555 - c_acc: 0.9561 - p_loss: 0.6156 - p_acc: 0.8137 - val_p_loss: 0.6316 - val_p_acc: 0.7850
# Epoch 20/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.2275 - c_acc: 0.9654 - p_loss: 0.5689 - p_acc: 0.8077 - val_p_loss: 0.5733 - val_p_acc: 0.7977
# Epoch 21/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.2197 - c_acc: 0.9660 - p_loss: 0.5307 - p_acc: 0.8317 - val_p_loss: 0.5544 - val_p_acc: 0.8244
# Epoch 22/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.1861 - c_acc: 0.9725 - p_loss: 0.4876 - p_acc: 0.8401 - val_p_loss: 0.5343 - val_p_acc: 0.8232
# Epoch 23/100
# 13/13 [==============================] - 13s 991ms/step - c_loss: 0.1845 - c_acc: 0.9688 - p_loss: 0.4722 - p_acc: 0.8546 - val_p_loss: 0.4919 - val_p_acc: 0.8333
# Epoch 24/100
# 13/13 [==============================] - 13s 987ms/step - c_loss: 0.1727 - c_acc: 0.9750 - p_loss: 0.4575 - p_acc: 0.8726 - val_p_loss: 0.4693 - val_p_acc: 0.8524
# Epoch 25/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 0.1662 - c_acc: 0.9771 - p_loss: 0.4471 - p_acc: 0.8606 - val_p_loss: 0.4350 - val_p_acc: 0.8651
# Epoch 26/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 0.1516 - c_acc: 0.9811 - p_loss: 0.3962 - p_acc: 0.8882 - val_p_loss: 0.4190 - val_p_acc: 0.8664
# Epoch 27/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.1474 - c_acc: 0.9796 - p_loss: 0.3689 - p_acc: 0.8882 - val_p_loss: 0.4360 - val_p_acc: 0.8550
# Epoch 28/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 0.1384 - c_acc: 0.9842 - p_loss: 0.3816 - p_acc: 0.8846 - val_p_loss: 0.4129 - val_p_acc: 0.8791
# Epoch 29/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.1414 - c_acc: 0.9818 - p_loss: 0.3748 - p_acc: 0.8846 - val_p_loss: 0.4201 - val_p_acc: 0.8690
# Epoch 30/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.1323 - c_acc: 0.9864 - p_loss: 0.3685 - p_acc: 0.8762 - val_p_loss: 0.3963 - val_p_acc: 0.8766
# Epoch 31/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.1074 - c_acc: 0.9910 - p_loss: 0.3846 - p_acc: 0.8666 - val_p_loss: 0.4359 - val_p_acc: 0.8537
# Epoch 32/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0998 - c_acc: 0.9917 - p_loss: 0.3890 - p_acc: 0.8774 - val_p_loss: 0.4265 - val_p_acc: 0.8562
# Epoch 33/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0888 - c_acc: 0.9935 - p_loss: 0.3569 - p_acc: 0.8942 - val_p_loss: 0.4022 - val_p_acc: 0.8613
# Epoch 34/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 0.0885 - c_acc: 0.9913 - p_loss: 0.3500 - p_acc: 0.8954 - val_p_loss: 0.3801 - val_p_acc: 0.8830
# Epoch 35/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.1025 - c_acc: 0.9876 - p_loss: 0.3540 - p_acc: 0.8990 - val_p_loss: 0.3947 - val_p_acc: 0.8715
# Epoch 36/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 0.0947 - c_acc: 0.9910 - p_loss: 0.3416 - p_acc: 0.9050 - val_p_loss: 0.3700 - val_p_acc: 0.8842
# Epoch 37/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.1020 - c_acc: 0.9886 - p_loss: 0.3215 - p_acc: 0.9014 - val_p_loss: 0.3780 - val_p_acc: 0.8817
# Epoch 38/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0869 - c_acc: 0.9944 - p_loss: 0.3288 - p_acc: 0.8990 - val_p_loss: 0.4043 - val_p_acc: 0.8715
# Epoch 39/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0862 - c_acc: 0.9929 - p_loss: 0.3338 - p_acc: 0.8942 - val_p_loss: 0.3602 - val_p_acc: 0.8842
# Epoch 40/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0907 - c_acc: 0.9910 - p_loss: 0.3306 - p_acc: 0.9147 - val_p_loss: 0.4147 - val_p_acc: 0.8728
# Epoch 41/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 0.0896 - c_acc: 0.9920 - p_loss: 0.3205 - p_acc: 0.9111 - val_p_loss: 0.3607 - val_p_acc: 0.8969
# Epoch 42/100
# 13/13 [==============================] - 13s 987ms/step - c_loss: 0.0834 - c_acc: 0.9935 - p_loss: 0.3034 - p_acc: 0.9075 - val_p_loss: 0.3364 - val_p_acc: 0.9097
# Epoch 43/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0824 - c_acc: 0.9920 - p_loss: 0.3081 - p_acc: 0.9014 - val_p_loss: 0.3611 - val_p_acc: 0.8804
# Epoch 44/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0837 - c_acc: 0.9935 - p_loss: 0.2993 - p_acc: 0.9038 - val_p_loss: 0.3455 - val_p_acc: 0.8842
# Epoch 45/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0771 - c_acc: 0.9947 - p_loss: 0.3090 - p_acc: 0.8942 - val_p_loss: 0.3753 - val_p_acc: 0.8702
# Epoch 46/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0856 - c_acc: 0.9910 - p_loss: 0.2934 - p_acc: 0.8894 - val_p_loss: 0.3350 - val_p_acc: 0.8880
# Epoch 47/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0883 - c_acc: 0.9907 - p_loss: 0.2707 - p_acc: 0.9111 - val_p_loss: 0.3202 - val_p_acc: 0.8982
# Epoch 48/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0955 - c_acc: 0.9892 - p_loss: 0.2819 - p_acc: 0.9014 - val_p_loss: 0.3380 - val_p_acc: 0.8969
# Epoch 49/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0842 - c_acc: 0.9901 - p_loss: 0.3017 - p_acc: 0.9159 - val_p_loss: 0.3233 - val_p_acc: 0.8944
# Epoch 50/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0784 - c_acc: 0.9944 - p_loss: 0.2562 - p_acc: 0.9231 - val_p_loss: 0.3065 - val_p_acc: 0.9033
# Epoch 51/100
# 13/13 [==============================] - 13s 992ms/step - c_loss: 0.0691 - c_acc: 0.9944 - p_loss: 0.2345 - p_acc: 0.9303 - val_p_loss: 0.2940 - val_p_acc: 0.9135
# Epoch 52/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0695 - c_acc: 0.9941 - p_loss: 0.2320 - p_acc: 0.9255 - val_p_loss: 0.2909 - val_p_acc: 0.9033
# Epoch 53/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0699 - c_acc: 0.9938 - p_loss: 0.2419 - p_acc: 0.9255 - val_p_loss: 0.2865 - val_p_acc: 0.9071
# Epoch 54/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0752 - c_acc: 0.9944 - p_loss: 0.2454 - p_acc: 0.9291 - val_p_loss: 0.2978 - val_p_acc: 0.8957
# Epoch 55/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0760 - c_acc: 0.9913 - p_loss: 0.2413 - p_acc: 0.9231 - val_p_loss: 0.2856 - val_p_acc: 0.9097
# Epoch 56/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0680 - c_acc: 0.9941 - p_loss: 0.2232 - p_acc: 0.9291 - val_p_loss: 0.2664 - val_p_acc: 0.9084
# Epoch 57/100
# 13/13 [==============================] - 13s 990ms/step - c_loss: 0.0768 - c_acc: 0.9929 - p_loss: 0.2371 - p_acc: 0.9315 - val_p_loss: 0.2720 - val_p_acc: 0.9160
# Epoch 58/100
# 13/13 [==============================] - 13s 981ms/step - c_loss: 0.0788 - c_acc: 0.9926 - p_loss: 0.2259 - p_acc: 0.9375 - val_p_loss: 0.3025 - val_p_acc: 0.8957
# Epoch 59/100
# 13/13 [==============================] - 13s 982ms/step - c_loss: 0.0662 - c_acc: 0.9941 - p_loss: 0.2336 - p_acc: 0.9303 - val_p_loss: 0.2882 - val_p_acc: 0.9059
# Epoch 60/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0623 - c_acc: 0.9963 - p_loss: 0.2309 - p_acc: 0.9231 - val_p_loss: 0.3019 - val_p_acc: 0.9059
# Epoch 61/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 0.0676 - c_acc: 0.9960 - p_loss: 0.2128 - p_acc: 0.9303 - val_p_loss: 0.2684 - val_p_acc: 0.9173
# Epoch 62/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0679 - c_acc: 0.9932 - p_loss: 0.2146 - p_acc: 0.9387 - val_p_loss: 0.2809 - val_p_acc: 0.9148
# Epoch 63/100
# 13/13 [==============================] - 13s 989ms/step - c_loss: 0.0539 - c_acc: 0.9985 - p_loss: 0.2206 - p_acc: 0.9339 - val_p_loss: 0.2699 - val_p_acc: 0.9186
# Epoch 64/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0547 - c_acc: 0.9978 - p_loss: 0.2175 - p_acc: 0.9315 - val_p_loss: 0.2640 - val_p_acc: 0.9097
# Epoch 65/100
# 13/13 [==============================] - 13s 976ms/step - c_loss: 0.0471 - c_acc: 0.9978 - p_loss: 0.2115 - p_acc: 0.9351 - val_p_loss: 0.2593 - val_p_acc: 0.9109
# Epoch 66/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0505 - c_acc: 0.9966 - p_loss: 0.1924 - p_acc: 0.9459 - val_p_loss: 0.2580 - val_p_acc: 0.9173
# Epoch 67/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0511 - c_acc: 0.9991 - p_loss: 0.2027 - p_acc: 0.9447 - val_p_loss: 0.2773 - val_p_acc: 0.9135
# Epoch 68/100
# 13/13 [==============================] - 13s 980ms/step - c_loss: 0.0561 - c_acc: 0.9957 - p_loss: 0.2101 - p_acc: 0.9435 - val_p_loss: 0.2560 - val_p_acc: 0.9186
# Epoch 69/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0532 - c_acc: 0.9957 - p_loss: 0.2129 - p_acc: 0.9339 - val_p_loss: 0.2618 - val_p_acc: 0.9071
# Epoch 70/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0528 - c_acc: 0.9972 - p_loss: 0.2107 - p_acc: 0.9327 - val_p_loss: 0.2873 - val_p_acc: 0.9046
# Epoch 71/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0517 - c_acc: 0.9960 - p_loss: 0.2061 - p_acc: 0.9351 - val_p_loss: 0.2889 - val_p_acc: 0.8995
# Epoch 72/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0498 - c_acc: 0.9960 - p_loss: 0.1959 - p_acc: 0.9399 - val_p_loss: 0.2794 - val_p_acc: 0.9046
# Epoch 73/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0523 - c_acc: 0.9969 - p_loss: 0.1976 - p_acc: 0.9363 - val_p_loss: 0.3295 - val_p_acc: 0.8880
# Epoch 74/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0559 - c_acc: 0.9954 - p_loss: 0.2203 - p_acc: 0.9351 - val_p_loss: 0.3185 - val_p_acc: 0.8944
# Epoch 75/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.0601 - c_acc: 0.9957 - p_loss: 0.1986 - p_acc: 0.9363 - val_p_loss: 0.2484 - val_p_acc: 0.9211
# Epoch 76/100
# 13/13 [==============================] - 13s 988ms/step - c_loss: 0.0529 - c_acc: 0.9975 - p_loss: 0.1918 - p_acc: 0.9339 - val_p_loss: 0.2464 - val_p_acc: 0.9237
# Epoch 77/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0460 - c_acc: 0.9981 - p_loss: 0.2031 - p_acc: 0.9411 - val_p_loss: 0.2660 - val_p_acc: 0.9224
# Epoch 78/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0492 - c_acc: 0.9966 - p_loss: 0.2057 - p_acc: 0.9339 - val_p_loss: 0.2787 - val_p_acc: 0.9135
# Epoch 79/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0445 - c_acc: 0.9985 - p_loss: 0.1969 - p_acc: 0.9435 - val_p_loss: 0.2626 - val_p_acc: 0.9122
# Epoch 80/100
# 13/13 [==============================] - 13s 985ms/step - c_loss: 0.0449 - c_acc: 0.9969 - p_loss: 0.1867 - p_acc: 0.9471 - val_p_loss: 0.2509 - val_p_acc: 0.9275
# Epoch 81/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0459 - c_acc: 0.9978 - p_loss: 0.1704 - p_acc: 0.9507 - val_p_loss: 0.2530 - val_p_acc: 0.9198
# Epoch 82/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0454 - c_acc: 0.9963 - p_loss: 0.1770 - p_acc: 0.9435 - val_p_loss: 0.2839 - val_p_acc: 0.9008
# Epoch 83/100
# 13/13 [==============================] - 13s 975ms/step - c_loss: 0.0442 - c_acc: 0.9975 - p_loss: 0.1726 - p_acc: 0.9483 - val_p_loss: 0.2599 - val_p_acc: 0.9046
# Epoch 84/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0564 - c_acc: 0.9944 - p_loss: 0.1690 - p_acc: 0.9519 - val_p_loss: 0.2554 - val_p_acc: 0.9097
# Epoch 85/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0553 - c_acc: 0.9963 - p_loss: 0.1690 - p_acc: 0.9471 - val_p_loss: 0.2339 - val_p_acc: 0.9160
# Epoch 86/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0562 - c_acc: 0.9947 - p_loss: 0.1819 - p_acc: 0.9411 - val_p_loss: 0.2534 - val_p_acc: 0.9020
# Epoch 87/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0511 - c_acc: 0.9954 - p_loss: 0.1675 - p_acc: 0.9519 - val_p_loss: 0.2529 - val_p_acc: 0.9109
# Epoch 88/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0643 - c_acc: 0.9932 - p_loss: 0.1841 - p_acc: 0.9327 - val_p_loss: 0.2433 - val_p_acc: 0.9059
# Epoch 89/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0639 - c_acc: 0.9935 - p_loss: 0.1954 - p_acc: 0.9279 - val_p_loss: 0.2612 - val_p_acc: 0.9059
# Epoch 90/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0736 - c_acc: 0.9932 - p_loss: 0.1830 - p_acc: 0.9399 - val_p_loss: 0.2827 - val_p_acc: 0.8957
# Epoch 91/100
# 13/13 [==============================] - 13s 979ms/step - c_loss: 0.0628 - c_acc: 0.9951 - p_loss: 0.1800 - p_acc: 0.9459 - val_p_loss: 0.2609 - val_p_acc: 0.9084
# Epoch 92/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0622 - c_acc: 0.9947 - p_loss: 0.1945 - p_acc: 0.9315 - val_p_loss: 0.2885 - val_p_acc: 0.9046
# Epoch 93/100
# 13/13 [==============================] - 13s 977ms/step - c_loss: 0.0689 - c_acc: 0.9907 - p_loss: 0.1812 - p_acc: 0.9375 - val_p_loss: 0.2547 - val_p_acc: 0.9173
# Epoch 94/100
# 13/13 [==============================] - 13s 978ms/step - c_loss: 0.0613 - c_acc: 0.9960 - p_loss: 0.1763 - p_acc: 0.9363 - val_p_loss: 0.2608 - val_p_acc: 0.9084
# Epoch 95/100
# 13/13 [==============================] - ETA: 0s - c_loss: 0.0602 - c_acc: 0.9954 - p_loss: 0.1908 - p_acc: 0.9291Restoring model weights from the end of the best epoch: 80.
# 13/13 [==============================] - 13s 985ms/step - c_loss: 0.0602 - c_acc: 0.9954 - p_loss: 0.1908 - p_acc: 0.9291 - val_p_loss: 0.3191 - val_p_acc: 0.8893
# Epoch 00095: early stopping
# Maximal validation accuracy: 92.75%

# %%
pretraining_model_df = pd.DataFrame(pretraining_history.history)
pretraining_model_df.to_csv( path_model_result + 'pretraining_model_df.csv' )
pretraining_model_df
# Out:
#       c_loss     c_acc    p_loss     p_acc  val_p_loss  val_p_acc
# 0   3.306300  0.222188  2.458947  0.171875    2.491671   0.174300
# 1   2.056402  0.426143  2.325563  0.156250    1.905599   0.201018
# 2   1.550079  0.544190  1.754176  0.283654    1.720769   0.337150
# 3   1.305588  0.631644  1.651934  0.352163    1.587927   0.377863
# 4   1.085718  0.705192  1.602026  0.383413    1.603301   0.418575
# ..       ...       ...       ...       ...         ...        ...
# 90  0.062825  0.995056  0.179950  0.945913    0.260914   0.908397
# 91  0.062167  0.994747  0.194460  0.931490    0.288508   0.904580
# 92  0.068929  0.990729  0.181193  0.937500    0.254675   0.917303
# 93  0.061305  0.995983  0.176324  0.936298    0.260785   0.908397
# 94  0.060209  0.995365  0.190821  0.929087    0.319140   0.889313
#
# [95 rows x 6 columns]

# %% [markdown]
# ## 3-5. Finetuning_model - augmenter image

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(class_num),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4710 - acc: 0.8554WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 15s 284ms/step - loss: 0.4710 - acc: 0.8554 - val_loss: 1.1330 - val_acc: 0.8537
# Epoch 2/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1594 - acc: 0.9538WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.1594 - acc: 0.9538 - val_loss: 0.7313 - val_acc: 0.8537
# Epoch 3/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1330 - acc: 0.9584WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.1330 - acc: 0.9584 - val_loss: 1.3169 - val_acc: 0.7863
# Epoch 4/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0774 - acc: 0.9767WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0774 - acc: 0.9767 - val_loss: 2.9980 - val_acc: 0.5738
# Epoch 5/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0756 - acc: 0.9788WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0756 - acc: 0.9788 - val_loss: 0.6524 - val_acc: 0.8142
# Epoch 6/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0616 - acc: 0.9818WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0616 - acc: 0.9818 - val_loss: 0.4248 - val_acc: 0.9059
# Epoch 7/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0647 - acc: 0.9792WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0647 - acc: 0.9792 - val_loss: 0.4631 - val_acc: 0.9135
# Epoch 8/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0622 - acc: 0.9843WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0622 - acc: 0.9843 - val_loss: 0.7180 - val_acc: 0.8830
# Epoch 9/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0569 - acc: 0.9847WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0569 - acc: 0.9847 - val_loss: 0.4541 - val_acc: 0.9033
# Epoch 10/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0549 - acc: 0.9830WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0549 - acc: 0.9830 - val_loss: 0.7646 - val_acc: 0.8308
# Epoch 11/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0716 - acc: 0.9801WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0716 - acc: 0.9801 - val_loss: 0.9736 - val_acc: 0.8003
# Epoch 12/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0534 - acc: 0.9835WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0534 - acc: 0.9835 - val_loss: 1.2394 - val_acc: 0.8168
# Epoch 13/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0364 - acc: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0364 - acc: 0.9898 - val_loss: 0.3330 - val_acc: 0.9377
# Epoch 14/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0483 - acc: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0483 - acc: 0.9864 - val_loss: 2.6262 - val_acc: 0.7010
# Epoch 15/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0394 - acc: 0.9915WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0394 - acc: 0.9915 - val_loss: 0.1864 - val_acc: 0.9504
# Epoch 16/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0087 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0087 - acc: 0.9966 - val_loss: 0.1886 - val_acc: 0.9631
# Epoch 17/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0506 - acc: 0.9869WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0506 - acc: 0.9869 - val_loss: 0.3759 - val_acc: 0.9033
# Epoch 18/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0424 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0424 - acc: 0.9890 - val_loss: 0.3853 - val_acc: 0.9186
# Epoch 19/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0466 - acc: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0466 - acc: 0.9864 - val_loss: 0.6942 - val_acc: 0.8995
# Epoch 20/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0384 - acc: 0.9881WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0384 - acc: 0.9881 - val_loss: 2.3088 - val_acc: 0.8041
# Epoch 21/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0486 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0486 - acc: 0.9890 - val_loss: 2.8614 - val_acc: 0.7303
# Epoch 22/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0402 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0402 - acc: 0.9890 - val_loss: 1.5570 - val_acc: 0.8244
# Epoch 23/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0151 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0151 - acc: 0.9953 - val_loss: 0.2726 - val_acc: 0.9389
# Epoch 24/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0376 - acc: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0376 - acc: 0.9898 - val_loss: 0.2906 - val_acc: 0.9466
# Epoch 25/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0214 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0214 - acc: 0.9932 - val_loss: 0.2660 - val_acc: 0.9517
# Epoch 26/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0220 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0220 - acc: 0.9932 - val_loss: 0.5809 - val_acc: 0.9033
# Epoch 27/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0277 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0277 - acc: 0.9932 - val_loss: 0.2724 - val_acc: 0.9364
# Epoch 28/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0218 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0218 - acc: 0.9945 - val_loss: 0.6596 - val_acc: 0.8740
# Epoch 29/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0310 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0310 - acc: 0.9941 - val_loss: 0.2606 - val_acc: 0.9402
# Epoch 30/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0401 - acc: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0401 - acc: 0.9894 - val_loss: 0.2780 - val_acc: 0.9389
# Epoch 31/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0259 - acc: 0.9919WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0259 - acc: 0.9919 - val_loss: 0.2756 - val_acc: 0.9288
# Epoch 32/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0422 - acc: 0.9902WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0422 - acc: 0.9902 - val_loss: 0.3837 - val_acc: 0.9160
# Epoch 33/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0380 - acc: 0.9919WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0380 - acc: 0.9919 - val_loss: 0.2521 - val_acc: 0.9389
# Epoch 34/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0521 - acc: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0521 - acc: 0.9864 - val_loss: 1.4984 - val_acc: 0.7634
# Epoch 35/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0477 - acc: 0.9885WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0477 - acc: 0.9885 - val_loss: 1.3446 - val_acc: 0.8066
# Epoch 36/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0089 - acc: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0089 - acc: 0.9970 - val_loss: 0.4972 - val_acc: 0.9033
# Epoch 37/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9992WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0032 - acc: 0.9992 - val_loss: 0.2261 - val_acc: 0.9542
# Epoch 38/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0136 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0136 - acc: 0.9945 - val_loss: 1.5237 - val_acc: 0.8473
# Epoch 39/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0125 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0125 - acc: 0.9953 - val_loss: 0.2960 - val_acc: 0.9555
# Epoch 40/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0062 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0062 - acc: 0.9979 - val_loss: 0.1472 - val_acc: 0.9656
# Epoch 41/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0111 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0111 - acc: 0.9979 - val_loss: 0.1592 - val_acc: 0.9618
# Epoch 42/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0150 - acc: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0150 - acc: 0.9962 - val_loss: 0.0932 - val_acc: 0.9758
# Epoch 43/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0140 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0140 - acc: 0.9975 - val_loss: 0.1527 - val_acc: 0.9542
# Epoch 44/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0055 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0055 - acc: 0.9979 - val_loss: 0.0978 - val_acc: 0.9707
# Epoch 45/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0045 - acc: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0045 - acc: 0.9983 - val_loss: 0.0976 - val_acc: 0.9682
# Epoch 46/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0161 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0161 - acc: 0.9953 - val_loss: 0.3189 - val_acc: 0.9453
# Epoch 47/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0223 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0223 - acc: 0.9945 - val_loss: 0.5536 - val_acc: 0.8868
# Epoch 48/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0184 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0184 - acc: 0.9941 - val_loss: 0.3631 - val_acc: 0.9109
# Epoch 49/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0198 - acc: 0.9949WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0198 - acc: 0.9949 - val_loss: 0.3961 - val_acc: 0.9135
# Epoch 50/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0173 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0173 - acc: 0.9945 - val_loss: 0.3283 - val_acc: 0.9338
# Epoch 51/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0198 - acc: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0198 - acc: 0.9962 - val_loss: 0.1933 - val_acc: 0.9517
# Epoch 52/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0274 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0274 - acc: 0.9941 - val_loss: 0.5218 - val_acc: 0.9173
# Epoch 53/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0307 - acc: 0.9894WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0307 - acc: 0.9894 - val_loss: 0.1841 - val_acc: 0.9478
# Epoch 54/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0103 - acc: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0103 - acc: 0.9970 - val_loss: 0.3102 - val_acc: 0.9275
# Epoch 55/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0193 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0193 - acc: 0.9953 - val_loss: 0.5840 - val_acc: 0.9097
# Epoch 56/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0161 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0161 - acc: 0.9958 - val_loss: 0.3210 - val_acc: 0.9389
# Epoch 57/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0080 - acc: 0.9992WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0080 - acc: 0.9992 - val_loss: 0.2149 - val_acc: 0.9542
# Epoch 58/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0094 - acc: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0094 - acc: 0.9970 - val_loss: 0.1851 - val_acc: 0.9656
# Epoch 59/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0251 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0251 - acc: 0.9932 - val_loss: 0.2021 - val_acc: 0.9402
# Epoch 60/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0243 - acc: 0.9924WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0243 - acc: 0.9924 - val_loss: 0.5737 - val_acc: 0.8664
# Epoch 61/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0345 - acc: 0.9915WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0345 - acc: 0.9915 - val_loss: 1.1938 - val_acc: 0.8359
# Epoch 62/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0200 - acc: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0200 - acc: 0.9941 - val_loss: 0.3335 - val_acc: 0.9300
# Epoch 63/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0075 - acc: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0075 - acc: 0.9983 - val_loss: 0.2493 - val_acc: 0.9415
# Epoch 64/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0017 - acc: 0.9996 - val_loss: 0.1439 - val_acc: 0.9631
# Epoch 65/100
# 37/37 [==============================] - ETA: 0s - loss: 7.3975e-04 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 7.3975e-04 - acc: 0.9996 - val_loss: 0.1058 - val_acc: 0.9669
# Epoch 66/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0026 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0026 - acc: 0.9996 - val_loss: 0.2070 - val_acc: 0.9567
# Epoch 67/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9987WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0024 - acc: 0.9987 - val_loss: 0.0814 - val_acc: 0.9771
# Epoch 68/100
# 37/37 [==============================] - ETA: 0s - loss: 4.6006e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 4.6006e-04 - acc: 1.0000 - val_loss: 0.0789 - val_acc: 0.9822
# Epoch 69/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0053 - acc: 0.9987WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0053 - acc: 0.9987 - val_loss: 0.1545 - val_acc: 0.9682
# Epoch 70/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0240 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0240 - acc: 0.9945 - val_loss: 0.2433 - val_acc: 0.9338
# Epoch 71/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0285 - acc: 0.9949WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0285 - acc: 0.9949 - val_loss: 0.4292 - val_acc: 0.9300
# Epoch 72/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0233 - acc: 0.9936WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0233 - acc: 0.9936 - val_loss: 0.2158 - val_acc: 0.9606
# Epoch 73/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0402 - acc: 0.9881WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0402 - acc: 0.9881 - val_loss: 0.9666 - val_acc: 0.8677
# Epoch 74/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0484 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0484 - acc: 0.9890 - val_loss: 0.9204 - val_acc: 0.7875
# Epoch 75/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0214 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0214 - acc: 0.9953 - val_loss: 0.7613 - val_acc: 0.8524
# Epoch 76/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0203 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0203 - acc: 0.9953 - val_loss: 0.2384 - val_acc: 0.9389
# Epoch 77/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0123 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0123 - acc: 0.9966 - val_loss: 0.6000 - val_acc: 0.8753
# Epoch 78/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0163 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0163 - acc: 0.9953 - val_loss: 0.5588 - val_acc: 0.9148
# Epoch 79/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0210 - acc: 0.9945WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0210 - acc: 0.9945 - val_loss: 0.6740 - val_acc: 0.8868
# Epoch 80/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0332 - acc: 0.9902WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0332 - acc: 0.9902 - val_loss: 0.1381 - val_acc: 0.9644
# Epoch 81/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0213 - acc: 0.9949WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0213 - acc: 0.9949 - val_loss: 0.2801 - val_acc: 0.9529
# Epoch 82/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0152 - acc: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0152 - acc: 0.9962 - val_loss: 0.0975 - val_acc: 0.9746
# Epoch 83/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0048 - acc: 0.9992WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0048 - acc: 0.9992 - val_loss: 0.0994 - val_acc: 0.9682
# Epoch 84/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0111 - acc: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0111 - acc: 0.9970 - val_loss: 0.7800 - val_acc: 0.8626
# Epoch 85/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0106 - acc: 0.9966WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0106 - acc: 0.9966 - val_loss: 0.2478 - val_acc: 0.9313
# Epoch 86/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0075 - acc: 0.9987WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0075 - acc: 0.9987 - val_loss: 0.5035 - val_acc: 0.9097
# Epoch 87/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0057 - acc: 0.9987WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0057 - acc: 0.9987 - val_loss: 0.1703 - val_acc: 0.9580
# Epoch 88/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0010 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0010 - acc: 0.9996 - val_loss: 0.1314 - val_acc: 0.9682
# Epoch 89/100
# 37/37 [==============================] - ETA: 0s - loss: 5.5185e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 5.5185e-04 - acc: 1.0000 - val_loss: 0.0793 - val_acc: 0.9809
# Epoch 90/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0034 - acc: 0.9996 - val_loss: 0.1195 - val_acc: 0.9682
# Epoch 91/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0064 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0064 - acc: 0.9979 - val_loss: 0.2536 - val_acc: 0.9517
# Epoch 92/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0012 - acc: 0.9996WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0012 - acc: 0.9996 - val_loss: 0.1163 - val_acc: 0.9746
# Epoch 93/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9983WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0038 - acc: 0.9983 - val_loss: 0.0740 - val_acc: 0.9822
# Epoch 94/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0237 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0237 - acc: 0.9932 - val_loss: 0.1987 - val_acc: 0.9644
# Epoch 95/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0235 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0235 - acc: 0.9958 - val_loss: 0.2820 - val_acc: 0.9427
# Epoch 96/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0072 - acc: 0.9975WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0072 - acc: 0.9975 - val_loss: 0.1527 - val_acc: 0.9695
# Epoch 97/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0524 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0524 - acc: 0.9890 - val_loss: 5.1299 - val_acc: 0.7875
# Epoch 98/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0460 - acc: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0460 - acc: 0.9864 - val_loss: 1.0053 - val_acc: 0.8550
# Epoch 99/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0384 - acc: 0.9890WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 265ms/step - loss: 0.0384 - acc: 0.9890 - val_loss: 1.9716 - val_acc: 0.7761
# Epoch 100/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0438 - acc: 0.9864WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 37/37 [==============================] - 10s 266ms/step - loss: 0.0438 - acc: 0.9864 - val_loss: 0.3341 - val_acc: 0.9453
# Maximal validation accuracy: 98.22%

# %%
finetuning_model_df = pd.DataFrame(finetuning_history.history)
finetuning_model_df.to_csv( path_model_result + 'finetuning_model_df.csv' )
finetuning_model_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.471037  0.855386  1.133025  0.853690
# 1   0.159424  0.953774  0.731281  0.853690
# 2   0.132955  0.958439  1.316878  0.786260
# 3   0.077370  0.976675  2.997957  0.573791
# 4   0.075571  0.978796  0.652442  0.814249
# ..       ...       ...       ...       ...
# 95  0.007157  0.997455  0.152720  0.969466
# 96  0.052444  0.988974  5.129917  0.787532
# 97  0.046026  0.986429  1.005322  0.854962
# 98  0.038352  0.988974  1.971576  0.776081
# 99  0.043828  0.986429  0.334123  0.945293
#
# [100 rows x 4 columns]

# %% [markdown]
# ## 4. Result Report

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history):
    for metric_key, metric_name in zip(["acc", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_model_original_image_history.history[f"val_{metric_key}"], label="original_image baseline"
        )
        plt.plot(
            baseline_model_augmenter_image_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")

plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history)

# %%
print (max(baseline_model_original_image_history.history["val_acc"]) * 100)
print (max(baseline_model_augmenter_image_history.history["val_acc"]) * 100)
print (max(pretraining_history.history["val_p_acc"]) * 100)
print (max(finetuning_history.history["val_acc"]) * 100)
# Out:
# 96.94656729698181
# 95.80152630805969
# 92.7480936050415
# 98.21882843971252

# %% [markdown]
# ## 5. Model Save

# %%
save_model = keras.Sequential(
    [
        pretraining_model.encoder,
    ],
    name="pretraining_model",
)

save_model.summary()
# Out:
# Model: "pretraining_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 128)               21123752
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.ckpt' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: gdrive/My Drive/Research_7_2_1/model_result/3 - SimCLR_model_result - 1/pretraining_model_encoder.ckpt/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
