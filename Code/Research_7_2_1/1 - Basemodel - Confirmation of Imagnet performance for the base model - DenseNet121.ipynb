# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5979345423006063597
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10125226100969453245
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 18:52:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'DenseNet121'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 7
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2", "S3", "S4", "S5", "S6"
T_all_labels = "T0", "T1", "T2", "T3", "T4", "T5", "T6"

#base_path = ''
base_path = 'gdrive/My Drive/Research_7_2_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_DenseNet121_None S_DenseNet121_imagenet T_DenseNet121_None T_DenseNet121_imagenet
# ['S_DenseNet121_imagenet',
#  'S_DenseNet121_None',
#  'T_DenseNet121_imagenet',
#  'T_DenseNet121_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2358, 128, 128, 3) (2358, 1)
# (786, 128, 128, 3) (786, 1)
# (786, 128, 128, 3) (786, 1)
#
# (2598, 128, 128, 3) (2598, 1)
# (866, 128, 128, 3) (866, 1)
# (866, 128, 128, 3) (866, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (2358, 128, 128, 3) (2358, 7)
# (786, 128, 128, 3) (786, 7)
# (786, 128, 128, 3) (786, 7)
#
# (2598, 128, 128, 3) (2598, 7)
# (866, 128, 128, 3) (866, 7)
# (866, 128, 128, 3) (866, 7)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2358
# xTrain_S image Numbers // 10 :  235
# 11

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  2598
# xTrain_S image Numbers // 10 :  259
# 11

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.DenseNet121 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 32s 268ms/step - loss: 1.1166 - accuracy: 0.6086 - val_loss: 3.1764 - val_accuracy: 0.0560
# Epoch 2/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.6267 - accuracy: 0.7913 - val_loss: 2.3183 - val_accuracy: 0.2786
# Epoch 3/100
# 37/37 [==============================] - 6s 170ms/step - loss: 0.4999 - accuracy: 0.8350 - val_loss: 7.0283 - val_accuracy: 0.1170
# Epoch 4/100
# 37/37 [==============================] - 6s 165ms/step - loss: 0.4514 - accuracy: 0.8571 - val_loss: 3.2678 - val_accuracy: 0.1539
# Epoch 5/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.3895 - accuracy: 0.8723 - val_loss: 7.9918 - val_accuracy: 0.0560
# Epoch 6/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.3450 - accuracy: 0.8813 - val_loss: 4.6822 - val_accuracy: 0.1616
# Epoch 7/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.2754 - accuracy: 0.9037 - val_loss: 6.7708 - val_accuracy: 0.0598
# Epoch 8/100
# 37/37 [==============================] - 6s 161ms/step - loss: 0.2329 - accuracy: 0.9215 - val_loss: 3.1670 - val_accuracy: 0.2888
# Epoch 9/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.2593 - accuracy: 0.9080 - val_loss: 4.5954 - val_accuracy: 0.1616
# Epoch 10/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.2339 - accuracy: 0.9215 - val_loss: 6.0395 - val_accuracy: 0.1120
# Epoch 11/100
# 37/37 [==============================] - 6s 161ms/step - loss: 0.1897 - accuracy: 0.9334 - val_loss: 3.0034 - val_accuracy: 0.3410
# Epoch 12/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.1620 - accuracy: 0.9432 - val_loss: 4.0115 - val_accuracy: 0.3601
# Epoch 13/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.1729 - accuracy: 0.9406 - val_loss: 6.0656 - val_accuracy: 0.1679
# Epoch 14/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.1416 - accuracy: 0.9508 - val_loss: 0.9185 - val_accuracy: 0.7405
# Epoch 15/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1129 - accuracy: 0.9631 - val_loss: 11.7402 - val_accuracy: 0.1450
# Epoch 16/100
# 37/37 [==============================] - 6s 159ms/step - loss: 0.1145 - accuracy: 0.9601 - val_loss: 1.4510 - val_accuracy: 0.6997
# Epoch 17/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1579 - accuracy: 0.9500 - val_loss: 2.3669 - val_accuracy: 0.5433
# Epoch 18/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1172 - accuracy: 0.9606 - val_loss: 1.7581 - val_accuracy: 0.5598
# Epoch 19/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0901 - accuracy: 0.9682 - val_loss: 1.8521 - val_accuracy: 0.6679
# Epoch 20/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.1030 - accuracy: 0.9678 - val_loss: 1.1728 - val_accuracy: 0.7430
# Epoch 21/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0793 - accuracy: 0.9720 - val_loss: 3.9337 - val_accuracy: 0.4644
# Epoch 22/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.1028 - accuracy: 0.9686 - val_loss: 1.8492 - val_accuracy: 0.6221
# Epoch 23/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0815 - accuracy: 0.9695 - val_loss: 2.3425 - val_accuracy: 0.6094
# Epoch 24/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.5580 - val_accuracy: 0.8651
# Epoch 25/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0570 - accuracy: 0.9830 - val_loss: 0.9723 - val_accuracy: 0.8003
# Epoch 26/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1000 - accuracy: 0.9703 - val_loss: 2.2101 - val_accuracy: 0.6209
# Epoch 27/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.1487 - accuracy: 0.9483 - val_loss: 4.5061 - val_accuracy: 0.3639
# Epoch 28/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0871 - accuracy: 0.9724 - val_loss: 2.0626 - val_accuracy: 0.6641
# Epoch 29/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0497 - accuracy: 0.9877 - val_loss: 1.0622 - val_accuracy: 0.7850
# Epoch 30/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0530 - accuracy: 0.9822 - val_loss: 1.1054 - val_accuracy: 0.7481
# Epoch 31/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0261 - accuracy: 0.9924 - val_loss: 0.8560 - val_accuracy: 0.8053
# Epoch 32/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0305 - accuracy: 0.9860 - val_loss: 3.1393 - val_accuracy: 0.5331
# Epoch 33/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0689 - accuracy: 0.9771 - val_loss: 4.5546 - val_accuracy: 0.4338
# Epoch 34/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0928 - accuracy: 0.9665 - val_loss: 3.4030 - val_accuracy: 0.5878
# Epoch 35/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0602 - accuracy: 0.9813 - val_loss: 3.9985 - val_accuracy: 0.5038
# Epoch 36/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0337 - accuracy: 0.9894 - val_loss: 0.8124 - val_accuracy: 0.8092
# Epoch 37/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0622 - accuracy: 0.9792 - val_loss: 3.5373 - val_accuracy: 0.5547
# Epoch 38/100
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0418 - accuracy: 0.9869 - val_loss: 3.9771 - val_accuracy: 0.6081
# Epoch 39/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0419 - accuracy: 0.9864 - val_loss: 2.4711 - val_accuracy: 0.5687
# Epoch 40/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0366 - accuracy: 0.9860 - val_loss: 1.7325 - val_accuracy: 0.6819
# Epoch 41/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0816 - accuracy: 0.9750 - val_loss: 4.5872 - val_accuracy: 0.5013
# Epoch 42/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0756 - accuracy: 0.9767 - val_loss: 2.2060 - val_accuracy: 0.6578
# Epoch 43/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0582 - accuracy: 0.9796 - val_loss: 2.2682 - val_accuracy: 0.6260
# Epoch 44/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.6957 - val_accuracy: 0.8130
# Epoch 45/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 1.0284 - val_accuracy: 0.7774
# Epoch 46/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.7367 - val_accuracy: 0.8499
# Epoch 47/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0501 - accuracy: 0.9864 - val_loss: 1.7296 - val_accuracy: 0.6692
# Epoch 48/100
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0565 - accuracy: 0.9826 - val_loss: 3.2180 - val_accuracy: 0.5293
# Epoch 49/100
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0404 - accuracy: 0.9864 - val_loss: 0.5003 - val_accuracy: 0.8753
# Epoch 50/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0185 - accuracy: 0.9932 - val_loss: 0.7247 - val_accuracy: 0.8372
# Epoch 51/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.9208 - val_accuracy: 0.7850
# Epoch 52/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0145 - accuracy: 0.9941 - val_loss: 1.9275 - val_accuracy: 0.7226
# Epoch 53/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0355 - accuracy: 0.9902 - val_loss: 3.6612 - val_accuracy: 0.5573
# Epoch 54/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0409 - accuracy: 0.9885 - val_loss: 1.6299 - val_accuracy: 0.6756
# Epoch 55/100
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.2676 - val_accuracy: 0.9224
# Epoch 56/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0493 - accuracy: 0.9835 - val_loss: 6.4573 - val_accuracy: 0.4555
# Epoch 57/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0691 - accuracy: 0.9788 - val_loss: 0.7206 - val_accuracy: 0.8575
# Epoch 58/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0431 - accuracy: 0.9822 - val_loss: 3.4371 - val_accuracy: 0.4746
# Epoch 59/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 3.8665 - val_accuracy: 0.4669
# Epoch 60/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0389 - accuracy: 0.9902 - val_loss: 2.9957 - val_accuracy: 0.5840
# Epoch 61/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.4893 - val_accuracy: 0.8702
# Epoch 62/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 1.2614 - val_accuracy: 0.7366
# Epoch 63/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0147 - accuracy: 0.9945 - val_loss: 7.1945 - val_accuracy: 0.3639
# Epoch 64/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.4076 - val_accuracy: 0.9020
# Epoch 65/100
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0099 - accuracy: 0.9979 - val_loss: 0.2753 - val_accuracy: 0.9300
# Epoch 66/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.4889 - val_accuracy: 0.8842
# Epoch 67/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.9587 - val_accuracy: 0.8295
# Epoch 68/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0063 - accuracy: 0.9970 - val_loss: 1.1018 - val_accuracy: 0.7812
# Epoch 69/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 1.0693 - val_accuracy: 0.8333
# Epoch 70/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.6421 - val_accuracy: 0.8690
# Epoch 71/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 1.4468 - val_accuracy: 0.7672
# Epoch 72/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0347 - accuracy: 0.9890 - val_loss: 9.9335 - val_accuracy: 0.3372
# Epoch 73/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0982 - accuracy: 0.9686 - val_loss: 5.1132 - val_accuracy: 0.3906
# Epoch 74/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0529 - accuracy: 0.9830 - val_loss: 3.9032 - val_accuracy: 0.5242
# Epoch 75/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0745 - accuracy: 0.9767 - val_loss: 1.7657 - val_accuracy: 0.6959
# Epoch 76/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0292 - accuracy: 0.9936 - val_loss: 1.3879 - val_accuracy: 0.7379
# Epoch 77/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 1.4291 - val_accuracy: 0.7392
# Epoch 78/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.7376 - val_accuracy: 0.8308
# Epoch 79/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.9730 - val_accuracy: 0.7710
# Epoch 80/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0369 - accuracy: 0.9890 - val_loss: 2.7527 - val_accuracy: 0.5865
# Epoch 81/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0358 - accuracy: 0.9881 - val_loss: 1.2556 - val_accuracy: 0.8066
# Epoch 82/100
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0225 - accuracy: 0.9936 - val_loss: 2.5240 - val_accuracy: 0.6565
# Epoch 83/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0306 - accuracy: 0.9902 - val_loss: 1.6468 - val_accuracy: 0.7405
# Epoch 84/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0287 - accuracy: 0.9898 - val_loss: 0.6051 - val_accuracy: 0.8753
# Epoch 85/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 2.3711 - val_accuracy: 0.6489
# Epoch 86/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.6738 - val_accuracy: 0.8486
# Epoch 87/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 3.6084 - val_accuracy: 0.5407
# Epoch 88/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0336 - accuracy: 0.9894 - val_loss: 4.0959 - val_accuracy: 0.4733
# Epoch 89/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0332 - accuracy: 0.9898 - val_loss: 3.0537 - val_accuracy: 0.5674
# Epoch 90/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0221 - accuracy: 0.9924 - val_loss: 3.9857 - val_accuracy: 0.5789
# Epoch 91/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0144 - accuracy: 0.9941 - val_loss: 4.1170 - val_accuracy: 0.5013
# Epoch 92/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.3063 - val_accuracy: 0.9148
# Epoch 93/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0163 - accuracy: 0.9949 - val_loss: 1.3019 - val_accuracy: 0.7723
# Epoch 94/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 1.5666 - val_accuracy: 0.7074
# Epoch 95/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9885Restoring model weights from the end of the best epoch: 65.
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0328 - accuracy: 0.9885 - val_loss: 1.4485 - val_accuracy: 0.7595
# Epoch 00095: early stopping
# Maximal validation accuracy: 93.00%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.116578  0.608567  3.176395      0.055980
# 1   0.626657  0.791349  2.318263      0.278626
# 2   0.499933  0.835030  7.028348      0.117048
# 3   0.451358  0.857082  3.267813      0.153944
# 4   0.389493  0.872349  7.991824      0.055980
# ..       ...       ...       ...           ...
# 90  0.014416  0.994063  4.116957      0.501272
# 91  0.011415  0.996183  0.306335      0.914758
# 92  0.016280  0.994911  1.301855      0.772265
# 93  0.033591  0.987701  1.566556      0.707379
# 94  0.032843  0.988550  1.448489      0.759542
#
# [95 rows x 4 columns]

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.2675749361515045
# Maximum validation accuracy: 0.9300254583358765

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 31ms/step - loss: 0.3227 - accuracy: 0.9237
# test loss, test acc: [0.322712779045105, 0.9236640930175781]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 25/25 [==============================] - 3s 31ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 21s 227ms/step - loss: 0.4719 - accuracy: 0.8270 - val_loss: 6.4765 - val_accuracy: 0.5420
# Epoch 2/100
# 37/37 [==============================] - 6s 163ms/step - loss: 0.1926 - accuracy: 0.9415 - val_loss: 4.6072 - val_accuracy: 0.5649
# Epoch 3/100
# 37/37 [==============================] - 6s 163ms/step - loss: 0.1163 - accuracy: 0.9589 - val_loss: 5.1423 - val_accuracy: 0.5992
# Epoch 4/100
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0735 - accuracy: 0.9771 - val_loss: 4.1834 - val_accuracy: 0.6641
# Epoch 5/100
# 37/37 [==============================] - 6s 164ms/step - loss: 0.0864 - accuracy: 0.9695 - val_loss: 0.7480 - val_accuracy: 0.8461
# Epoch 6/100
# 37/37 [==============================] - 6s 159ms/step - loss: 0.1256 - accuracy: 0.9589 - val_loss: 0.7355 - val_accuracy: 0.8003
# Epoch 7/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0785 - accuracy: 0.9729 - val_loss: 2.3615 - val_accuracy: 0.6527
# Epoch 8/100
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0419 - accuracy: 0.9881 - val_loss: 0.2471 - val_accuracy: 0.9338
# Epoch 9/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0422 - accuracy: 0.9869 - val_loss: 1.2765 - val_accuracy: 0.7786
# Epoch 10/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0717 - accuracy: 0.9775 - val_loss: 0.3491 - val_accuracy: 0.9160
# Epoch 11/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0832 - accuracy: 0.9750 - val_loss: 1.3425 - val_accuracy: 0.7837
# Epoch 12/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0410 - accuracy: 0.9885 - val_loss: 0.5481 - val_accuracy: 0.8728
# Epoch 13/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0273 - accuracy: 0.9932 - val_loss: 0.8760 - val_accuracy: 0.8104
# Epoch 14/100
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.0918 - val_accuracy: 0.9758
# Epoch 15/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0166 - accuracy: 0.9962 - val_loss: 0.1901 - val_accuracy: 0.9504
# Epoch 16/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0197 - accuracy: 0.9919 - val_loss: 0.3933 - val_accuracy: 0.9313
# Epoch 17/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0388 - accuracy: 0.9894 - val_loss: 2.8069 - val_accuracy: 0.6489
# Epoch 18/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0434 - accuracy: 0.9856 - val_loss: 3.1860 - val_accuracy: 0.5700
# Epoch 19/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0751 - accuracy: 0.9775 - val_loss: 1.0954 - val_accuracy: 0.7913
# Epoch 20/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0296 - accuracy: 0.9894 - val_loss: 0.1502 - val_accuracy: 0.9631
# Epoch 21/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.3425 - val_accuracy: 0.9211
# Epoch 22/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.1340 - val_accuracy: 0.9669
# Epoch 23/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0339 - accuracy: 0.9877 - val_loss: 1.6357 - val_accuracy: 0.7290
# Epoch 24/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0245 - accuracy: 0.9902 - val_loss: 0.4644 - val_accuracy: 0.8957
# Epoch 25/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0250 - accuracy: 0.9928 - val_loss: 1.0191 - val_accuracy: 0.8206
# Epoch 26/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0320 - accuracy: 0.9890 - val_loss: 0.3273 - val_accuracy: 0.9262
# Epoch 27/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0437 - accuracy: 0.9869 - val_loss: 0.2423 - val_accuracy: 0.9478
# Epoch 28/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0593 - accuracy: 0.9847 - val_loss: 2.4863 - val_accuracy: 0.7290
# Epoch 29/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0366 - accuracy: 0.9898 - val_loss: 0.3562 - val_accuracy: 0.9198
# Epoch 30/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0180 - accuracy: 0.9953 - val_loss: 0.4140 - val_accuracy: 0.9173
# Epoch 31/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0348 - accuracy: 0.9907 - val_loss: 1.9736 - val_accuracy: 0.7557
# Epoch 32/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.7226 - val_accuracy: 0.8079
# Epoch 33/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.1152 - val_accuracy: 0.9644
# Epoch 34/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9966Restoring model weights from the end of the best epoch: 14.
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.2469 - val_accuracy: 0.9313
# Epoch 00034: early stopping
# Maximal validation accuracy: 97.58%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.471900  0.826972  6.476537      0.541985
# 1   0.192569  0.941476  4.607157      0.564885
# 2   0.116278  0.958863  5.142294      0.599237
# 3   0.073492  0.977099  4.183392      0.664122
# 4   0.086416  0.969466  0.748000      0.846056
# 5   0.125593  0.958863  0.735513      0.800254
# 6   0.078496  0.972858  2.361462      0.652672
# 7   0.041904  0.988126  0.247109      0.933842
# 8   0.042234  0.986853  1.276531      0.778626
# 9   0.071672  0.977523  0.349056      0.916031
# 10  0.083193  0.974979  1.342517      0.783715
# 11  0.041015  0.988550  0.548101      0.872774
# 12  0.027250  0.993215  0.875982      0.810433
# 13  0.014112  0.995759  0.091769      0.975827
# 14  0.016557  0.996183  0.190130      0.950382
# 15  0.019713  0.991942  0.393310      0.931298
# 16  0.038810  0.989398  2.806852      0.648855
# 17  0.043369  0.985581  3.185982      0.569975
# 18  0.075116  0.977523  1.095376      0.791349
# 19  0.029573  0.989398  0.150234      0.963104
# 20  0.011474  0.996183  0.342503      0.921120
# 21  0.006866  0.997880  0.134024      0.966921
# 22  0.033903  0.987701  1.635728      0.729008
# 23  0.024518  0.990246  0.464432      0.895674
# 24  0.024965  0.992791  1.019134      0.820611
# 25  0.032038  0.988974  0.327316      0.926209
# 26  0.043742  0.986853  0.242277      0.947837
# 27  0.059284  0.984733  2.486281      0.729008
# 28  0.036611  0.989822  0.356182      0.919847
# 29  0.017959  0.995335  0.413965      0.917303
# 30  0.034827  0.990670  1.973613      0.755725
# 31  0.027187  0.991942  0.722553      0.807888
# 32  0.004020  0.999576  0.115183      0.964377
# 33  0.010385  0.996607  0.246917      0.931298

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.0917685404419899
# Maximum validation accuracy: 0.9758269786834717

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 25/25 [==============================] - 1s 33ms/step - loss: 0.1176 - accuracy: 0.9656
# test loss, test acc: [0.11761024594306946, 0.9656488299369812]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 25/25 [==============================] - 3s 32ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 23s 248ms/step - loss: 1.1266 - accuracy: 0.5897 - val_loss: 2.2599 - val_accuracy: 0.1155
# Epoch 2/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.7193 - accuracy: 0.7375 - val_loss: 6.6220 - val_accuracy: 0.1155
# Epoch 3/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.6167 - accuracy: 0.7841 - val_loss: 9.6072 - val_accuracy: 0.1155
# Epoch 4/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.5457 - accuracy: 0.8018 - val_loss: 7.7403 - val_accuracy: 0.1155
# Epoch 5/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.4891 - accuracy: 0.8199 - val_loss: 9.4725 - val_accuracy: 0.1155
# Epoch 6/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.4645 - accuracy: 0.8183 - val_loss: 10.4536 - val_accuracy: 0.1166
# Epoch 7/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.3883 - accuracy: 0.8526 - val_loss: 2.9145 - val_accuracy: 0.3048
# Epoch 8/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.3660 - accuracy: 0.8630 - val_loss: 4.4335 - val_accuracy: 0.1709
# Epoch 9/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.3774 - accuracy: 0.8584 - val_loss: 2.8504 - val_accuracy: 0.3626
# Epoch 10/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.2967 - accuracy: 0.8915 - val_loss: 2.3802 - val_accuracy: 0.4734
# Epoch 11/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.3029 - accuracy: 0.8838 - val_loss: 4.5876 - val_accuracy: 0.2737
# Epoch 12/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.2794 - accuracy: 0.8845 - val_loss: 0.8517 - val_accuracy: 0.7286
# Epoch 13/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.2788 - accuracy: 0.8926 - val_loss: 3.0973 - val_accuracy: 0.4042
# Epoch 14/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.2460 - accuracy: 0.9107 - val_loss: 2.7744 - val_accuracy: 0.5566
# Epoch 15/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.2493 - accuracy: 0.9061 - val_loss: 1.6998 - val_accuracy: 0.6467
# Epoch 16/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.2219 - accuracy: 0.9099 - val_loss: 2.7191 - val_accuracy: 0.5081
# Epoch 17/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.2038 - accuracy: 0.9207 - val_loss: 1.6138 - val_accuracy: 0.6339
# Epoch 18/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.2121 - accuracy: 0.9157 - val_loss: 0.7044 - val_accuracy: 0.8025
# Epoch 19/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.1592 - accuracy: 0.9396 - val_loss: 2.0624 - val_accuracy: 0.5508
# Epoch 20/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1556 - accuracy: 0.9396 - val_loss: 1.1153 - val_accuracy: 0.6836
# Epoch 21/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1347 - accuracy: 0.9496 - val_loss: 1.4347 - val_accuracy: 0.6732
# Epoch 22/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1798 - accuracy: 0.9273 - val_loss: 1.4568 - val_accuracy: 0.6455
# Epoch 23/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1673 - accuracy: 0.9380 - val_loss: 1.6440 - val_accuracy: 0.6617
# Epoch 24/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1404 - accuracy: 0.9473 - val_loss: 3.4004 - val_accuracy: 0.5739
# Epoch 25/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1112 - accuracy: 0.9619 - val_loss: 1.5176 - val_accuracy: 0.6524
# Epoch 26/100
# 41/41 [==============================] - 7s 162ms/step - loss: 0.0801 - accuracy: 0.9704 - val_loss: 0.7781 - val_accuracy: 0.8141
# Epoch 27/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1201 - accuracy: 0.9577 - val_loss: 1.5031 - val_accuracy: 0.6755
# Epoch 28/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1350 - accuracy: 0.9511 - val_loss: 2.6425 - val_accuracy: 0.5635
# Epoch 29/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1466 - accuracy: 0.9492 - val_loss: 2.9579 - val_accuracy: 0.5439
# Epoch 30/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1080 - accuracy: 0.9615 - val_loss: 1.2057 - val_accuracy: 0.7298
# Epoch 31/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1025 - accuracy: 0.9607 - val_loss: 1.0914 - val_accuracy: 0.7321
# Epoch 32/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1050 - accuracy: 0.9596 - val_loss: 1.5962 - val_accuracy: 0.6998
# Epoch 33/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0740 - accuracy: 0.9719 - val_loss: 3.0760 - val_accuracy: 0.4215
# Epoch 34/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0577 - accuracy: 0.9800 - val_loss: 1.3802 - val_accuracy: 0.6721
# Epoch 35/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0399 - accuracy: 0.9854 - val_loss: 0.6765 - val_accuracy: 0.8256
# Epoch 36/100
# 41/41 [==============================] - 7s 160ms/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.6516 - val_accuracy: 0.8603
# Epoch 37/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0549 - accuracy: 0.9808 - val_loss: 1.7001 - val_accuracy: 0.6605
# Epoch 38/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0905 - accuracy: 0.9715 - val_loss: 3.4299 - val_accuracy: 0.4919
# Epoch 39/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0571 - accuracy: 0.9765 - val_loss: 1.9895 - val_accuracy: 0.6617
# Epoch 40/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0486 - accuracy: 0.9827 - val_loss: 3.1606 - val_accuracy: 0.6143
# Epoch 41/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0576 - accuracy: 0.9808 - val_loss: 1.1418 - val_accuracy: 0.7748
# Epoch 42/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0613 - accuracy: 0.9792 - val_loss: 2.1358 - val_accuracy: 0.6374
# Epoch 43/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0587 - accuracy: 0.9804 - val_loss: 2.1205 - val_accuracy: 0.6952
# Epoch 44/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0633 - accuracy: 0.9765 - val_loss: 1.9231 - val_accuracy: 0.6536
# Epoch 45/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.1038 - accuracy: 0.9638 - val_loss: 5.0945 - val_accuracy: 0.5162
# Epoch 46/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0791 - accuracy: 0.9727 - val_loss: 1.9595 - val_accuracy: 0.6351
# Epoch 47/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0595 - accuracy: 0.9834 - val_loss: 3.7202 - val_accuracy: 0.5358
# Epoch 48/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0349 - accuracy: 0.9877 - val_loss: 6.9682 - val_accuracy: 0.3903
# Epoch 49/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0379 - accuracy: 0.9877 - val_loss: 1.3512 - val_accuracy: 0.7217
# Epoch 50/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 1.0416 - val_accuracy: 0.7818
# Epoch 51/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 1.1864 - val_accuracy: 0.7506
# Epoch 52/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0169 - accuracy: 0.9954 - val_loss: 2.5257 - val_accuracy: 0.6120
# Epoch 53/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0521 - accuracy: 0.9842 - val_loss: 1.5412 - val_accuracy: 0.7159
# Epoch 54/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0464 - accuracy: 0.9831 - val_loss: 0.9652 - val_accuracy: 0.8072
# Epoch 55/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0401 - accuracy: 0.9846 - val_loss: 0.8990 - val_accuracy: 0.8141
# Epoch 56/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0330 - accuracy: 0.9888 - val_loss: 1.8306 - val_accuracy: 0.7067
# Epoch 57/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0277 - accuracy: 0.9911 - val_loss: 1.1399 - val_accuracy: 0.7933
# Epoch 58/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0168 - accuracy: 0.9923 - val_loss: 5.1347 - val_accuracy: 0.5000
# Epoch 59/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0352 - accuracy: 0.9873 - val_loss: 1.7056 - val_accuracy: 0.6882
# Epoch 60/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0509 - accuracy: 0.9796 - val_loss: 1.4229 - val_accuracy: 0.7506
# Epoch 61/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0401 - accuracy: 0.9850 - val_loss: 1.9268 - val_accuracy: 0.7194
# Epoch 62/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0350 - accuracy: 0.9888 - val_loss: 0.7556 - val_accuracy: 0.8533
# Epoch 63/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.6743 - val_accuracy: 0.8510
# Epoch 64/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.7250 - val_accuracy: 0.8545
# Epoch 65/100
# 41/41 [==============================] - 7s 160ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.6811 - val_accuracy: 0.8776
# Epoch 66/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0180 - accuracy: 0.9927 - val_loss: 1.6985 - val_accuracy: 0.7379
# Epoch 67/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 2.1508 - val_accuracy: 0.6605
# Epoch 68/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0643 - accuracy: 0.9773 - val_loss: 2.4498 - val_accuracy: 0.6744
# Epoch 69/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0510 - accuracy: 0.9784 - val_loss: 4.6933 - val_accuracy: 0.5497
# Epoch 70/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0729 - accuracy: 0.9800 - val_loss: 1.6756 - val_accuracy: 0.7517
# Epoch 71/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0428 - accuracy: 0.9842 - val_loss: 0.8110 - val_accuracy: 0.8326
# Epoch 72/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0466 - accuracy: 0.9838 - val_loss: 4.0337 - val_accuracy: 0.5531
# Epoch 73/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0638 - accuracy: 0.9811 - val_loss: 0.6829 - val_accuracy: 0.8291
# Epoch 74/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0531 - accuracy: 0.9831 - val_loss: 8.7273 - val_accuracy: 0.3210
# Epoch 75/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0425 - accuracy: 0.9842 - val_loss: 1.7695 - val_accuracy: 0.6617
# Epoch 76/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 2.3824 - val_accuracy: 0.6397
# Epoch 77/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 1.1335 - val_accuracy: 0.7344
# Epoch 78/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.7069 - val_accuracy: 0.8383
# Epoch 79/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.6151 - val_accuracy: 0.8499
# Epoch 80/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0028 - accuracy: 0.9988 - val_loss: 0.7729 - val_accuracy: 0.8395
# Epoch 81/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.9216 - val_accuracy: 0.8037
# Epoch 82/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.8799
# Epoch 83/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 1.0180 - val_accuracy: 0.8152
# Epoch 84/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.6370 - val_accuracy: 0.8557
# Epoch 85/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0186 - accuracy: 0.9954 - val_loss: 5.8880 - val_accuracy: 0.4746
# Epoch 86/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0188 - accuracy: 0.9950 - val_loss: 6.3144 - val_accuracy: 0.3580
# Epoch 87/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.1005 - accuracy: 0.9673 - val_loss: 4.8874 - val_accuracy: 0.5104
# Epoch 88/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1086 - accuracy: 0.9638 - val_loss: 1.9749 - val_accuracy: 0.6409
# Epoch 89/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 1.2907 - val_accuracy: 0.7494
# Epoch 90/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0130 - accuracy: 0.9946 - val_loss: 0.7517 - val_accuracy: 0.8337
# Epoch 91/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.4422 - val_accuracy: 0.9065
# Epoch 92/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.5293 - val_accuracy: 0.8995
# Epoch 93/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.6342 - val_accuracy: 0.8672
# Epoch 94/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0306 - accuracy: 0.9911 - val_loss: 0.8910 - val_accuracy: 0.8176
# Epoch 95/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 2.0380 - val_accuracy: 0.6998
# Epoch 96/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 1.3220 - val_accuracy: 0.7598
# Epoch 97/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 3.0142 - val_accuracy: 0.6686
# Epoch 98/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 2.4318 - val_accuracy: 0.6871
# Epoch 99/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0306 - accuracy: 0.9915 - val_loss: 2.6552 - val_accuracy: 0.6478
# Epoch 100/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 2.0059 - val_accuracy: 0.6570
# Maximal validation accuracy: 90.65%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.126591  0.589684  2.259884      0.115473
# 1   0.719329  0.737490  6.622005      0.115473
# 2   0.616679  0.784065  9.607202      0.115473
# 3   0.545667  0.801771  7.740342      0.115473
# 4   0.489132  0.819861  9.472522      0.115473
# ..       ...       ...       ...           ...
# 95  0.022528  0.992687  1.322010      0.759815
# 96  0.016078  0.995381  3.014190      0.668591
# 97  0.005374  0.997691  2.431844      0.687067
# 98  0.030624  0.991532  2.655164      0.647806
# 99  0.022474  0.993072  2.005917      0.657044
#
# [100 rows x 4 columns]

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.4421664774417877
# Maximum validation accuracy: 0.9064664840698242

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 43ms/step - loss: 2.0379 - accuracy: 0.6686
# test loss, test acc: [2.037863254547119, 0.6685912013053894]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 28/28 [==============================] - 3s 31ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 41/41 [==============================] - 22s 220ms/step - loss: 0.6439 - accuracy: 0.7764 - val_loss: 5.2353 - val_accuracy: 0.1478
# Epoch 2/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.2492 - accuracy: 0.9022 - val_loss: 4.3276 - val_accuracy: 0.3753
# Epoch 3/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.1362 - accuracy: 0.9457 - val_loss: 2.4318 - val_accuracy: 0.6570
# Epoch 4/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1353 - accuracy: 0.9500 - val_loss: 3.6154 - val_accuracy: 0.4769
# Epoch 5/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.1005 - accuracy: 0.9707 - val_loss: 0.9969 - val_accuracy: 0.8176
# Epoch 6/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0591 - accuracy: 0.9811 - val_loss: 0.5314 - val_accuracy: 0.8707
# Epoch 7/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0960 - accuracy: 0.9669 - val_loss: 2.0477 - val_accuracy: 0.7055
# Epoch 8/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1263 - accuracy: 0.9557 - val_loss: 2.6627 - val_accuracy: 0.5912
# Epoch 9/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.1042 - accuracy: 0.9661 - val_loss: 0.9408 - val_accuracy: 0.8002
# Epoch 10/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0915 - accuracy: 0.9700 - val_loss: 1.2153 - val_accuracy: 0.7564
# Epoch 11/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0494 - accuracy: 0.9834 - val_loss: 1.2083 - val_accuracy: 0.7702
# Epoch 12/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.5009 - val_accuracy: 0.9122
# Epoch 13/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.5718 - val_accuracy: 0.8995
# Epoch 14/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0227 - accuracy: 0.9946 - val_loss: 0.2670 - val_accuracy: 0.9192
# Epoch 15/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0236 - accuracy: 0.9915 - val_loss: 0.3238 - val_accuracy: 0.9180
# Epoch 16/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0362 - accuracy: 0.9861 - val_loss: 0.8630 - val_accuracy: 0.8684
# Epoch 17/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0959 - accuracy: 0.9719 - val_loss: 1.0194 - val_accuracy: 0.8210
# Epoch 18/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0812 - accuracy: 0.9754 - val_loss: 2.3585 - val_accuracy: 0.6490
# Epoch 19/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 1.2273 - val_accuracy: 0.7471
# Epoch 20/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.6301 - val_accuracy: 0.9053
# Epoch 21/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0243 - accuracy: 0.9896 - val_loss: 0.5234 - val_accuracy: 0.8360
# Epoch 22/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0310 - accuracy: 0.9888 - val_loss: 0.3979 - val_accuracy: 0.8926
# Epoch 23/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0376 - accuracy: 0.9888 - val_loss: 0.8908 - val_accuracy: 0.8314
# Epoch 24/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0790 - accuracy: 0.9761 - val_loss: 0.8568 - val_accuracy: 0.8060
# Epoch 25/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0691 - accuracy: 0.9804 - val_loss: 0.9903 - val_accuracy: 0.7956
# Epoch 26/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0570 - accuracy: 0.9842 - val_loss: 0.4568 - val_accuracy: 0.8984
# Epoch 27/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0373 - accuracy: 0.9881 - val_loss: 0.7935 - val_accuracy: 0.8372
# Epoch 28/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0074 - accuracy: 0.9988 - val_loss: 0.2899 - val_accuracy: 0.9319
# Epoch 29/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.2742 - val_accuracy: 0.9365
# Epoch 30/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.3378 - val_accuracy: 0.9238
# Epoch 31/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.5467 - val_accuracy: 0.8637
# Epoch 32/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.4653 - val_accuracy: 0.8926
# Epoch 33/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.2732 - val_accuracy: 0.9388
# Epoch 34/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0189 - accuracy: 0.9954 - val_loss: 1.5421 - val_accuracy: 0.7206
# Epoch 35/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0101 - accuracy: 0.9958 - val_loss: 0.5716 - val_accuracy: 0.8834
# Epoch 36/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.5287 - val_accuracy: 0.9042
# Epoch 37/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.2632 - val_accuracy: 0.9238
# Epoch 38/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.2773 - val_accuracy: 0.9330
# Epoch 39/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 1.5209 - val_accuracy: 0.7633
# Epoch 40/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0145 - accuracy: 0.9969 - val_loss: 0.4456 - val_accuracy: 0.9030
# Epoch 41/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.4624 - val_accuracy: 0.9226
# Epoch 42/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0279 - accuracy: 0.9919 - val_loss: 0.7418 - val_accuracy: 0.8233
# Epoch 43/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0593 - accuracy: 0.9827 - val_loss: 0.7156 - val_accuracy: 0.8129
# Epoch 44/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0624 - accuracy: 0.9819 - val_loss: 3.5574 - val_accuracy: 0.6005
# Epoch 45/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0917 - accuracy: 0.9707 - val_loss: 0.6891 - val_accuracy: 0.8199
# Epoch 46/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0533 - accuracy: 0.9861 - val_loss: 1.2558 - val_accuracy: 0.7621
# Epoch 47/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.8314 - val_accuracy: 0.8868
# Epoch 48/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.5409 - val_accuracy: 0.9111
# Epoch 49/100
# 41/41 [==============================] - 7s 161ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.2982 - val_accuracy: 0.9434
# Epoch 50/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.4079 - val_accuracy: 0.9296
# Epoch 51/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.6486 - val_accuracy: 0.8730
# Epoch 52/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.4449 - val_accuracy: 0.9180
# Epoch 53/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.3268 - val_accuracy: 0.9365
# Epoch 54/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0148 - accuracy: 0.9962 - val_loss: 0.3184 - val_accuracy: 0.9284
# Epoch 55/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 0.5162 - val_accuracy: 0.9215
# Epoch 56/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.8649 - val_accuracy: 0.8557
# Epoch 57/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0694 - accuracy: 0.9842 - val_loss: 2.4990 - val_accuracy: 0.6397
# Epoch 58/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0776 - accuracy: 0.9746 - val_loss: 1.7220 - val_accuracy: 0.6928
# Epoch 59/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0324 - accuracy: 0.9919 - val_loss: 0.5571 - val_accuracy: 0.8868
# Epoch 60/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0175 - accuracy: 0.9958 - val_loss: 1.4238 - val_accuracy: 0.7206
# Epoch 61/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.5393 - val_accuracy: 0.9169
# Epoch 62/100
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.6887 - val_accuracy: 0.9088
# Epoch 63/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.3903 - val_accuracy: 0.9296
# Epoch 64/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.4060 - val_accuracy: 0.9261
# Epoch 65/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.6297 - val_accuracy: 0.8614
# Epoch 66/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0410 - accuracy: 0.9873 - val_loss: 0.7266 - val_accuracy: 0.8406
# Epoch 67/100
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0193 - accuracy: 0.9931 - val_loss: 0.2767 - val_accuracy: 0.9284
# Epoch 68/100
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.5032 - val_accuracy: 0.8868
# Epoch 69/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9981Restoring model weights from the end of the best epoch: 49.
# 41/41 [==============================] - 7s 163ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.4117 - val_accuracy: 0.9157
# Epoch 00069: early stopping
# Maximal validation accuracy: 94.34%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.643858  0.776366  5.235339      0.147806
# 1   0.249205  0.902232  4.327555      0.375289
# 2   0.136238  0.945727  2.431836      0.657044
# 3   0.135319  0.949961  3.615449      0.476905
# 4   0.100515  0.970747  0.996861      0.817552
# ..       ...       ...       ...           ...
# 64  0.023551  0.992302  0.629686      0.861432
# 65  0.040970  0.987298  0.726604      0.840647
# 66  0.019256  0.993072  0.276684      0.928406
# 67  0.011676  0.995766  0.503214      0.886836
# 68  0.005736  0.998075  0.411655      0.915704
#
# [69 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.26318424940109253
# Maximum validation accuracy: 0.943418025970459

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2783 - accuracy: 0.9469
# test loss, test acc: [0.2783489525318146, 0.9468821883201599]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 28/28 [==============================] - 3s 30ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_DenseNet121_None
# test loss, test acc: [0.322712779045105, 0.9236640930175781]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_DenseNet121_imagenet
# test loss, test acc: [0.11761024594306946, 0.9656488299369812]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_DenseNet121_None
# test loss, test acc: [2.037863254547119, 0.6685912013053894]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_DenseNet121_imagenet
# test loss, test acc: [0.2783489525318146, 0.9468821883201599]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_DenseNet121_None →→→ Target Test
# 28/28 [==============================] - 1s 32ms/step - loss: 7.4999 - accuracy: 0.1663
# test loss, test acc: [7.499903678894043, 0.16628175973892212]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_DenseNet121_imagenet →→→ Target Test
# 28/28 [==============================] - 1s 33ms/step - loss: 4.8029 - accuracy: 0.2448
# test loss, test acc: [4.802939414978027, 0.24480369687080383]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_DenseNet121_None →→→ Source Test
# 25/25 [==============================] - 1s 33ms/step - loss: 9.6509 - accuracy: 0.1336
# test loss, test acc: [9.65090274810791, 0.1335877925157547]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_DenseNet121_imagenet →→→ Source Test
# 25/25 [==============================] - 1s 32ms/step - loss: 5.3486 - accuracy: 0.2214
# test loss, test acc: [5.348585605621338, 0.221374049782753]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
