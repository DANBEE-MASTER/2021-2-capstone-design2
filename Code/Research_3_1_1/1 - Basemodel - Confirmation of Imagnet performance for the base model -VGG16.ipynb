# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from keras.utils import np_utils
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Input
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.metrics import AUC

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3423514390762609103
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10465773028794736940
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Sat Dec 18 08:11:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    31W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
basemodel = 'VGG16'
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 3
None_patience_num = 30
imagenet_patience_num = 20
S_all_labels = "S0", "S1", "S2"
T_all_labels = "T0", "T1", "T2"

#base_path = ''
base_path = 'gdrive/My Drive/Research_3_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/1 - Base_model_result/' + basemodel + '/'

# %%
S_model_name_imagenet = 'S_' + basemodel + '_imagenet'
S_model_name_None = 'S_' + basemodel + '_None'
T_model_name_imagenet = 'T_' + basemodel + '_imagenet'
T_model_name_None = 'T_' + basemodel + '_None'

print(S_model_name_None, S_model_name_imagenet, T_model_name_None, T_model_name_imagenet)

basemodel_list=[S_model_name_imagenet, S_model_name_None, T_model_name_imagenet, T_model_name_None]
basemodel_list
# Out:
# S_VGG16_None S_VGG16_imagenet T_VGG16_None T_VGG16_imagenet
# ['S_VGG16_imagenet', 'S_VGG16_None', 'T_VGG16_imagenet', 'T_VGG16_None']

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(path_model_result + name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
for i in basemodel_list:
    createDirectory(i)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTrain_T = np.load(path_data + 'xTrain_T.npy')
xValid_T = np.load(path_data + 'xValid_T.npy')
xTest_T = np.load(path_data + 'xTest_T.npy')

yTrain_T = np.load(path_data + 'yTrain_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1920, 128, 128, 3) (1920, 1)
# (640, 128, 128, 3) (640, 1)
# (640, 128, 128, 3) (640, 1)
#
# (1440, 128, 128, 3) (1440, 1)
# (480, 128, 128, 3) (480, 1)
# (480, 128, 128, 3) (480, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

yTrain_S = np_utils.to_categorical(yTrain_S, class_num)
yValid_S = np_utils.to_categorical(yValid_S, class_num)
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTrain_T = xTrain_T.astype('float32')/255
xValid_T = xValid_T.astype('float32')/255
xTest_T = xTest_T.astype('float32')/255

yTrain_T = np_utils.to_categorical(yTrain_T, class_num)
yValid_T = np_utils.to_categorical(yValid_T, class_num)
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
print()
print(xTrain_T.shape, yTrain_T.shape)
print(xValid_T.shape, yValid_T.shape)
print(xTest_T.shape, yTest_T.shape)
# Out:
# (1920, 128, 128, 3) (1920, 3)
# (640, 128, 128, 3) (640, 3)
# (640, 128, 128, 3) (640, 3)
#
# (1440, 128, 128, 3) (1440, 3)
# (480, 128, 128, 3) (480, 3)
# (480, 128, 128, 3) (480, 3)

# %% [markdown]
# ## 2-2. Image Check

# %%
temp_S_a = len(xTrain_S)
print("xTrain_S image Numbers : ", temp_S_a)
temp_S_b = temp_S_a//10
print("xTrain_S image Numbers // 10 : ", temp_S_b)
temp_S_c = 0
for i in range(0, temp_S_a, temp_S_b):
    temp_S_c += 1
print(temp_S_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0, temp_S_a, temp_S_b):
    plt.subplot(1, temp_S_c, c+1)
    plt.imshow(xTrain_S[i])
    plt.title(yTrain_S[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1920
# xTrain_S image Numbers // 10 :  192
# 10

# %%
temp_T_a = len(xTrain_T)
print("xTrain_S image Numbers : ", temp_T_a)
temp_T_b = temp_T_a//10
print("xTrain_S image Numbers // 10 : ", temp_T_b)
temp_T_c = 0
for i in range(0, temp_T_a, temp_T_b):
    temp_T_c += 1
print(temp_T_c)


c=0
plt.figure(figsize=(20,3))
for i in range(0,temp_T_a,temp_T_b):
    plt.subplot(1, temp_T_c, c+1)
    plt.imshow(xTrain_T[i])
    plt.title(yTrain_T[i].argmax(),fontsize=30)
    plt.tight_layout()
    plt.axis('off')
    c+=1
plt.show()
# Out:
# xTrain_S image Numbers :  1440
# xTrain_S image Numbers // 10 :  144
# 10

# %% [markdown]
# # 3. Network Setting and Training

# %% [markdown]
# ## 3-1. Network Setting

# %%
def feature_extractor_None(inp):
    base_model=tf.keras.applications.VGG16 (
                include_top=False, weights=None, input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_None(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_None():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_None(inp)
    classifier_output = classifier_None(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
def feature_extractor_imagenet(inp):
    base_model=tf.keras.applications.VGG16 (
                include_top=False, weights='imagenet', input_tensor=inp)
    input = base_model.input
    out = base_model.layers[-1].output
    feature_output = tf.keras.layers.GlobalAveragePooling2D(name='feature')(out)
    return feature_output


def classifier_imagenet(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(32, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out)
    return classifier_output


def model_imagenet():
    inp = Input(shape=(image_size, image_size, image_channels))   
    feature_output = feature_extractor_imagenet(inp)
    classifier_output = classifier_imagenet(feature_output)
    model = Model(inputs=inp, outputs=classifier_output)
    return model

# %%
#plot_model(model_None())
#plot_model(model_imagenet())

# %% [markdown]
# ## 3-2. Source Domain Training - weights=None

# %%
S_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
S_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

S_basemodel_None_main =S_basemodel_None.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 16s 160ms/step - loss: 1.0984 - accuracy: 0.4922 - val_loss: 1.0595 - val_accuracy: 0.5000
# Epoch 2/100
# 30/30 [==============================] - 4s 148ms/step - loss: 1.0460 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 3/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0417 - accuracy: 0.5000 - val_loss: 1.0417 - val_accuracy: 0.5000
# Epoch 4/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0430 - val_accuracy: 0.5000
# Epoch 5/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0433 - accuracy: 0.5000 - val_loss: 1.0418 - val_accuracy: 0.5000
# Epoch 6/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0423 - accuracy: 0.5000 - val_loss: 1.0402 - val_accuracy: 0.5000
# Epoch 7/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0406 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 8/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0428 - accuracy: 0.5000 - val_loss: 1.0401 - val_accuracy: 0.5000
# Epoch 9/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0409 - accuracy: 0.5000 - val_loss: 1.0404 - val_accuracy: 0.5000
# Epoch 10/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0424 - accuracy: 0.5000 - val_loss: 1.0434 - val_accuracy: 0.5000
# Epoch 11/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0425 - accuracy: 0.5000 - val_loss: 1.0410 - val_accuracy: 0.5000
# Epoch 12/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0412 - accuracy: 0.5000 - val_loss: 1.0404 - val_accuracy: 0.5000
# Epoch 13/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0418 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 14/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0407 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 15/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0402 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 16/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0402 - val_accuracy: 0.5000
# Epoch 17/100
# 30/30 [==============================] - 4s 145ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0401 - val_accuracy: 0.5000
# Epoch 18/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0412 - accuracy: 0.5000 - val_loss: 1.0403 - val_accuracy: 0.5000
# Epoch 19/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0412 - accuracy: 0.5000 - val_loss: 1.0406 - val_accuracy: 0.5000
# Epoch 20/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0417 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 21/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0417 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 22/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0406 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 23/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0406 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 24/100
# 30/30 [==============================] - 4s 145ms/step - loss: 1.0411 - accuracy: 0.5000 - val_loss: 1.0400 - val_accuracy: 0.5000
# Epoch 25/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0402 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 26/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0409 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 27/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0427 - accuracy: 0.5000 - val_loss: 1.0403 - val_accuracy: 0.5000
# Epoch 28/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0411 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 29/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0413 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 30/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0403 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 31/100
# 30/30 [==============================] - ETA: 0s - loss: 1.0404 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 1.
# 30/30 [==============================] - 4s 145ms/step - loss: 1.0404 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 00031: early stopping
# Maximal validation accuracy: 50.00%

# %%
S_basemodel_None_df = pd.DataFrame(S_basemodel_None_main.history)
S_basemodel_None_df.to_csv( path_model_result + S_model_name_None + '/' + S_model_name_None + '_df.csv' )
S_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.098389  0.492188  1.059520           0.5
# 1   1.045977  0.500000  1.039722           0.5
# 2   1.041738  0.500000  1.041736           0.5
# 3   1.040995  0.500000  1.043009           0.5
# 4   1.043342  0.500000  1.041825           0.5
# 5   1.042312  0.500000  1.040195           0.5
# 6   1.040564  0.500000  1.039848           0.5
# 7   1.042826  0.500000  1.040130           0.5
# 8   1.040874  0.500000  1.040412           0.5
# 9   1.042383  0.500000  1.043437           0.5
# 10  1.042451  0.500000  1.041010           0.5
# 11  1.041157  0.500000  1.040434           0.5
# 12  1.041823  0.500000  1.039930           0.5
# 13  1.040740  0.500000  1.039824           0.5
# 14  1.040247  0.500000  1.039734           0.5
# 15  1.040987  0.500000  1.040166           0.5
# 16  1.041008  0.500000  1.040097           0.5
# 17  1.041192  0.500000  1.040258           0.5
# 18  1.041205  0.500000  1.040639           0.5
# 19  1.041678  0.500000  1.039853           0.5
# 20  1.041700  0.500000  1.039739           0.5
# 21  1.040583  0.500000  1.039935           0.5
# 22  1.040563  0.500000  1.039790           0.5
# 23  1.041137  0.500000  1.040045           0.5
# 24  1.040230  0.500000  1.039736           0.5
# 25  1.040866  0.500000  1.039854           0.5
# 26  1.042722  0.500000  1.040265           0.5
# 27  1.041098  0.500000  1.039826           0.5
# 28  1.041280  0.500000  1.039729           0.5
# 29  1.040265  0.500000  1.039855           0.5
# 30  1.040417  0.500000  1.039743           0.5

# %%
S_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_loss,val_loss.png')
S_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_None + '/' + S_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 1.0397217273712158
# Maximum validation accuracy: 0.5

# %%
print("Evaluate on test data")
S_basemodel_None_results = S_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 2s 23ms/step - loss: 1.0595 - accuracy: 0.5000
# test loss, test acc: [1.059519648551941, 0.5]

# %%
S_basemodel_None_pred_Y = S_basemodel_None.predict(xTest_S, verbose = True)
# Out:
# 20/20 [==============================] - 1s 20ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_None + '/' + S_model_name_None +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-3. Source Domain Training - weights='imagenet'

# %%
S_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
S_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

S_basemodel_imagenet_main =S_basemodel_imagenet.fit(xTrain_S, yTrain_S, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_S, yValid_S), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(S_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 30/30 [==============================] - 5s 156ms/step - loss: 11.2604 - accuracy: 0.4677 - val_loss: 1.0378 - val_accuracy: 0.5000
# Epoch 2/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0373 - accuracy: 0.5000 - val_loss: 1.0171 - val_accuracy: 0.5000
# Epoch 3/100
# 30/30 [==============================] - 4s 146ms/step - loss: 1.0055 - accuracy: 0.5068 - val_loss: 0.9371 - val_accuracy: 0.5891
# Epoch 4/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.9759 - accuracy: 0.5276 - val_loss: 0.9109 - val_accuracy: 0.5766
# Epoch 5/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.9462 - accuracy: 0.5516 - val_loss: 0.9341 - val_accuracy: 0.5750
# Epoch 6/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.9121 - accuracy: 0.5771 - val_loss: 0.8443 - val_accuracy: 0.6078
# Epoch 7/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.8779 - accuracy: 0.5932 - val_loss: 0.8102 - val_accuracy: 0.6297
# Epoch 8/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.8597 - accuracy: 0.5984 - val_loss: 0.8853 - val_accuracy: 0.6219
# Epoch 9/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.8480 - accuracy: 0.5990 - val_loss: 0.7729 - val_accuracy: 0.6391
# Epoch 10/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.8472 - accuracy: 0.6094 - val_loss: 0.9195 - val_accuracy: 0.5406
# Epoch 11/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.8431 - accuracy: 0.5766 - val_loss: 0.8121 - val_accuracy: 0.6141
# Epoch 12/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.7172 - accuracy: 0.6604 - val_loss: 0.7480 - val_accuracy: 0.6641
# Epoch 13/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.7061 - accuracy: 0.6719 - val_loss: 0.7402 - val_accuracy: 0.6672
# Epoch 14/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.6345 - accuracy: 0.7141 - val_loss: 0.6524 - val_accuracy: 0.7250
# Epoch 15/100
# 30/30 [==============================] - 4s 147ms/step - loss: 0.6110 - accuracy: 0.7411 - val_loss: 0.5737 - val_accuracy: 0.7891
# Epoch 16/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.6360 - accuracy: 0.7245 - val_loss: 0.5680 - val_accuracy: 0.7609
# Epoch 17/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.5597 - accuracy: 0.7703 - val_loss: 0.6739 - val_accuracy: 0.6875
# Epoch 18/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.7086 - accuracy: 0.6823 - val_loss: 0.6741 - val_accuracy: 0.6984
# Epoch 19/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.5585 - accuracy: 0.7625 - val_loss: 0.6186 - val_accuracy: 0.7422
# Epoch 20/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.5136 - accuracy: 0.7958 - val_loss: 0.6425 - val_accuracy: 0.7734
# Epoch 21/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.4469 - accuracy: 0.8260 - val_loss: 0.4946 - val_accuracy: 0.8156
# Epoch 22/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.4115 - accuracy: 0.8432 - val_loss: 0.5508 - val_accuracy: 0.8000
# Epoch 23/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.4325 - accuracy: 0.8276 - val_loss: 0.4726 - val_accuracy: 0.8172
# Epoch 24/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.3833 - accuracy: 0.8484 - val_loss: 0.4039 - val_accuracy: 0.8516
# Epoch 25/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.3619 - accuracy: 0.8646 - val_loss: 0.4800 - val_accuracy: 0.8203
# Epoch 26/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.3593 - accuracy: 0.8578 - val_loss: 0.5067 - val_accuracy: 0.8156
# Epoch 27/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.3163 - accuracy: 0.8755 - val_loss: 0.4876 - val_accuracy: 0.7937
# Epoch 28/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.3528 - accuracy: 0.8583 - val_loss: 0.5739 - val_accuracy: 0.7875
# Epoch 29/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.3544 - accuracy: 0.8651 - val_loss: 0.3696 - val_accuracy: 0.8609
# Epoch 30/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.2485 - accuracy: 0.9099 - val_loss: 0.3661 - val_accuracy: 0.8687
# Epoch 31/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.3223 - accuracy: 0.8724 - val_loss: 0.4263 - val_accuracy: 0.8328
# Epoch 32/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.2586 - accuracy: 0.8974 - val_loss: 0.4143 - val_accuracy: 0.8594
# Epoch 33/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.1790 - accuracy: 0.9380 - val_loss: 0.4662 - val_accuracy: 0.8516
# Epoch 34/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.1718 - accuracy: 0.9354 - val_loss: 0.4365 - val_accuracy: 0.8766
# Epoch 35/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.2403 - accuracy: 0.9042 - val_loss: 0.4028 - val_accuracy: 0.8578
# Epoch 36/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.2415 - accuracy: 0.9151 - val_loss: 0.3900 - val_accuracy: 0.8734
# Epoch 37/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1590 - accuracy: 0.9385 - val_loss: 0.5848 - val_accuracy: 0.8547
# Epoch 38/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1931 - accuracy: 0.9266 - val_loss: 0.5019 - val_accuracy: 0.8578
# Epoch 39/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.1776 - accuracy: 0.9370 - val_loss: 0.3680 - val_accuracy: 0.8891
# Epoch 40/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.1105 - accuracy: 0.9609 - val_loss: 0.4472 - val_accuracy: 0.8781
# Epoch 41/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0854 - accuracy: 0.9703 - val_loss: 0.4591 - val_accuracy: 0.8687
# Epoch 42/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1292 - accuracy: 0.9557 - val_loss: 0.9529 - val_accuracy: 0.8016
# Epoch 43/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.3209 - accuracy: 0.8823 - val_loss: 0.3669 - val_accuracy: 0.8766
# Epoch 44/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.1439 - accuracy: 0.9469 - val_loss: 0.4454 - val_accuracy: 0.8797
# Epoch 45/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1002 - accuracy: 0.9651 - val_loss: 0.5116 - val_accuracy: 0.8453
# Epoch 46/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.1032 - accuracy: 0.9573 - val_loss: 0.5981 - val_accuracy: 0.8500
# Epoch 47/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.1034 - accuracy: 0.9620 - val_loss: 0.4692 - val_accuracy: 0.8906
# Epoch 48/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0727 - accuracy: 0.9750 - val_loss: 0.4684 - val_accuracy: 0.8625
# Epoch 49/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0880 - accuracy: 0.9688 - val_loss: 0.7706 - val_accuracy: 0.7781
# Epoch 50/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1111 - accuracy: 0.9620 - val_loss: 0.5493 - val_accuracy: 0.8562
# Epoch 51/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0874 - accuracy: 0.9672 - val_loss: 0.4708 - val_accuracy: 0.8734
# Epoch 52/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0533 - accuracy: 0.9839 - val_loss: 0.9676 - val_accuracy: 0.8156
# Epoch 53/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.1484 - accuracy: 0.9422 - val_loss: 0.4514 - val_accuracy: 0.8797
# Epoch 54/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0523 - accuracy: 0.9833 - val_loss: 0.4798 - val_accuracy: 0.8750
# Epoch 55/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0237 - accuracy: 0.9943 - val_loss: 0.6121 - val_accuracy: 0.8813
# Epoch 56/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.6829 - val_accuracy: 0.8734
# Epoch 57/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0589 - accuracy: 0.9802 - val_loss: 0.5625 - val_accuracy: 0.8625
# Epoch 58/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0847 - accuracy: 0.9682 - val_loss: 0.7122 - val_accuracy: 0.8453
# Epoch 59/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0702 - accuracy: 0.9760 - val_loss: 0.7031 - val_accuracy: 0.8406
# Epoch 60/100
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0211 - accuracy: 0.9974 - val_loss: 0.5441 - val_accuracy: 0.8813
# Epoch 61/100
# 30/30 [==============================] - 4s 145ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.6008 - val_accuracy: 0.8891
# Epoch 62/100
# 30/30 [==============================] - 4s 146ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6331 - val_accuracy: 0.8938
# Epoch 63/100
# 30/30 [==============================] - 4s 146ms/step - loss: 7.8073e-04 - accuracy: 1.0000 - val_loss: 0.6837 - val_accuracy: 0.8969
# Epoch 64/100
# 30/30 [==============================] - 4s 144ms/step - loss: 5.8439e-04 - accuracy: 1.0000 - val_loss: 0.7097 - val_accuracy: 0.8953
# Epoch 65/100
# 30/30 [==============================] - 4s 145ms/step - loss: 4.6241e-04 - accuracy: 1.0000 - val_loss: 0.7488 - val_accuracy: 0.8953
# Epoch 66/100
# 30/30 [==============================] - 4s 144ms/step - loss: 3.7313e-04 - accuracy: 1.0000 - val_loss: 0.7720 - val_accuracy: 0.8906
# Epoch 67/100
# 30/30 [==============================] - 4s 145ms/step - loss: 3.0726e-04 - accuracy: 1.0000 - val_loss: 0.8027 - val_accuracy: 0.8922
# Epoch 68/100
# 30/30 [==============================] - 4s 145ms/step - loss: 2.6140e-04 - accuracy: 1.0000 - val_loss: 0.8325 - val_accuracy: 0.8922
# Epoch 69/100
# 30/30 [==============================] - 4s 144ms/step - loss: 2.2399e-04 - accuracy: 1.0000 - val_loss: 0.8549 - val_accuracy: 0.8906
# Epoch 70/100
# 30/30 [==============================] - 4s 145ms/step - loss: 1.8831e-04 - accuracy: 1.0000 - val_loss: 0.8801 - val_accuracy: 0.8891
# Epoch 71/100
# 30/30 [==============================] - 4s 145ms/step - loss: 1.6381e-04 - accuracy: 1.0000 - val_loss: 0.9084 - val_accuracy: 0.8922
# Epoch 72/100
# 30/30 [==============================] - 4s 145ms/step - loss: 1.3525e-04 - accuracy: 1.0000 - val_loss: 0.9393 - val_accuracy: 0.8875
# Epoch 73/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0825e-04 - accuracy: 1.0000 - val_loss: 1.0040 - val_accuracy: 0.8813
# Epoch 74/100
# 30/30 [==============================] - 4s 144ms/step - loss: 1.0098e-04 - accuracy: 1.0000 - val_loss: 1.0359 - val_accuracy: 0.8859
# Epoch 75/100
# 30/30 [==============================] - 4s 144ms/step - loss: 8.6449e-05 - accuracy: 1.0000 - val_loss: 1.0761 - val_accuracy: 0.8859
# Epoch 76/100
# 30/30 [==============================] - 4s 145ms/step - loss: 6.6393e-05 - accuracy: 1.0000 - val_loss: 1.1273 - val_accuracy: 0.8813
# Epoch 77/100
# 30/30 [==============================] - 4s 144ms/step - loss: 5.4940e-05 - accuracy: 1.0000 - val_loss: 1.1574 - val_accuracy: 0.8828
# Epoch 78/100
# 30/30 [==============================] - 4s 145ms/step - loss: 4.8042e-05 - accuracy: 1.0000 - val_loss: 1.1946 - val_accuracy: 0.8813
# Epoch 79/100
# 30/30 [==============================] - 4s 144ms/step - loss: 4.2246e-05 - accuracy: 1.0000 - val_loss: 1.2243 - val_accuracy: 0.8813
# Epoch 80/100
# 30/30 [==============================] - 4s 144ms/step - loss: 3.8801e-05 - accuracy: 1.0000 - val_loss: 1.2525 - val_accuracy: 0.8797
# Epoch 81/100
# 30/30 [==============================] - 4s 144ms/step - loss: 3.5991e-05 - accuracy: 1.0000 - val_loss: 1.2795 - val_accuracy: 0.8813
# Epoch 82/100
# 30/30 [==============================] - 4s 144ms/step - loss: 3.1175e-05 - accuracy: 1.0000 - val_loss: 1.2994 - val_accuracy: 0.8797
# Epoch 83/100
# 30/30 [==============================] - ETA: 0s - loss: 2.7496e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 63.
# 30/30 [==============================] - 4s 145ms/step - loss: 2.7496e-05 - accuracy: 1.0000 - val_loss: 1.3284 - val_accuracy: 0.8797
# Epoch 00083: early stopping
# Maximal validation accuracy: 89.69%

# %%
S_basemodel_imagenet_df = pd.DataFrame(S_basemodel_imagenet_main.history)
S_basemodel_imagenet_df.to_csv( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_df.csv' )
S_basemodel_imagenet_df
# Out:
#          loss  accuracy  val_loss  val_accuracy
# 0   11.260423  0.467708  1.037823      0.500000
# 1    1.037314  0.500000  1.017057      0.500000
# 2    1.005545  0.506771  0.937074      0.589063
# 3    0.975880  0.527604  0.910910      0.576563
# 4    0.946198  0.551562  0.934079      0.575000
# ..        ...       ...       ...           ...
# 78   0.000042  1.000000  1.224262      0.881250
# 79   0.000039  1.000000  1.252496      0.879687
# 80   0.000036  1.000000  1.279506      0.881250
# 81   0.000031  1.000000  1.299422      0.879687
# 82   0.000027  1.000000  1.328369      0.879687
#
# [83 rows x 4 columns]

# %%
S_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_loss,val_loss.png')
S_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(S_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(S_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.366138219833374
# Maximum validation accuracy: 0.8968750238418579

# %%
print("Evaluate on test data")
S_model_name_imagenet_results = S_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 20/20 [==============================] - 1s 23ms/step - loss: 0.5784 - accuracy: 0.8922
# test loss, test acc: [0.5784012079238892, 0.8921874761581421]

# %%
S_model_name_imagenet_pred_Y = S_basemodel_imagenet.predict(xTest_S, verbose = True)
# Out:
# 20/20 [==============================] - 1s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(S_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_S[:,idx].astype(int), S_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet +'_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-4. Target Domain Training - weights=None

# %%
T_basemodel_None=model_None()
#S_basemodel_None.summary()

# %%
T_basemodel_None.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=None_patience_num, restore_best_weights=True)

T_basemodel_None_main =T_basemodel_None.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_None_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 5s 192ms/step - loss: 1.0801 - accuracy: 0.5000 - val_loss: 1.0630 - val_accuracy: 0.5000
# Epoch 2/100
# 23/23 [==============================] - 3s 143ms/step - loss: 1.0480 - accuracy: 0.5000 - val_loss: 1.0421 - val_accuracy: 0.5000
# Epoch 3/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0427 - accuracy: 0.5000 - val_loss: 1.0405 - val_accuracy: 0.5000
# Epoch 4/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0308 - accuracy: 0.5028 - val_loss: 1.6108 - val_accuracy: 0.5000
# Epoch 5/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.1066 - accuracy: 0.5000 - val_loss: 1.0535 - val_accuracy: 0.5000
# Epoch 6/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0458 - accuracy: 0.5000 - val_loss: 1.0485 - val_accuracy: 0.5000
# Epoch 7/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0454 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 8/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0409 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 9/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0419 - accuracy: 0.5000 - val_loss: 1.0400 - val_accuracy: 0.5000
# Epoch 10/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0401 - val_accuracy: 0.5000
# Epoch 11/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0400 - val_accuracy: 0.5000
# Epoch 12/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0414 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 13/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0411 - accuracy: 0.5000 - val_loss: 1.0401 - val_accuracy: 0.5000
# Epoch 14/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0409 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 15/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0410 - accuracy: 0.5000 - val_loss: 1.0403 - val_accuracy: 0.5000
# Epoch 16/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0415 - accuracy: 0.5000 - val_loss: 1.0399 - val_accuracy: 0.5000
# Epoch 17/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0403 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 18/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0400 - accuracy: 0.5000 - val_loss: 1.0402 - val_accuracy: 0.5000
# Epoch 19/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0405 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 20/100
# 23/23 [==============================] - 3s 141ms/step - loss: 1.0405 - accuracy: 0.5000 - val_loss: 1.0382 - val_accuracy: 0.5000
# Epoch 21/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0413 - accuracy: 0.5000 - val_loss: 1.0397 - val_accuracy: 0.5000
# Epoch 22/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0413 - accuracy: 0.5000 - val_loss: 1.0400 - val_accuracy: 0.5000
# Epoch 23/100
# 23/23 [==============================] - 3s 141ms/step - loss: 1.0408 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 24/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0404 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 25/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0577 - accuracy: 0.5000 - val_loss: 1.0450 - val_accuracy: 0.5000
# Epoch 26/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0448 - accuracy: 0.5000 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 27/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0422 - accuracy: 0.5000 - val_loss: 1.0416 - val_accuracy: 0.5000
# Epoch 28/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0418 - accuracy: 0.5000 - val_loss: 1.0426 - val_accuracy: 0.5000
# Epoch 29/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0419 - accuracy: 0.5000 - val_loss: 1.0405 - val_accuracy: 0.5000
# Epoch 30/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0411 - accuracy: 0.5000 - val_loss: 1.0396 - val_accuracy: 0.5000
# Epoch 31/100
# 23/23 [==============================] - ETA: 0s - loss: 1.0399 - accuracy: 0.5000Restoring model weights from the end of the best epoch: 1.
# 23/23 [==============================] - 3s 143ms/step - loss: 1.0399 - accuracy: 0.5000 - val_loss: 1.0403 - val_accuracy: 0.5000
# Epoch 00031: early stopping
# Maximal validation accuracy: 50.00%

# %%
T_basemodel_None_df = pd.DataFrame(T_basemodel_None_main.history)
T_basemodel_None_df.to_csv( path_model_result + T_model_name_None + '/' + T_model_name_None + '_df.csv' )
T_basemodel_None_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.080055  0.500000  1.062955           0.5
# 1   1.048048  0.500000  1.042083           0.5
# 2   1.042739  0.500000  1.040532           0.5
# 3   1.030820  0.502778  1.610779           0.5
# 4   1.106641  0.500000  1.053548           0.5
# 5   1.045819  0.500000  1.048542           0.5
# 6   1.045382  0.500000  1.039850           0.5
# 7   1.040925  0.500000  1.039843           0.5
# 8   1.041875  0.500000  1.039978           0.5
# 9   1.040965  0.500000  1.040072           0.5
# 10  1.041026  0.500000  1.039969           0.5
# 11  1.041443  0.500000  1.039748           0.5
# 12  1.041137  0.500000  1.040065           0.5
# 13  1.040853  0.500000  1.039860           0.5
# 14  1.041048  0.500000  1.040296           0.5
# 15  1.041464  0.500000  1.039862           0.5
# 16  1.040295  0.500000  1.039779           0.5
# 17  1.039975  0.500000  1.040191           0.5
# 18  1.040456  0.500000  1.039730           0.5
# 19  1.040491  0.500000  1.038152           0.5
# 20  1.041327  0.500000  1.039724           0.5
# 21  1.041343  0.500000  1.039957           0.5
# 22  1.040801  0.500000  1.039807           0.5
# 23  1.040384  0.500000  1.039833           0.5
# 24  1.057730  0.500000  1.044984           0.5
# 25  1.044767  0.500000  1.039770           0.5
# 26  1.042191  0.500000  1.041613           0.5
# 27  1.041837  0.500000  1.042639           0.5
# 28  1.041874  0.500000  1.040466           0.5
# 29  1.041134  0.500000  1.039599           0.5
# 30  1.039899  0.500000  1.040308           0.5

# %%
T_basemodel_None_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_loss,val_loss.png')
T_basemodel_None_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_None + '/' + T_model_name_None + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_None_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_None_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 1.0381519794464111
# Maximum validation accuracy: 0.5

# %%
print("Evaluate on test data")
T_basemodel_None_results = T_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 23ms/step - loss: 1.0630 - accuracy: 0.5000
# test loss, test acc: [1.0629551410675049, 0.5]

# %%
T_basemodel_None_pred_Y = T_basemodel_None.predict(xTest_T, verbose = True)
# Out:
# 15/15 [==============================] - 0s 20ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_basemodel_None_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_None + '/' + T_model_name_None + '_TESTSET_AUC.png' )

# %% [markdown]
# ## 3-5. Target Domain Training - weights='imagenet'

# %%
T_basemodel_imagenet=model_imagenet()
#S_basemodel_None.summary()

# %%
T_basemodel_imagenet.compile(optimizer='adam', 
              loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])

ES = EarlyStopping(monitor='val_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)

T_basemodel_imagenet_main =T_basemodel_imagenet.fit(xTrain_T, yTrain_T, 
                    epochs=num_epochs, batch_size=batch_size, validation_data=(xValid_T, yValid_T), callbacks=[ES])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(T_basemodel_imagenet_main.history["val_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 4s 157ms/step - loss: 1.2795 - accuracy: 0.4639 - val_loss: 1.0502 - val_accuracy: 0.5000
# Epoch 2/100
# 23/23 [==============================] - 3s 143ms/step - loss: 1.0448 - accuracy: 0.5000 - val_loss: 1.0363 - val_accuracy: 0.5000
# Epoch 3/100
# 23/23 [==============================] - 3s 142ms/step - loss: 1.0434 - accuracy: 0.5007 - val_loss: 1.0251 - val_accuracy: 0.5000
# Epoch 4/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.9665 - accuracy: 0.5201 - val_loss: 0.8745 - val_accuracy: 0.5958
# Epoch 5/100
# 23/23 [==============================] - 3s 145ms/step - loss: 0.8033 - accuracy: 0.6319 - val_loss: 0.6969 - val_accuracy: 0.6812
# Epoch 6/100
# 23/23 [==============================] - 3s 145ms/step - loss: 0.6113 - accuracy: 0.7382 - val_loss: 0.6325 - val_accuracy: 0.7667
# Epoch 7/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.3966 - accuracy: 0.8583 - val_loss: 0.4571 - val_accuracy: 0.8271
# Epoch 8/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.3675 - accuracy: 0.8674 - val_loss: 0.3007 - val_accuracy: 0.9042
# Epoch 9/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.3996 - accuracy: 0.8542 - val_loss: 0.3107 - val_accuracy: 0.9104
# Epoch 10/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.2207 - accuracy: 0.9306 - val_loss: 0.2193 - val_accuracy: 0.9375
# Epoch 11/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.2454 - accuracy: 0.9132 - val_loss: 0.4648 - val_accuracy: 0.8292
# Epoch 12/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.2343 - accuracy: 0.9215 - val_loss: 0.2211 - val_accuracy: 0.9333
# Epoch 13/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.2187 - accuracy: 0.9271 - val_loss: 0.2272 - val_accuracy: 0.9167
# Epoch 14/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.1295 - accuracy: 0.9604 - val_loss: 0.1743 - val_accuracy: 0.9417
# Epoch 15/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.0937 - accuracy: 0.9708 - val_loss: 0.1376 - val_accuracy: 0.9604
# Epoch 16/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0806 - accuracy: 0.9743 - val_loss: 0.1419 - val_accuracy: 0.9500
# Epoch 17/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0809 - accuracy: 0.9729 - val_loss: 0.2115 - val_accuracy: 0.9396
# Epoch 18/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0836 - accuracy: 0.9771 - val_loss: 0.1765 - val_accuracy: 0.9563
# Epoch 19/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0956 - accuracy: 0.9681 - val_loss: 0.1635 - val_accuracy: 0.9500
# Epoch 20/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0970 - accuracy: 0.9681 - val_loss: 0.1703 - val_accuracy: 0.9563
# Epoch 21/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0622 - accuracy: 0.9799 - val_loss: 0.1300 - val_accuracy: 0.9604
# Epoch 22/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0512 - accuracy: 0.9861 - val_loss: 0.1688 - val_accuracy: 0.9521
# Epoch 23/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0616 - accuracy: 0.9778 - val_loss: 0.2653 - val_accuracy: 0.9354
# Epoch 24/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0767 - accuracy: 0.9778 - val_loss: 0.2454 - val_accuracy: 0.9146
# Epoch 25/100
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0585 - accuracy: 0.9806 - val_loss: 0.1374 - val_accuracy: 0.9708
# Epoch 26/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0382 - accuracy: 0.9917 - val_loss: 0.1250 - val_accuracy: 0.9667
# Epoch 27/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0633 - accuracy: 0.9812 - val_loss: 0.1213 - val_accuracy: 0.9646
# Epoch 28/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0219 - accuracy: 0.9944 - val_loss: 0.1504 - val_accuracy: 0.9646
# Epoch 29/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0431 - accuracy: 0.9847 - val_loss: 0.1311 - val_accuracy: 0.9583
# Epoch 30/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0637 - accuracy: 0.9812 - val_loss: 0.1706 - val_accuracy: 0.9625
# Epoch 31/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0594 - accuracy: 0.9847 - val_loss: 0.1018 - val_accuracy: 0.9667
# Epoch 32/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0186 - accuracy: 0.9958 - val_loss: 0.1649 - val_accuracy: 0.9667
# Epoch 33/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0339 - accuracy: 0.9868 - val_loss: 0.2742 - val_accuracy: 0.9396
# Epoch 34/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0654 - accuracy: 0.9806 - val_loss: 0.1721 - val_accuracy: 0.9500
# Epoch 35/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0929 - accuracy: 0.9722 - val_loss: 0.1571 - val_accuracy: 0.9521
# Epoch 36/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 0.1410 - val_accuracy: 0.9625
# Epoch 37/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0435 - accuracy: 0.9868 - val_loss: 0.1869 - val_accuracy: 0.9521
# Epoch 38/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0347 - accuracy: 0.9910 - val_loss: 0.2576 - val_accuracy: 0.9354
# Epoch 39/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.1691 - accuracy: 0.9500 - val_loss: 0.1521 - val_accuracy: 0.9625
# Epoch 40/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0433 - accuracy: 0.9875 - val_loss: 0.2330 - val_accuracy: 0.9333
# Epoch 41/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0398 - accuracy: 0.9917 - val_loss: 0.1237 - val_accuracy: 0.9625
# Epoch 42/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0250 - accuracy: 0.9937 - val_loss: 0.1058 - val_accuracy: 0.9667
# Epoch 43/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0169 - accuracy: 0.9979 - val_loss: 0.1590 - val_accuracy: 0.9542
# Epoch 44/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0167 - accuracy: 0.9965 - val_loss: 0.1150 - val_accuracy: 0.9688
# Epoch 45/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.0133 - accuracy: 0.9986 - val_loss: 0.1349 - val_accuracy: 0.9729
# Epoch 46/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0100 - accuracy: 0.9986 - val_loss: 0.1367 - val_accuracy: 0.9729
# Epoch 47/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.1242 - val_accuracy: 0.9708
# Epoch 48/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.1969 - val_accuracy: 0.9583
# Epoch 49/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 0.1146 - val_accuracy: 0.9708
# Epoch 50/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0289 - accuracy: 0.9924 - val_loss: 2.0126 - val_accuracy: 0.7167
# Epoch 51/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.8135 - accuracy: 0.8000 - val_loss: 0.3462 - val_accuracy: 0.8792
# Epoch 52/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.1904 - accuracy: 0.9396 - val_loss: 0.2686 - val_accuracy: 0.9146
# Epoch 53/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0893 - accuracy: 0.9722 - val_loss: 0.1551 - val_accuracy: 0.9583
# Epoch 54/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0491 - accuracy: 0.9868 - val_loss: 0.1212 - val_accuracy: 0.9604
# Epoch 55/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0465 - accuracy: 0.9854 - val_loss: 0.2500 - val_accuracy: 0.9375
# Epoch 56/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0795 - accuracy: 0.9757 - val_loss: 0.1596 - val_accuracy: 0.9500
# Epoch 57/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0336 - accuracy: 0.9931 - val_loss: 0.1480 - val_accuracy: 0.9563
# Epoch 58/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0315 - accuracy: 0.9937 - val_loss: 0.1159 - val_accuracy: 0.9646
# Epoch 59/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 0.1459 - val_accuracy: 0.9708
# Epoch 60/100
# 23/23 [==============================] - 3s 144ms/step - loss: 0.0178 - accuracy: 0.9972 - val_loss: 0.1062 - val_accuracy: 0.9750
# Epoch 61/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 0.1162 - val_accuracy: 0.9729
# Epoch 62/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0090 - accuracy: 0.9986 - val_loss: 0.1414 - val_accuracy: 0.9646
# Epoch 63/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.1347 - val_accuracy: 0.9667
# Epoch 64/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.1989 - val_accuracy: 0.9688
# Epoch 65/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0480 - accuracy: 0.9854 - val_loss: 0.1617 - val_accuracy: 0.9563
# Epoch 66/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 0.2563 - val_accuracy: 0.9333
# Epoch 67/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0306 - accuracy: 0.9924 - val_loss: 0.1168 - val_accuracy: 0.9708
# Epoch 68/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0268 - accuracy: 0.9910 - val_loss: 0.1209 - val_accuracy: 0.9625
# Epoch 69/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0270 - accuracy: 0.9951 - val_loss: 0.1261 - val_accuracy: 0.9667
# Epoch 70/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0110 - accuracy: 0.9986 - val_loss: 0.1109 - val_accuracy: 0.9729
# Epoch 71/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.1342 - val_accuracy: 0.9729
# Epoch 72/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0110 - accuracy: 0.9986 - val_loss: 0.1338 - val_accuracy: 0.9729
# Epoch 73/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.1377 - val_accuracy: 0.9729
# Epoch 74/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.1400 - val_accuracy: 0.9708
# Epoch 75/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.1575 - val_accuracy: 0.9729
# Epoch 76/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.1603 - val_accuracy: 0.9750
# Epoch 77/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.1854 - val_accuracy: 0.9646
# Epoch 78/100
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0702 - accuracy: 0.9799 - val_loss: 1.1246 - val_accuracy: 0.7271
# Epoch 79/100
# 23/23 [==============================] - 3s 142ms/step - loss: 0.1421 - accuracy: 0.9590 - val_loss: 0.1130 - val_accuracy: 0.9563
# Epoch 80/100
# 23/23 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9854Restoring model weights from the end of the best epoch: 60.
# 23/23 [==============================] - 3s 143ms/step - loss: 0.0514 - accuracy: 0.9854 - val_loss: 0.1014 - val_accuracy: 0.9750
# Epoch 00080: early stopping
# Maximal validation accuracy: 97.50%

# %%
T_basemodel_imagenet_df = pd.DataFrame(T_basemodel_imagenet_main.history)
T_basemodel_imagenet_df.to_csv( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_df.csv' )
T_basemodel_imagenet_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.279491  0.463889  1.050178      0.500000
# 1   1.044847  0.500000  1.036308      0.500000
# 2   1.043422  0.500694  1.025094      0.500000
# 3   0.966459  0.520139  0.874544      0.595833
# 4   0.803324  0.631944  0.696903      0.681250
# ..       ...       ...       ...           ...
# 75  0.005185  0.998611  0.160313      0.975000
# 76  0.005371  0.997917  0.185408      0.964583
# 77  0.070160  0.979861  1.124621      0.727083
# 78  0.142132  0.959028  0.113029      0.956250
# 79  0.051393  0.985417  0.101382      0.975000
#
# [80 rows x 4 columns]

# %%
T_basemodel_imagenet_df.loc[:, ['loss', 'val_loss']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_loss,val_loss.png')
T_basemodel_imagenet_df.loc[:, ['accuracy', 'val_accuracy']].plot();
plt.savefig(path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(T_basemodel_imagenet_df['val_loss'].min()))
print("Maximum validation accuracy: {}".format(T_basemodel_imagenet_df['val_accuracy'].max()))
# Out:
# Minimum validation loss: 0.10138174146413803
# Maximum validation accuracy: 0.9750000238418579

# %%
print("Evaluate on test data")
T_model_name_imagenet_results = T_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# Evaluate on test data
# 15/15 [==============================] - 1s 23ms/step - loss: 0.0545 - accuracy: 0.9812
# test loss, test acc: [0.05450378730893135, 0.981249988079071]

# %%
T_model_name_imagenet_pred_Y = T_basemodel_imagenet.predict(xTest_T, verbose = True)
# Out:
# 15/15 [==============================] - 0s 21ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(T_all_labels):
    fpr, tpr, thresholds = roc_curve(yTest_T[:,idx].astype(int), T_model_name_imagenet_pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '_TESTSET_AUC.png' )

# %% [markdown]
# # 4. Result Report

# %%
print(S_model_name_None)
print("test loss, test acc:", S_basemodel_None_results)
# Out:
# S_VGG16_None
# test loss, test acc: [1.059519648551941, 0.5]

# %%
print(S_model_name_imagenet)
print("test loss, test acc:", S_model_name_imagenet_results)
# Out:
# S_VGG16_imagenet
# test loss, test acc: [0.5784012079238892, 0.8921874761581421]

# %%
print(T_model_name_None)
print("test loss, test acc:", T_basemodel_None_results)
# Out:
# T_VGG16_None
# test loss, test acc: [1.0629551410675049, 0.5]

# %%
print(T_model_name_imagenet)
print("test loss, test acc:", T_model_name_imagenet_results)
# Out:
# T_VGG16_imagenet
# test loss, test acc: [0.05450378730893135, 0.981249988079071]

# %% [markdown]
# # 5. Source Domain Training Model ↔ Target Domain Training Model 상호 Test Data Set 평가

# %%
print( S_model_name_None + " →→→ Target Test")
S_basemodel_None_results_T = S_basemodel_None.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_basemodel_None_results_T)
# Out:
# S_VGG16_None →→→ Target Test
# 15/15 [==============================] - 0s 22ms/step - loss: 1.0595 - accuracy: 0.5000
# test loss, test acc: [1.0595201253890991, 0.5]

# %%
print( S_model_name_imagenet + " →→→ Target Test")
S_model_name_imagenet_results_T = S_basemodel_imagenet.evaluate(xTest_T, yTest_T)
print("test loss, test acc:", S_model_name_imagenet_results_T)
# Out:
# S_VGG16_imagenet →→→ Target Test
# 15/15 [==============================] - 0s 22ms/step - loss: 8.6071 - accuracy: 0.5104
# test loss, test acc: [8.607061386108398, 0.5104166865348816]

# %%
print( T_model_name_None + " →→→ Source Test")
T_basemodel_None_results_S = T_basemodel_None.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_basemodel_None_results_S)
# Out:
# T_VGG16_None →→→ Source Test
# 20/20 [==============================] - 0s 23ms/step - loss: 1.0630 - accuracy: 0.5000
# test loss, test acc: [1.062955617904663, 0.5]

# %%
print( T_model_name_imagenet + " →→→ Source Test")
T_model_name_imagenet_results_S = T_basemodel_imagenet.evaluate(xTest_S, yTest_S)
print("test loss, test acc:", T_model_name_imagenet_results_S)
# Out:
# T_VGG16_imagenet →→→ Source Test
# 20/20 [==============================] - 0s 23ms/step - loss: 3.1556 - accuracy: 0.3875
# test loss, test acc: [3.1555581092834473, 0.38749998807907104]

# %% [markdown]
# # 6. Model Save

# %%
S_basemodel_None.save( path_model_result + S_model_name_None + '/' + S_model_name_None + '.h5' )
S_basemodel_imagenet.save( path_model_result + S_model_name_imagenet + '/' + S_model_name_imagenet + '.h5' )
T_basemodel_None.save( path_model_result + T_model_name_None + '/' + T_model_name_None + '.h5' )
T_basemodel_imagenet.save( path_model_result + T_model_name_imagenet + '/' + T_model_name_imagenet + '.h5' )
