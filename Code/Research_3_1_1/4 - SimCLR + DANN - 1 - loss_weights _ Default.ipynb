# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import os
import numpy as np
from keras.utils import np_utils
import tensorflow as tf
import pandas as pd
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
import tqdm

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7092674578654764552
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15031658253944169081
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Sat Dec 18 04:19:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. parameter setup

# %%
image_size = 128
image_channels = 3
batch_size = 64
num_epochs = 100
class_num = 3
imagenet_patience_num = 30

#base_path = ''
base_path = 'gdrive/My Drive/Research_3_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/4 - SimCLR + DANN_result - 1/'
model_path = path_model_result + 'model_'

basemodel_load = tf.keras.models.load_model( 'gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR_result/pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Data Setting

# %% [markdown]
# ## 2-1. Data Load

# %%
combined_train_imgs = np.load(path_data + 'combined_train_imgs.npy')
combined_train_labels = np.load(path_data + 'combined_train_labels.npy')
combined_train_domain = np.load(path_data + 'combined_train_domain.npy')

combined_Valid_imgs = np.load(path_data + 'combined_Valid_imgs.npy')
combined_Valid_labels = np.load(path_data + 'combined_Valid_labels.npy')
combined_Valid_domain = np.load(path_data + 'combined_Valid_domain.npy')

combined_test_imgs = np.load(path_data + 'combined_test_imgs.npy')
combined_test_labels = np.load(path_data + 'combined_test_labels.npy')
combined_test_domain = np.load(path_data + 'combined_test_domain.npy')

# %%
sample_weights_class_label = np.load(path_data + 'sample_weights_class_label.npy')
sample_weights_domain_label = np.load(path_data + 'sample_weights_domain_label.npy')

# %%
print(combined_train_imgs.shape)
print(combined_train_labels.shape)
print(combined_train_domain.shape)
print()
print(combined_Valid_imgs.shape)
print(combined_Valid_labels.shape)
print(combined_Valid_domain.shape)
print()
print(sample_weights_class_label.shape)
print(sample_weights_domain_label.shape)
# Out:
# (3360, 128, 128, 3)
# (3360, 3)
# (3360, 2)
#
# (1120, 128, 128, 3)
# (1120, 3)
# (1120, 2)
#
# (3360,)
# (3360,)

# %%
xValid_S = np.load(path_data + 'xValid_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')

xValid_T = np.load(path_data + 'xValid_T.npy')
yValid_T = np.load(path_data + 'yValid_T.npy')

Valid_S_domain = np.load(path_data + 'Valid_S_domain.npy')
Valid_T_domain = np.load(path_data + 'Valid_T_domain.npy')

xValid_S = xValid_S.astype('float32')/255
yValid_S = np_utils.to_categorical(yValid_S, class_num)

xValid_T = xValid_T.astype('float32')/255
yValid_T = np_utils.to_categorical(yValid_T, class_num)

# %%
print(xValid_S.shape, yValid_S.shape)
print(xValid_T.shape, yValid_T.shape)
print()
print(Valid_S_domain.shape)
print(Valid_T_domain.shape)
# Out:
# (640, 128, 128, 3) (640, 3)
# (480, 128, 128, 3) (480, 3)
#
# (640, 2)
# (480, 2)

# %%
xTest_S = np.load(path_data + 'xTest_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

xTest_T = np.load(path_data + 'xTest_T.npy')
yTest_T = np.load(path_data + 'yTest_T.npy')

test_S_domain = np.load(path_data + 'test_S_domain.npy')
test_T_domain = np.load(path_data + 'test_T_domain.npy')

xTest_S = xTest_S.astype('float32')/255
yTest_S = np_utils.to_categorical(yTest_S, class_num)

xTest_T = xTest_T.astype('float32')/255
yTest_T = np_utils.to_categorical(yTest_T, class_num)

# %%
print(xTest_S.shape, yTest_S.shape)
print(xTest_T.shape, yTest_T.shape)
print()
print(test_S_domain.shape)
print(test_T_domain.shape)
# Out:
# (640, 128, 128, 3) (640, 3)
# (480, 128, 128, 3) (480, 3)
#
# (640, 2)
# (480, 2)

# %% [markdown]
# # 3. DANN Network

# %% [markdown]
# ## 3-1. DANN Setting

# %%
@tf.custom_gradient
def GradientReversalOperator(x):
    def grad(dy):
        return -1 * dy
    return x, grad

class GradientReversalLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(GradientReversalLayer, self).__init__()
    def call(self, inputs):
        return GradientReversalOperator(inputs)

def classifier(feature_output):
    out = feature_output
    out = Dense(128, activation="relu")(out)
    out = Dense(64, activation="relu")(out)
    classifier_output = Dense(class_num, activation="softmax", name="classifier_output")(out) 
    return classifier_output

def discriminator(inp):
    out = Dense(32, activation="relu")(inp)
    discriminator_output = Dense(2, activation="softmax", name="discriminator_output")(out)
    return discriminator_output

def dann():    
    inp = Input(shape=(image_size, image_size, image_channels))
    feature_output = basemodel_load(inp)
    classifier_output = classifier(feature_output)
    grl_layer = GradientReversalLayer()(feature_output)
    discriminator_output = discriminator(grl_layer)
    model = tf.keras.models.Model(inputs=inp, outputs=[discriminator_output,classifier_output])
    return model

# %% [markdown]
# ## 3-2. Model Training

# %%
model = dann()
#print(S_dann_model.summary())

# %%
model.compile(optimizer='adam', 
              loss={'discriminator_output': 'binary_crossentropy',
                    'classifier_output': 'categorical_crossentropy'},
              metrics = ['accuracy'])


ES = EarlyStopping(monitor='val_classifier_output_accuracy', verbose=1, patience=imagenet_patience_num, restore_best_weights=True)
MC = ModelCheckpoint( path_model_result + 'model_{epoch}.h5', monitor='val_classifier_output_accuracy', mode='max', verbose=1, save_best_only=False, save_freq='epoch')


dann_model = model.fit(combined_train_imgs,[combined_train_domain,combined_train_labels], 
                        sample_weight=[sample_weights_domain_label, sample_weights_class_label],
                        epochs=num_epochs, batch_size=batch_size, validation_data=(combined_Valid_imgs,[combined_Valid_domain,combined_Valid_labels]), callbacks=[ES, MC])


print( "Maximal validation accuracy: {:.2f}%".format(
        max(dann_model.history["val_classifier_output_accuracy"]) * 100))
# Out:
# Epoch 1/100
# 53/53 [==============================] - ETA: 0s - loss: 5.9803 - discriminator_output_loss: 5.8781 - classifier_output_loss: 0.1022 - discriminator_output_accuracy: 0.1750 - classifier_output_accuracy: 0.8378
# Epoch 00001: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 53/53 [==============================] - 31s 322ms/step - loss: 5.9803 - discriminator_output_loss: 5.8781 - classifier_output_loss: 0.1022 - discriminator_output_accuracy: 0.1750 - classifier_output_accuracy: 0.8378 - val_loss: 11.2555 - val_discriminator_output_loss: 7.9818 - val_classifier_output_loss: 3.2737 - val_discriminator_output_accuracy: 0.2509 - val_classifier_output_accuracy: 0.8482
# Epoch 2/100
# 53/53 [==============================] - ETA: 0s - loss: 2.3953 - discriminator_output_loss: 2.2628 - classifier_output_loss: 0.1326 - discriminator_output_accuracy: 0.5458 - classifier_output_accuracy: 0.7833
# Epoch 00002: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_2.h5
# 53/53 [==============================] - 15s 281ms/step - loss: 2.3953 - discriminator_output_loss: 2.2628 - classifier_output_loss: 0.1326 - discriminator_output_accuracy: 0.5458 - classifier_output_accuracy: 0.7833 - val_loss: 46.7309 - val_discriminator_output_loss: 9.4862 - val_classifier_output_loss: 37.2448 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.3625
# Epoch 3/100
# 53/53 [==============================] - ETA: 0s - loss: 6.8390 - discriminator_output_loss: 6.6861 - classifier_output_loss: 0.1529 - discriminator_output_accuracy: 0.2220 - classifier_output_accuracy: 0.7446
# Epoch 00003: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model
- discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8092 - val_loss: 33.4569 - val_discriminator_output_loss: 0.6833 - val_classifier_output_loss: 32.7735 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7812
# Epoch 25/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6865 - discriminator_output_loss: 0.6849 - classifier_output_loss: 0.0016 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8167
# Epoch 00025: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_25.h5
# 53/53 [==============================] - 15s 283ms/step - loss: 0.6865 - discriminator_output_loss: 0.6849 - classifier_output_loss: 0.0016 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8167 - val_loss: 18.8222 - val_discriminator_output_loss: 0.6837 - val_classifier_output_loss: 18.1385 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7884
# Epoch 26/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6837 - discriminator_output_loss: 0.6792 - classifier_output_loss: 0.0045 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8170
# Epoch 00026: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_26.h5
# 53/53 [==============================] - 15s 284ms/step - loss: 0.6837 - discriminator_output_loss: 0.6792 - classifier_output_loss: 0.0045 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8170 - val_loss: 9.5611 - val_discriminator_output_loss: 0.7150 - val_classifier_output_loss: 8.8460 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7911
# Epoch 27/100
# 53/53 [==============================] - ETA: 0s - loss: 0.7781 - discriminator_output_loss: 0.7026 - classifier_output_loss: 0.0755 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7810
# Epoch 00027: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_27.h5
# 53/53 [==============================] - 15s 284ms/step - loss: 0.7781 - discriminator_output_loss: 0.7026 - classifier_output_loss: 0.0755 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7810 - val_loss: 990.0399 - val_discriminator_output_loss: 0.6833 - val_classifier_output_loss: 989.3564 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7393
# Epoch 28/100
# 53/53 [==============================] - ETA: 0s - loss: 0.7073 - discriminator_output_loss: 0.6841 - classifier_output_loss: 0.0232 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7902
# Epoch 00028: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_28.h5
# 53/53 [==============================] - 15s 283ms/step - loss: 0.7073 - discriminator_output_loss: 0.6841 - classifier_output_loss: 0.0232 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.7902 - val_loss: 195.6643 - val_discriminator_output_loss: 0.6830 - val_classifier_output_loss: 194.9812 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7741
# Epoch 29/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6870 - discriminator_output_loss: 0.6821 - classifier_output_loss: 0.0049 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8140
# Epoch 00029: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_29.h5
# 53/53 [==============================] - 15s 284ms/step - loss: 0.6870 - discriminator_output_loss: 0.6821 - classifier_output_loss: 0.0049 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8140 - val_loss: 59.6434 - val_discriminator_output_loss: 0.6830 - val_classifier_output_loss: 58.9604 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.7893
# Epoch 30/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6866 - discriminator_output_loss: 0.6828 - classifier_output_loss: 0.0039 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8134
# Epoch 00030: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_30.h5
# 53/53 [==============================] - 15s 283ms/step - loss: 0.6866 - discriminator_output_loss: 0.6828 - classifier_output_loss: 0.0039 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8134 - val_loss: 20.6745 - val_discriminator_output_loss: 0.6830 - val_classifier_output_loss: 19.9915 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.8036
# Epoch 31/100
# 53/53 [==============================] - ETA: 0s - loss: 0.6871 - discriminator_output_loss: 0.6830 - classifier_output_loss: 0.0041 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8208Restoring model weights from the end of the best epoch: 1.
#
# Epoch 00031: saving model to gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_31.h5
# 53/53 [==============================] - 15s 286ms/step - loss: 0.6871 - discriminator_output_loss: 0.6830 - classifier_output_loss: 0.0041 - discriminator_output_accuracy: 0.5714 - classifier_output_accuracy: 0.8208 - val_loss: 23.4530 - val_discriminator_output_loss: 0.6830 - val_classifier_output_loss: 22.7701 - val_discriminator_output_accuracy: 0.5714 - val_classifier_output_accuracy: 0.8018
# Epoch 00031: early stopping
# Maximal validation accuracy: 84.82%

# %%
dann_model_df = pd.DataFrame(dann_model.history)
dann_model_df.to_csv( path_model_result + 'history_df.csv' )
dann_model_df
# Out:
#         loss  ...  val_classifier_output_accuracy
# 0   5.980280  ...                        0.848214
# 1   2.395345  ...                        0.362500
# 2   6.838997  ...                        0.651786
# 3   2.839233  ...                        0.636607
# 4   2.723397  ...                        0.607143
# 5   2.194247  ...                        0.651786
# 6   2.055053  ...                        0.603571
# 7   1.587681  ...                        0.546429
# 8   0.938084  ...                        0.683929
# 9   1.618629  ...                        0.617857
# 10  1.263687  ...                        0.650000
# 11  0.734371  ...                        0.683929
# 12  0.901948  ...                        0.743750
# 13  0.670922  ...                        0.799107
# 14  0.730463  ...                        0.784821
# 15  0.673227  ...                        0.794643
# 16  0.726783  ...                        0.744643
# 17  0.796086  ...                        0.718750
# 18  0.683752  ...                        0.790179
# 19  0.707106  ...                        0.789286
# 20  0.680855  ...                        0.767857
# 21  0.724225  ...                        0.751786
# 22  0.752886  ...                        0.775000
# 23  0.692893  ...                        0.781250
# 24  0.686509  ...                        0.788393
# 25  0.683741  ...                        0.791071
# 26  0.778104  ...                        0.739286
# 27  0.707282  ...                        0.774107
# 28  0.686978  ...                        0.789286
# 29  0.686633  ...                        0.803571
# 30  0.687077  ...                        0.801786
#
# [31 rows x 10 columns]

# %%
dann_model_df.loc[:, ['loss', 'discriminator_output_loss', 'classifier_output_loss', 'val_loss']].plot();
plt.savefig(path_model_result + 'loss,val_loss.png')
dann_model_df.loc[:, ['discriminator_output_accuracy', 'classifier_output_accuracy', 'val_discriminator_output_accuracy', 'val_classifier_output_accuracy']].plot();
plt.savefig(path_model_result + 'accuracy,val_accuracy.png')
print("Minimum validation loss: {}".format(dann_model_df['val_loss'].min()))
print("Maximum val_classifier_output_accuracy: {}".format(dann_model_df['val_classifier_output_accuracy'].max()))
# Out:
# Minimum validation loss: 1.8704450130462646
# Maximum val_classifier_output_accuracy: 0.8482142686843872

# %%
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 20/20 [==============================] - 2s 32ms/step - loss: 11.2769 - discriminator_output_loss: 11.1504 - classifier_output_loss: 0.1265 - discriminator_output_accuracy: 0.0016 - classifier_output_accuracy: 0.9766
# dann_source_acc : 97.65625 %

# %%
print("Evaluate on test data")
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 15/15 [==============================] - 0s 31ms/step - loss: 11.5780 - discriminator_output_loss: 4.3351 - classifier_output_loss: 7.2429 - discriminator_output_accuracy: 0.5542 - classifier_output_accuracy: 0.6729
# dann_target_acc : 67.29167 %

# %% [markdown]
# ## 3-3. Load_weights and epoch_train,epoch_evaluate

# %%
def epoch_train():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xValid_S,[Valid_S_domain, yValid_S] )
        target_acc = model.evaluate( xValid_T,[Valid_T_domain, yValid_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_train_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_train_df.to_csv( path_model_result + 'epoch_train_df_df.csv' )
    epoch_train_df

    return ()

# %%
epoch_train()
# Out:
# 31
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 11.0055 - discriminator_output_loss: 10.8300 - classifier_output_loss: 0.1755 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9719
# 15/15 [==============================] - 0s 31ms/step - loss: 11.5889 - discriminator_output_loss: 4.1843 - classifier_output_loss: 7.4046 - discriminator_output_accuracy: 0.5854 - classifier_output_accuracy: 0.6833
# dann_source_acc : 97.1875 %
# dann_target_acc : 68.33333 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_2.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_2.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 9.1567 - discriminator_output_loss: 0.2765 - classifier_output_loss: 8.8801 - discriminator_output_accuracy: 0.9969 - classifier_output_accuracy: 0.4969
# 15/15 [==============================] - 0s 31ms/step - loss: 96.8300 - discriminator_output_loss: 21.7657 - classifier_output_loss: 75.0642 - discriminator_output_accuracy: 0.0042 - classifier_output_accuracy: 0.1833
# dann_source_acc : 49.6875 %
# dann_target_acc : 18.33333 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model
 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_26.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_26.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6313 - discriminator_output_loss: 0.5362 - classifier_output_loss: 0.0952 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9703
# 15/15 [==============================] - 0s 31ms/step - loss: 21.4674 - discriminator_output_loss: 0.9535 - classifier_output_loss: 20.5139 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5521
# dann_source_acc : 97.03125 %
# dann_target_acc : 55.20833 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_27.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_27.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 3.8956 - discriminator_output_loss: 0.5676 - classifier_output_loss: 3.3280 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9109
# 15/15 [==============================] - 0s 31ms/step - loss: 2304.8987 - discriminator_output_loss: 0.8376 - classifier_output_loss: 2304.0613 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5104
# dann_source_acc : 91.09375 %
# dann_target_acc : 51.04167 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_28.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_28.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.7373 - discriminator_output_loss: 0.5666 - classifier_output_loss: 0.1707 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9469
# 15/15 [==============================] - 0s 32ms/step - loss: 455.5669 - discriminator_output_loss: 0.8383 - classifier_output_loss: 454.7286 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5437
# dann_source_acc : 94.6875 %
# dann_target_acc : 54.375 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_29.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_29.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6634 - discriminator_output_loss: 0.5661 - classifier_output_loss: 0.0973 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9703
# 15/15 [==============================] - 0s 31ms/step - loss: 138.2833 - discriminator_output_loss: 0.8387 - classifier_output_loss: 137.4445 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5479
# dann_source_acc : 97.03125 %
# dann_target_acc : 54.79167 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_30.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_30.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6376 - discriminator_output_loss: 0.5650 - classifier_output_loss: 0.0726 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9797
# 15/15 [==============================] - 0s 31ms/step - loss: 47.3904 - discriminator_output_loss: 0.8403 - classifier_output_loss: 46.5500 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5688
# dann_source_acc : 97.96875 %
# dann_target_acc : 56.875 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_31.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_31.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 11.0055 - discriminator_output_loss: 10.8300 - classifier_output_loss: 0.1755 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.9719
# 15/15 [==============================] - 0s 31ms/step - loss: 11.5889 - discriminator_output_loss: 4.1843 - classifier_output_loss: 7.4046 - discriminator_output_accuracy: 0.5854 - classifier_output_accuracy: 0.6833
# dann_source_acc : 97.1875 %
# dann_target_acc : 68.33333 %
# ()

# %%
def epoch_evaluate():

    epoch_num = dann_model_df.shape[0]
    print(epoch_num)
    epoch_num = epoch_num+1

    epoch_source_acc_evaluate = []
    epoch_target_acc_evaluate = []

    for i in range(1, epoch_num):
        temp = i
        temp = str(temp)
        print(path_model_result + 'model_' + temp + '.h5')
        temp1=str(path_model_result + 'model_' + temp + '.h5')
        print(temp1)

        model.load_weights(temp1)
        source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
        target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
        print('dann_source_acc :',round(source_acc[-1]*100,5),'%')
        print('dann_target_acc :',round(target_acc[-1]*100,5),'%')

        epoch_source_acc_evaluate.append(source_acc)
        epoch_target_acc_evaluate.append(target_acc)

    epoch_result_temp = list(map(list.__add__, epoch_source_acc_evaluate, epoch_target_acc_evaluate))
    epoch_evaluate_df = pd.DataFrame(epoch_result_temp, columns=['S-loss', 'S-discriminator_output_loss', 'S-classifier_output_loss', 'S-discriminator_output_accuracy', 'S-classifier_output_accuracy', 'T-loss', 'T-discriminator_output_loss', 'T-classifier_output_loss', 'T-discriminator_output_accuracy', 'T-classifier_output_accuracy'])
    epoch_evaluate_df.to_csv( path_model_result + 'epoch_evaluate_df.csv' )
    epoch_evaluate_df

    return ()

# %%
epoch_evaluate()
# Out:
# 31
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 11.2769 - discriminator_output_loss: 11.1504 - classifier_output_loss: 0.1265 - discriminator_output_accuracy: 0.0016 - classifier_output_accuracy: 0.9766
# 15/15 [==============================] - 0s 31ms/step - loss: 11.5780 - discriminator_output_loss: 4.3351 - classifier_output_loss: 7.2429 - discriminator_output_accuracy: 0.5542 - classifier_output_accuracy: 0.6729
# dann_source_acc : 97.65625 %
# dann_target_acc : 67.29167 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_2.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_2.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 8.2359 - discriminator_output_loss: 0.2839 - classifier_output_loss: 7.9520 - discriminator_output_accuracy: 0.9984 - classifier_output_accuracy: 0.5344
# 15/15 [==============================] - 0s 32ms/step - loss: 96.8301 - discriminator_output_loss: 21.9349 - classifier_output_loss: 74.8951 - discriminator_output_accuracy: 0.0021 - classifier_output_accuracy: 0.1875
# dann_source_acc : 53.4375 %
# dann_target_acc : 18.75 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_3.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_3.h5
# 20/20 [==============================] - 1s 31ms/step - loss:
 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_18.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_18.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.7575 - discriminator_output_loss: 0.3913 - classifier_output_loss: 0.3662 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9625
# 15/15 [==============================] - 0s 31ms/step - loss: 19.9234 - discriminator_output_loss: 0.8778 - classifier_output_loss: 19.0456 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.4458
# dann_source_acc : 96.25 %
# dann_target_acc : 44.58333 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_19.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_19.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.7714 - discriminator_output_loss: 0.5886 - classifier_output_loss: 0.1828 - discriminator_output_accuracy: 0.9844 - classifier_output_accuracy: 0.9578
# 15/15 [==============================] - 0s 31ms/step - loss: 27.1139 - discriminator_output_loss: 1.2537 - classifier_output_loss: 25.8602 - discriminator_output_accuracy: 0.1458 - classifier_output_accuracy: 0.5938
# dann_source_acc : 95.78125 %
# dann_target_acc : 59.375 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_20.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_20.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 1.4729 - discriminator_output_loss: 0.8080 - classifier_output_loss: 0.6649 - discriminator_output_accuracy: 0.9172 - classifier_output_accuracy: 0.9812
# 15/15 [==============================] - 1s 33ms/step - loss: 589.6166 - discriminator_output_loss: 0.6509 - classifier_output_loss: 588.9657 - discriminator_output_accuracy: 0.2354 - classifier_output_accuracy: 0.5667
# dann_source_acc : 98.125 %
# dann_target_acc : 56.66667 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_21.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_21.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6439 - discriminator_output_loss: 0.5570 - classifier_output_loss: 0.0869 - discriminator_output_accuracy: 0.9984 - classifier_output_accuracy: 0.9734
# 15/15 [==============================] - 0s 32ms/step - loss: 29.5705 - discriminator_output_loss: 0.8533 - classifier_output_loss: 28.7172 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5292
# dann_source_acc : 97.34375 %
# dann_target_acc : 52.91666 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_22.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_22.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.5522 - discriminator_output_loss: 0.4260 - classifier_output_loss: 0.1262 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9547
# 15/15 [==============================] - 0s 32ms/step - loss: 115.7255 - discriminator_output_loss: 0.9104 - classifier_output_loss: 114.8151 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5292
# dann_source_acc : 95.46875 %
# dann_target_acc : 52.91666 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_23.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_23.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6598 - discriminator_output_loss: 0.5709 - classifier_output_loss: 0.0889 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9719
# 15/15 [==============================] - 0s 32ms/step - loss: 383.9721 - discriminator_output_loss: 0.8332 - classifier_output_loss: 383.1389 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5417
# dann_source_acc : 97.1875 %
# dann_target_acc : 54.16667 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_24.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_24.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6694 - discriminator_output_loss: 0.5695 - classifier_output_loss: 0.0999 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9734
# 15/15 [==============================] - 0s 31ms/step - loss: 75.9011 - discriminator_output_loss: 0.8351 - classifier_output_loss: 75.0661 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5625
# dann_source_acc : 97.34375 %
# dann_target_acc : 56.25 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_25.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_25.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6742 - discriminator_output_loss: 0.5684 - classifier_output_loss: 0.1058 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9750
# 15/15 [==============================] - 0s 31ms/step - loss: 39.0369 - discriminator_output_loss: 0.8376 - classifier_output_loss: 38.1993 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5646
# dann_source_acc : 97.5 %
# dann_target_acc : 56.45834 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_26.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_26.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6198 - discriminator_output_loss: 0.5349 - classifier_output_loss: 0.0849 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9797
# 15/15 [==============================] - 0s 31ms/step - loss: 12.0026 - discriminator_output_loss: 0.9515 - classifier_output_loss: 11.0511 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5708
# dann_source_acc : 97.96875 %
# dann_target_acc : 57.08333 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_27.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_27.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 5.9086 - discriminator_output_loss: 0.5676 - classifier_output_loss: 5.3410 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9141
# 15/15 [==============================] - 0s 31ms/step - loss: 1926.5183 - discriminator_output_loss: 0.8387 - classifier_output_loss: 1925.6797 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5104
# dann_source_acc : 91.40625 %
# dann_target_acc : 51.04167 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_28.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_28.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.7275 - discriminator_output_loss: 0.5666 - classifier_output_loss: 0.1609 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9406
# 15/15 [==============================] - 0s 32ms/step - loss: 387.2463 - discriminator_output_loss: 0.8383 - classifier_output_loss: 386.4081 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5521
# dann_source_acc : 94.0625 %
# dann_target_acc : 55.20833 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_29.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_29.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 0.6592 - discriminator_output_loss: 0.5661 - classifier_output_loss: 0.0931 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9734
# 15/15 [==============================] - 0s 31ms/step - loss: 117.0755 - discriminator_output_loss: 0.8387 - classifier_output_loss: 116.2368 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5792
# dann_source_acc : 97.34375 %
# dann_target_acc : 57.91667 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_30.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_30.h5
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6157 - discriminator_output_loss: 0.5650 - classifier_output_loss: 0.0508 - discriminator_output_accuracy: 1.0000 - classifier_output_accuracy: 0.9844
# 15/15 [==============================] - 0s 32ms/step - loss: 41.5818 - discriminator_output_loss: 0.8403 - classifier_output_loss: 40.7415 - discriminator_output_accuracy: 0.0000e+00 - classifier_output_accuracy: 0.5938
# dann_source_acc : 98.4375 %
# dann_target_acc : 59.375 %
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_31.h5
# gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_31.h5
# 20/20 [==============================] - 1s 31ms/step - loss: 11.2769 - discriminator_output_loss: 11.1504 - classifier_output_loss: 0.1265 - discriminator_output_accuracy: 0.0016 - classifier_output_accuracy: 0.9766
# 15/15 [==============================] - 0s 31ms/step - loss: 11.5780 - discriminator_output_loss: 4.3351 - classifier_output_loss: 7.2429 - discriminator_output_accuracy: 0.5542 - classifier_output_accuracy: 0.6729
# dann_source_acc : 97.65625 %
# dann_target_acc : 67.29167 %
# ()

# %%
model.load_weights('gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR + DANN_result - 1/model_1.h5')
print("Evaluate on test data")
source_acc = model.evaluate( xTest_S,[test_S_domain, yTest_S] )
print('dann_target_acc :',round(source_acc [-1]*100,5),'%')
target_acc = model.evaluate( xTest_T,[test_T_domain, yTest_T] )
print('dann_target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# Evaluate on test data
# 20/20 [==============================] - 11s 30ms/step - loss: 11.2769 - discriminator_output_loss: 11.1504 - classifier_output_loss: 0.1265 - discriminator_output_accuracy: 0.0016 - classifier_output_accuracy: 0.9766
# dann_target_acc : 97.65625 %
# 15/15 [==============================] - 0s 30ms/step - loss: 11.5780 - discriminator_output_loss: 4.3351 - classifier_output_loss: 7.2429 - discriminator_output_accuracy: 0.5542 - classifier_output_accuracy: 0.6729
# dann_target_acc : 67.29167 %

# %% [markdown]
# # 4. Result Report

# %%
print( 'dann_model' + " →→→ Target Test")
print('target_acc :',round(target_acc[-1]*100,5),'%')
# Out:
# dann_model →→→ Target Test
# target_acc : 67.29167 %

# %% [markdown]
# # 5. Model Save

# %%
model.save( path_model_result + 'dann_model_last.h5' )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %% [markdown]
# ## 기타 - TSNE 확인

# %%
def plot_embedding1(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def plot_embedding2(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(30,30))
    ax = plt.subplot(111)
    for i in tqdm.tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'red'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 10})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
TSNE_model_none = dann()

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 1822.93it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding1(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 2953.31it/s]

# %%
feature_model = Model(TSNE_model_none.input, TSNE_model_none.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 2991.92it/s]

# %%
feature_model = Model(model.input, model.get_layer('classifier_output').output)
emb = feature_model.predict(combined_test_imgs)
tsne = TSNE(perplexity=50, n_components=2, init='pca', n_iter=500)
tsne_model = tsne.fit_transform(emb)
plot_embedding2(tsne_model, combined_test_labels.argmax(1)
               ,combined_test_domain.argmax(1),'DANN')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# 100%|██████████| 1120/1120 [00:00<00:00, 1926.32it/s]
