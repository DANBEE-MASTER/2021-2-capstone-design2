# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1-1. Library Setup

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import pandas as pd
import os

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9860754342689724840
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16154099712
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10568322164316199107
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
# !nvidia-smi
# Out:
# Fri Dec 17 18:14:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    32W / 250W |    375MiB / 16280MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## 1-2. Hyperparameter setup

# %%
# Dataset hyperparameters
image_size = 128
image_channels = 3

# Algorithm hyperparameters
num_epochs = 100
patience_num = 10
class_num = 3
batch_size = 64  
width = 128
temperature = 0.1

# Stronger augmentations for contrastive, weaker ones for supervised training
contrastive_augmentation = {"min_area": 0.25, "brightness": 0.6, "jitter": 0.2}
classification_augmentation = {"min_area": 0.75, "brightness": 0.3, "jitter": 0.1}

#base_path = ''
base_path = 'gdrive/My Drive/Research_3_1_1/'

path_data = base_path + 'data_numpy/'
path_model_result = base_path + 'model_result/3 - SimCLR_result/'

# %%
def createDirectory(name): 
    try: 
        if not os.path.exists(name): 
            os.makedirs(name) 
    except OSError: 
        print("Error: Failed to create the directory.")  
        
createDirectory(path_model_result)

# %% [markdown]
# # 2. Data Load and Image Check

# %% [markdown]
# ## 2-1. Data Load

# %%
xTrain_S = np.load(path_data + 'xTrain_S.npy')
xValid_S = np.load(path_data + 'xValid_S.npy')
xTest_S = np.load(path_data + 'xTest_S.npy')

yTrain_S = np.load(path_data + 'yTrain_S.npy')
yValid_S = np.load(path_data + 'yValid_S.npy')
yTest_S = np.load(path_data + 'yTest_S.npy')

# %%
print(xTrain_S.shape, yTrain_S.shape)
print(xValid_S.shape, yValid_S.shape)
print(xTest_S.shape, yTest_S.shape)
# Out:
# (1920, 128, 128, 3) (1920, 1)
# (640, 128, 128, 3) (640, 1)
# (640, 128, 128, 3) (640, 1)

# %%
xTrain_S = xTrain_S.astype('float32')/255
xValid_S = xValid_S.astype('float32')/255
xTest_S = xTest_S.astype('float32')/255

# %% [markdown]
# ## 2-2. Dataset

# %%
labeled_train_data = tf.data.Dataset.from_tensor_slices((xTrain_S, yTrain_S))
unlabeled_train_data = tf.data.Dataset.from_tensor_slices((xValid_S, yValid_S))
test_data = tf.data.Dataset.from_tensor_slices((xTest_S, yTest_S))

# %%
labeled_train_dataset = labeled_train_data.batch(batch_size)
unlabeled_train_dataset = unlabeled_train_data.batch(batch_size)
test_dataset = test_data.batch(batch_size)

# %%
train_dataset = tf.data.Dataset.zip(
        (unlabeled_train_dataset, labeled_train_dataset)
    ).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
print ('labeled_train_dataset : ' , labeled_train_dataset)
print ('labeled_train_dataset 총 batch_size 세트 : ' , len(labeled_train_dataset))
print ('unlabeled_train_dataset : ' , unlabeled_train_dataset)
print ('unlabeled_train_dataset 총 batch_size 세트 : ' , len(unlabeled_train_dataset))
print ('test_dataset : ' , test_dataset)
print ('test_dataset 총 batch_size 세트 : ' , len(test_dataset)) 
print ('train_dataset : ' , train_dataset)
print ('train_dataset 총 batch_size 세트 : ' , len(train_dataset))
# Out:
# labeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# labeled_train_dataset 총 batch_size 세트 :  30
# unlabeled_train_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# unlabeled_train_dataset 총 batch_size 세트 :  10
# test_dataset :  <BatchDataset shapes: ((None, 128, 128, 3), (None, 1)), types: (tf.float32, tf.int32)>
# test_dataset 총 batch_size 세트 :  10
# train_dataset :  <PrefetchDataset shapes: (((None, 128, 128, 3), (None, 1)), ((None, 128, 128, 3), (None, 1))), types: ((tf.float32, tf.int32), (tf.float32, tf.int32))>
# train_dataset 총 batch_size 세트 :  10

# %% [markdown]
# ## 2-3. Image augmentations and visualize_augmentations

# %%
from tensorflow.keras.layers.experimental import preprocessing

# %%
# Distorts the color distibutions of images
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def call(self, images, training=True):
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images


# Image augmentation module
def get_augmenter(min_area, brightness, jitter):
    zoom_factor = 1.0 - tf.sqrt(min_area)
    return tf.keras.Sequential(
        [
            tf.keras.Input(shape=(image_size, image_size, image_channels)),
            #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255),
            tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
            tf.keras.layers.experimental.preprocessing.RandomTranslation(zoom_factor / 2, zoom_factor / 2),
            tf.keras.layers.experimental.preprocessing.RandomZoom((-zoom_factor, 0.0), (-zoom_factor, 0.0)),
            RandomColorAffine(brightness, jitter),
        ]
    )


def visualize_augmentations(num_images):
    # Sample a batch from a dataset
    images = next(iter(train_dataset))[0][0][:num_images]
    # Apply augmentations
    augmented_images = zip(
        (images),
        #tf.keras.layers.experimental.preprocessing.Rescaling(1 / 255)(images),
        get_augmenter(**classification_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
        get_augmenter(**contrastive_augmentation)(images),
    )
    row_titles = [
        "Original:",
        "Weakly augmented:",
        "Strongly augmented:",
        "Strongly augmented:",
    ]
    plt.figure(figsize=(num_images * 2.2, 4 * 2.2), dpi=100)
    for column, image_row in enumerate(augmented_images):
        for row, image in enumerate(image_row):
            plt.subplot(4, num_images, row * num_images + column + 1)
            plt.imshow(image)
            if column == 0:
                plt.title(row_titles[row], loc="left")
            plt.axis("off")
    plt.tight_layout()

# %%
visualize_augmentations(num_images=8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 3. Network

# %% [markdown]
# ## 3-1. Encoder architecture

# %%
def get_encoder():
    base_model = tf.keras.applications.Xception(
    weights='imagenet',
    include_top=False,
    pooling='avg')
    
    model = keras.Sequential([
    base_model,
    layers.Dense(width, activation="relu"),
    ])
    
    return model

# %% [markdown]
# ## 3-2. Supervised baseline model - original image

# %%
# Baseline supervised training with random initialization
baseline_model_original_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        #get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_original_image",
)

baseline_model_original_image.summary()

baseline_model_original_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 3s 0us/step
# 83697664/83683744 [==============================] - 3s 0us/step
# Model: "baseline_model_original_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 128)               21123752
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21,148,715
# Trainable params: 21,094,187
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_original_image_history = baseline_model_original_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_original_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 30/30 [==============================] - 20s 288ms/step - loss: 0.4119 - acc: 0.8354 - val_loss: 32.9392 - val_acc: 0.5000
# Epoch 2/100
# 30/30 [==============================] - 8s 260ms/step - loss: 0.0922 - acc: 0.9740 - val_loss: 3.1084 - val_acc: 0.7828
# Epoch 3/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.0620 - acc: 0.9802 - val_loss: 1.1126 - val_acc: 0.8703
# Epoch 4/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0393 - acc: 0.9896 - val_loss: 1.4901 - val_acc: 0.8031
# Epoch 5/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0222 - acc: 0.9927 - val_loss: 1.3654 - val_acc: 0.8266
# Epoch 6/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.0598 - acc: 0.9870 - val_loss: 1.1965 - val_acc: 0.8969
# Epoch 7/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.0377 - acc: 0.9885 - val_loss: 0.8056 - val_acc: 0.8938
# Epoch 8/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0401 - acc: 0.9891 - val_loss: 11.7424 - val_acc: 0.7953
# Epoch 9/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0465 - acc: 0.9865 - val_loss: 94.6700 - val_acc: 0.6438
# Epoch 10/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0318 - acc: 0.9906 - val_loss: 52.7621 - val_acc: 0.7234
# Epoch 11/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.0150 - acc: 0.9953 - val_loss: 0.3266 - val_acc: 0.9516
# Epoch 12/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.0064 - acc: 0.9979 - val_loss: 0.2462 - val_acc: 0.9594
# Epoch 13/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0178 - acc: 0.9964 - val_loss: 0.5157 - val_acc: 0.9516
# Epoch 14/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0289 - acc: 0.9896 - val_loss: 11.0140 - val_acc: 0.8750
# Epoch 15/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0187 - acc: 0.9943 - val_loss: 0.8121 - val_acc: 0.8844
# Epoch 16/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.0052 - acc: 0.9984 - val_loss: 1.7958 - val_acc: 0.8609
# Epoch 17/100
# 30/30 [==============================] - 8s 256ms/step - loss: 7.1370e-04 - acc: 1.0000 - val_loss: 1.2384 - val_acc: 0.9078
# Epoch 18/100
# 30/30 [==============================] - 8s 255ms/step - loss: 4.6710e-04 - acc: 1.0000 - val_loss: 0.3739 - val_acc: 0.9578
# Epoch 19/100
# 30/30 [==============================] - 8s 260ms/step - loss: 3.9733e-05 - acc: 1.0000 - val_loss: 0.2721 - val_acc: 0.9641
# Epoch 20/100
# 30/30 [==============================] - 8s 260ms/step - loss: 1.1667e-05 - acc: 1.0000 - val_loss: 0.2125 - val_acc: 0.9688
# Epoch 21/100
# 30/30 [==============================] - 8s 260ms/step - loss: 9.1061e-06 - acc: 1.0000 - val_loss: 0.1844 - val_acc: 0.9734
# Epoch 22/100
# 30/30 [==============================] - 8s 260ms/step - loss: 7.6612e-06 - acc: 1.0000 - val_loss: 0.1713 - val_acc: 0.9766
# Epoch 23/100
# 30/30 [==============================] - 8s 259ms/step - loss: 6.6398e-06 - acc: 1.0000 - val_loss: 0.1692 - val_acc: 0.9781
# Epoch 24/100
# 30/30 [==============================] - 8s 256ms/step - loss: 5.8648e-06 - acc: 1.0000 - val_loss: 0.1690 - val_acc: 0.9781
# Epoch 25/100
# 30/30 [==============================] - 8s 256ms/step - loss: 5.2533e-06 - acc: 1.0000 - val_loss: 0.1690 - val_acc: 0.9781
# Epoch 26/100
# 30/30 [==============================] - 8s 256ms/step - loss: 4.7544e-06 - acc: 1.0000 - val_loss: 0.1694 - val_acc: 0.9781
# Epoch 27/100
# 30/30 [==============================] - 8s 255ms/step - loss: 4.3420e-06 - acc: 1.0000 - val_loss: 0.1698 - val_acc: 0.9781
# Epoch 28/100
# 30/30 [==============================] - 8s 255ms/step - loss: 3.9922e-06 - acc: 1.0000 - val_loss: 0.1702 - val_acc: 0.9781
# Epoch 29/100
# 30/30 [==============================] - 8s 259ms/step - loss: 3.6915e-06 - acc: 1.0000 - val_loss: 0.1707 - val_acc: 0.9812
# Epoch 30/100
# 30/30 [==============================] - 8s 255ms/step - loss: 3.4275e-06 - acc: 1.0000 - val_loss: 0.1712 - val_acc: 0.9812
# Epoch 31/100
# 30/30 [==============================] - 8s 256ms/step - loss: 3.1945e-06 - acc: 1.0000 - val_loss: 0.1716 - val_acc: 0.9812
# Epoch 32/100
# 30/30 [==============================] - 8s 255ms/step - loss: 2.9878e-06 - acc: 1.0000 - val_loss: 0.1720 - val_acc: 0.9812
# Epoch 33/100
# 30/30 [==============================] - 8s 256ms/step - loss: 2.8032e-06 - acc: 1.0000 - val_loss: 0.1724 - val_acc: 0.9812
# Epoch 34/100
# 30/30 [==============================] - 8s 256ms/step - loss: 2.6373e-06 - acc: 1.0000 - val_loss: 0.1727 - val_acc: 0.9812
# Epoch 35/100
# 30/30 [==============================] - 8s 256ms/step - loss: 2.4862e-06 - acc: 1.0000 - val_loss: 0.1731 - val_acc: 0.9812
# Epoch 36/100
# 30/30 [==============================] - 8s 256ms/step - loss: 2.3490e-06 - acc: 1.0000 - val_loss: 0.1734 - val_acc: 0.9812
# Epoch 37/100
# 30/30 [==============================] - 8s 255ms/step - loss: 2.2245e-06 - acc: 1.0000 - val_loss: 0.1737 - val_acc: 0.9812
# Epoch 38/100
# 30/30 [==============================] - 8s 255ms/step - loss: 2.1093e-06 - acc: 1.0000 - val_loss: 0.1740 - val_acc: 0.9812
# Epoch 39/100
# 30/30 [==============================] - ETA: 0s - loss: 2.0036e-06 - acc: 1.0000Restoring model weights from the end of the best epoch: 29.
# 30/30 [==============================] - 8s 259ms/step - loss: 2.0036e-06 - acc: 1.0000 - val_loss: 0.1743 - val_acc: 0.9812
# Epoch 00039: early stopping
# Maximal validation accuracy: 98.12%

# %%
baseline_model_original_image_df = pd.DataFrame(baseline_model_original_image_history.history)
baseline_model_original_image_df.to_csv( path_model_result + 'baseline_model_original_image_df.csv' )
baseline_model_original_image_df
# Out:
#         loss       acc   val_loss   val_acc
# 0   0.411877  0.835417  32.939232  0.500000
# 1   0.092173  0.973958   3.108354  0.782812
# 2   0.062017  0.980208   1.112588  0.870313
# 3   0.039255  0.989583   1.490072  0.803125
# 4   0.022157  0.992708   1.365387  0.826563
# 5   0.059753  0.986979   1.196549  0.896875
# 6   0.037683  0.988542   0.805567  0.893750
# 7   0.040109  0.989062  11.742406  0.795313
# 8   0.046458  0.986458  94.670013  0.643750
# 9   0.031808  0.990625  52.762138  0.723437
# 10  0.014963  0.995313   0.326572  0.951563
# 11  0.006358  0.997917   0.246250  0.959375
# 12  0.017774  0.996354   0.515737  0.951563
# 13  0.028916  0.989583  11.014034  0.875000
# 14  0.018745  0.994271   0.812054  0.884375
# 15  0.005185  0.998438   1.795779  0.860937
# 16  0.000714  1.000000   1.238437  0.907812
# 17  0.000467  1.000000   0.373887  0.957812
# 18  0.000040  1.000000   0.272100  0.964063
# 19  0.000012  1.000000   0.212508  0.968750
# 20  0.000009  1.000000   0.184396  0.973437
# 21  0.000008  1.000000   0.171310  0.976562
# 22  0.000007  1.000000   0.169240  0.978125
# 23  0.000006  1.000000   0.168989  0.978125
# 24  0.000005  1.000000   0.169044  0.978125
# 25  0.000005  1.000000   0.169384  0.978125
# 26  0.000004  1.000000   0.169802  0.978125
# 27  0.000004  1.000000   0.170244  0.978125
# 28  0.000004  1.000000   0.170706  0.981250
# 29  0.000003  1.000000   0.171156  0.981250
# 30  0.000003  1.000000   0.171580  0.981250
# 31  0.000003  1.000000   0.171978  0.981250
# 32  0.000003  1.000000   0.172357  0.981250
# 33  0.000003  1.000000   0.172719  0.981250
# 34  0.000002  1.000000   0.173067  0.981250
# 35  0.000002  1.000000   0.173398  0.981250
# 36  0.000002  1.000000   0.173717  0.981250
# 37  0.000002  1.000000   0.174021  0.981250
# 38  0.000002  1.000000   0.174315  0.981250

# %% [markdown]
# ## 3-3. Supervised baseline model - augmenter image

# %%
# Baseline supervised training with random initialization
baseline_model_augmenter_image = keras.Sequential(
    [
        keras.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        get_encoder(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(class_num, activation='softmax'),
    ],
    name="baseline_model_augmenter_image",
)

baseline_model_augmenter_image.summary()

baseline_model_augmenter_image.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Out:
# Model: "baseline_model_augmenter_image"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 128, 128, 3)       0
#
#  sequential_5 (Sequential)   (None, 128)               21123752
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21,148,715
# Trainable params: 21,094,187
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
ES = EarlyStopping(monitor='val_acc', verbose=1, patience=patience_num, restore_best_weights=True)

baseline_model_augmenter_image_history = baseline_model_augmenter_image.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(baseline_model_augmenter_image_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 30/30 [==============================] - 13s 291ms/step - loss: 0.5327 - acc: 0.7812 - val_loss: 8.2983 - val_acc: 0.6812
# Epoch 2/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.2170 - acc: 0.9266 - val_loss: 4.4311 - val_acc: 0.6438
# Epoch 3/100
# 30/30 [==============================] - 8s 265ms/step - loss: 0.1814 - acc: 0.9479 - val_loss: 0.6328 - val_acc: 0.8656
# Epoch 4/100
# 30/30 [==============================] - 8s 264ms/step - loss: 0.1064 - acc: 0.9703 - val_loss: 0.7757 - val_acc: 0.9203
# Epoch 5/100
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0914 - acc: 0.9729 - val_loss: 0.2944 - val_acc: 0.9547
# Epoch 6/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0582 - acc: 0.9828 - val_loss: 0.4230 - val_acc: 0.9422
# Epoch 7/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0794 - acc: 0.9734 - val_loss: 0.1883 - val_acc: 0.9531
# Epoch 8/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0772 - acc: 0.9807 - val_loss: 0.2940 - val_acc: 0.9406
# Epoch 9/100
# 30/30 [==============================] - 8s 262ms/step - loss: 0.0730 - acc: 0.9823 - val_loss: 0.6520 - val_acc: 0.9156
# Epoch 10/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0400 - acc: 0.9896 - val_loss: 1.0884 - val_acc: 0.8734
# Epoch 11/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0390 - acc: 0.9870 - val_loss: 0.3359 - val_acc: 0.9312
# Epoch 12/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0282 - acc: 0.9922 - val_loss: 0.3221 - val_acc: 0.9312
# Epoch 13/100
# 30/30 [==============================] - 8s 262ms/step - loss: 0.0279 - acc: 0.9896 - val_loss: 1.0187 - val_acc: 0.8672
# Epoch 14/100
# 30/30 [==============================] - 8s 261ms/step - loss: 0.0412 - acc: 0.9885 - val_loss: 1.0705 - val_acc: 0.7656
# Epoch 15/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0475 - acc: 0.9891Restoring model weights from the end of the best epoch: 5.
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0475 - acc: 0.9891 - val_loss: 0.1573 - val_acc: 0.9531
# Epoch 00015: early stopping
# Maximal validation accuracy: 95.47%

# %%
baseline_model_augmenter_image_df = pd.DataFrame(baseline_model_augmenter_image_history.history)
baseline_model_augmenter_image_df.to_csv( path_model_result + 'baseline_model_augmenter_image_df.csv' )
baseline_model_augmenter_image_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.532653  0.781250  8.298272  0.681250
# 1   0.216959  0.926562  4.431075  0.643750
# 2   0.181430  0.947917  0.632771  0.865625
# 3   0.106355  0.970312  0.775654  0.920313
# 4   0.091405  0.972917  0.294433  0.954687
# 5   0.058189  0.982813  0.422997  0.942187
# 6   0.079392  0.973437  0.188343  0.953125
# 7   0.077232  0.980729  0.293970  0.940625
# 8   0.072979  0.982292  0.652038  0.915625
# 9   0.039977  0.989583  1.088409  0.873438
# 10  0.038975  0.986979  0.335879  0.931250
# 11  0.028151  0.992188  0.322140  0.931250
# 12  0.027887  0.989583  1.018729  0.867188
# 13  0.041231  0.988542  1.070536  0.765625
# 14  0.047543  0.989062  0.157312  0.953125

# %% [markdown]
# ## 3-4. ContrastiveModel - augmenter image

# %%
# Define the contrastive model with model-subclassing
class ContrastiveModel(keras.Model):
    def __init__(self):
        super().__init__()

        self.temperature = temperature
        self.contrastive_augmenter = get_augmenter(**contrastive_augmentation)
        self.classification_augmenter = get_augmenter(**classification_augmentation)
        self.encoder = get_encoder()
        # Non-linear MLP as projection head
        self.projection_head = keras.Sequential(
            [
                keras.Input(shape=(width,)),
                layers.Dense(width, activation="relu"),
                layers.Dense(width),
            ],
            name="projection_head",
        )
        # Single dense layer for linear probing
        self.linear_probe = keras.Sequential(
            [layers.Input(shape=(width,)), layers.Dense(class_num)], name="linear_probe"
        )

        self.encoder.summary()
        self.projection_head.summary()
        self.linear_probe.summary()

    def compile(self, contrastive_optimizer, probe_optimizer, **kwargs):
        super().compile(**kwargs)

        self.contrastive_optimizer = contrastive_optimizer
        self.probe_optimizer = probe_optimizer

        # self.contrastive_loss will be defined as a method
        self.probe_loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

        self.contrastive_loss_tracker = keras.metrics.Mean(name="c_loss")
        self.contrastive_accuracy = keras.metrics.SparseCategoricalAccuracy(
            name="c_acc"
        )
        self.probe_loss_tracker = keras.metrics.Mean(name="p_loss")
        self.probe_accuracy = keras.metrics.SparseCategoricalAccuracy(name="p_acc")

    @property
    def metrics(self):
        return [
            self.contrastive_loss_tracker,
            self.contrastive_accuracy,
            self.probe_loss_tracker,
            self.probe_accuracy,
        ]

    def contrastive_loss(self, projections_1, projections_2):
        # InfoNCE loss (information noise-contrastive estimation)
        # NT-Xent loss (normalized temperature-scaled cross entropy)

        # Cosine similarity: the dot product of the l2-normalized feature vectors
        projections_1 = tf.math.l2_normalize(projections_1, axis=1)
        projections_2 = tf.math.l2_normalize(projections_2, axis=1)
        similarities = (
            tf.matmul(projections_1, projections_2, transpose_b=True) / self.temperature
        )

        # The similarity between the representations of two augmented views of the
        # same image should be higher than their similarity with other views
        batch_size = tf.shape(projections_1)[0]
        contrastive_labels = tf.range(batch_size)
        self.contrastive_accuracy.update_state(contrastive_labels, similarities)
        self.contrastive_accuracy.update_state(
            contrastive_labels, tf.transpose(similarities)
        )

        # The temperature-scaled similarities are used as logits for cross-entropy
        # a symmetrized version of the loss is used here
        loss_1_2 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, similarities, from_logits=True
        )
        loss_2_1 = keras.losses.sparse_categorical_crossentropy(
            contrastive_labels, tf.transpose(similarities), from_logits=True
        )
        return (loss_1_2 + loss_2_1) / 2

    def train_step(self, data):
        (unlabeled_images, _), (labeled_images, labels) = data

        # Both labeled and unlabeled images are used, without labels
        images = tf.concat((unlabeled_images, labeled_images), axis=0)
        # Each image is augmented twice, differently
        augmented_images_1 = self.contrastive_augmenter(images, training=True)
        augmented_images_2 = self.contrastive_augmenter(images, training=True)
        with tf.GradientTape() as tape:
            features_1 = self.encoder(augmented_images_1, training=True)
            features_2 = self.encoder(augmented_images_2, training=True)
            # The representations are passed through a projection mlp
            projections_1 = self.projection_head(features_1, training=True)
            projections_2 = self.projection_head(features_2, training=True)
            contrastive_loss = self.contrastive_loss(projections_1, projections_2)
        gradients = tape.gradient(
            contrastive_loss,
            self.encoder.trainable_weights + self.projection_head.trainable_weights,
        )
        self.contrastive_optimizer.apply_gradients(
            zip(
                gradients,
                self.encoder.trainable_weights + self.projection_head.trainable_weights,
            )
        )
        self.contrastive_loss_tracker.update_state(contrastive_loss)

        # Labels are only used in evalutation for an on-the-fly logistic regression
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=True
        )
        with tf.GradientTape() as tape:
            # the encoder is used in inference mode here to avoid regularization
            # and updating the batch normalization paramers if they are used
            features = self.encoder(preprocessed_images, training=False)
            class_logits = self.linear_probe(features, training=True)
            probe_loss = self.probe_loss(labels, class_logits)
        gradients = tape.gradient(probe_loss, self.linear_probe.trainable_weights)
        self.probe_optimizer.apply_gradients(
            zip(gradients, self.linear_probe.trainable_weights)
        )
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        labeled_images, labels = data

        # For testing the components are used with a training=False flag
        preprocessed_images = self.classification_augmenter(
            labeled_images, training=False
        )
        features = self.encoder(preprocessed_images, training=False)
        class_logits = self.linear_probe(features, training=False)
        probe_loss = self.probe_loss(labels, class_logits)
        self.probe_loss_tracker.update_state(probe_loss)
        self.probe_accuracy.update_state(labels, class_logits)

        # Only the probe metrics are logged at test time
        return {m.name: m.result() for m in self.metrics[2:]}

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

# Contrastive pretraining
pretraining_model = ContrastiveModel()
pretraining_model.compile(
    contrastive_optimizer=keras.optimizers.Adam(),
    probe_optimizer=keras.optimizers.Adam(),
)

pretraining_history = pretraining_model.fit(
    train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(pretraining_history.history["val_p_acc"]) * 100
    )
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense_8 (Dense)             (None, 128)               262272
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________
# Model: "projection_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 128)               16512
#
# =================================================================
# Total params: 33,024
# Trainable params: 33,024
# Non-trainable params: 0
# _________________________________________________________________
# Model: "linear_probe"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 387
# Trainable params: 387
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 22s 1s/step - c_loss: 3.9339 - c_acc: 0.1430 - p_loss: 1.1261 - p_acc: 0.4609 - val_p_loss: 1.4354 - val_p_acc: 0.4750
# Epoch 2/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 2.5998 - c_acc: 0.3289 - p_loss: 1.6601 - p_acc: 0.4359 - val_p_loss: 1.7307 - val_p_acc: 0.4234
# Epoch 3/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 1.9197 - c_acc: 0.4855 - p_loss: 1.5039 - p_acc: 0.4000 - val_p_loss: 1.4744 - val_p_acc: 0.4047
# Epoch 4/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 1.4978 - c_acc: 0.5844 - p_loss: 1.4937 - p_acc: 0.3766 - val_p_loss: 1.5344 - val_p_acc: 0.4500
# Epoch 5/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 1.1601 - c_acc: 0.6938 - p_loss: 1.3789 - p_acc: 0.4172 - val_p_loss: 1.3637 - val_p_acc: 0.4781
# Epoch 6/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.9951 - c_acc: 0.7465 - p_loss: 1.0318 - p_acc: 0.5141 - val_p_loss: 0.9872 - val_p_acc: 0.5516
# Epoch 7/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.7744 - c_acc: 0.8145 - p_loss: 0.9429 - p_acc: 0.6000 - val_p_loss: 0.9920 - val_p_acc: 0.5641
# Epoch 8/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.7205 - c_acc: 0.8293 - p_loss: 0.9120 - p_acc: 0.5875 - val_p_loss: 0.9322 - val_p_acc: 0.5922
# Epoch 9/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.5924 - c_acc: 0.8621 - p_loss: 0.7786 - p_acc: 0.6516 - val_p_loss: 0.6912 - val_p_acc: 0.7078
# Epoch 10/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.5166 - c_acc: 0.8898 - p_loss: 0.7295 - p_acc: 0.6781 - val_p_loss: 0.7803 - val_p_acc: 0.6562
# Epoch 11/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.4718 - c_acc: 0.8945 - p_loss: 0.7750 - p_acc: 0.6797 - val_p_loss: 0.7558 - val_p_acc: 0.6828
# Epoch 12/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.4331 - c_acc: 0.9254 - p_loss: 0.6762 - p_acc: 0.7234 - val_p_loss: 0.6162 - val_p_acc: 0.7250
# Epoch 13/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.3872 - c_acc: 0.9379 - p_loss: 0.6752 - p_acc: 0.7219 - val_p_loss: 0.6722 - val_p_acc: 0.7109
# Epoch 14/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.3477 - c_acc: 0.9340 - p_loss: 0.6666 - p_acc: 0.7422 - val_p_loss: 0.6535 - val_p_acc: 0.7437
# Epoch 15/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.2994 - c_acc: 0.9496 - p_loss: 0.6187 - p_acc: 0.7719 - val_p_loss: 0.5994 - val_p_acc: 0.7750
# Epoch 16/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.3099 - c_acc: 0.9465 - p_loss: 0.6202 - p_acc: 0.7672 - val_p_loss: 0.5658 - val_p_acc: 0.7875
# Epoch 17/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.2732 - c_acc: 0.9566 - p_loss: 0.6123 - p_acc: 0.7594 - val_p_loss: 0.6014 - val_p_acc: 0.7578
# Epoch 18/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.2478 - c_acc: 0.9582 - p_loss: 0.5848 - p_acc: 0.7797 - val_p_loss: 0.5780 - val_p_acc: 0.7781
# Epoch 19/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.2108 - c_acc: 0.9711 - p_loss: 0.5872 - p_acc: 0.7875 - val_p_loss: 0.5762 - val_p_acc: 0.7656
# Epoch 20/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1928 - c_acc: 0.9793 - p_loss: 0.5728 - p_acc: 0.7953 - val_p_loss: 0.5451 - val_p_acc: 0.7922
# Epoch 21/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1829 - c_acc: 0.9766 - p_loss: 0.5244 - p_acc: 0.8047 - val_p_loss: 0.4809 - val_p_acc: 0.8219
# Epoch 22/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1686 - c_acc: 0.9785 - p_loss: 0.4841 - p_acc: 0.8219 - val_p_loss: 0.4474 - val_p_acc: 0.8578
# Epoch 23/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1484 - c_acc: 0.9836 - p_loss: 0.4630 - p_acc: 0.8500 - val_p_loss: 0.4476 - val_p_acc: 0.8500
# Epoch 24/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1390 - c_acc: 0.9855 - p_loss: 0.4477 - p_acc: 0.8484 - val_p_loss: 0.4336 - val_p_acc: 0.8516
# Epoch 25/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1331 - c_acc: 0.9855 - p_loss: 0.4478 - p_acc: 0.8406 - val_p_loss: 0.4296 - val_p_acc: 0.8562
# Epoch 26/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1229 - c_acc: 0.9895 - p_loss: 0.4198 - p_acc: 0.8625 - val_p_loss: 0.3761 - val_p_acc: 0.8969
# Epoch 27/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1302 - c_acc: 0.9852 - p_loss: 0.3974 - p_acc: 0.8750 - val_p_loss: 0.3536 - val_p_acc: 0.8922
# Epoch 28/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1297 - c_acc: 0.9844 - p_loss: 0.4009 - p_acc: 0.8547 - val_p_loss: 0.3607 - val_p_acc: 0.8781
# Epoch 29/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1192 - c_acc: 0.9883 - p_loss: 0.3738 - p_acc: 0.8656 - val_p_loss: 0.3333 - val_p_acc: 0.8891
# Epoch 30/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1206 - c_acc: 0.9840 - p_loss: 0.3840 - p_acc: 0.8625 - val_p_loss: 0.3525 - val_p_acc: 0.8828
# Epoch 31/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1032 - c_acc: 0.9887 - p_loss: 0.3936 - p_acc: 0.8703 - val_p_loss: 0.3717 - val_p_acc: 0.8953
# Epoch 32/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1063 - c_acc: 0.9879 - p_loss: 0.3835 - p_acc: 0.8703 - val_p_loss: 0.3420 - val_p_acc: 0.8844
# Epoch 33/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1021 - c_acc: 0.9883 - p_loss: 0.3531 - p_acc: 0.8687 - val_p_loss: 0.3087 - val_p_acc: 0.9016
# Epoch 34/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0949 - c_acc: 0.9902 - p_loss: 0.3733 - p_acc: 0.8625 - val_p_loss: 0.3266 - val_p_acc: 0.9031
# Epoch 35/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1093 - c_acc: 0.9867 - p_loss: 0.3594 - p_acc: 0.8813 - val_p_loss: 0.3158 - val_p_acc: 0.8984
# Epoch 36/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1011 - c_acc: 0.9930 - p_loss: 0.3526 - p_acc: 0.8906 - val_p_loss: 0.3370 - val_p_acc: 0.8938
# Epoch 37/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.1012 - c_acc: 0.9914 - p_loss: 0.3662 - p_acc: 0.8750 - val_p_loss: 0.3723 - val_p_acc: 0.8797
# Epoch 38/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0960 - c_acc: 0.9895 - p_loss: 0.3967 - p_acc: 0.8656 - val_p_loss: 0.3854 - val_p_acc: 0.8813
# Epoch 39/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0977 - c_acc: 0.9902 - p_loss: 0.3685 - p_acc: 0.8578 - val_p_loss: 0.3377 - val_p_acc: 0.8859
# Epoch 40/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0947 - c_acc: 0.9934 - p_loss: 0.3181 - p_acc: 0.8859 - val_p_loss: 0.2796 - val_p_acc: 0.9141
# Epoch 41/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0896 - c_acc: 0.9914 - p_loss: 0.3190 - p_acc: 0.8969 - val_p_loss: 0.2831 - val_p_acc: 0.9109
# Epoch 42/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0800 - c_acc: 0.9922 - p_loss: 0.3062 - p_acc: 0.9000 - val_p_loss: 0.2562 - val_p_acc: 0.9125
# Epoch 43/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0773 - c_acc: 0.9945 - p_loss: 0.3145 - p_acc: 0.8922 - val_p_loss: 0.2648 - val_p_acc: 0.9016
# Epoch 44/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0731 - c_acc: 0.9941 - p_loss: 0.3034 - p_acc: 0.9000 - val_p_loss: 0.2733 - val_p_acc: 0.9047
# Epoch 45/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0718 - c_acc: 0.9949 - p_loss: 0.2979 - p_acc: 0.9031 - val_p_loss: 0.2710 - val_p_acc: 0.9078
# Epoch 46/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0748 - c_acc: 0.9926 - p_loss: 0.2940 - p_acc: 0.9000 - val_p_loss: 0.2631 - val_p_acc: 0.9250
# Epoch 47/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0720 - c_acc: 0.9937 - p_loss: 0.2980 - p_acc: 0.8953 - val_p_loss: 0.2770 - val_p_acc: 0.9203
# Epoch 48/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0631 - c_acc: 0.9961 - p_loss: 0.3178 - p_acc: 0.8938 - val_p_loss: 0.2921 - val_p_acc: 0.9031
# Epoch 49/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0585 - c_acc: 0.9961 - p_loss: 0.3185 - p_acc: 0.8922 - val_p_loss: 0.2796 - val_p_acc: 0.9172
# Epoch 50/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0580 - c_acc: 0.9949 - p_loss: 0.3029 - p_acc: 0.8984 - val_p_loss: 0.2484 - val_p_acc: 0.9266
# Epoch 51/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0574 - c_acc: 0.9953 - p_loss: 0.2870 - p_acc: 0.9094 - val_p_loss: 0.2343 - val_p_acc: 0.9297
# Epoch 52/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0688 - c_acc: 0.9930 - p_loss: 0.2801 - p_acc: 0.9047 - val_p_loss: 0.2435 - val_p_acc: 0.9344
# Epoch 53/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0707 - c_acc: 0.9941 - p_loss: 0.2799 - p_acc: 0.9062 - val_p_loss: 0.2595 - val_p_acc: 0.9172
# Epoch 54/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0594 - c_acc: 0.9953 - p_loss: 0.2753 - p_acc: 0.9016 - val_p_loss: 0.2463 - val_p_acc: 0.9219
# Epoch 55/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0540 - c_acc: 0.9973 - p_loss: 0.2683 - p_acc: 0.9172 - val_p_loss: 0.2362 - val_p_acc: 0.9266
# Epoch 56/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0696 - c_acc: 0.9914 - p_loss: 0.2612 - p_acc: 0.9094 - val_p_loss: 0.2380 - val_p_acc: 0.9187
# Epoch 57/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0649 - c_acc: 0.9953 - p_loss: 0.2651 - p_acc: 0.9141 - val_p_loss: 0.2392 - val_p_acc: 0.9266
# Epoch 58/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0609 - c_acc: 0.9934 - p_loss: 0.2517 - p_acc: 0.9109 - val_p_loss: 0.2390 - val_p_acc: 0.9250
# Epoch 59/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0535 - c_acc: 0.9969 - p_loss: 0.2630 - p_acc: 0.9141 - val_p_loss: 0.2268 - val_p_acc: 0.9297
# Epoch 60/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0630 - c_acc: 0.9945 - p_loss: 0.2541 - p_acc: 0.9250 - val_p_loss: 0.2559 - val_p_acc: 0.9375
# Epoch 61/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0610 - c_acc: 0.9953 - p_loss: 0.2693 - p_acc: 0.9219 - val_p_loss: 0.2586 - val_p_acc: 0.9438
# Epoch 62/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0554 - c_acc: 0.9949 - p_loss: 0.2673 - p_acc: 0.9219 - val_p_loss: 0.2180 - val_p_acc: 0.9406
# Epoch 63/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0502 - c_acc: 0.9961 - p_loss: 0.2478 - p_acc: 0.9266 - val_p_loss: 0.2175 - val_p_acc: 0.9391
# Epoch 64/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0499 - c_acc: 0.9965 - p_loss: 0.2544 - p_acc: 0.9219 - val_p_loss: 0.2244 - val_p_acc: 0.9359
# Epoch 65/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0588 - c_acc: 0.9930 - p_loss: 0.2569 - p_acc: 0.9141 - val_p_loss: 0.2165 - val_p_acc: 0.9297
# Epoch 66/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0514 - c_acc: 0.9957 - p_loss: 0.2475 - p_acc: 0.9203 - val_p_loss: 0.2064 - val_p_acc: 0.9422
# Epoch 67/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0542 - c_acc: 0.9934 - p_loss: 0.2498 - p_acc: 0.9234 - val_p_loss: 0.2105 - val_p_acc: 0.9391
# Epoch 68/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0552 - c_acc: 0.9957 - p_loss: 0.2549 - p_acc: 0.9219 - val_p_loss: 0.2572 - val_p_acc: 0.9359
# Epoch 69/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0489 - c_acc: 0.9973 - p_loss: 0.2471 - p_acc: 0.9297 - val_p_loss: 0.2545 - val_p_acc: 0.9281
# Epoch 70/100
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0438 - c_acc: 0.9988 - p_loss: 0.2425 - p_acc: 0.9266 - val_p_loss: 0.2335 - val_p_acc: 0.9344
# Epoch 71/100
# 10/10 [==============================] - ETA: 0s - c_loss: 0.0448 - c_acc: 0.9965 - p_loss: 0.2346 - p_acc: 0.9281Restoring model weights from the end of the best epoch: 61.
# 10/10 [==============================] - 10s 1s/step - c_loss: 0.0448 - c_acc: 0.9965 - p_loss: 0.2346 - p_acc: 0.9281 - val_p_loss: 0.2354 - val_p_acc: 0.9328
# Epoch 00071: early stopping
# Maximal validation accuracy: 94.38%

# %%
pretraining_model_df = pd.DataFrame(pretraining_history.history)
pretraining_model_df.to_csv( path_model_result + 'pretraining_model_df.csv' )
pretraining_model_df
# Out:
#       c_loss     c_acc    p_loss     p_acc  val_p_loss  val_p_acc
# 0   3.933913  0.142969  1.126133  0.460938    1.435421   0.475000
# 1   2.599754  0.328906  1.660129  0.435937    1.730704   0.423438
# 2   1.919738  0.485547  1.503852  0.400000    1.474441   0.404687
# 3   1.497797  0.584375  1.493672  0.376563    1.534446   0.450000
# 4   1.160149  0.693750  1.378863  0.417188    1.363665   0.478125
# ..       ...       ...       ...       ...         ...        ...
# 66  0.054207  0.993359  0.249790  0.923437    0.210464   0.939062
# 67  0.055188  0.995703  0.254943  0.921875    0.257186   0.935938
# 68  0.048875  0.997266  0.247076  0.929688    0.254466   0.928125
# 69  0.043758  0.998828  0.242499  0.926562    0.233455   0.934375
# 70  0.044822  0.996484  0.234571  0.928125    0.235424   0.932813
#
# [71 rows x 6 columns]

# %% [markdown]
# ## 3-5. Finetuning_model - augmenter image

# %%
ES = EarlyStopping(monitor='val_p_acc', verbose=1, patience=patience_num, restore_best_weights=True)

finetuning_model = keras.Sequential(
    [
        layers.Input(shape=(image_size, image_size, image_channels)),
        get_augmenter(**classification_augmentation),
        pretraining_model.encoder,
        layers.Dense(class_num),
    ],
    name="finetuning_model",
)
finetuning_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)

finetuning_history = finetuning_model.fit(
    labeled_train_dataset, epochs=num_epochs, validation_data=test_dataset, callbacks=[ES]
)
print(
    "Maximal validation accuracy: {:.2f}%".format(
        max(finetuning_history.history["val_acc"]) * 100
    )
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - ETA: 0s - loss: 0.3070 - acc: 0.8932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 13s 286ms/step - loss: 0.3070 - acc: 0.8932 - val_loss: 1.5245 - val_acc: 0.8828
# Epoch 2/100
# 30/30 [==============================] - ETA: 0s - loss: 0.1234 - acc: 0.9594WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.1234 - acc: 0.9594 - val_loss: 1.5077 - val_acc: 0.8719
# Epoch 3/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0965 - acc: 0.9708WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0965 - acc: 0.9708 - val_loss: 0.5660 - val_acc: 0.9141
# Epoch 4/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0540 - acc: 0.9797WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0540 - acc: 0.9797 - val_loss: 1.0614 - val_acc: 0.8500
# Epoch 5/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0753 - acc: 0.9766WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0753 - acc: 0.9766 - val_loss: 6.3714 - val_acc: 0.6297
# Epoch 6/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0462 - acc: 0.9823WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0462 - acc: 0.9823 - val_loss: 0.5869 - val_acc: 0.8938
# Epoch 7/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0261 - acc: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0261 - acc: 0.9906 - val_loss: 0.1481 - val_acc: 0.9609
# Epoch 8/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0493 - acc: 0.9859WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0493 - acc: 0.9859 - val_loss: 0.1032 - val_acc: 0.9656
# Epoch 9/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0438 - acc: 0.9885WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0438 - acc: 0.9885 - val_loss: 0.3632 - val_acc: 0.9312
# Epoch 10/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0508 - acc: 0.9812WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0508 - acc: 0.9812 - val_loss: 0.4629 - val_acc: 0.9187
# Epoch 11/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0466 - acc: 0.9812WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0466 - acc: 0.9812 - val_loss: 0.2730 - val_acc: 0.9516
# Epoch 12/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0303 - acc: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0303 - acc: 0.9896 - val_loss: 0.2513 - val_acc: 0.9453
# Epoch 13/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0459 - acc: 0.9891WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0459 - acc: 0.9891 - val_loss: 0.1377 - val_acc: 0.9750
# Epoch 14/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0368 - acc: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0368 - acc: 0.9875 - val_loss: 0.9166 - val_acc: 0.8984
# Epoch 15/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0261 - acc: 0.9891WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0261 - acc: 0.9891 - val_loss: 2.2352 - val_acc: 0.7656
# Epoch 16/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0376 - acc: 0.9896WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0376 - acc: 0.9896 - val_loss: 0.2707 - val_acc: 0.9453
# Epoch 17/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0511 - acc: 0.9875WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0511 - acc: 0.9875 - val_loss: 0.2491 - val_acc: 0.9000
# Epoch 18/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0138 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0138 - acc: 0.9958 - val_loss: 0.1531 - val_acc: 0.9578
# Epoch 19/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0351 - acc: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0351 - acc: 0.9906 - val_loss: 0.5834 - val_acc: 0.9250
# Epoch 20/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0484 - acc: 0.9859WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0484 - acc: 0.9859 - val_loss: 2.3025 - val_acc: 0.8219
# Epoch 21/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0524 - acc: 0.9859WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0524 - acc: 0.9859 - val_loss: 0.4825 - val_acc: 0.9062
# Epoch 22/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0195 - acc: 0.9943WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0195 - acc: 0.9943 - val_loss: 1.4801 - val_acc: 0.8562
# Epoch 23/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0190 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0190 - acc: 0.9932 - val_loss: 0.1178 - val_acc: 0.9734
# Epoch 24/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0291 - acc: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0291 - acc: 0.9906 - val_loss: 0.4837 - val_acc: 0.9266
# Epoch 25/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0339 - acc: 0.9911WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0339 - acc: 0.9911 - val_loss: 0.3550 - val_acc: 0.9047
# Epoch 26/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0131 - acc: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0131 - acc: 0.9969 - val_loss: 0.3557 - val_acc: 0.9109
# Epoch 27/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0086 - acc: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0086 - acc: 0.9974 - val_loss: 0.1385 - val_acc: 0.9531
# Epoch 28/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0187 - acc: 0.9943WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0187 - acc: 0.9943 - val_loss: 0.2707 - val_acc: 0.9547
# Epoch 29/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0113 - acc: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0113 - acc: 0.9969 - val_loss: 0.1273 - val_acc: 0.9609
# Epoch 30/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0176 - acc: 0.9948WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0176 - acc: 0.9948 - val_loss: 0.0403 - val_acc: 0.9844
# Epoch 31/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0042 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0042 - acc: 0.9990 - val_loss: 0.0525 - val_acc: 0.9797
# Epoch 32/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0032 - acc: 0.9990 - val_loss: 0.2088 - val_acc: 0.9531
# Epoch 33/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0088 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0088 - acc: 0.9979 - val_loss: 0.0863 - val_acc: 0.9750
# Epoch 34/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0065 - acc: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0065 - acc: 0.9974 - val_loss: 0.1388 - val_acc: 0.9656
# Epoch 35/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0128 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0128 - acc: 0.9953 - val_loss: 0.1271 - val_acc: 0.9688
# Epoch 36/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0092 - acc: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0092 - acc: 0.9974 - val_loss: 0.2188 - val_acc: 0.9625
# Epoch 37/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0200 - acc: 0.9927WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0200 - acc: 0.9927 - val_loss: 0.2522 - val_acc: 0.9344
# Epoch 38/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0117 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0117 - acc: 0.9953 - val_loss: 0.6343 - val_acc: 0.8891
# Epoch 39/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0051 - acc: 0.9984 - val_loss: 0.2240 - val_acc: 0.9453
# Epoch 40/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0025 - acc: 0.9990 - val_loss: 0.1893 - val_acc: 0.9734
# Epoch 41/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0021 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0021 - acc: 0.9990 - val_loss: 0.2925 - val_acc: 0.9563
# Epoch 42/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0045 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0045 - acc: 0.9984 - val_loss: 0.1972 - val_acc: 0.9641
# Epoch 43/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0090 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0090 - acc: 0.9979 - val_loss: 0.0799 - val_acc: 0.9797
# Epoch 44/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0069 - acc: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0069 - acc: 0.9969 - val_loss: 0.1270 - val_acc: 0.9766
# Epoch 45/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0020 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 0.1222 - val_acc: 0.9734
# Epoch 46/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0091 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0091 - acc: 0.9953 - val_loss: 0.4273 - val_acc: 0.9406
# Epoch 47/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0143 - acc: 0.9948WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0143 - acc: 0.9948 - val_loss: 5.5198 - val_acc: 0.6578
# Epoch 48/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0551 - acc: 0.9854WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0551 - acc: 0.9854 - val_loss: 0.3552 - val_acc: 0.9469
# Epoch 49/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0345 - acc: 0.9891WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0345 - acc: 0.9891 - val_loss: 0.2288 - val_acc: 0.9453
# Epoch 50/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0300 - acc: 0.9927WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0300 - acc: 0.9927 - val_loss: 0.5687 - val_acc: 0.9281
# Epoch 51/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0314 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0314 - acc: 0.9917 - val_loss: 0.8432 - val_acc: 0.8359
# Epoch 52/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0169 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0169 - acc: 0.9932 - val_loss: 0.1895 - val_acc: 0.9734
# Epoch 53/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0210 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0210 - acc: 0.9958 - val_loss: 0.3455 - val_acc: 0.9312
# Epoch 54/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0140 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0140 - acc: 0.9953 - val_loss: 0.3651 - val_acc: 0.9391
# Epoch 55/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0152 - acc: 0.9953WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0152 - acc: 0.9953 - val_loss: 0.3054 - val_acc: 0.9500
# Epoch 56/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0071 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0071 - acc: 0.9984 - val_loss: 0.1449 - val_acc: 0.9719
# Epoch 57/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0225 - acc: 0.9943WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0225 - acc: 0.9943 - val_loss: 0.2107 - val_acc: 0.9641
# Epoch 58/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0181 - acc: 0.9943WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0181 - acc: 0.9943 - val_loss: 0.1109 - val_acc: 0.9812
# Epoch 59/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0342 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0342 - acc: 0.9917 - val_loss: 0.2231 - val_acc: 0.9750
# Epoch 60/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0159 - acc: 0.9964WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0159 - acc: 0.9964 - val_loss: 0.2347 - val_acc: 0.9422
# Epoch 61/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0281 - acc: 0.9917WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0281 - acc: 0.9917 - val_loss: 0.2780 - val_acc: 0.9484
# Epoch 62/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0141 - acc: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0141 - acc: 0.9969 - val_loss: 0.1741 - val_acc: 0.9625
# Epoch 63/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0061 - acc: 0.9974 - val_loss: 0.1137 - val_acc: 0.9828
# Epoch 64/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0028 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0028 - acc: 0.9995 - val_loss: 0.1215 - val_acc: 0.9703
# Epoch 65/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0083 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0083 - acc: 0.9984 - val_loss: 0.3386 - val_acc: 0.9391
# Epoch 66/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0076 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0076 - acc: 0.9984 - val_loss: 0.3612 - val_acc: 0.9500
# Epoch 67/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0012 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 0.2254 - val_acc: 0.9594
# Epoch 68/100
# 30/30 [==============================] - ETA: 0s - loss: 6.6038e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 6.6038e-04 - acc: 1.0000 - val_loss: 0.1372 - val_acc: 0.9703
# Epoch 69/100
# 30/30 [==============================] - ETA: 0s - loss: 2.9861e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 2.9861e-04 - acc: 1.0000 - val_loss: 0.1132 - val_acc: 0.9719
# Epoch 70/100
# 30/30 [==============================] - ETA: 0s - loss: 2.5740e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 2.5740e-04 - acc: 1.0000 - val_loss: 0.0987 - val_acc: 0.9766
# Epoch 71/100
# 30/30 [==============================] - ETA: 0s - loss: 7.6386e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 7.6386e-05 - acc: 1.0000 - val_loss: 0.0941 - val_acc: 0.9750
# Epoch 72/100
# 30/30 [==============================] - ETA: 0s - loss: 1.1844e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 1.1844e-04 - acc: 1.0000 - val_loss: 0.0888 - val_acc: 0.9828
# Epoch 73/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0032 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0032 - acc: 0.9995 - val_loss: 0.0877 - val_acc: 0.9781
# Epoch 74/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0036 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0036 - acc: 0.9979 - val_loss: 0.0926 - val_acc: 0.9797
# Epoch 75/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0023 - acc: 0.9995 - val_loss: 0.0672 - val_acc: 0.9859
# Epoch 76/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0019 - acc: 0.9990 - val_loss: 0.0938 - val_acc: 0.9812
# Epoch 77/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0049 - acc: 0.9984WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0049 - acc: 0.9984 - val_loss: 0.1040 - val_acc: 0.9812
# Epoch 78/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0046 - acc: 0.9990 - val_loss: 0.0872 - val_acc: 0.9844
# Epoch 79/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0023 - acc: 0.9990 - val_loss: 0.1268 - val_acc: 0.9781
# Epoch 80/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0099 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0099 - acc: 0.9979 - val_loss: 0.1870 - val_acc: 0.9531
# Epoch 81/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0053 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0053 - acc: 0.9979 - val_loss: 0.1436 - val_acc: 0.9750
# Epoch 82/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0086 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0086 - acc: 0.9979 - val_loss: 0.4455 - val_acc: 0.9312
# Epoch 83/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0093 - acc: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0093 - acc: 0.9974 - val_loss: 0.0858 - val_acc: 0.9797
# Epoch 84/100
# 30/30 [==============================] - ETA: 0s - loss: 9.7725e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 9.7725e-04 - acc: 1.0000 - val_loss: 0.0796 - val_acc: 0.9797
# Epoch 85/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0262 - acc: 0.9932WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0262 - acc: 0.9932 - val_loss: 0.3289 - val_acc: 0.9156
# Epoch 86/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0117 - acc: 0.9964WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0117 - acc: 0.9964 - val_loss: 0.1739 - val_acc: 0.9609
# Epoch 87/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0065 - acc: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 266ms/step - loss: 0.0065 - acc: 0.9979 - val_loss: 0.1104 - val_acc: 0.9719
# Epoch 88/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0035 - acc: 0.9990 - val_loss: 0.1448 - val_acc: 0.9609
# Epoch 89/100
# 30/30 [==============================] - ETA: 0s - loss: 8.5869e-04 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 8.5869e-04 - acc: 1.0000 - val_loss: 0.2009 - val_acc: 0.9547
# Epoch 90/100
# 30/30 [==============================] - ETA: 0s - loss: 8.0022e-04 - acc: 0.9995WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 8.0022e-04 - acc: 0.9995 - val_loss: 0.1114 - val_acc: 0.9703
# Epoch 91/100
# 30/30 [==============================] - ETA: 0s - loss: 7.2043e-05 - acc: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 7.2043e-05 - acc: 1.0000 - val_loss: 0.0857 - val_acc: 0.9703
# Epoch 92/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0033 - acc: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0033 - acc: 0.9990 - val_loss: 0.1657 - val_acc: 0.9719
# Epoch 93/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0345 - acc: 0.9906WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0345 - acc: 0.9906 - val_loss: 0.5564 - val_acc: 0.9109
# Epoch 94/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0343 - acc: 0.9891WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0343 - acc: 0.9891 - val_loss: 1.4707 - val_acc: 0.8984
# Epoch 95/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0244 - acc: 0.9927WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0244 - acc: 0.9927 - val_loss: 0.7644 - val_acc: 0.8938
# Epoch 96/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0187 - acc: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0187 - acc: 0.9937 - val_loss: 1.2079 - val_acc: 0.9094
# Epoch 97/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0296 - acc: 0.9922WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0296 - acc: 0.9922 - val_loss: 3.1552 - val_acc: 0.8031
# Epoch 98/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0164 - acc: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0164 - acc: 0.9958 - val_loss: 0.4973 - val_acc: 0.9391
# Epoch 99/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0307 - acc: 0.9885WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 264ms/step - loss: 0.0307 - acc: 0.9885 - val_loss: 0.2733 - val_acc: 0.9453
# Epoch 100/100
# 30/30 [==============================] - ETA: 0s - loss: 0.0208 - acc: 0.9943WARNING:tensorflow:Early stopping conditioned on metric `val_p_acc` which is not available. Available metrics are: loss,acc,val_loss,val_acc
# 30/30 [==============================] - 8s 265ms/step - loss: 0.0208 - acc: 0.9943 - val_loss: 0.6818 - val_acc: 0.9062
# Maximal validation accuracy: 98.59%

# %%
finetuning_model_df = pd.DataFrame(finetuning_history.history)
finetuning_model_df.to_csv( path_model_result + 'finetuning_model_df.csv' )
finetuning_model_df
# Out:
#         loss       acc  val_loss   val_acc
# 0   0.307013  0.893229  1.524521  0.882812
# 1   0.123377  0.959375  1.507694  0.871875
# 2   0.096524  0.970833  0.565977  0.914062
# 3   0.054019  0.979688  1.061362  0.850000
# 4   0.075306  0.976562  6.371402  0.629687
# ..       ...       ...       ...       ...
# 95  0.018726  0.993750  1.207871  0.909375
# 96  0.029579  0.992188  3.155249  0.803125
# 97  0.016445  0.995833  0.497270  0.939062
# 98  0.030726  0.988542  0.273262  0.945312
# 99  0.020760  0.994271  0.681782  0.906250
#
# [100 rows x 4 columns]

# %% [markdown]
# ## 4. Result Report

# %%
# The classification accuracies of the baseline and the pretraining + finetuning process:
def plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history):
    for metric_key, metric_name in zip(["acc", "loss"], ["accuracy", "loss"]):
        plt.figure(figsize=(8, 5), dpi=100)
        plt.plot(
            baseline_model_original_image_history.history[f"val_{metric_key}"], label="original_image baseline"
        )
        plt.plot(
            baseline_model_augmenter_image_history.history[f"val_{metric_key}"], label="supervised baseline"
        )
        plt.plot(
            pretraining_history.history[f"val_p_{metric_key}"],
            label="self-supervised pretraining",
        )
        plt.plot(
            finetuning_history.history[f"val_{metric_key}"],
            label="supervised finetuning",
        )
        plt.legend()
        plt.title(f"Classification {metric_name} during training")
        plt.xlabel("epochs")
        plt.ylabel(f"validation {metric_name}")

plot_training_curves(pretraining_history, finetuning_history, baseline_model_augmenter_image_history, baseline_model_original_image_history)

# %%
print (max(baseline_model_original_image_history.history["val_acc"]) * 100)
print (max(baseline_model_augmenter_image_history.history["val_acc"]) * 100)
print (max(pretraining_history.history["val_p_acc"]) * 100)
print (max(finetuning_history.history["val_acc"]) * 100)
# Out:
# 98.1249988079071
# 95.46874761581421
# 94.37500238418579
# 98.59374761581421

# %% [markdown]
# ## 5. Model Save

# %%
save_model = keras.Sequential(
    [
        pretraining_model.encoder,
    ],
    name="pretraining_model",
)

save_model.summary()
# Out:
# Model: "pretraining_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 128)               21123752
#
# =================================================================
# Total params: 21,123,752
# Trainable params: 21,069,224
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.h5' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
save_model.save( path_model_result + 'pretraining_model_encoder.ckpt' )
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: gdrive/My Drive/Research_3_1_1/model_result/3 - SimCLR_model_result - 1/pretraining_model_encoder.ckpt/assets
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
